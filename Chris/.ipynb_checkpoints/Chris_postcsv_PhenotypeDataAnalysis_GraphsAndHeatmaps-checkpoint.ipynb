# %% [markdown]
# # To use this notebook, have data of the following form in a CSV file
# ![data format example](Ben_CSV_example.jpg)

# %% [markdown]
# # Contents
#
# #### 1. Prepare for analysis (import packages and set working directory)
# #### 2. Read in, tidy, and explore the data
# #### 3. Generate speed trace
# #### 4. Generate OffFood/OnFood comparison bar plots (including BSR)
# #### 5. Generate phenotype heatmap

# %% [markdown]
# # 1 - Prepare for analysis

# %% [markdown]
# ## 1.1 - Import required packages

# %%
import os  # <- package used to work with system filepaths
import pandas as pd  # <- package used to import and organize data
import numpy as np  # <- package used to import and organize data
import math
import seaborn as sns  # <- package used to plot graphs
from matplotlib import pyplot as plt  # <- another package used to plot graphs
from itertools import cycle  # <- package used to iterate down rows
from ipywidgets import widgets  # <- widget tool to generate button
from IPython.display import display  # <- displays button
from tkinter import Tk, filedialog  # <- Tkinter is a GUI package
from tqdm.notebook import tqdm
import pingouin as pg
from pingouin import ttest
from scipy.stats import ttest_ind
import sklearn
pd.set_option('display.max_columns', 50)
print("done step 1")
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.3, the latest is 0.5.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# done step 1

# %% [markdown]
# ## 1.2 - Set working directory to where the CSV file with experiment data is

# %%
os.getcwd()
os.chdir('C:\\Users\\chris\\Desktop\\Rankin_Lab\\valid_data')

# %% [markdown]
# # 2 - Read in, tidy, and explore the data

# %% [markdown]
# ## 2.1 - Read in the data, check its size and format

# %%
df1 = pd.read_csv('BSR_baseline_output_folder_1.csv')
df2 = pd.read_csv('BSR_baseline_output_folder_2.csv')
df3 = pd.read_csv('BSR_baseline_output_folder_3.csv')
df4 = pd.read_csv('BSR_baseline_output_folder_4.csv')
df5 = pd.read_csv('BSR_baseline_output_folder_5.csv')
df6 = pd.read_csv('BSR_baseline_output_folder_6.csv')
df7 = pd.read_csv('BSR_baseline_output_folder_7.csv')
df8 = pd.read_csv('BSR_baseline_output_folder_8.csv')
df9 = pd.read_csv('BSR_baseline_output_folder_9.csv')
df10 = pd.read_csv('BSR_baseline_output_folder_10.csv')
df11 = pd.read_csv('BSR_baseline_output_folder_11.csv')
df12 = pd.read_csv('BSR_baseline_output_folder_12.csv')
df13 = pd.read_csv('BSR_baseline_output_folder_13.csv')
df14 = pd.read_csv('BSR_baseline_output_folder_14.csv')
df15 = pd.read_csv('BSR_baseline_output_folder_15.csv')
df16 = pd.read_csv('BSR_baseline_output_folder_16.csv')
df17 = pd.read_csv('BSR_baseline_output_folder_17.csv')
df18 = pd.read_csv('BSR_baseline_output_folder_18.csv')
df19 = pd.read_csv('BSR_baseline_output_folder_19.csv')
df20 = pd.read_csv('BSR_baseline_output_folder_20.csv')
df21 = pd.read_csv('BSR_baseline_output_folder_21.csv')
df22 = pd.read_csv('BSR_baseline_output_folder_22.csv')
df23 = pd.read_csv('BSR_baseline_output_folder_23.csv')
df24 = pd.read_csv('BSR_baseline_output_folder_24.csv')
df25 = pd.read_csv('BSR_baseline_output_folder_25.csv')
df26 = pd.read_csv('BSR_baseline_output_folder_26.csv')
df27 = pd.read_csv('BSR_baseline_output_folder_27.csv')


# List of DataFrames to append
dfs_to_append = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11,
    df12, df13, df14, df15, df16, df17, df18, df19, df20,
    df21, df22, df23, df24, df25, df26, df27]

# Concatenate the DataFrames
TotalConcatenated = pd.concat(dfs_to_append, ignore_index=True)

# TotalConcatenated = pd.read_csv('baseline_output.csv')

print(TotalConcatenated.shape)
print(TotalConcatenated.head())
print(TotalConcatenated.tail())
# Out:
# (1839012, 22)
#    Unnamed: 0  time_bin  worm  plate_id      date        time     speed  \
# 0       27767     300.0     2    110251  20230421  299.499909  0.197877
# 1       27768     300.0    10    110251  20230421  299.488261  0.373387
# 2       27769     300.0    12    110251  20230421  299.505667  0.256321
# 3       27770     300.0    13    110251  20230421  299.505667  0.198883
# 4       27771     300.0    16    110251  20230421  299.505667  0.088025
#
#            x          y  angularspeed  pathlength       kink   bias  \
# 0  10.546518  19.907895    101.981818    2.221182  89.931818 -1.000
# 1  34.798839  39.313109     49.413043   18.721391  47.695652  1.000
# 2  11.079850  27.872992      6.195833   18.512125  45.525000  1.000
# 3  27.390542  54.795271      8.779167    6.854792  38.533333 -1.000
# 4   9.111817  42.155808      7.375000   -8.181792  99.312500 -0.875
#
#        curve       dir      crab    length   midline     width  morphwidth  \
# 0  61.336364  0.000273  0.106305  0.592895  1.085877  0.448077    0.159305
# 1  41.791304  0.000087  0.059300  0.715617  1.039226  0.366848    0.128874
# 2  31.650000  0.000417  0.019787  0.898087  1.165200  0.204300    0.128146
# 3  35.341667  0.000000  0.033200  0.972900  1.186692  0.303862    0.099525
# 4  47.600000  0.020333  0.011854  0.513900  0.797050  0.312975    0.176933
#
#        area                 Strain
# 0  0.128602  acr-12(ok367)_OffFood
# 1  0.111537  acr-12(ok367)_OffFood
# 2  0.132465  acr-12(ok367)_OffFood
# 3  0.107740  acr-12(ok367)_OffFood
# 4  0.114544  acr-12(ok367)_OffFood
#          Unnamed: 0  time_bin  worm  plate_id      date        time     speed  \
# 1839007       65805     400.0   986    140219  20231002  399.493929  0.167786
# 1839008       65806     400.0   988    122415  20231009  399.510778  0.139056
# 1839009       65807     400.0   996    140219  20231002  399.502867  0.194587
# 1839010       65808     400.0   997    113106  20231009  399.546875  0.009038
# 1839011       65809     400.0   998    103455  20221107  399.482000  0.217983
#
#                  x          y  angularspeed  pathlength        kink  bias  \
# 1839007  11.046979  46.370050     37.335714    3.378929  114.507143   1.0
# 1839008  26.862633  36.299789     10.122222    3.903000   65.444444   1.0
# 1839009   7.954160  31.535660     15.560000   12.227133   40.813333   1.0
# 1839010   9.082175  23.230375      1.212500    0.522000   35.200000   0.0
# 1839011  14.362475  10.029758      5.225000    8.535250   54.258333   1.0
#
#              curve       dir      crab    length   midline     width  \
# 1839007  48.071429  0.000000  0.043750  0.740379  1.119364  0.390921
# 1839008  30.044444  0.004222  0.018467  0.820200  0.980044  0.169200
# 1839009  51.360000  0.000133  0.031000  0.849600  1.084973  0.279360
# 1839010  17.975000  0.000000  0.002537  0.861638  0.931225  0.144450
# 1839011  26.258333  0.000417  0.009383  0.973800  1.063450  0.151875
#
#          morphwidth      area               Strain
# 1839007    0.138821  0.127575  cat-2(e1112)_OnFood
# 1839008    0.135278  0.126279  cat-2(e1112)_OnFood
# 1839009    0.124967  0.126992  cat-2(e1112)_OnFood
# 1839010    0.130763  0.116549  cat-2(e1112)_OnFood
# 1839011    0.107508  0.124295  cat-2(e1112)_OnFood

# %% [markdown]
# ## 2.2 - Get list of strains in the data set

# %%
TotalConcatenated_strains = TotalConcatenated.groupby(["Strain", "worm"], as_index=False).mean()
TotalConcatenated_strains[['Genotype', 'Treatment']] = TotalConcatenated_strains['Strain'].str.split('_', 1, expand = True)
TotalConcatenated_strains = TotalConcatenated_strains.dropna()
TotalConcatenated_strains = TotalConcatenated_strains.Genotype.unique()

# print(TotalConcatenated_strains.head())
# print(TotalConcatenated_strains.tail())

print(TotalConcatenated_strains)

all_strains = pd.DataFrame(TotalConcatenated_strains, columns = ['Genotype'])
print(all_strains.shape)
print(all_strains)
# Out:
# ['C29E4.10(ok2752)' 'F53B2.5(ok226)' 'N2' 'R07G3.8(tm5683)'
#  'SSSD1.1(ok1527)' 'Y18D10A.22(ok3535)' 'acr-12(ok367)' 'acr-3(ok2049)'
#  'acr-6(ok3117)' 'acr-8(ok1240)' 'bas-1(tm351)' 'cat-1(e1111)'
#  'cat-1(ok411)' 'cat-2(e1112)' 'cat-2(n4547)' 'cat-2(tm2261)'
#  'cat-4(e1141)' 'cat-4(tm773)' 'catp-6(ok3473)' 'catp-7(tm4438)'
#  'catp-7(tm8556)' 'chd-7(tm6183)' 'cpr-4(ok3413)' 'cpr-4(tm3718)'
#  'cpr-5(ok2344)' 'cpr-5(rb1810)' 'cpr-6(tm12210)' 'cpr-8(ok2956)'
#  'crls-1(tm2542)' 'crls-1(tm2575)' 'djr-1.1(tm918)' 'djr-1.2(tm1346)'
#  'djr-1.2(tm817)' 'djr-1.2(tm951)' 'dnj-25(ok422)' 'dop-1(vs101)'
#  'dop-3(ok295)' 'dop-3(tm1356)' 'exp-2(sa26ad1426)' 'exp-2(tm5668)'
#  'gba-1(tm3816)' 'gba-1(tm4173)' 'gba-2(tm4623)' 'gba-2(tm4808)'
#  'gba-3(gk3287)' 'gba-3(tm3302)' 'gba-4(tm3314)' 'gba-4(tm3349)'
#  'gck-3(tm1223)' 'gck-3(tm1296)' 'glo-1(tm15275)' 'glo-1(tm3240)'
#  'glo-1(zu391)' 'hipr-1(ok1081)' 'hipr-1(tm14191)' 'igcm-2(ok1527)'
#  'kvs-1(tm2034)' 'kvs-2(tm6231)' 'kvs-2(tm6358)' 'kvs-3(nf140)'
#  'kvs-4(tm10514)' 'kvs-4(tm14987)' 'kvs-5(tm6152)' 'let-19(gk149538)'
#  'let-19(os33)' 'lfe-2(sy326)' 'lfe-2(tm14109)' 'lrk-1(tm1898)'
#  'lrk-1(tm7568)' 'mbk-1(pk1389)' 'mbl-1(tm1207)' 'mbl-1(tm1277)'
#  'mbr-1(qa5901)' 'mbr-1(tm1235)' 'mex-3(spr10)' 'mex-3(spr5)'
#  'mex-3(spr6)' 'mex-3(spr7)' 'mex-3(spr9)' 'mex-3(zu155)'
#  'mop-25.1(ok3762)' 'ncs-4(tm4409)' 'ncs-4(tm8422)' 'ncs-7(tm4648)'
#  'ncs-7(tm5037)' 'pdr-1(gk448)' 'pdr-1(tm598)' 'pink-1(ok3538)'
#  'pink-1(tm1779)' 'rme-8(b1023)' 'rskd-1(gk1208)' 'rskd-1(tm4031)'
#  'sac-2(ok2743)' 'set-2(n4589)' 'set-2(ok1484)' 'set-2(ok952)'
#  'sipa-1(ok879)' 'sipa-1(tm11702)' 'snb-5(ok1434)' 'snb-5(tm6182)'
#  'snb-7(ok2662)' 'snb-7(tm5266)' 'tag-138(gk247)' 'unc-10(ad591)'
#  'unc-57(e406)' 'unc-57(ok310)' 'vps-35(hu68)' 'vps-35(ok1880)']
# (108, 1)
#              Genotype
# 0    C29E4.10(ok2752)
# 1      F53B2.5(ok226)
# 2                  N2
# 3     R07G3.8(tm5683)
# 4     SSSD1.1(ok1527)
# ..                ...
# 103     unc-10(ad591)
# 104      unc-57(e406)
# 105     unc-57(ok310)
# 106      vps-35(hu68)
# 107    vps-35(ok1880)
#
# [108 rows x 1 columns]
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\1179930406.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   TotalConcatenated_strains[['Genotype', 'Treatment']] = TotalConcatenated_strains['Strain'].str.split('_', 1, expand = True)

# %% [markdown]
# ## 2.3 - Determine the range for which you want to analyze data

# %%
start = 100  # <----- set the start time of the range
point = 400  # <----- set the end time of your range

TotalConcatenated_chunked0 = TotalConcatenated[TotalConcatenated["time"] >= start]
TotalConcatenated_chunked = TotalConcatenated_chunked0[TotalConcatenated_chunked0["time"] <= point]
print(TotalConcatenated_chunked.head())
# Out:
#    Unnamed: 0  time_bin  worm  plate_id      date        time     speed  \
# 0       27767     300.0     2    110251  20230421  299.499909  0.197877
# 1       27768     300.0    10    110251  20230421  299.488261  0.373387
# 2       27769     300.0    12    110251  20230421  299.505667  0.256321
# 3       27770     300.0    13    110251  20230421  299.505667  0.198883
# 4       27771     300.0    16    110251  20230421  299.505667  0.088025
#
#            x          y  angularspeed  pathlength       kink   bias  \
# 0  10.546518  19.907895    101.981818    2.221182  89.931818 -1.000
# 1  34.798839  39.313109     49.413043   18.721391  47.695652  1.000
# 2  11.079850  27.872992      6.195833   18.512125  45.525000  1.000
# 3  27.390542  54.795271      8.779167    6.854792  38.533333 -1.000
# 4   9.111817  42.155808      7.375000   -8.181792  99.312500 -0.875
#
#        curve       dir      crab    length   midline     width  morphwidth  \
# 0  61.336364  0.000273  0.106305  0.592895  1.085877  0.448077    0.159305
# 1  41.791304  0.000087  0.059300  0.715617  1.039226  0.366848    0.128874
# 2  31.650000  0.000417  0.019787  0.898087  1.165200  0.204300    0.128146
# 3  35.341667  0.000000  0.033200  0.972900  1.186692  0.303862    0.099525
# 4  47.600000  0.020333  0.011854  0.513900  0.797050  0.312975    0.176933
#
#        area                 Strain
# 0  0.128602  acr-12(ok367)_OffFood
# 1  0.111537  acr-12(ok367)_OffFood
# 2  0.132465  acr-12(ok367)_OffFood
# 3  0.107740  acr-12(ok367)_OffFood
# 4  0.114544  acr-12(ok367)_OffFood

# %% [markdown]
# ## 2.4 - Find average measures for each worm (across duration of specified range), split 'Strain' column into two
#
# Ex: 'N2_OnFood' becomes 'N2' & 'OnFood'

# %%
TotalConcatenated_mean = TotalConcatenated_chunked.groupby(["Strain", "worm"], as_index=False).mean()
TotalConcatenated_mean[['Genotype', 'Treatment']] = TotalConcatenated_mean['Strain'].str.split('_', expand = True)
TotalConcatenated_mean[['Gene','Allele']]=TotalConcatenated_mean['Genotype'].str.split('(',expand=True)
TotalConcatenated_mean['Allele']=TotalConcatenated_mean['Allele'].str[:-1]
print(TotalConcatenated_mean.groupby(['Gene'], as_index = False).mean())
# # TotalConcatenated_mean['Gene']=TotalConcatenated['Gene'].fill_na('N2')
print(TotalConcatenated_mean)
print(TotalConcatenated_mean.Gene.unique())

# SELECT ONLY NECESSARY COLUMNS
# TotalConcatenated_worm_avg_speed = TotalConcatenated_mean[['Gene','Genotype', 'Treatment', 'Strain', 'speed']]
TotalConcatenated_worm_avg_speed = TotalConcatenated_mean[['Gene','Genotype', 'Treatment', 'Strain', 'speed', 'angularspeed', 'bias', 'curve', 'crab', 'kink']]
print(TotalConcatenated_worm_avg_speed.shape)
print(TotalConcatenated_worm_avg_speed)
By_gene_avg_speed=TotalConcatenated_mean[['Gene','Treatment', 'speed']]
# Out:
#         Gene        worm    Unnamed: 0    time_bin       plate_id  \
# 0   C29E4.10   37.608696  14630.267701  348.086957  132978.826087
# 1    F53B2.5   21.037037   9659.858483  349.351852  120083.574074
# 2         N2  512.213763  72496.272687  347.153236  133272.194729
# 3    R07G3.8  305.436224  40272.864131  346.354490  114961.994898
# 4    SSSD1.1  344.972678  47069.036037  345.524590  113257.027322
# ..       ...         ...           ...         ...            ...
# 59     snb-7  140.963899  28906.430576  347.819495  130914.620939
# 60   tag-138   94.017647  24739.374658  348.224970  121850.258824
# 61    unc-10   44.657143  12379.747315  352.857143  124228.357143
# 62    unc-57   13.325581   2507.957121  353.941096  150065.465116
# 63    vps-35  114.909968  24556.806389  347.870198  120836.125402
#
#             date        time     speed          x          y  angularspeed  \
# 0   2.023032e+07  347.587150  0.099207  22.617169  31.402917      8.189310
# 1   2.022042e+07  348.851200  0.079350  22.947456  29.774839      7.511324
# 2   2.022938e+07  346.651101  0.149914  23.517135  29.221606     10.233717
# 3   2.023021e+07  345.852069  0.117549  22.296810  29.855596      6.937386
# 4   2.023021e+07  345.025232  0.143277  21.626080  32.872956     13.177217
# ..           ...         ...       ...        ...        ...           ...
# 59  2.024014e+07  347.318996  0.083472  23.440016  28.892687      8.305980
# 60  2.022082e+07  347.724168  0.105523  25.385935  30.931456      7.415395
# 61  2.022042e+07  352.359712  0.068170  23.217340  29.549621     13.002479
# 62  2.023071e+07  353.442772  0.027400  21.394070  30.015920      7.286100
# 63  2.022348e+07  347.370212  0.065619  23.273260  31.713237      5.882775
#
#     pathlength       kink      bias      curve       dir      crab    length  \
# 0    15.458135  51.596555  0.488456  31.568490  0.003755  0.012901  0.840095
# 1    14.170329  50.440937  0.465443  32.393079  0.003220  0.011453  0.768079
# 2     7.957444  50.144281  0.666147  33.682562  0.005635  0.017435  0.866640
# 3     6.118397  44.974244  0.499720  28.264338  0.005678  0.010966  0.858451
# 4     6.603496  54.075196  0.553196  34.347888  0.005066  0.018292  0.777207
# ..         ...        ...       ...        ...       ...       ...       ...
# 59    4.954574  54.830780  0.230247  33.060390  0.005988  0.012443  0.735992
# 60   11.029024  53.924877  0.500363  32.758615  0.006764  0.012221  0.889663
# 61    3.893378  67.833404  0.468275  41.295053  0.004401  0.015317  0.596186
# 62    0.646163  54.887244  0.190085  29.091618  0.003914  0.006651  0.435505
# 63    6.453872  49.106609  0.387110  28.934672  0.005613  0.009377  0.711527
#
#      midline     width  morphwidth      area
# 0   1.022124  0.239475    0.141594  0.132821
# 1   0.940571  0.221349    0.139272  0.121686
# 2   1.055022  0.239542    0.126955  0.125120
# 3   1.012455  0.209311    0.126870  0.124469
# 4   0.968961  0.242123    0.133307  0.118676
# ..       ...       ...         ...       ...
# 59  0.904518  0.216350    0.101854  0.089864
# 60  1.076973  0.235215    0.119416  0.123227
# 61  0.823587  0.264909    0.157008  0.107751
# 62  0.558490  0.160287    0.104507  0.055251
# 63  0.847957  0.181464    0.096557  0.083156
#
# [64 rows x 22 columns]
#                          Strain  worm    Unnamed: 0  time_bin  plate_id  \
# 0      C29E4.10(ok2752)_OffFood     1  12377.623762     350.0  131103.0
# 1      C29E4.10(ok2752)_OffFood     2  11534.862745     325.0  131103.0
# 2      C29E4.10(ok2752)_OffFood     7  12379.128713     350.0  131103.0
# 3      C29E4.10(ok2752)_OffFood     8  12380.128713     350.0  131103.0
# 4      C29E4.10(ok2752)_OffFood     9  12381.128713     350.0  131103.0
# ...                         ...   ...           ...       ...       ...
# 29902     vps-35(ok1880)_OnFood   227  29222.712871     350.0  124222.0
# 29903     vps-35(ok1880)_OnFood   230  26195.692308     312.5  124222.0
# 29904     vps-35(ok1880)_OnFood   231  29223.970297     350.0  124222.0
# 29905     vps-35(ok1880)_OnFood   232  29224.970297     350.0  124222.0
# 29906     vps-35(ok1880)_OnFood   233  27764.125000     331.5  124222.0
#
#              date        time     speed          x          y  angularspeed  \
# 0      20230317.0  349.501619  0.177988  21.303260  27.964247     13.311112
# 1      20230317.0  324.500074  0.150072  27.000117  23.874490     12.307607
# 2      20230317.0  349.501544  0.118945  30.005213  15.482308     13.542631
# 3      20230317.0  349.500662  0.152337  25.688140  21.548710     11.940276
# 4      20230317.0  349.503004  0.145859  18.648988  25.432246     12.647542
# ...           ...         ...       ...        ...        ...           ...
# 29902  20220818.0  349.500164  0.112387  14.777099  32.218514      9.962774
# 29903  20220818.0  311.981809  0.113788  27.417792  27.622298      7.854383
# 29904  20220818.0  349.499231  0.140467  19.585637  37.259483      8.729077
# 29905  20220818.0  349.501414  0.137325  18.676353  39.583079      6.076780
# 29906  20220818.0  330.998326  0.044354  18.095927  15.066453      6.743038
#
#        pathlength       kink      bias      curve       dir      crab  \
# 0       46.408252  47.108963  0.853181  32.552866  0.003152  0.021211
# 1       10.194632  48.074202  0.538919  31.020283  0.005575  0.018103
# 2       22.289745  49.671910  0.553288  33.878099  0.003662  0.017152
# 3       30.133724  49.009825  0.803978  29.976256  0.008720  0.017168
# 4       16.940695  48.129221 -0.990099  32.694270  0.000966  0.017954
# ...           ...        ...       ...        ...       ...       ...
# 29902    3.872338  46.724396  0.540142  28.958899  0.012166  0.012061
# 29903    6.436110  37.466544  0.962525  28.725660  0.000256  0.010754
# 29904    7.434440  42.652253  0.822544  26.793408  0.005927  0.011807
# 29905    8.626435  40.045113  0.936672  29.103406  0.005324  0.011388
# 29906    1.648880  47.435857  0.566232  32.094716  0.000941  0.010222
#
#          length   midline     width  morphwidth      area          Genotype  \
# 0      0.813311  0.991506  0.245576    0.186202  0.160776  C29E4.10(ok2752)
# 1      0.739020  0.968371  0.283148    0.176783  0.153972  C29E4.10(ok2752)
# 2      0.715868  0.882431  0.232332    0.148921  0.116568  C29E4.10(ok2752)
# 3      0.790745  0.932164  0.210803    0.174021  0.140310  C29E4.10(ok2752)
# 4      0.738279  0.944094  0.266603    0.172613  0.149509  C29E4.10(ok2752)
# ...         ...       ...       ...         ...       ...               ...
# 29902  0.651331  0.757265  0.161734    0.097091  0.072717    vps-35(ok1880)
# 29903  0.620248  0.706402  0.127874    0.092289  0.062669    vps-35(ok1880)
# 29904  0.701585  0.842681  0.184350    0.118245  0.096817    vps-35(ok1880)
# 29905  0.832635  0.954598  0.184953    0.119382  0.114609    vps-35(ok1880)
# 29906  0.478957  0.628263  0.164093    0.066733  0.046840    vps-35(ok1880)
#
#       Treatment      Gene  Allele
# 0       OffFood  C29E4.10  ok2752
# 1       OffFood  C29E4.10  ok2752
# 2       OffFood  C29E4.10  ok2752
# 3       OffFood  C29E4.10  ok2752
# 4       OffFood  C29E4.10  ok2752
# ...         ...       ...     ...
# 29902    OnFood    vps-35  ok1880
# 29903    OnFood    vps-35  ok1880
# 29904    OnFood    vps-35  ok1880
# 29905    OnFood    vps-35  ok1880
# 29906    OnFood    vps-35  ok1880
#
# [29907 rows x 26 columns]
# ['C29E4.10' 'F53B2.5' 'N2' 'R07G3.8' 'SSSD1.1' 'Y18D10A.22' 'acr-12'
#  'acr-3' 'acr-6' 'acr-8' 'bas-1' 'cat-1' 'cat-2' 'cat-4' 'catp-6' 'catp-7'
#  'chd-7' 'cpr-4' 'cpr-5' 'cpr-6' 'cpr-8' 'crls-1' 'djr-1.1' 'djr-1.2'
#  'dnj-25' 'dop-1' 'dop-3' 'exp-2' 'gba-1' 'gba-2' 'gba-3' 'gba-4' 'gck-3'
#  'glo-1' 'hipr-1' 'igcm-2' 'kvs-1' 'kvs-2' 'kvs-3' 'kvs-4' 'kvs-5'
#  'let-19' 'lfe-2' 'lrk-1' 'mbk-1' 'mbl-1' 'mbr-1' 'mex-3' 'mop-25.1'
#  'ncs-4' 'ncs-7' 'pdr-1' 'pink-1' 'rme-8' 'rskd-1' 'sac-2' 'set-2'
#  'sipa-1' 'snb-5' 'snb-7' 'tag-138' 'unc-10' 'unc-57' 'vps-35']
# (29907, 10)
#            Gene          Genotype Treatment                    Strain  \
# 0      C29E4.10  C29E4.10(ok2752)   OffFood  C29E4.10(ok2752)_OffFood
# 1      C29E4.10  C29E4.10(ok2752)   OffFood  C29E4.10(ok2752)_OffFood
# 2      C29E4.10  C29E4.10(ok2752)   OffFood  C29E4.10(ok2752)_OffFood
# 3      C29E4.10  C29E4.10(ok2752)   OffFood  C29E4.10(ok2752)_OffFood
# 4      C29E4.10  C29E4.10(ok2752)   OffFood  C29E4.10(ok2752)_OffFood
# ...         ...               ...       ...                       ...
# 29902    vps-35    vps-35(ok1880)    OnFood     vps-35(ok1880)_OnFood
# 29903    vps-35    vps-35(ok1880)    OnFood     vps-35(ok1880)_OnFood
# 29904    vps-35    vps-35(ok1880)    OnFood     vps-35(ok1880)_OnFood
# 29905    vps-35    vps-35(ok1880)    OnFood     vps-35(ok1880)_OnFood
# 29906    vps-35    vps-35(ok1880)    OnFood     vps-35(ok1880)_OnFood
#
#           speed  angularspeed      bias      curve      crab       kink
# 0      0.177988     13.311112  0.853181  32.552866  0.021211  47.108963
# 1      0.150072     12.307607  0.538919  31.020283  0.018103  48.074202
# 2      0.118945     13.542631  0.553288  33.878099  0.017152  49.671910
# 3      0.152337     11.940276  0.803978  29.976256  0.017168  49.009825
# 4      0.145859     12.647542 -0.990099  32.694270  0.017954  48.129221
# ...         ...           ...       ...        ...       ...        ...
# 29902  0.112387      9.962774  0.540142  28.958899  0.012061  46.724396
# 29903  0.113788      7.854383  0.962525  28.725660  0.010754  37.466544
# 29904  0.140467      8.729077  0.822544  26.793408  0.011807  42.652253
# 29905  0.137325      6.076780  0.936672  29.103406  0.011388  40.045113
# 29906  0.044354      6.743038  0.566232  32.094716  0.010222  47.435857
#
# [29907 rows x 10 columns]
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\285059495.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(TotalConcatenated_mean.groupby(['Gene'], as_index = False).mean())

# %% [markdown]
# ## 2.5 - Find average speed measures for each genotype and treatment (across duration of specified range)

# %%
TotalConcatenated_avg_speed = TotalConcatenated_worm_avg_speed.groupby(['Gene','Strain', 'Treatment', 'Genotype'], as_index = False).mean()
print(TotalConcatenated_avg_speed)
# TotalConcatenated_avg_speed.to_csv('C:\\Users\\chris\\Desktop\\Rankin_Lab\\valid_data\\TotalConcatenated_avg_speed.csv', index=True)

# print(TotalConcatenated_avg_speed['speed'][1])

ByGene_avg_speed = By_gene_avg_speed.groupby(['Gene','Treatment'], as_index = False).mean()
print(ByGene_avg_speed)
# Out:
#          Gene                    Strain Treatment          Genotype     speed  \
# 0    C29E4.10  C29E4.10(ok2752)_OffFood   OffFood  C29E4.10(ok2752)  0.154308
# 1    C29E4.10   C29E4.10(ok2752)_OnFood    OnFood  C29E4.10(ok2752)  0.050854
# 2     F53B2.5    F53B2.5(ok226)_OffFood   OffFood    F53B2.5(ok226)  0.123559
# 3     F53B2.5     F53B2.5(ok226)_OnFood    OnFood    F53B2.5(ok226)  0.053344
# 4          N2                N2_OffFood   OffFood                N2  0.200640
# ..        ...                       ...       ...               ...       ...
# 211    unc-57      unc-57(ok310)_OnFood    OnFood     unc-57(ok310)  0.033912
# 212    vps-35      vps-35(hu68)_OffFood   OffFood      vps-35(hu68)  0.059708
# 213    vps-35       vps-35(hu68)_OnFood    OnFood      vps-35(hu68)  0.041059
# 214    vps-35    vps-35(ok1880)_OffFood   OffFood    vps-35(ok1880)  0.082482
# 215    vps-35     vps-35(ok1880)_OnFood    OnFood    vps-35(ok1880)  0.054421
#
#      angularspeed      bias      curve      crab       kink
# 0       12.784817  0.527541  35.311472  0.018922  54.678514
# 1        4.156518  0.454156  28.283832  0.007616  48.891979
# 2       14.172941  0.368033  36.681574  0.017470  60.044820
# 3        3.592726  0.522744  29.870436  0.007913  44.791593
# 4       14.794726  0.643031  35.820620  0.023942  53.749891
# ..            ...       ...        ...       ...        ...
# 211      6.833305  0.332135  29.481421  0.006526  55.494141
# 212      4.928021  0.302786  30.133980  0.008433  51.575581
# 213      3.646758  0.130575  26.037996  0.007936  43.283153
# 214      7.605800  0.441679  30.056527  0.011298  51.365520
# 215      4.882757  0.437539  27.539965  0.007912  46.262557
#
# [216 rows x 10 columns]
#          Gene Treatment     speed
# 0    C29E4.10   OffFood  0.154308
# 1    C29E4.10    OnFood  0.050854
# 2     F53B2.5   OffFood  0.123559
# 3     F53B2.5    OnFood  0.053344
# 4          N2   OffFood  0.200640
# ..        ...       ...       ...
# 124    unc-10    OnFood  0.048651
# 125    unc-57   OffFood  0.021584
# 126    unc-57    OnFood  0.030208
# 127    vps-35   OffFood  0.075013
# 128    vps-35    OnFood  0.051642
#
# [129 rows x 3 columns]

# %% [markdown]
# ## 2.6 - Generate dataframe containing only data for N2 and CB1112 for use in speed trace

# %%
# print(TotalConcatenated_avg_speed.Allele.unique())
print(TotalConcatenated_avg_speed.Strain.unique().shape)
print(TotalConcatenated_avg_speed.Strain.unique())
# Out:
# (216,)
# ['C29E4.10(ok2752)_OffFood' 'C29E4.10(ok2752)_OnFood'
#  'F53B2.5(ok226)_OffFood' 'F53B2.5(ok226)_OnFood' 'N2_OffFood' 'N2_OnFood'
#  'R07G3.8(tm5683)_OffFood' 'R07G3.8(tm5683)_OnFood'
#  'SSSD1.1(ok1527)_OffFood' 'SSSD1.1(ok1527)_OnFood'
#  'Y18D10A.22(ok3535)_OffFood' 'Y18D10A.22(ok3535)_OnFood'
#  'acr-12(ok367)_OffFood' 'acr-12(ok367)_OnFood' 'acr-3(ok2049)_OffFood'
#  'acr-3(ok2049)_OnFood' 'acr-6(ok3117)_OffFood' 'acr-6(ok3117)_OnFood'
#  'acr-8(ok1240)_OffFood' 'acr-8(ok1240)_OnFood' 'bas-1(tm351)_OffFood'
#  'bas-1(tm351)_OnFood' 'cat-1(e1111)_OffFood' 'cat-1(e1111)_OnFood'
#  'cat-1(ok411)_OffFood' 'cat-1(ok411)_OnFood' 'cat-2(e1112)_OffFood'
#  'cat-2(e1112)_OnFood' 'cat-2(n4547)_OffFood' 'cat-2(n4547)_OnFood'
#  'cat-2(tm2261)_OffFood' 'cat-2(tm2261)_OnFood' 'cat-4(e1141)_OffFood'
#  'cat-4(e1141)_OnFood' 'cat-4(tm773)_OffFood' 'cat-4(tm773)_OnFood'
#  'catp-6(ok3473)_OffFood' 'catp-6(ok3473)_OnFood' 'catp-7(tm4438)_OffFood'
#  'catp-7(tm4438)_OnFood' 'catp-7(tm8556)_OffFood' 'catp-7(tm8556)_OnFood'
#  'chd-7(tm6183)_OffFood' 'chd-7(tm6183)_OnFood' 'cpr-4(ok3413)_OffFood'
#  'cpr-4(ok3413)_OnFood' 'cpr-4(tm3718)_OffFood' 'cpr-4(tm3718)_OnFood'
#  'cpr-5(ok2344)_OffFood' 'cpr-5(ok2344)_OnFood' 'cpr-5(rb1810)_OffFood'
#  'cpr-5(rb1810)_OnFood' 'cpr-6(tm12210)_OffFood' 'cpr-6(tm12210)_OnFood'
#  'cpr-8(ok2956)_OffFood' 'cpr-8(ok2956)_OnFood' 'crls-1(tm2542)_OffFood'
#  'crls-1(tm2542)_OnFood' 'crls-1(tm2575)_OffFood' 'crls-1(tm2575)_OnFood'
#  'djr-1.1(tm918)_OffFood' 'djr-1.1(tm918)_OnFood'
#  'djr-1.2(tm1346)_OffFood' 'djr-1.2(tm1346)_OnFood'
#  'djr-1.2(tm817)_OffFood' 'djr-1.2(tm817)_OnFood' 'djr-1.2(tm951)_OffFood'
#  'djr-1.2(tm951)_OnFood' 'dnj-25(ok422)_OffFood' 'dnj-25(ok422)_OnFood'
#  'dop-1(vs101)_OffFood' 'dop-1(vs101)_OnFood' 'dop-3(ok295)_OffFood'
#  'dop-3(ok295)_OnFood' 'dop-3(tm1356)_OffFood' 'dop-3(tm1356)_OnFood'
#  'exp-2(sa26ad1426)_OffFood' 'exp-2(sa26ad1426)_OnFood'
#  'exp-2(tm5668)_OffFood' 'exp-2(tm5668)_OnFood' 'gba-1(tm3816)_OffFood'
#  'gba-1(tm3816)_OnFood' 'gba-1(tm4173)_OffFood' 'gba-1(tm4173)_OnFood'
#  'gba-2(tm4623)_OffFood' 'gba-2(tm4623)_OnFood' 'gba-2(tm4808)_OffFood'
#  'gba-2(tm4808)_OnFood' 'gba-3(gk3287)_OffFood' 'gba-3(gk3287)_OnFood'
#  'gba-3(tm3302)_OffFood' 'gba-3(tm3302)_OnFood' 'gba-4(tm3314)_OffFood'
#  'gba-4(tm3314)_OnFood' 'gba-4(tm3349)_OffFood' 'gba-4(tm3349)_OnFood'
#  'gck-3(tm1223)_OffFood' 'gck-3(tm1223)_OnFood' 'gck-3(tm1296)_OffFood'
#  'gck-3(tm1296)_OnFood' 'glo-1(tm15275)_OffFood' 'glo-1(tm15275)_OnFood'
#  'glo-1(tm3240)_OffFood' 'glo-1(tm3240)_OnFood' 'glo-1(zu391)_OffFood'
#  'glo-1(zu391)_Onfood' 'hipr-1(ok1081)_OffFood' 'hipr-1(ok1081)_OnFood'
#  'hipr-1(tm14191)_OffFood' 'hipr-1(tm14191)_OnFood'
#  'igcm-2(ok1527)_OffFood' 'igcm-2(ok1527)_OnFood' 'kvs-1(tm2034)_OffFood'
#  'kvs-1(tm2034)_OnFood' 'kvs-2(tm6231)_OffFood' 'kvs-2(tm6231)_OnFood'
#  'kvs-2(tm6358)_OffFood' 'kvs-2(tm6358)_OnFood' 'kvs-3(nf140)_OffFood'
#  'kvs-3(nf140)_OnFood' 'kvs-4(tm10514)_OffFood' 'kvs-4(tm10514)_OnFood'
#  'kvs-4(tm14987)_OffFood' 'kvs-4(tm14987)_OnFood' 'kvs-5(tm6152)_OffFood'
#  'kvs-5(tm6152)_OnFood' 'let-19(gk149538)_OffFood'
#  'let-19(gk149538)_OnFood' 'let-19(os33)_OffFood' 'let-19(os33)_OnFood'
#  'lfe-2(sy326)_OffFood' 'lfe-2(sy326)_OnFood' 'lfe-2(tm14109)_OffFood'
#  'lfe-2(tm14109)_OnFood' 'lrk-1(tm1898)_OffFood' 'lrk-1(tm1898)_OnFood'
#  'lrk-1(tm7568)_OffFood' 'lrk-1(tm7568)_OnFood' 'mbk-1(pk1389)_OffFood'
#  'mbk-1(pk1389)_OnFood' 'mbl-1(tm1207)_OffFood' 'mbl-1(tm1207)_OnFood'
#  'mbl-1(tm1277)_OffFood' 'mbl-1(tm1277)_OnFood' 'mbr-1(qa5901)_OffFood'
#  'mbr-1(qa5901)_OnFood' 'mbr-1(tm1235)_OffFood' 'mbr-1(tm1235)_OnFood'
#  'mex-3(spr10)_OffFood' 'mex-3(spr10)_OnFood' 'mex-3(spr5)_OffFood'
#  'mex-3(spr5)_OnFood' 'mex-3(spr6)_OffFood' 'mex-3(spr6)_OnFood'
#  'mex-3(spr7)_OffFood' 'mex-3(spr7)_OnFood' 'mex-3(spr9)_OffFood'
#  'mex-3(spr9)_OnFood' 'mex-3(zu155)_OffFood' 'mex-3(zu155)_OnFood'
#  'mop-25.1(ok3762)_OffFood' 'mop-25.1(ok3762)_OnFood'
#  'ncs-4(tm4409)_OffFood' 'ncs-4(tm4409)_OnFood' 'ncs-4(tm8422)_OffFood'
#  'ncs-4(tm8422)_OnFood' 'ncs-7(tm4648)_OffFood' 'ncs-7(tm4648)_OnFood'
#  'ncs-7(tm5037)_OffFood' 'ncs-7(tm5037)_OnFood' 'pdr-1(gk448)_OffFood'
#  'pdr-1(gk448)_OnFood' 'pdr-1(tm598)_OffFood' 'pdr-1(tm598)_OnFood'
#  'pink-1(ok3538)_OffFood' 'pink-1(ok3538)_OnFood' 'pink-1(tm1779)_OffFood'
#  'pink-1(tm1779)_OnFood' 'rme-8(b1023)_OffFood' 'rme-8(b1023)_OnFood'
#  'rskd-1(gk1208)_OffFood' 'rskd-1(gk1208)_OnFood' 'rskd-1(tm4031)_OffFood'
#  'rskd-1(tm4031)_OnFood' 'sac-2(ok2743)_OffFood' 'sac-2(ok2743)_OnFood'
#  'set-2(n4589)_OffFood' 'set-2(n4589)_OnFood' 'set-2(ok1484)_OffFood'
#  'set-2(ok1484)_OnFood' 'set-2(ok952)_OffFood' 'set-2(ok952)_OnFood'
#  'sipa-1(ok879)_OffFood' 'sipa-1(ok879)_OnFood' 'sipa-1(tm11702)_OffFood'
#  'sipa-1(tm11702)_OnFood' 'snb-5(ok1434)_OffFood' 'snb-5(ok1434)_OnFood'
#  'snb-5(tm6182)_OffFood' 'snb-5(tm6182)_OnFood' 'snb-7(ok2662)_OffFood'
#  'snb-7(ok2662)_OnFood' 'snb-7(tm5266)_OffFood' 'snb-7(tm5266)_OnFood'
#  'tag-138(gk247)_OffFood' 'tag-138(gk247)_OnFood' 'unc-10(ad591)_OffFood'
#  'unc-10(ad591)_OnFood' 'unc-57(e406)_OffFood' 'unc-57(e406)_OnFood'
#  'unc-57(ok310)_OffFood' 'unc-57(ok310)_OnFood' 'vps-35(hu68)_OffFood'
#  'vps-35(hu68)_OnFood' 'vps-35(ok1880)_OffFood' 'vps-35(ok1880)_OnFood']

# %%
list=['N2', 'cat-2']
print(TotalConcatenated_avg_speed[TotalConcatenated_avg_speed['Gene'].isin(list)])
# Out:
#      Gene                 Strain Treatment       Genotype     speed  \
# 4      N2             N2_OffFood   OffFood             N2  0.200640
# 5      N2              N2_OnFood    OnFood             N2  0.099040
# 26  cat-2   cat-2(e1112)_OffFood   OffFood   cat-2(e1112)  0.211908
# 27  cat-2    cat-2(e1112)_OnFood    OnFood   cat-2(e1112)  0.177376
# 28  cat-2   cat-2(n4547)_OffFood   OffFood   cat-2(n4547)  0.196612
# 29  cat-2    cat-2(n4547)_OnFood    OnFood   cat-2(n4547)  0.170817
# 30  cat-2  cat-2(tm2261)_OffFood   OffFood  cat-2(tm2261)  0.180682
# 31  cat-2   cat-2(tm2261)_OnFood    OnFood  cat-2(tm2261)  0.147890
#
#     angularspeed      bias      curve      crab       kink
# 4      14.794726  0.643031  35.820620  0.023942  53.749891
# 5       5.659332  0.689331  31.538233  0.010910  46.528097
# 26     17.923158  0.572904  36.284281  0.027606  57.192792
# 27     13.004970  0.670549  34.100160  0.021189  51.450494
# 28     16.383737  0.619494  33.525845  0.023070  52.278527
# 29     13.710190  0.762736  31.451725  0.019476  48.307763
# 30     13.682373  0.464918  32.626797  0.018779  52.784290
# 31     10.250441  0.681232  28.995210  0.014855  46.893725

# %%
N2_cat2 = ['N2_OffFood', 'N2_OnFood', 'cat-2(e1112)_OffFood', 'cat-2(e1112)_OnFood']
# N2_cat2 = ['N2_NoFood', 'N2_Food', 'cat-2(e1112)_NoFood', 'cat-2(e1112)_Food']
TotalN2cat2 = TotalConcatenated[TotalConcatenated['Strain'].isin(N2_cat2)]

print(TotalN2cat2.shape)
print(TotalN2cat2)
# Out:
# (72659, 22)
#          Unnamed: 0  time_bin  worm  plate_id      date        time     speed  \
# 372994        49173     300.0     2    104256  20230206  299.501600  0.187460
# 372995        49174     300.0     5    132840  20220929  299.510333  0.208308
# 372996        49175     300.0    15     21626  20240221  299.481750  0.098517
# 372997        49176     300.0    18    200300  20240131  299.493125  0.344119
# 372998        49177     300.0    23    134818  20230712  299.324750  0.193575
# ...             ...       ...   ...       ...       ...         ...       ...
# 1839007       65805     400.0   986    140219  20231002  399.493929  0.167786
# 1839008       65806     400.0   988    122415  20231009  399.510778  0.139056
# 1839009       65807     400.0   996    140219  20231002  399.502867  0.194587
# 1839010       65808     400.0   997    113106  20231009  399.546875  0.009038
# 1839011       65809     400.0   998    103455  20221107  399.482000  0.217983
#
#                  x          y  angularspeed  pathlength        kink  bias  \
# 372994   17.492100  34.367640     49.680000    2.239467   73.340000  1.00
# 372995   32.736317  13.491742     30.200000   25.775333   76.633333  1.00
# 372996   14.853692  31.639967      1.483333    0.485750   51.091667  1.00
# 372997   24.155400  32.400469     11.400000   -0.623000   37.800000 -1.00
# 372998   39.042500  13.682850      6.362500   17.418875   44.312500  0.75
# ...            ...        ...           ...         ...         ...   ...
# 1839007  11.046979  46.370050     37.335714    3.378929  114.507143  1.00
# 1839008  26.862633  36.299789     10.122222    3.903000   65.444444  1.00
# 1839009   7.954160  31.535660     15.560000   12.227133   40.813333  1.00
# 1839010   9.082175  23.230375      1.212500    0.522000   35.200000  0.00
# 1839011  14.362475  10.029758      5.225000    8.535250   54.258333  1.00
#
#              curve       dir      crab    length   midline     width  \
# 372994   35.720000  0.000000  0.032893  0.578880  0.791067  0.302580
# 372995   28.858333  0.004833  0.028167  0.944325  1.145983  0.332550
# 372996   34.066667  0.000000  0.003650  1.013400  1.130392  0.134775
# 372997   37.956250  0.000125  0.032262  0.970988  1.175444  0.267469
# 372998   33.712500  0.000000  0.011550  0.842062  0.959762  0.184950
# ...            ...       ...       ...       ...       ...       ...
# 1839007  48.071429  0.000000  0.043750  0.740379  1.119364  0.390921
# 1839008  30.044444  0.004222  0.018467  0.820200  0.980044  0.169200
# 1839009  51.360000  0.000133  0.031000  0.849600  1.084973  0.279360
# 1839010  17.975000  0.000000  0.002537  0.861638  0.931225  0.144450
# 1839011  26.258333  0.000417  0.009383  0.973800  1.063450  0.151875
#
#          morphwidth      area               Strain
# 372994     0.166473  0.111537           N2_OffFood
# 372995     0.137950  0.152422           N2_OffFood
# 372996     0.116833  0.132860           N2_OffFood
# 372997     0.099125  0.120513           N2_OffFood
# 372998     0.113412  0.107254           N2_OffFood
# ...             ...       ...                  ...
# 1839007    0.138821  0.127575  cat-2(e1112)_OnFood
# 1839008    0.135278  0.126279  cat-2(e1112)_OnFood
# 1839009    0.124967  0.126992  cat-2(e1112)_OnFood
# 1839010    0.130763  0.116549  cat-2(e1112)_OnFood
# 1839011    0.107508  0.124295  cat-2(e1112)_OnFood
#
# [72659 rows x 22 columns]

# %% [markdown]
# # 3 - Generate speed trace

# %%
# Setting viewing range for your graph
top = 0.30
bottom = 0
left = 0
right = 420

# Set specifications for graph
sns.set_context("talk")
plt.figure(linewidth = 2.5)
plt.figure(figsize = (12, 7))
plt.gca().xaxis.grid(False)

# Specify data and colours to be used
ax = sns.lineplot(x = "time_bin",
                  y = "speed",
                  # data = TotalConcatenated,  # <----- uncomment and comment row below if using all data
                  data = TotalN2cat2,
                  hue = 'Strain',
                  palette = ['black',
                             'grey',
                             '#FF00FF',
                             '#8B008B',
                             # 'green',  # <----- uncomment additional colours if analyzing more strains (2 per strain)
                             # 'lightgreen',
                             # 'royalblue',
                             # 'lightblue',
                             # '#FFB5C5',
                             # '#CD6889'
                            ])

# Specify labels
plt.xlabel("Time (s)")
plt.ylabel("Speed (mm/s)")
plt.title("Speed Trace")

# Specify viewing range using variables at top of cell
plt.ylim(top = top)
plt.ylim(bottom = bottom)
plt.xlim(left= left)
plt.xlim(right = right)

# Add horizontal lines to visualize mean speed of each strain and condition (comment out if using more than N2 & CB1112)
# If keeping uncommented, may need to adjust indexing to calculate proper speeds
plt.axhline(y = TotalConcatenated_avg_speed['speed'][0], color = 'black', linestyle = ':', alpha = 0.5)
plt.axhline(y = TotalConcatenated_avg_speed['speed'][1], color = 'grey', linestyle = ':', alpha = 0.5)
plt.axhline(y = TotalConcatenated_avg_speed['speed'][2], color = '#FF00FF', linestyle = ':', alpha = 0.5)
plt.axhline(y = TotalConcatenated_avg_speed['speed'][3], color = '#8B008B', linestyle = ':', alpha = 0.5)

# # Add annotations to show mean speed of each strain and condition
# # Same caution as previous step regarding proper speeds
# ax.annotate(f" M = {round(TotalConcatenated_avg_speed['speed'][0], 3)}",
#             xy = (420, TotalConcatenated_avg_speed['speed'][0]),
#             xytext = (420, TotalConcatenated_avg_speed['speed'][0]),
#             color = 'black', size = 14)
# ax.annotate(f" M = {round(TotalConcatenated_avg_speed['speed'][1], 3)}",
#             xy = (420, TotalConcatenated_avg_speed['speed'][1] - 0.003),
#             xytext = (420, TotalConcatenated_avg_speed['speed'][1] - 0.003),
#             color = 'grey', size = 14)
# ax.annotate(f" M = {round(TotalConcatenated_avg_speed['speed'][4], 3)}",
#             xy = (420, TotalConcatenated_avg_speed['speed'][4] - 0.003),
#             xytext = (420, TotalConcatenated_avg_speed['speed'][4] - 0.003),
#             color = '#FF00FF', size = 14)
# ax.annotate(f" M = {round(TotalConcatenated_avg_speed['speed'][5], 3)}",
#             xy = (420, TotalConcatenated_avg_speed['speed'][5] - 0.005),
#             xytext = (420, TotalConcatenated_avg_speed['speed'][5] - 0.007),
#             color = '#8B008B', size = 14)

# Specify location for legend
ax.legend(loc = 'upper right', fontsize = '12'
          # , labels = ['N2 (Off Food)', 'N2 (On Food)', 'CB1112 (Off Food)', 'CB1112 (On Food)']
         )

# Save figure to current working directory
plt.savefig(f'Speed_Trace_{left}to{right}s.jpg', format = 'jpg', dpi = 450)

plt.show()

# %% [markdown]
# # 4 - Generate OffFood/OnFood comparison bar plots

# %% [markdown]
# ## 4.1 - BSR bar plots (difference of differences and difference of percent change)

# %% [markdown]
# ### 4.1.1 - First, take data only from the time in the experiment(s) you want to analyze, and find the average speed for each genotype and treatment

# %%
# print(TotalConcatenated.head(1))

start = 100  # <----- set the start time of the range
point = 350  # <----- set the end time of your range

# Take data between specified time points
chunkeddata0 = TotalConcatenated[TotalConcatenated["time"] >= start]
chunkeddata = chunkeddata0[chunkeddata0["time"] <= point]

# Take mean of all measures for each worm
chunkeddata_mean = chunkeddata.groupby(["Strain", "worm"], as_index = False).mean()

# Split `Strain` column into `Genotype` and `Treatment` columns
chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)

# Select only the specified columns from previous result (others not important for BSR score)
worm_avg_speed = chunkeddata_mean[['Genotype', 'Treatment', 'Strain', 'speed']]

# Take mean speed for each genotype and treatment (should result in 2 rows for each genotype - 1 for each condition)
avg_speed = worm_avg_speed.groupby(["Strain", 'Treatment', 'Genotype'], as_index = False).mean()
print(avg_speed)
# avg_speed.to_csv("avg_speed.csv")
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\4139028439.py:14: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)
#                        Strain Treatment          Genotype     speed
# 0    C29E4.10(ok2752)_OffFood   OffFood  C29E4.10(ok2752)  0.152319
# 1     C29E4.10(ok2752)_OnFood    OnFood  C29E4.10(ok2752)  0.052303
# 2      F53B2.5(ok226)_OffFood   OffFood    F53B2.5(ok226)  0.122354
# 3       F53B2.5(ok226)_OnFood    OnFood    F53B2.5(ok226)  0.054230
# 4                  N2_OffFood   OffFood                N2  0.195115
# ..                        ...       ...               ...       ...
# 211      unc-57(ok310)_OnFood    OnFood     unc-57(ok310)  0.030973
# 212      vps-35(hu68)_OffFood   OffFood      vps-35(hu68)  0.055477
# 213       vps-35(hu68)_OnFood    OnFood      vps-35(hu68)  0.043880
# 214    vps-35(ok1880)_OffFood   OffFood    vps-35(ok1880)  0.083485
# 215     vps-35(ok1880)_OnFood    OnFood    vps-35(ok1880)  0.054554
#
# [216 rows x 4 columns]

# %% [markdown]
# ### 4.1.2 - Then, calculate the difference in speed between conditions for each genotype (in mm/s), as well as the percent change in speed relative to OffFood speed for each genotype

# %%
# ABSOLUTE DIFFERENCE
# Drop `Strain` and `Treatment` columns, group by `Genotype` (without making index based on `Genotype`)
# Then, for each `Genotype`, subtract OnFood from OffFood speed
speed_diff = avg_speed.drop(columns = ["Strain", "Treatment"])
speed_diff = speed_diff.groupby("Genotype", as_index = False).diff(periods = -1).dropna()

# rename difference column to 'speed_diff'
speed_diff.columns = ['speed_diff']

print(speed_diff)

# PERCENT DIFFERENCE
avg_speed['speed_pct_diff'] = avg_speed.groupby('Genotype', as_index = False)['speed'].apply(lambda x: (x - x.shift(-1)) / x)
speed_pct_diff = avg_speed['speed_pct_diff'].dropna()
avg_speed = avg_speed.drop(columns = ['speed_pct_diff'])

print(speed_pct_diff)
# Out:
#      speed_diff
# 0      0.100016
# 2      0.068125
# 4      0.096557
# 6      0.111828
# 8      0.088691
# ..          ...
# 206    0.025005
# 208   -0.000308
# 210   -0.014482
# 212    0.011597
# 214    0.028932
#
# [108 rows x 1 columns]
# 0      0.656624
# 2      0.556782
# 4      0.494871
# 6      0.691061
# 8      0.506647
#          ...
# 206    0.338389
# 208   -0.012317
# 210   -0.878221
# 212    0.209042
# 214    0.346547
# Name: speed_pct_diff, Length: 108, dtype: float64
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\1886152336.py:13: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   avg_speed['speed_pct_diff'] = avg_speed.groupby('Genotype', as_index = False)['speed'].apply(lambda x: (x - x.shift(-1)) / x)

# %% [markdown]
# ### 4.1.3 - Combine the absolute difference and percent difference data

# %%
all_diff_measures = pd.concat([speed_diff, speed_pct_diff], axis = 1)
# all_diff_measures = all_diff_measures.rename(columns = {0: 'speed_pct_diff'})

# add `Genotype` labels back to speed difference measures so differences can be identified
all_diff_measures.insert(loc = 0, column = 'Genotype', value = avg_speed['Genotype'].unique())
all_diff_measures.reset_index(drop = True)
# Out:
#              Genotype  speed_diff  speed_pct_diff
# 0    C29E4.10(ok2752)    0.100016        0.656624
# 1      F53B2.5(ok226)    0.068125        0.556782
# 2                  N2    0.096557        0.494871
# 3     R07G3.8(tm5683)    0.111828        0.691061
# 4     SSSD1.1(ok1527)    0.088691        0.506647
# ..                ...         ...             ...
# 103     unc-10(ad591)    0.025005        0.338389
# 104      unc-57(e406)   -0.000308       -0.012317
# 105     unc-57(ok310)   -0.014482       -0.878221
# 106      vps-35(hu68)    0.011597        0.209042
# 107    vps-35(ok1880)    0.028932        0.346547
#
# [108 rows x 3 columns]

# %% [markdown]
# ### 4.1.4 - Calculate BSR score using both methods (difference of differences & difference of percent change)

# %%
# # find N2 speed differences
# print(all_diff_measures.iloc[0, 1])
# print(all_diff_measures.iloc[0, 2])

# calculate BSR score using difference of differences
all_diff_measures['Score_diff_of_diff'] = all_diff_measures['speed_diff'] - all_diff_measures.iloc[0,1]
all_diff_measures['Score_diff_of_pct_diff'] = all_diff_measures['speed_pct_diff'] - all_diff_measures.iloc[0,2]

print(all_diff_measures)
# Out:
#              Genotype  speed_diff  speed_pct_diff  Score_diff_of_diff  \
# 0    C29E4.10(ok2752)    0.100016        0.656624            0.000000
# 2      F53B2.5(ok226)    0.068125        0.556782           -0.031892
# 4                  N2    0.096557        0.494871           -0.003460
# 6     R07G3.8(tm5683)    0.111828        0.691061            0.011811
# 8     SSSD1.1(ok1527)    0.088691        0.506647           -0.011326
# ..                ...         ...             ...                 ...
# 206     unc-10(ad591)    0.025005        0.338389           -0.075011
# 208      unc-57(e406)   -0.000308       -0.012317           -0.100324
# 210     unc-57(ok310)   -0.014482       -0.878221           -0.114499
# 212      vps-35(hu68)    0.011597        0.209042           -0.088419
# 214    vps-35(ok1880)    0.028932        0.346547           -0.071085
#
#      Score_diff_of_pct_diff
# 0                  0.000000
# 2                 -0.099842
# 4                 -0.161753
# 6                  0.034437
# 8                 -0.149977
# ..                      ...
# 206               -0.318235
# 208               -0.668941
# 210               -1.534845
# 212               -0.447582
# 214               -0.310077
#
# [108 rows x 5 columns]

# %% [markdown]
# ### 4.1.5 - Make separate dataframe for each method of BSR calculation, and sort by ascending BSR score

# %%
# DIFFERENCE OF DIFFERENCES
speed_diff_sorted = all_diff_measures.sort_values(by = ["Score_diff_of_diff"]).drop(columns = ['speed_pct_diff',
                                                                                               'Score_diff_of_pct_diff'])
speed_diff_sorted = speed_diff_sorted.reset_index(drop = True)
print(speed_diff_sorted)

# DIFFERENCE OF PERCENT CHANGE
speed_pct_diff_sorted = all_diff_measures.sort_values(by = ["Score_diff_of_pct_diff"]).drop(columns = ['speed_diff',
                                                                                                       'Score_diff_of_diff'])
speed_pct_diff_sorted = speed_pct_diff_sorted.reset_index(drop = True)
print(speed_pct_diff_sorted)
# Out:
#             Genotype  speed_diff  Score_diff_of_diff
# 0      unc-57(ok310)   -0.014482           -0.114499
# 1       unc-57(e406)   -0.000308           -0.100324
# 2       vps-35(hu68)    0.011597           -0.088419
# 3       set-2(n4589)    0.012977           -0.087039
# 4       cat-2(n4547)    0.022774           -0.077242
# ..               ...         ...                 ...
# 103   catp-7(tm4438)    0.136296            0.036279
# 104  djr-1.2(tm1346)    0.138277            0.038261
# 105    gba-4(tm3349)    0.141797            0.041780
# 106   glo-1(tm15275)    0.149939            0.049922
# 107     let-19(os33)    0.175124            0.075108
#
# [108 rows x 3 columns]
#             Genotype  speed_pct_diff  Score_diff_of_pct_diff
# 0      unc-57(ok310)       -0.878221               -1.534845
# 1       unc-57(e406)       -0.012317               -0.668941
# 2       cat-2(n4547)        0.117117               -0.539507
# 3      cpr-5(rb1810)        0.171449               -0.485175
# 4       cat-2(e1112)        0.180397               -0.476227
# ..               ...             ...                     ...
# 103  hipr-1(tm14191)        0.780583                0.123959
# 104   catp-7(tm4438)        0.780812                0.124188
# 105   rskd-1(gk1208)        0.786069                0.129445
# 106    snb-7(ok2662)        0.809638                0.153014
# 107    mbl-1(tm1207)        0.829803                0.173179
#
# [108 rows x 3 columns]

# %%
# NOT SURE WHAT THE USE OF THIS IS - BEN

# avg_speed["new"] = range(1, len(avg_speed) + 1)
# avg_speed.loc[avg_speed.index == 4, 'new'] = 0
# avg_speed.loc[avg_speed.index == 4, 'new'] = 0
# print(avg_speed)
# # avg_speed.sort_values("new").drop('new', axis=1)

# %% [markdown]
# ## 4.1.6 - Making the bar plot (difference of differences)

# %%
Title = "BSR Score - Difference of Differences"  # <---------------- Input Here -----------------
sns.set_context("talk")
plt.figure(linewidth = 1)
plt.figure(figsize = (21, 7))
plt.gca().xaxis.grid(False)
ax = sns.barplot(x = 'Genotype', 
             y = 'Score_diff_of_diff', 
             data = speed_diff_sorted,  # <--------------- Input Here -------------
             color = 'CornflowerBlue',
             edgecolor = "DodgerBlue",
             linewidth = 2.5,
#              seed=5,
#              ci = 95, # 'sd' for SD, '68' for SEM
#              palette = ['grey',
#                         'black'
#                        ]
                )
plt.xlabel("Genotype")
plt.xticks(rotation = 90, fontsize = 9)
plt.ylabel("BSR Score (Normalized to N2)")
# plt.ylim(top = 0.1)
# plt.ylim(bottom = -0.1)
plt.ylim(top = 0.07)
plt.ylim(bottom = -0.07)
plt.title(Title)
# plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.savefig(f'{Title}.jpg', format = 'jpg', dpi = 450, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## 4.1.7 - Making the bar plot (difference of percent change)

# %%
Title = "BSR Score - Difference of Percent Change"  # <---------------- Input Here -----------------
sns.set_context("talk")
plt.figure(linewidth = 1)
plt.figure(figsize = (21, 7))
plt.gca().xaxis.grid(False)
ax = sns.barplot(x = 'Genotype', 
             y = 'Score_diff_of_pct_diff', 
             data = speed_pct_diff_sorted,  # <--------------- Input Here -------------
             color = 'CornflowerBlue',
             edgecolor = "DodgerBlue",
             linewidth = 2.5,
#              seed=5,
#              ci = 95, # 'sd' for SD, '68' for SEM
#              palette = ['grey',
#                         'black'
#                        ]
                )
plt.xlabel("Genotype")
plt.xticks(rotation = 90, fontsize = 9)
plt.ylabel("BSR Score (Normalized to N2)")
plt.ylim(top = 0.4)
plt.ylim(bottom = -0.4)
plt.title(Title)
# plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.savefig(f'{Title}.jpg', format = 'jpg', dpi = 450, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## 4.2 - Generic differences of differences script (for any behavioural phenotype)
#
# Very little commentary here, as code is similar to that for BSR score apart from inputting behavioural phenotype of interest

# %%
parameter = 'bias'  # <----- INPUT PHENOTYPE OF INTEREST HERE

start = 100 #<----- set the start time of the range
point = 400 #<------- set the end time of your range

chunkeddata0 = TotalConcatenated[TotalConcatenated["time"] >= start]
chunkeddata = chunkeddata0[chunkeddata0["time"] <= point]
chunkeddata_mean = chunkeddata.groupby(["Strain","worm"], as_index=False).mean()
chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)
worm_avg_parameter = chunkeddata_mean[['Genotype', 'Treatment', 'Strain', parameter]]
avg_parameter = worm_avg_parameter.groupby(["Strain", 'Treatment', 'Genotype'], as_index=False).mean()
# print(avg_parameter)

# avg_parameter.to_csv("avg_parameter.csv")

parameter_diff = avg_parameter.drop(columns=["Strain", "Treatment"]).groupby("Genotype", as_index = False).diff(periods = -1).dropna()
parameter_diff.insert(loc = 0, column='Genotype', value = avg_parameter['Genotype'].unique())
parameter_diff.reset_index(drop = True)
# print(parameter_diff)
# print(parameter_diff.iloc[0,1])
parameter_diff['Score'] = parameter_diff[parameter] - parameter_diff.iloc[0,1]
parameter_diff = parameter_diff.sort_values(by = ["Score"])
print(parameter_diff)

#################

# print(parameter_diff.iloc[0,1])

#################

# AGAIN, NOT SURE WHAT THIS IS FOR - BEN
# avg_parameter["new"] = range(1,len(avg_parameter) + 1)
# avg_parameter.loc[avg_parameter.index == 4, 'new'] = 0
# avg_parameter.loc[avg_parameter.index == 4, 'new'] = 0
# print(avg_parameter)
# # avg_parameter.sort_values("new").drop('new', axis=1)

#################

Title = f"{parameter.capitalize()} Score"  # <---------------- Input Here -----------------
sns.set_context("talk")
plt.figure(linewidth = 1)
plt.figure(figsize = (21, 7))
plt.gca().xaxis.grid(False)
ax = sns.barplot(x = "Genotype",
                 y = 'Score',
                 data = parameter_diff,  # <--------------- Input Here -------------
                 color = 'CornflowerBlue',
                 edgecolor = "DodgerBlue",
                 linewidth = 2.5,
                 # seed=5,
                 # ci = 95, # 'sd' for SD, '68' for SEM
                 # palette = ['grey',
                 #            'black'
                 #           ]
                )

plt.xlabel("Genotype")
plt.xticks(rotation = 90, fontsize = 9)
plt.ylabel(f"{parameter.capitalize()} Score (Normalized to N2)")

# plt.ylim(top = 0.1)
# plt.ylim(bottom = -0.1)
plt.title(Title)
# plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)

plt.savefig(f'{Title}.jpg', format = 'jpg', dpi = 450, bbox_inches = 'tight')

plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\1243954605.py:9: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)
#             Genotype      bias     Score
# 184    sac-2(ok2743) -0.466808 -0.540194
# 190     set-2(ok952) -0.327989 -0.401374
# 210    unc-57(ok310) -0.277190 -0.350575
# 192    sipa-1(ok879) -0.271403 -0.344788
# 74     dop-3(tm1356) -0.232192 -0.305577
# ..               ...       ...       ...
# 6    R07G3.8(tm5683)  0.446815  0.373429
# 98     gck-3(tm1296)  0.498826  0.425440
# 174   pink-1(ok3538)  0.509435  0.436049
# 142    mbl-1(tm1277)  0.544400  0.471014
# 140    mbl-1(tm1207)  0.590281  0.516896
#
# [108 rows x 3 columns]

# %% [markdown]
# # 5 - Phenotype Heatmap

# %% [markdown]
# ## 5.1 - Calculate difference of differences scores for all behavioural phenotypes

# %%
behavioural_phenotypes = ['speed', 'angularspeed', 'bias', 'curve', 'crab', 'kink']
# print(all_strains)

def differences_of_differences(start, point, df):
    chunkeddata0 = df[df["time"] >= start]
    chunkeddata = chunkeddata0[chunkeddata0["time"] <= point]
    chunkeddata_mean = chunkeddata.groupby(["Strain", "worm"], as_index=False).mean()
    chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)
    all_scores = all_strains
    for parameter in behavioural_phenotypes:
        worm_avg_parameter = chunkeddata_mean[['Genotype', 'Treatment', 'Strain', parameter]]
        avg_parameter = worm_avg_parameter.groupby(["Strain", 'Treatment', 'Genotype'], as_index=False).mean()
        # print(avg_parameter)

        # avg_parameter.to_csv("avg_parameter.csv")

        parameter_diff = avg_parameter.drop(columns=["Strain", "Treatment"]).groupby("Genotype", as_index=False).diff(periods=-1).dropna()
        parameter_diff.insert(loc=0, column='Genotype', value = avg_parameter['Genotype'].unique())
        parameter_diff.reset_index(drop=True)
        # print(parameter_diff)
        # print(parameter_diff.iloc[0,1])
        parameter_diff['Score'] = parameter_diff[parameter] - parameter_diff.iloc[0,1]
        # parameter_diff = parameter_diff.sort_values(by = ["Score"])
        parameter_diff = parameter_diff.drop(columns = [parameter])
        parameter_diff = parameter_diff.rename(columns = {'Score':parameter})
        parameter_diff = parameter_diff.reset_index(drop = True)
        # print(parameter_diff)
        all_scores = all_scores.join(parameter_diff.iloc[:,1])
    all_scores = all_scores.set_index("Genotype")
    return(all_scores)

differences_of_differences(100, 400, TotalConcatenated)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\2023198025.py:8: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)
#                      speed  angularspeed      bias     curve      crab  \
# Genotype
# C29E4.10(ok2752)  0.000000      0.000000  0.000000  0.000000  0.000000
# F53B2.5(ok226)   -0.033239      1.951916 -0.228096 -0.216502 -0.001749
# N2               -0.001854      0.507095 -0.119685 -2.745252  0.001726
# R07G3.8(tm5683)   0.010444     -2.188713  0.373429 -3.222969 -0.003392
# SSSD1.1(ok1527)  -0.016286      2.189510 -0.176071 -1.009507  0.001448
# ...                    ...           ...       ...       ...       ...
# unc-10(ad591)    -0.078611     -1.308816  0.079745 -6.014647 -0.005355
# unc-57(e406)     -0.096587      3.909834 -0.100012 -5.533572 -0.010855
# unc-57(ok310)    -0.117489    -10.417054 -0.350575 -6.964731 -0.012083
# vps-35(hu68)     -0.084805     -7.347036  0.098826 -2.931656 -0.010809
# vps-35(ok1880)   -0.075392     -5.905257 -0.069245 -4.511078 -0.007920
#
#                       kink
# Genotype
# C29E4.10(ok2752)  0.000000
# F53B2.5(ok226)    9.466691
# N2                1.435259
# R07G3.8(tm5683)  -4.736515
# SSSD1.1(ok1527)   4.130939
# ...                    ...
# unc-10(ad591)    -1.397503
# unc-57(e406)     -4.778179
# unc-57(ok310)    -3.452003
# vps-35(hu68)      2.505893
# vps-35(ok1880)   -0.683573
#
# [108 rows x 6 columns]

# %% [markdown]
# ### 5.1.1 - Use function defined above to store difference of difference dataframe in a new variable

# %%
PD_gene_behavioural_scores = differences_of_differences(100, 400, TotalConcatenated)
PD_gene_behavioural_scores = PD_gene_behavioural_scores.dropna().sort_index()
print(PD_gene_behavioural_scores)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\2023198025.py:8: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split('_', 1, expand=True)
#                      speed  angularspeed      bias     curve      crab  \
# Genotype
# C29E4.10(ok2752)  0.000000      0.000000  0.000000  0.000000  0.000000
# F53B2.5(ok226)   -0.033239      1.951916 -0.228096 -0.216502 -0.001749
# N2               -0.001854      0.507095 -0.119685 -2.745252  0.001726
# R07G3.8(tm5683)   0.010444     -2.188713  0.373429 -3.222969 -0.003392
# SSSD1.1(ok1527)  -0.016286      2.189510 -0.176071 -1.009507  0.001448
# ...                    ...           ...       ...       ...       ...
# unc-10(ad591)    -0.078611     -1.308816  0.079745 -6.014647 -0.005355
# unc-57(e406)     -0.096587      3.909834 -0.100012 -5.533572 -0.010855
# unc-57(ok310)    -0.117489    -10.417054 -0.350575 -6.964731 -0.012083
# vps-35(hu68)     -0.084805     -7.347036  0.098826 -2.931656 -0.010809
# vps-35(ok1880)   -0.075392     -5.905257 -0.069245 -4.511078 -0.007920
#
#                       kink
# Genotype
# C29E4.10(ok2752)  0.000000
# F53B2.5(ok226)    9.466691
# N2                1.435259
# R07G3.8(tm5683)  -4.736515
# SSSD1.1(ok1527)   4.130939
# ...                    ...
# unc-10(ad591)    -1.397503
# unc-57(e406)     -4.778179
# unc-57(ok310)    -3.452003
# vps-35(hu68)      2.505893
# vps-35(ok1880)   -0.683573
#
# [108 rows x 6 columns]

# %% [markdown]
# ### 5.1.2 - Standardize and normalize the difference of difference scores

# %%
PD_gene_behavioural_scores_standardize = (PD_gene_behavioural_scores - PD_gene_behavioural_scores.mean())/PD_gene_behavioural_scores.std()
print(PD_gene_behavioural_scores_standardize)

PD_gene_behavioural_scores_normalize = PD_gene_behavioural_scores_standardize - PD_gene_behavioural_scores_standardize[PD_gene_behavioural_scores_standardize.index == 'N2'].squeeze()
PD_gene_behavioural_scores_normalize = PD_gene_behavioural_scores_normalize.drop(index = 'N2')
print(PD_gene_behavioural_scores_normalize)
# Out:
#                      speed  angularspeed      bias     curve      crab  \
# Genotype
# C29E4.10(ok2752)  0.530677      0.476976 -0.131459  1.222600  0.682744
# F53B2.5(ok226)   -0.399635      1.111723 -1.168583  1.126459  0.238984
# N2                0.478788      0.641879 -0.675651  0.003519  1.120612
# R07G3.8(tm5683)   0.822995     -0.234775  1.566479 -0.208620 -0.177607
# SSSD1.1(ok1527)   0.074846      1.188987 -0.932032  0.774310  1.050156
# ...                    ...           ...       ...       ...       ...
# unc-10(ad591)    -1.669561      0.051360  0.231130 -1.448317 -0.675568
# unc-57(e406)     -2.172676      1.748421 -0.586202 -1.234687 -2.070942
# unc-57(ok310)    -2.757700     -2.910562 -1.725483 -1.870220 -2.382339
# vps-35(hu68)     -1.842920     -1.912218  0.317890 -0.079257 -2.059302
# vps-35(ok1880)   -1.579461     -1.443363 -0.446306 -0.780629 -1.326300
#
#                       kink
# Genotype
# C29E4.10(ok2752)  0.386069
# F53B2.5(ok226)    2.051418
# N2                0.638555
# R07G3.8(tm5683)  -0.447163
# SSSD1.1(ok1527)   1.112770
# ...                    ...
# unc-10(ad591)     0.140225
# unc-57(e406)     -0.454492
# unc-57(ok310)    -0.221196
# vps-35(hu68)      0.826898
# vps-35(ok1880)    0.265817
#
# [108 rows x 6 columns]
#                        speed  angularspeed      bias     curve      crab  \
# Genotype
# C29E4.10(ok2752)    0.051889     -0.164903  0.544192  1.219081 -0.437869
# F53B2.5(ok226)     -0.878423      0.469843 -0.492932  1.122940 -0.881629
# R07G3.8(tm5683)     0.344207     -0.876654  2.242130 -0.212139 -1.298219
# SSSD1.1(ok1527)    -0.403942      0.547107 -0.256381  0.770790 -0.070456
# Y18D10A.22(ok3535) -0.626116     -1.636755  2.094739 -0.148573 -1.860779
# ...                      ...           ...       ...       ...       ...
# unc-10(ad591)      -2.148349     -0.590519  0.906781 -1.451836 -1.796180
# unc-57(e406)       -2.651464      1.106542  0.089450 -1.238206 -3.191554
# unc-57(ok310)      -3.236488     -3.552441 -1.049832 -1.873739 -3.502952
# vps-35(hu68)       -2.321708     -2.554097  0.993541 -0.082776 -3.179914
# vps-35(ok1880)     -2.058249     -2.085243  0.229345 -0.784148 -2.446912
#
#                         kink
# Genotype
# C29E4.10(ok2752)   -0.252486
# F53B2.5(ok226)      1.412863
# R07G3.8(tm5683)    -1.085718
# SSSD1.1(ok1527)     0.474215
# Y18D10A.22(ok3535) -1.570981
# ...                      ...
# unc-10(ad591)      -0.498330
# unc-57(e406)       -1.093047
# unc-57(ok310)      -0.859751
# vps-35(hu68)        0.188342
# vps-35(ok1880)     -0.372738
#
# [107 rows x 6 columns]

# %% [markdown]
# ## 5.2 - Calculate, standardize, and normalize t-scores for all baseline behavioural and morphological phenotypes

# %% [markdown]
# ### 5.2.1 - Read in and tidy data (same data as used previously)

# %%
# PD_baseline = pd.read_csv('baseline_output.csv')
PD_baseline = pd.concat(dfs_to_append, ignore_index=True)
PD_baseline = PD_baseline.iloc[:, 1:]
PD_baseline = PD_baseline.drop(columns=["x", "y"])
PD_baseline[['Genotype', 'Treatment']] = PD_baseline['Strain'].str.split('_', 1, expand=True)

print(PD_baseline.head())
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\1017856684.py:5: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   PD_baseline[['Genotype', 'Treatment']] = PD_baseline['Strain'].str.split('_', 1, expand=True)
#    time_bin  worm  plate_id      date        time     speed  angularspeed  \
# 0     300.0     2    110251  20230421  299.499909  0.197877    101.981818
# 1     300.0    10    110251  20230421  299.488261  0.373387     49.413043
# 2     300.0    12    110251  20230421  299.505667  0.256321      6.195833
# 3     300.0    13    110251  20230421  299.505667  0.198883      8.779167
# 4     300.0    16    110251  20230421  299.505667  0.088025      7.375000
#
#    pathlength       kink   bias      curve       dir      crab    length  \
# 0    2.221182  89.931818 -1.000  61.336364  0.000273  0.106305  0.592895
# 1   18.721391  47.695652  1.000  41.791304  0.000087  0.059300  0.715617
# 2   18.512125  45.525000  1.000  31.650000  0.000417  0.019787  0.898087
# 3    6.854792  38.533333 -1.000  35.341667  0.000000  0.033200  0.972900
# 4   -8.181792  99.312500 -0.875  47.600000  0.020333  0.011854  0.513900
#
#     midline     width  morphwidth      area                 Strain  \
# 0  1.085877  0.448077    0.159305  0.128602  acr-12(ok367)_OffFood
# 1  1.039226  0.366848    0.128874  0.111537  acr-12(ok367)_OffFood
# 2  1.165200  0.204300    0.128146  0.132465  acr-12(ok367)_OffFood
# 3  1.186692  0.303862    0.099525  0.107740  acr-12(ok367)_OffFood
# 4  0.797050  0.312975    0.176933  0.114544  acr-12(ok367)_OffFood
#
#         Genotype Treatment
# 0  acr-12(ok367)   OffFood
# 1  acr-12(ok367)   OffFood
# 2  acr-12(ok367)   OffFood
# 3  acr-12(ok367)   OffFood
# 4  acr-12(ok367)   OffFood

# %% [markdown]
# ### 5.2.2 - Subset the final 100 seconds of the experiment

# %%
PD_baseline_last100 = PD_baseline[((PD_baseline.time <= 420) & (PD_baseline.time >= 320))]
PD_baseline_last100 = PD_baseline_last100.reset_index()
PD_baseline_last100 = PD_baseline_last100.dropna()
print(PD_baseline_last100)
# Out:
#            index  time_bin  worm  plate_id      date        time     speed  \
# 0           1709     321.0     2    110251  20230421  320.505042  0.100921
# 1           1710     321.0    10    110251  20230421  320.505042  0.311258
# 2           1711     321.0    13    110251  20230421  320.505042  0.223213
# 3           1712     321.0    16    110251  20230421  320.505042  0.300467
# 4           1713     321.0    17    110251  20230421  320.505042  0.226862
# ...          ...       ...   ...       ...       ...         ...       ...
# 1444596  1839007     400.0   986    140219  20231002  399.493929  0.167786
# 1444597  1839008     400.0   988    122415  20231009  399.510778  0.139056
# 1444598  1839009     400.0   996    140219  20231002  399.502867  0.194587
# 1444599  1839010     400.0   997    113106  20231009  399.546875  0.009038
# 1444600  1839011     400.0   998    103455  20221107  399.482000  0.217983
#
#          angularspeed  pathlength        kink  bias      curve       dir  \
# 0           40.787500    2.222958   92.195833   1.0  42.933333  0.000000
# 1           16.641667   18.565625   38.620833  -1.0  35.058333  0.000000
# 2           32.387500    2.572792   44.212500  -1.0  45.208333  0.000333
# 3           16.316667   -8.379750   67.250000  -1.0  41.533333  0.000583
# 4           24.766667    7.856042   50.741667   1.0  40.875000  0.002167
# ...               ...         ...         ...   ...        ...       ...
# 1444596     37.335714    3.378929  114.507143   1.0  48.071429  0.000000
# 1444597     10.122222    3.903000   65.444444   1.0  30.044444  0.004222
# 1444598     15.560000   12.227133   40.813333   1.0  51.360000  0.000133
# 1444599      1.212500    0.522000   35.200000   0.0  17.975000  0.000000
# 1444600      5.225000    8.535250   54.258333   1.0  26.258333  0.000417
#
#              crab    length   midline     width  morphwidth      area  \
# 0        0.056454  0.559350  0.816042  0.292725    0.186671  0.119829
# 1        0.029717  0.850500  1.056437  0.272587    0.110704  0.113299
# 2        0.035842  0.882675  1.154354  0.334237    0.113004  0.107467
# 3        0.052787  0.811013  1.097962  0.325462    0.104012  0.113116
# 4        0.038933  0.950625  1.211067  0.318150    0.101900  0.125054
# ...           ...       ...       ...       ...         ...       ...
# 1444596  0.043750  0.740379  1.119364  0.390921    0.138821  0.127575
# 1444597  0.018467  0.820200  0.980044  0.169200    0.135278  0.126279
# 1444598  0.031000  0.849600  1.084973  0.279360    0.124967  0.126992
# 1444599  0.002537  0.861638  0.931225  0.144450    0.130763  0.116549
# 1444600  0.009383  0.973800  1.063450  0.151875    0.107508  0.124295
#
#                         Strain       Genotype Treatment
# 0        acr-12(ok367)_OffFood  acr-12(ok367)   OffFood
# 1        acr-12(ok367)_OffFood  acr-12(ok367)   OffFood
# 2        acr-12(ok367)_OffFood  acr-12(ok367)   OffFood
# 3        acr-12(ok367)_OffFood  acr-12(ok367)   OffFood
# 4        acr-12(ok367)_OffFood  acr-12(ok367)   OffFood
# ...                        ...            ...       ...
# 1444596    cat-2(e1112)_OnFood   cat-2(e1112)    OnFood
# 1444597    cat-2(e1112)_OnFood   cat-2(e1112)    OnFood
# 1444598    cat-2(e1112)_OnFood   cat-2(e1112)    OnFood
# 1444599    cat-2(e1112)_OnFood   cat-2(e1112)    OnFood
# 1444600    cat-2(e1112)_OnFood   cat-2(e1112)    OnFood
#
# [1444601 rows x 22 columns]

# %% [markdown]
# ### 5.2.3 - Generate list of all strains in data set

# %%
list = PD_baseline_last100["Genotype"].unique()
print(list)
# Out:
# ['acr-12(ok367)' 'acr-3(ok2049)' 'acr-6(ok3117)' 'acr-8(ok1240)'
#  'Y18D10A.22(ok3535)' 'vps-35(hu68)' 'vps-35(ok1880)' 'tag-138(gk247)'
#  'unc-10(ad591)' 'unc-57(e406)' 'unc-57(ok310)' 'SSSD1.1(ok1527)'
#  'snb-5(tm6182)' 'snb-7(ok2662)' 'snb-7(tm5266)' 'set-2(ok1484)'
#  'sipa-1(ok879)' 'sipa-1(tm11702)' 'snb-5(ok1434)' 'rskd-1(tm4031)'
#  'sac-2(ok2743)' 'set-2(n4589)' 'set-2(ok952)' 'R07G3.8(tm5683)'
#  'pink-1(tm1779)' 'rme-8(b1023)' 'rskd-1(gk1208)' 'ncs-7(tm5037)'
#  'pdr-1(gk448)' 'pdr-1(tm598)' 'pink-1(ok3538)' 'N2' 'ncs-4(tm4409)'
#  'ncs-4(tm8422)' 'ncs-7(tm4648)' 'mex-3(spr10)' 'mex-3(spr9)'
#  'mex-3(zu155)' 'mop-25.1(ok3762)' 'mbr-1(tm1235)' 'mex-3(spr5)'
#  'mex-3(spr6)' 'mex-3(spr7)' 'mbk-1(pk1389)' 'mbl-1(tm1207)'
#  'mbl-1(tm1277)' 'mbr-1(qa5901)' 'lfe-2(sy326)' 'lfe-2(tm14109)'
#  'lrk-1(tm1898)' 'lrk-1(tm7568)' 'kvs-4(tm14987)' 'kvs-5(tm6152)'
#  'let-19(gk149538)' 'let-19(os33)' 'kvs-2(tm6231)' 'kvs-2(tm6358)'
#  'kvs-3(nf140)' 'kvs-4(tm10514)' 'hipr-1(ok1081)' 'hipr-1(tm14191)'
#  'igcm-2(ok1527)' 'kvs-1(tm2034)' 'gck-3(tm1296)' 'glo-1(tm15275)'
#  'glo-1(tm3240)' 'glo-1(zu391)' 'gba-3(tm3302)' 'gba-4(tm3314)'
#  'gba-4(tm3349)' 'gck-3(tm1223)' 'gba-1(tm4173)' 'gba-2(tm4623)'
#  'gba-2(tm4808)' 'gba-3(gk3287)' 'F53B2.5(ok226)' 'exp-2(sa26ad1426)'
#  'exp-2(tm5668)' 'gba-1(tm3816)' 'dnj-25(ok422)' 'dop-1(vs101)'
#  'dop-3(ok295)' 'dop-3(tm1356)' 'djr-1.1(tm918)' 'djr-1.2(tm1346)'
#  'djr-1.2(tm817)' 'djr-1.2(tm951)' 'cpr-6(tm12210)' 'cpr-8(ok2956)'
#  'crls-1(tm2542)' 'crls-1(tm2575)' 'cpr-4(ok3413)' 'cpr-4(tm3718)'
#  'cpr-5(ok2344)' 'cpr-5(rb1810)' 'catp-6(ok3473)' 'catp-7(tm4438)'
#  'catp-7(tm8556)' 'chd-7(tm6183)' 'cat-2(n4547)' 'cat-2(tm2261)'
#  'cat-4(e1141)' 'cat-4(tm773)' 'C29E4.10(ok2752)' 'bas-1(tm351)'
#  'cat-1(e1111)' 'cat-1(ok411)' 'cat-2(e1112)']

# %% [markdown]
# ### 5.2.4 - Separate OffFood and OnFood data for comparison of behaviour within conditions

# %%
PD_baseline_last100_OffFood = PD_baseline_last100[PD_baseline_last100["Treatment"] == "OffFood"].dropna().add_suffix('_OffFood')
PD_baseline_last100_OffFood = PD_baseline_last100_OffFood.rename(columns = {'Genotype_OffFood': 'Genotype'})
# PD_baseline_last100_OffFood = PD_baseline_last100[PD_baseline_last100["Treatment"] == "NoFood"].dropna().add_suffix('_OffFood')
# PD_baseline_last100_OffFood = PD_baseline_last100_OffFood.rename(columns = {'Genotype_OffFood': 'Genotype'})


PD_baseline_last100_OnFood = PD_baseline_last100[PD_baseline_last100["Treatment"] == "OnFood"].dropna().add_suffix('_OnFood')
PD_baseline_last100_OnFood = PD_baseline_last100_OnFood.rename(columns = {'Genotype_OnFood': 'Genotype'})
# PD_baseline_last100_OnFood = PD_baseline_last100[PD_baseline_last100["Treatment"] == "Food"].dropna().add_suffix('_OnFood')
# PD_baseline_last100_OnFood = PD_baseline_last100_OnFood.rename(columns = {'Genotype_OnFood': 'Genotype'})
print(PD_baseline_last100_OffFood.shape)
print(PD_baseline_last100_OffFood)
print(PD_baseline_last100_OnFood.shape)
print(PD_baseline_last100_OnFood)
# Out:
# (698877, 22)
#          index_OffFood  time_bin_OffFood  worm_OffFood  plate_id_OffFood  \
# 0                 1709             321.0             2            110251
# 1                 1710             321.0            10            110251
# 2                 1711             321.0            13            110251
# 3                 1712             321.0            16            110251
# 4                 1713             321.0            17            110251
# ...                ...               ...           ...               ...
# 1431817        1822365             400.0           949            124835
# 1431818        1822366             400.0           961            153200
# 1431819        1822367             400.0           973            135649
# 1431820        1822368             400.0           986            131256
# 1431821        1822369             400.0           994            121905
#
#          date_OffFood  time_OffFood  speed_OffFood  angularspeed_OffFood  \
# 0            20230421    320.505042       0.100921             40.787500
# 1            20230421    320.505042       0.311258             16.641667
# 2            20230421    320.505042       0.223213             32.387500
# 3            20230421    320.505042       0.300467             16.316667
# 4            20230421    320.505042       0.226862             24.766667
# ...               ...           ...            ...                   ...
# 1431817      20231002    399.508583       0.094083              3.350000
# 1431818      20221020    399.505231       0.252785             17.707692
# 1431819      20231012    399.485875       0.096375              6.575000
# 1431820      20231009    399.498333       0.341892              7.841667
# 1431821      20231002    399.507304       0.038830             39.404348
#
#          pathlength_OffFood  kink_OffFood  bias_OffFood  curve_OffFood  \
# 0                  2.222958     92.195833      1.000000      42.933333
# 1                 18.565625     38.620833     -1.000000      35.058333
# 2                  2.572792     44.212500     -1.000000      45.208333
# 3                 -8.379750     67.250000     -1.000000      41.533333
# 4                  7.856042     50.741667      1.000000      40.875000
# ...                     ...           ...           ...            ...
# 1431817            6.874917     47.116667      1.000000      33.766667
# 1431818           -4.311923     33.215385      1.000000      34.146154
# 1431819           14.037500     26.837500      0.125000      24.425000
# 1431820            0.922000     40.516667     -1.000000      28.558333
# 1431821            3.636652     50.617391      0.217391      25.947826
#
#          dir_OffFood  crab_OffFood  length_OffFood  midline_OffFood  \
# 0           0.000000      0.056454        0.559350         0.816042
# 1           0.000000      0.029717        0.850500         1.056437
# 2           0.000333      0.035842        0.882675         1.154354
# 3           0.000583      0.052787        0.811013         1.097962
# 4           0.002167      0.038933        0.950625         1.211067
# ...              ...           ...             ...              ...
# 1431817     0.000000      0.008258        0.860175         1.033900
# 1431818     0.000000      0.035746        0.808546         1.019638
# 1431819     0.122750      0.008287        0.958500         1.026975
# 1431820     0.001667      0.016400        0.990900         1.072525
# 1431821     0.020304      0.009143        0.453248         0.531457
#
#          width_OffFood  morphwidth_OffFood  area_OffFood  \
# 0             0.292725            0.186671      0.119829
# 1             0.272587            0.110704      0.113299
# 2             0.334237            0.113004      0.107467
# 3             0.325462            0.104012      0.113116
# 4             0.318150            0.101900      0.125054
# ...                ...                 ...           ...
# 1431817       0.284850            0.105367      0.104976
# 1431818       0.310708            0.156315      0.151239
# 1431819       0.139050            0.103150      0.109532
# 1431820       0.143550            0.094675      0.113177
# 1431821       0.229852            0.205922      0.090079
#
#                 Strain_OffFood       Genotype Treatment_OffFood
# 0        acr-12(ok367)_OffFood  acr-12(ok367)           OffFood
# 1        acr-12(ok367)_OffFood  acr-12(ok367)           OffFood
# 2        acr-12(ok367)_OffFood  acr-12(ok367)           OffFood
# 3        acr-12(ok367)_OffFood  acr-12(ok367)           OffFood
# 4        acr-12(ok367)_OffFood  acr-12(ok367)           OffFood
# ...                        ...            ...               ...
# 1431817   cat-2(e1112)_OffFood   cat-2(e1112)           OffFood
# 1431818   cat-2(e1112)_OffFood   cat-2(e1112)           OffFood
# 1431819   cat-2(e1112)_OffFood   cat-2(e1112)           OffFood
# 1431820   cat-2(e1112)_OffFood   cat-2(e1112)           OffFood
# 1431821   cat-2(e1112)_OffFood   cat-2(e1112)           OffFood
#
# [698877 rows x 22 columns]
# (741769, 22)
#          index_OnFood  time_bin_OnFood  worm_OnFood  plate_id_OnFood  \
# 6253            10252            321.0            1           115203
# 6254            10253            321.0            8           115203
# 6255            10254            321.0           11           115203
# 6256            10255            321.0           14           115203
# 6257            10256            321.0           15           115203
# ...               ...              ...          ...              ...
# 1444596       1839007            400.0          986           140219
# 1444597       1839008            400.0          988           122415
# 1444598       1839009            400.0          996           140219
# 1444599       1839010            400.0          997           113106
# 1444600       1839011            400.0          998           103455
#
#          date_OnFood  time_OnFood  speed_OnFood  angularspeed_OnFood  \
# 6253        20230421   320.503462      0.013769             7.415385
# 6254        20230421   320.503462      0.134308            24.976923
# 6255        20230421   320.503462      0.083815             2.015385
# 6256        20230421   320.488818      0.130600            11.936364
# 6257        20230421   320.503462      0.138100             4.500000
# ...              ...          ...           ...                  ...
# 1444596     20231002   399.493929      0.167786            37.335714
# 1444597     20231009   399.510778      0.139056            10.122222
# 1444598     20231002   399.502867      0.194587            15.560000
# 1444599     20231009   399.546875      0.009038             1.212500
# 1444600     20221107   399.482000      0.217983             5.225000
#
#          pathlength_OnFood  kink_OnFood  bias_OnFood  curve_OnFood  \
# 6253             24.667000    83.407692          0.0     29.500000
# 6254              8.727154    63.553846          1.0     31.853846
# 6255              4.065538    31.769231          1.0     20.661538
# 6256              5.687636    53.936364          1.0     27.727273
# 6257             33.249308    33.723077          1.0     19.976923
# ...                    ...          ...          ...           ...
# 1444596           3.378929   114.507143          1.0     48.071429
# 1444597           3.903000    65.444444          1.0     30.044444
# 1444598          12.227133    40.813333          1.0     51.360000
# 1444599           0.522000    35.200000          0.0     17.975000
# 1444600           8.535250    54.258333          1.0     26.258333
#
#          dir_OnFood  crab_OnFood  length_OnFood  midline_OnFood  width_OnFood  \
# 6253       0.000000     0.005631       0.584862        0.677192      0.328154
# 6254       0.004154     0.026238       0.706985        0.877123      0.226177
# 6255       0.000000     0.004008       0.909692        0.980738      0.200631
# 6256       0.001455     0.018927       0.808773        1.039455      0.325227
# 6257       0.000000     0.008769       0.866492        0.952738      0.145800
# ...             ...          ...            ...             ...           ...
# 1444596    0.000000     0.043750       0.740379        1.119364      0.390921
# 1444597    0.004222     0.018467       0.820200        0.980044      0.169200
# 1444598    0.000133     0.031000       0.849600        1.084973      0.279360
# 1444599    0.000000     0.002537       0.861638        0.931225      0.144450
# 1444600    0.000417     0.009383       0.973800        1.063450      0.151875
#
#          morphwidth_OnFood  area_OnFood         Strain_OnFood       Genotype  \
# 6253              0.298977     0.164025  acr-12(ok367)_OnFood  acr-12(ok367)
# 6254              0.175131     0.130996  acr-12(ok367)_OnFood  acr-12(ok367)
# 6255              0.152131     0.143108  acr-12(ok367)_OnFood  acr-12(ok367)
# 6256              0.163282     0.167206  acr-12(ok367)_OnFood  acr-12(ok367)
# 6257              0.173108     0.148772  acr-12(ok367)_OnFood  acr-12(ok367)
# ...                    ...          ...                   ...            ...
# 1444596           0.138821     0.127575   cat-2(e1112)_OnFood   cat-2(e1112)
# 1444597           0.135278     0.126279   cat-2(e1112)_OnFood   cat-2(e1112)
# 1444598           0.124967     0.126992   cat-2(e1112)_OnFood   cat-2(e1112)
# 1444599           0.130763     0.116549   cat-2(e1112)_OnFood   cat-2(e1112)
# 1444600           0.107508     0.124295   cat-2(e1112)_OnFood   cat-2(e1112)
#
#         Treatment_OnFood
# 6253              OnFood
# 6254              OnFood
# 6255              OnFood
# 6256              OnFood
# 6257              OnFood
# ...                  ...
# 1444596           OnFood
# 1444597           OnFood
# 1444598           OnFood
# 1444599           OnFood
# 1444600           OnFood
#
# [741769 rows x 22 columns]

# %% [markdown]
# ### 5.2.5 - Generate empty dataframes for each measure of phenotype (scores will be added to these)

# %%
PD_gene_baseline_length_T = pd.DataFrame(columns = ["Genotype", "length"])
PD_gene_baseline_midline_T = pd.DataFrame(columns = ["Genotype", "midline"])
PD_gene_baseline_width_T = pd.DataFrame(columns = ["Genotype", "width"])
PD_gene_baseline_morphwidth_T = pd.DataFrame(columns = ["Genotype", "morphwidth"])
PD_gene_baseline_area_T = pd.DataFrame(columns = ["Genotype", "area"])

PD_gene_baseline_speed_T_OffFood = pd.DataFrame(columns = ["Genotype", "speed_OffFood"])
PD_gene_baseline_angularspeed_T_OffFood = pd.DataFrame(columns = ["Genotype", "angularspeed_OffFood"])
PD_gene_baseline_bias_T_OffFood = pd.DataFrame(columns = ["Genotype", "bias_OffFood"])
PD_gene_baseline_curve_T_OffFood = pd.DataFrame(columns = ["Genotype", "curve_OffFood"])
PD_gene_baseline_crab_T_OffFood = pd.DataFrame(columns = ["Genotype", "crab_OffFood"])
PD_gene_baseline_kink_T_OffFood = pd.DataFrame(columns = ["Genotype", "kink_OffFood"])

PD_gene_baseline_speed_T_OnFood = pd.DataFrame(columns = ["Genotype", "speed_OnFood"])
PD_gene_baseline_angularspeed_T_OnFood = pd.DataFrame(columns = ["Genotype", "angularspeed_OnFood"])
PD_gene_baseline_bias_T_OnFood = pd.DataFrame(columns = ["Genotype", "bias_OnFood"])
PD_gene_baseline_curve_T_OnFood = pd.DataFrame(columns = ["Genotype", "curve_OnFood"])
PD_gene_baseline_crab_T_OnFood = pd.DataFrame(columns = ["Genotype", "crab_OnFood"])
PD_gene_baseline_kink_T_OnFood = pd.DataFrame(columns = ["Genotype", "kink_OnFood"])

print(PD_gene_baseline_midline_T)
# Out:
# Empty DataFrame
# Columns: [Genotype, midline]
# Index: []

# %% [markdown]
# ### 5.2.6 - Define t-test function

# %%
def TTest_Gene(DatasetList, Type, DF_ref, output):
    for a in DatasetList:
        Tstat = ttest_ind(DF_ref[DF_ref.Genotype == a][Type], DF_ref[DF_ref.Genotype == "N2"][Type], equal_var = False)[0]
        row = [a, Tstat]
        output.loc[len(output)] = row
    print(output)

# %% [markdown]
# ### 5.2.7 - Use `TTest_Gene()` function to generate t-scores for each genotype, measure of phenotype, and condition

# %%
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "length", PD_baseline_last100, PD_gene_baseline_length_T)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "midline", PD_baseline_last100, PD_gene_baseline_midline_T)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "width", PD_baseline_last100, PD_gene_baseline_width_T)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "morphwidth", PD_baseline_last100, PD_gene_baseline_morphwidth_T)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "area", PD_baseline_last100, PD_gene_baseline_area_T)

TTest_Gene(PD_baseline_last100["Genotype"].unique(), "speed_OffFood",
           PD_baseline_last100_OffFood, PD_gene_baseline_speed_T_OffFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "angularspeed_OffFood",
           PD_baseline_last100_OffFood, PD_gene_baseline_angularspeed_T_OffFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "bias_OffFood",
           PD_baseline_last100_OffFood, PD_gene_baseline_bias_T_OffFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "curve_OffFood",
           PD_baseline_last100_OffFood, PD_gene_baseline_curve_T_OffFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "crab_OffFood",
           PD_baseline_last100_OffFood, PD_gene_baseline_crab_T_OffFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "kink_OffFood",
           PD_baseline_last100_OffFood, PD_gene_baseline_kink_T_OffFood)

TTest_Gene(PD_baseline_last100["Genotype"].unique(), "speed_OnFood",
           PD_baseline_last100_OnFood, PD_gene_baseline_speed_T_OnFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "angularspeed_OnFood",
           PD_baseline_last100_OnFood, PD_gene_baseline_angularspeed_T_OnFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "bias_OnFood",
           PD_baseline_last100_OnFood, PD_gene_baseline_bias_T_OnFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "curve_OnFood",
           PD_baseline_last100_OnFood, PD_gene_baseline_curve_T_OnFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "crab_OnFood",
           PD_baseline_last100_OnFood, PD_gene_baseline_crab_T_OnFood)
TTest_Gene(PD_baseline_last100["Genotype"].unique(), "kink_OnFood",
           PD_baseline_last100_OnFood, PD_gene_baseline_kink_T_OnFood)
# Out:
#                Genotype     length
# 0         acr-12(ok367) -65.795785
# 1         acr-3(ok2049) -37.043382
# 2         acr-6(ok3117)   3.747528
# 3         acr-8(ok1240) -10.311611
# 4    Y18D10A.22(ok3535) -82.271239
# ..                  ...        ...
# 103    C29E4.10(ok2752) -16.786142
# 104        bas-1(tm351) -68.297877
# 105        cat-1(e1111) -43.414009
# 106        cat-1(ok411) -69.043898
# 107        cat-2(e1112) -40.455176
#
# [108 rows x 2 columns]
#                Genotype     midline
# 0         acr-12(ok367)  -49.604534
# 1         acr-3(ok2049)  -22.706991
# 2         acr-6(ok3117)  -28.960398
# 3         acr-8(ok1240)   15.461441
# 4    Y18D10A.22(ok3535) -163.990440
# ..                  ...         ...
# 103    C29E4.10(ok2752)  -25.452567
# 104        bas-1(tm351)  -90.660760
# 105        cat-1(e1111)  -63.240669
# 106        cat-1(ok411) -107.303969
# 107        cat-2(e1112)  -25.973586
#
# [108 rows x 2 columns]
#                Genotype      width
# 0         acr-12(ok367)  46.585798
# 1         acr-3(ok2049)  32.368522
# 2         acr-6(ok3117) -26.635481
# 3         acr-8(ok1240)  27.732318
# 4    Y18D10A.22(ok3535) -87.655591
# ..                  ...        ...
# 103    C29E4.10(ok2752)   3.072019
# 104        bas-1(tm351) -16.143131
# 105        cat-1(e1111) -16.861975
# 106        cat-1(ok411) -32.135801
# 107        cat-2(e1112)  29.940704
#
# [108 rows x 2 columns]
#                Genotype  morphwidth
# 0         acr-12(ok367)   52.972338
# 1         acr-3(ok2049)   31.915839
# 2         acr-6(ok3117)   44.051943
# 3         acr-8(ok1240)   -7.486829
# 4    Y18D10A.22(ok3535) -110.009994
# ..                  ...         ...
# 103    C29E4.10(ok2752)   29.910115
# 104        bas-1(tm351) -100.167942
# 105        cat-1(e1111)  -61.816064
# 106        cat-1(ok411)  -95.198297
# 107        cat-2(e1112)    8.152391
#
# [108 rows x 2 columns]
#                Genotype        area
# 0         acr-12(ok367)   11.806199
# 1         acr-3(ok2049)   11.142785
# 2         acr-6(ok3117)   48.420136
# 3         acr-8(ok1240)  -13.008010
# 4    Y18D10A.22(ok3535) -169.453957
# ..                  ...         ...
# 103    C29E4.10(ok2752)   23.093364
# 104        bas-1(tm351) -168.126790
# 105        cat-1(e1111) -131.805804
# 106        cat-1(ok411) -159.618161
# 107        cat-2(e1112)  -26.722992
#
# [108 rows x 2 columns]
#                Genotype  speed_OffFood
# 0         acr-12(ok367)       9.369826
# 1         acr-3(ok2049)     -12.608866
# 2         acr-6(ok3117)     -66.163439
# 3         acr-8(ok1240)     -46.093920
# 4    Y18D10A.22(ok3535)     -62.069587
# ..                  ...            ...
# 103    C29E4.10(ok2752)     -35.669840
# 104        bas-1(tm351)     -20.091231
# 105        cat-1(e1111)    -121.104199
# 106        cat-1(ok411)     -34.319378
# 107        cat-2(e1112)       6.366553
#
# [108 rows x 2 columns]
#                Genotype  angularspeed_OffFood
# 0         acr-12(ok367)             30.589735
# 1         acr-3(ok2049)             14.106675
# 2         acr-6(ok3117)            -37.275543
# 3         acr-8(ok1240)            -11.794497
# 4    Y18D10A.22(ok3535)            -45.270695
# ..                  ...                   ...
# 103    C29E4.10(ok2752)             -6.386035
# 104        bas-1(tm351)             -0.266234
# 105        cat-1(e1111)            -47.018506
# 106        cat-1(ok411)             -7.719141
# 107        cat-2(e1112)             17.989218
#
# [108 rows x 2 columns]
#                Genotype  bias_OffFood
# 0         acr-12(ok367)    -12.220690
# 1         acr-3(ok2049)     -4.720580
# 2         acr-6(ok3117)     12.791614
# 3         acr-8(ok1240)     -0.331928
# 4    Y18D10A.22(ok3535)     11.797049
# ..                  ...           ...
# 103    C29E4.10(ok2752)    -11.928263
# 104        bas-1(tm351)     -7.608348
# 105        cat-1(e1111)    -33.544533
# 106        cat-1(ok411)     -0.351032
# 107        cat-2(e1112)    -15.717280
#
# [108 rows x 2 columns]
#                Genotype  curve_OffFood
# 0         acr-12(ok367)       3.956345
# 1         acr-3(ok2049)       6.485939
# 2         acr-6(ok3117)     -45.046132
# 3         acr-8(ok1240)      30.332552
# 4    Y18D10A.22(ok3535)     -52.609643
# ..                  ...            ...
# 103    C29E4.10(ok2752)      -3.321696
# 104        bas-1(tm351)       9.538307
# 105        cat-1(e1111)     -31.534859
# 106        cat-1(ok411)     -50.045189
# 107        cat-2(e1112)       7.384935
#
# [108 rows x 2 columns]
#                Genotype  crab_OffFood
# 0         acr-12(ok367)     26.077685
# 1         acr-3(ok2049)      8.567561
# 2         acr-6(ok3117)    -59.411478
# 3         acr-8(ok1240)    -20.354509
# 4    Y18D10A.22(ok3535)    -55.092772
# ..                  ...           ...
# 103    C29E4.10(ok2752)    -18.085303
# 104        bas-1(tm351)    -17.514100
# 105        cat-1(e1111)    -79.908179
# 106        cat-1(ok411)    -29.048417
# 107        cat-2(e1112)     16.957757
#
# [108 rows x 2 columns]
#                Genotype  kink_OffFood
# 0         acr-12(ok367)     16.403126
# 1         acr-3(ok2049)     15.618369
# 2         acr-6(ok3117)    -27.398300
# 3         acr-8(ok1240)     11.261223
# 4    Y18D10A.22(ok3535)    -41.013208
# ..                  ...           ...
# 103    C29E4.10(ok2752)      1.034836
# 104        bas-1(tm351)      1.125326
# 105        cat-1(e1111)      9.588432
# 106        cat-1(ok411)      0.395679
# 107        cat-2(e1112)     13.971566
#
# [108 rows x 2 columns]
#                Genotype  speed_OnFood
# 0         acr-12(ok367)    -29.235117
# 1         acr-3(ok2049)     19.128954
# 2         acr-6(ok3117)    -35.851747
# 3         acr-8(ok1240)     -6.815147
# 4    Y18D10A.22(ok3535)    -69.905699
# ..                  ...           ...
# 103    C29E4.10(ok2752)    -57.058032
# 104        bas-1(tm351)     38.485659
# 105        cat-1(e1111)   -133.216262
# 106        cat-1(ok411)    -18.759246
# 107        cat-2(e1112)     92.690825
#
# [108 rows x 2 columns]
#                Genotype  angularspeed_OnFood
# 0         acr-12(ok367)            27.814248
# 1         acr-3(ok2049)            24.895842
# 2         acr-6(ok3117)           -37.423979
# 3         acr-8(ok1240)            11.352614
# 4    Y18D10A.22(ok3535)           -28.897386
# ..                  ...                  ...
# 103    C29E4.10(ok2752)           -12.269337
# 104        bas-1(tm351)            28.921645
# 105        cat-1(e1111)           -49.896236
# 106        cat-1(ok411)             6.280476
# 107        cat-2(e1112)            60.116523
#
# [108 rows x 2 columns]
#                Genotype  bias_OnFood
# 0         acr-12(ok367)   -37.239018
# 1         acr-3(ok2049)    12.650964
# 2         acr-6(ok3117)   -28.161822
# 3         acr-8(ok1240)     1.397285
# 4    Y18D10A.22(ok3535)   -34.761913
# ..                  ...          ...
# 103    C29E4.10(ok2752)   -18.446675
# 104        bas-1(tm351)     8.587913
# 105        cat-1(e1111)  -109.562209
# 106        cat-1(ok411)   -38.613302
# 107        cat-2(e1112)     1.363693
#
# [108 rows x 2 columns]
#                Genotype  curve_OnFood
# 0         acr-12(ok367)     12.298642
# 1         acr-3(ok2049)     41.106334
# 2         acr-6(ok3117)    -52.247338
# 3         acr-8(ok1240)     36.936302
# 4    Y18D10A.22(ok3535)    -46.385133
# ..                  ...           ...
# 103    C29E4.10(ok2752)    -20.751424
# 104        bas-1(tm351)     12.931516
# 105        cat-1(e1111)    -47.975709
# 106        cat-1(ok411)    -32.096598
# 107        cat-2(e1112)     30.490394
#
# [108 rows x 2 columns]
#                Genotype  crab_OnFood
# 0         acr-12(ok367)    21.087994
# 1         acr-3(ok2049)    30.343861
# 2         acr-6(ok3117)   -29.366866
# 3         acr-8(ok1240)     6.282188
# 4    Y18D10A.22(ok3535)   -35.433437
# ..                  ...          ...
# 103    C29E4.10(ok2752)   -26.555313
# 104        bas-1(tm351)    24.851370
# 105        cat-1(e1111)   -70.248086
# 106        cat-1(ok411)    -1.365754
# 107        cat-2(e1112)    76.073914
#
# [108 rows x 2 columns]
#                Genotype  kink_OnFood
# 0         acr-12(ok367)    43.051062
# 1         acr-3(ok2049)    23.679468
# 2         acr-6(ok3117)   -24.047690
# 3         acr-8(ok1240)    26.921067
# 4    Y18D10A.22(ok3535)   -17.899889
# ..                  ...          ...
# 103    C29E4.10(ok2752)     5.802926
# 104        bas-1(tm351)     7.523537
# 105        cat-1(e1111)     8.102297
# 106        cat-1(ok411)    13.395560
# 107        cat-2(e1112)    16.039742
#
# [108 rows x 2 columns]

# %% [markdown]
# ### 5.2.8 - Combine all dataframes generated in step 5.2.7

# %%
PD_gene_baseline_Tstats = PD_gene_baseline_length_T
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_midline_T.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_width_T.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_morphwidth_T.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_area_T.iloc[:,1])

PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_speed_T_OffFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_angularspeed_T_OffFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_bias_T_OffFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_curve_T_OffFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_crab_T_OffFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_kink_T_OffFood.iloc[:,1])

PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_speed_T_OnFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_angularspeed_T_OnFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_bias_T_OnFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_curve_T_OnFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_crab_T_OnFood.iloc[:,1])
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.join(PD_gene_baseline_kink_T_OnFood.iloc[:,1])

PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.set_index("Genotype")
print(PD_gene_baseline_Tstats)
# Out:
#                        length     midline      width  morphwidth        area  \
# Genotype
# acr-12(ok367)      -65.795785  -49.604534  46.585798   52.972338   11.806199
# acr-3(ok2049)      -37.043382  -22.706991  32.368522   31.915839   11.142785
# acr-6(ok3117)        3.747528  -28.960398 -26.635481   44.051943   48.420136
# acr-8(ok1240)      -10.311611   15.461441  27.732318   -7.486829  -13.008010
# Y18D10A.22(ok3535) -82.271239 -163.990440 -87.655591 -110.009994 -169.453957
# ...                       ...         ...        ...         ...         ...
# C29E4.10(ok2752)   -16.786142  -25.452567   3.072019   29.910115   23.093364
# bas-1(tm351)       -68.297877  -90.660760 -16.143131 -100.167942 -168.126790
# cat-1(e1111)       -43.414009  -63.240669 -16.861975  -61.816064 -131.805804
# cat-1(ok411)       -69.043898 -107.303969 -32.135801  -95.198297 -159.618161
# cat-2(e1112)       -40.455176  -25.973586  29.940704    8.152391  -26.722992
#
#                     speed_OffFood  angularspeed_OffFood  bias_OffFood  \
# Genotype
# acr-12(ok367)            9.369826             30.589735    -12.220690
# acr-3(ok2049)          -12.608866             14.106675     -4.720580
# acr-6(ok3117)          -66.163439            -37.275543     12.791614
# acr-8(ok1240)          -46.093920            -11.794497     -0.331928
# Y18D10A.22(ok3535)     -62.069587            -45.270695     11.797049
# ...                           ...                   ...           ...
# C29E4.10(ok2752)       -35.669840             -6.386035    -11.928263
# bas-1(tm351)           -20.091231             -0.266234     -7.608348
# cat-1(e1111)          -121.104199            -47.018506    -33.544533
# cat-1(ok411)           -34.319378             -7.719141     -0.351032
# cat-2(e1112)             6.366553             17.989218    -15.717280
#
#                     curve_OffFood  crab_OffFood  kink_OffFood  speed_OnFood  \
# Genotype
# acr-12(ok367)            3.956345     26.077685     16.403126    -29.235117
# acr-3(ok2049)            6.485939      8.567561     15.618369     19.128954
# acr-6(ok3117)          -45.046132    -59.411478    -27.398300    -35.851747
# acr-8(ok1240)           30.332552    -20.354509     11.261223     -6.815147
# Y18D10A.22(ok3535)     -52.609643    -55.092772    -41.013208    -69.905699
# ...                           ...           ...           ...           ...
# C29E4.10(ok2752)        -3.321696    -18.085303      1.034836    -57.058032
# bas-1(tm351)             9.538307    -17.514100      1.125326     38.485659
# cat-1(e1111)           -31.534859    -79.908179      9.588432   -133.216262
# cat-1(ok411)           -50.045189    -29.048417      0.395679    -18.759246
# cat-2(e1112)             7.384935     16.957757     13.971566     92.690825
#
#                     angularspeed_OnFood  bias_OnFood  curve_OnFood  \
# Genotype
# acr-12(ok367)                 27.814248   -37.239018     12.298642
# acr-3(ok2049)                 24.895842    12.650964     41.106334
# acr-6(ok3117)                -37.423979   -28.161822    -52.247338
# acr-8(ok1240)                 11.352614     1.397285     36.936302
# Y18D10A.22(ok3535)           -28.897386   -34.761913    -46.385133
# ...                                 ...          ...           ...
# C29E4.10(ok2752)             -12.269337   -18.446675    -20.751424
# bas-1(tm351)                  28.921645     8.587913     12.931516
# cat-1(e1111)                 -49.896236  -109.562209    -47.975709
# cat-1(ok411)                   6.280476   -38.613302    -32.096598
# cat-2(e1112)                  60.116523     1.363693     30.490394
#
#                     crab_OnFood  kink_OnFood
# Genotype
# acr-12(ok367)         21.087994    43.051062
# acr-3(ok2049)         30.343861    23.679468
# acr-6(ok3117)        -29.366866   -24.047690
# acr-8(ok1240)          6.282188    26.921067
# Y18D10A.22(ok3535)   -35.433437   -17.899889
# ...                         ...          ...
# C29E4.10(ok2752)     -26.555313     5.802926
# bas-1(tm351)          24.851370     7.523537
# cat-1(e1111)         -70.248086     8.102297
# cat-1(ok411)          -1.365754    13.395560
# cat-2(e1112)          76.073914    16.039742
#
# [108 rows x 17 columns]

# %% [markdown]
# ### 5.2.9 - Standardize and normalize t-scores

# %%
# PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.dropna().sort_index()

# PD_gene_baseline_Tstats_standardize = (PD_gene_baseline_Tstats - PD_gene_baseline_Tstats.mean())/PD_gene_baseline_Tstats.std()
# print(PD_gene_baseline_Tstats_standardize)

# PD_gene_baseline_Tstats_normalize = PD_gene_baseline_Tstats_standardize - PD_gene_baseline_Tstats_standardize[PD_gene_baseline_Tstats_standardize.index == 'N2'].squeeze()
# print('-'*45)
# print(PD_gene_baseline_Tstats_normalize)
# PD_gene_baseline_Tstats_normalize = PD_gene_baseline_Tstats_normalize.drop(index = 'N2')
# print('-'*45)
# print(PD_gene_baseline_Tstats_normalize)

# %% [markdown]
# ## 5.3 - Generate phenotype heatmap with all measures

# %% [markdown]
# ### 5.3.1A - Combine dataframe containing morphology and behaviour t-scores with dataframe containing difference of difference scores

# %%
# full_heatmap_normalized = PD_gene_baseline_Tstats_normalize.join(PD_gene_behavioural_scores_normalize)

# # Save the merged DataFrame as a CSV file to a specific directory
# full_heatmap_normalized.to_csv('C:\\Users\\chris\\Desktop\\Rankin_Lab\\valid_data\\phenotype_heatmap_normalized_dataframe.csv', index=True)

# print(full_heatmap_normalized)

# %% [markdown]
# ### 5.3.1B - Combine dataframe containing morphology and behaviour raw scores (t-statistics) with dataframe containing difference of difference scores

# %%
PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.dropna().sort_index()
# PD_gene_baseline_Tstats = PD_gene_baseline_Tstats.drop(index = 'N2')
PD_gene_behavioural_scores = PD_gene_behavioural_scores.dropna().sort_index()

phenotype_heatmap_dataframe = PD_gene_baseline_Tstats.join(PD_gene_behavioural_scores)

# Save the merged DataFrame as a CSV file to a specific directory
phenotype_heatmap_dataframe.to_csv('C:\\Users\\chris\\Desktop\\Rankin_Lab\\valid_data\\phenotype_heatmap_dataframe.csv', index=True)

print(phenotype_heatmap_dataframe.shape)
print(phenotype_heatmap_dataframe)
# Out:
# (107, 23)
#                       length     midline      width  morphwidth        area  \
# Genotype
# C29E4.10(ok2752)  -16.786142  -25.452567   3.072019   29.910115   23.093364
# F53B2.5(ok226)    -51.029134  -78.474989 -14.817783   21.450837  -18.114356
# N2                  0.000000    0.000000   0.000000    0.000000    0.000000
# R07G3.8(tm5683)   -10.779684  -51.494920 -42.339794   -2.451845   -8.991483
# SSSD1.1(ok1527)   -77.811690  -96.931289   5.307536   23.041070  -51.953493
# ...                      ...         ...        ...         ...         ...
# unc-10(ad591)    -129.229398 -100.825461  22.402661   44.109534  -74.077143
# unc-57(e406)     -120.398214 -133.901162 -45.671103  -16.678132 -223.784115
# unc-57(ok310)    -148.969522 -170.311405 -44.692854  -27.024595 -266.848999
# vps-35(hu68)      -63.483496  -97.981472 -54.904084  -98.850119 -138.096408
# vps-35(ok1880)   -125.510462 -174.169471 -78.421121 -127.362521 -231.321896
#
#                   speed_OffFood  angularspeed_OffFood  bias_OffFood  \
# Genotype
# C29E4.10(ok2752)     -35.669840             -6.386035    -11.928263
# F53B2.5(ok226)       -48.654369             -0.702849    -13.606677
# N2                     0.000000              0.000000      0.000000
# R07G3.8(tm5683)      -42.644460            -32.268041      3.996838
# SSSD1.1(ok1527)      -23.477830             15.218604    -14.954337
# ...                         ...                   ...           ...
# unc-10(ad591)       -139.947234             -0.637343    -14.266759
# unc-57(e406)        -115.676240              1.892615    -15.342211
# unc-57(ok310)       -255.859904            -34.566353    -53.755498
# vps-35(hu68)        -158.543111            -62.607321    -31.889422
# vps-35(ok1880)      -135.040681            -42.527068    -18.911249
#
#                   curve_OffFood  crab_OffFood  kink_OffFood  speed_OnFood  \
# Genotype
# C29E4.10(ok2752)      -3.321696    -18.085303      1.034836    -57.058032
# F53B2.5(ok226)         2.601134    -18.643178      8.371295    -48.164731
# N2                     0.000000      0.000000      0.000000      0.000000
# R07G3.8(tm5683)      -64.246560    -58.434130    -25.889548    -86.249053
# SSSD1.1(ok1527)        4.325631     -0.800416     11.754119    -12.807988
# ...                         ...           ...           ...           ...
# unc-10(ad591)         23.288155    -34.310051     24.942923    -48.536923
# unc-57(e406)          -7.964258    -56.824523     -0.706323   -108.880142
# unc-57(ok310)        -20.507050   -119.836637      4.953996    -77.901522
# vps-35(hu68)         -39.814583    -95.149842     -4.641228    -70.730071
# vps-35(ok1880)       -49.544648    -79.338725     -5.716805    -60.562093
#
#                   angularspeed_OnFood  bias_OnFood  curve_OnFood  crab_OnFood  \
# Genotype
# C29E4.10(ok2752)           -12.269337   -18.446675    -20.751424   -26.555313
# F53B2.5(ok226)             -16.583580    -8.596799     -9.674243   -22.081033
# N2                           0.000000     0.000000      0.000000     0.000000
# R07G3.8(tm5683)            -38.344296   -63.021548    -59.061469   -65.057121
# SSSD1.1(ok1527)              6.301452    -6.392243     -6.364046    -7.426552
# ...                               ...          ...           ...          ...
# unc-10(ad591)                6.404838   -14.471581     36.791107     0.077122
# unc-57(e406)                 5.072130   -39.126464     -9.990211   -23.242092
# unc-57(ok310)                4.728782   -19.377938     -3.733326   -29.052648
# vps-35(hu68)               -16.663004   -59.812021    -30.166743   -21.536965
# vps-35(ok1880)              -5.543926   -26.068631    -36.243808   -29.874350
#
#                   kink_OnFood     speed  angularspeed      bias     curve  \
# Genotype
# C29E4.10(ok2752)     5.802926  0.000000      0.000000  0.000000  0.000000
# F53B2.5(ok226)      -5.847698 -0.033239      1.951916 -0.228096 -0.216502
# N2                   0.000000 -0.001854      0.507095 -0.119685 -2.745252
# R07G3.8(tm5683)     -6.444493  0.010444     -2.188713  0.373429 -3.222969
# SSSD1.1(ok1527)      2.496090 -0.016286      2.189510 -0.176071 -1.009507
# ...                       ...       ...           ...       ...       ...
# unc-10(ad591)       19.125080 -0.078611     -1.308816  0.079745 -6.014647
# unc-57(e406)         6.100652 -0.096587      3.909834 -0.100012 -5.533572
# unc-57(ok310)       11.579987 -0.117489    -10.417054 -0.350575 -6.964731
# vps-35(hu68)        -6.863453 -0.084805     -7.347036  0.098826 -2.931656
# vps-35(ok1880)      -2.527753 -0.075392     -5.905257 -0.069245 -4.511078
#
#                       crab      kink
# Genotype
# C29E4.10(ok2752)  0.000000  0.000000
# F53B2.5(ok226)   -0.001749  9.466691
# N2                0.001726  1.435259
# R07G3.8(tm5683)  -0.003392 -4.736515
# SSSD1.1(ok1527)   0.001448  4.130939
# ...                    ...       ...
# unc-10(ad591)    -0.005355 -1.397503
# unc-57(e406)     -0.010855 -4.778179
# unc-57(ok310)    -0.012083 -3.452003
# vps-35(hu68)     -0.010809  2.505893
# vps-35(ok1880)   -0.007920 -0.683573
#
# [107 rows x 23 columns]

# %% [markdown]
# ### Bonus: combine alleles of the same gene into a single gene, taking the average of all the allele data for that single gene (and remove allele name from genotype column)

# %%
phenotype_heatmap_dataframe = pd.read_csv('phenotype_heatmap_dataframe.csv')

# Split the 'Genotype' column into 'Gene' and 'Allele'
phenotype_heatmap_dataframe[['Gene', 'Allele']] = phenotype_heatmap_dataframe['Genotype'].str.split('(', expand=True)

# Remove the trailing ')' from the 'Allele' column
phenotype_heatmap_dataframe['Allele'] = phenotype_heatmap_dataframe['Allele'].str.rstrip(')')

# Step 3: Group by 'Gene' and calculate the mean for each group
phenotype_heatmap_dataframe = phenotype_heatmap_dataframe.groupby('Gene').mean()

phenotype_heatmap_dataframe.to_csv('C:\\Users\\chris\\Desktop\\Rankin_Lab\\valid_data\\phenotype_heatmap_dataframe.csv', index=True)
print(phenotype_heatmap_dataframe.shape)
print(phenotype_heatmap_dataframe)
# Out:
# (64, 23)
#               length     midline      width  morphwidth        area  \
# Gene
# C29E4.10  -16.786142  -25.452567   3.072019   29.910115   23.093364
# F53B2.5   -51.029134  -78.474989 -14.817783   21.450837  -18.114356
# N2          0.000000    0.000000   0.000000    0.000000    0.000000
# R07G3.8   -10.779684  -51.494920 -42.339794   -2.451845   -8.991483
# SSSD1.1   -77.811690  -96.931289   5.307536   23.041070  -51.953493
# ...              ...         ...        ...         ...         ...
# snb-7     -77.511795 -116.602234 -30.042112  -84.400075 -164.066444
# tag-138     6.893976   12.487811  -2.391608  -24.460192  -17.078462
# unc-10   -129.229398 -100.825461  22.402661   44.109534  -74.077143
# unc-57   -134.683868 -152.106283 -45.181979  -21.851364 -245.316557
# vps-35    -94.496979 -136.075472 -66.662602 -113.106320 -184.709152
#
#           speed_OffFood  angularspeed_OffFood  bias_OffFood  curve_OffFood  \
# Gene
# C29E4.10     -35.669840             -6.386035    -11.928263      -3.321696
# F53B2.5      -48.654369             -0.702849    -13.606677       2.601134
# N2             0.000000              0.000000      0.000000       0.000000
# R07G3.8      -42.644460            -32.268041      3.996838     -64.246560
# SSSD1.1      -23.477830             15.218604    -14.954337       4.325631
# ...                 ...                   ...           ...            ...
# snb-7        -64.591126            -11.200202    -25.837638      -3.041451
# tag-138      -25.181509            -12.248241    -15.872816      -5.838013
# unc-10      -139.947234             -0.637343    -14.266759      23.288155
# unc-57      -185.768072            -16.336869    -34.548855     -14.235654
# vps-35      -146.791896            -52.567194    -25.400336     -44.679616
#
#           crab_OffFood  kink_OffFood  speed_OnFood  angularspeed_OnFood  \
# Gene
# C29E4.10    -18.085303      1.034836    -57.058032           -12.269337
# F53B2.5     -18.643178      8.371295    -48.164731           -16.583580
# N2            0.000000      0.000000      0.000000             0.000000
# R07G3.8     -58.434130    -25.889548    -86.249053           -38.344296
# SSSD1.1      -0.800416     11.754119    -12.807988             6.301452
# ...                ...           ...           ...                  ...
# snb-7       -36.063718      3.259236    -94.261624           -31.463244
# tag-138     -28.817822      1.343799    -68.581005           -28.059880
# unc-10      -34.310051     24.942923    -48.536923             6.404838
# unc-57      -88.330580      2.123837    -93.390832             4.900456
# vps-35      -87.244283     -5.179016    -65.646082           -11.103465
#
#           bias_OnFood  curve_OnFood  crab_OnFood  kink_OnFood     speed  \
# Gene
# C29E4.10   -18.446675    -20.751424   -26.555313     5.802926  0.000000
# F53B2.5     -8.596799     -9.674243   -22.081033    -5.847698 -0.033239
# N2           0.000000      0.000000     0.000000     0.000000 -0.001854
# R07G3.8    -63.021548    -59.061469   -65.057121    -6.444493  0.010444
# SSSD1.1     -6.392243     -6.364046    -7.426552     2.496090 -0.016286
# ...               ...           ...          ...          ...       ...
# snb-7      -58.334460    -19.981834   -40.159842     4.855494 -0.017742
# tag-138    -20.693435     -5.625102   -37.062447    16.392268  0.019186
# unc-10     -14.471581     36.791107     0.077122    19.125080 -0.078611
# unc-57     -29.252201     -6.861769   -26.147370     8.840320 -0.107038
# vps-35     -42.940326    -33.205276   -25.705657    -4.695603 -0.080099
#
#           angularspeed      bias     curve      crab      kink
# Gene
# C29E4.10      0.000000  0.000000  0.000000  0.000000  0.000000
# F53B2.5       1.951916 -0.228096 -0.216502 -0.001749  9.466691
# N2            0.507095 -0.119685 -2.745252  0.001726  1.435259
# R07G3.8      -2.188713  0.373429 -3.222969 -0.003392 -4.736515
# SSSD1.1       2.189510 -0.176071 -1.009507  0.001448  4.130939
# ...                ...       ...       ...       ...       ...
# snb-7        -0.084851  0.000809 -0.745456 -0.003154 -0.896371
# tag-138       0.314901 -0.064055 -2.562783 -0.000808 -3.988527
# unc-10       -1.308816  0.079745 -6.014647 -0.005355 -1.397503
# unc-57       -3.253610 -0.225294 -6.249151 -0.011469 -4.115091
# vps-35       -6.626146  0.014791 -3.721367 -0.009365  0.911160
#
# [64 rows x 23 columns]
# C:\Users\chris\AppData\Local\Temp\ipykernel_43972\3985560354.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   phenotype_heatmap_dataframe = phenotype_heatmap_dataframe.groupby('Gene').mean()

# %% [markdown]
# ### 5.3.2 - Produce and save heatmap

# %% [markdown]
# #### 5.3.2A - Heatmap of raw data

# %%
sns.set_context('notebook')
plt.figure(figsize = (20,14))
plt.rc('xtick', labelsize = 16)
plt.rc('ytick', labelsize = 16) 
ax = sns.heatmap(data = full_heatmap, 
                 annot = False, 
                 linewidth = 0.5, 
                 square = True, 
                 cmap = "vlag", 
                 center = 0, 
                 vmax = 150, # full_heatmap max = 236.046
                 vmin = -150, # full_heatmap min = -446.724
                 # xticklabels = 1,
                 xticklabels = ['Length', 'Midline', 'Width', 'Morphwidth', 'Area',
                                'Speed (Off Food)', 'Angular Speed (Off Food)', 'Bias (Off Food)',
                                'Curve (Off Food)', 'Crab (Off Food)', 'Kink (Off Food)',
                                'Speed (On Food)', 'Angular Speed (On Food)', 'Bias (On Food)',
                                'Curve (On Food)', 'Crab (On Food)', 'Kink (On Food)',
                                'Speed (Difference)', 'Angular Speed (Difference)', 'Bias (Difference)',
                                'Curve (Difference)', 'Crab (Difference)', 'Kink (Difference)'],
                 yticklabels = 1,
                 cbar_kws = {"shrink": .5,
                             # "label": "Normalized Behaviour Score"
                            })
ax.set_ylabel('Genotype', fontsize = 24)
ax.set_xlabel('Phenotype', fontsize = 24)
ax.set_title('Phenotype Heatmap', fontsize = 24)
# plt.savefig('BehaviourScore_GENE_normalized2_square.jpg', format='jpg', dpi=450, bbox_inches = "tight")
plt.savefig('Complete_GENE_heatmap_square.jpg', format = 'jpg', dpi = 450, bbox_inches = "tight")
plt.show()

# %% [markdown]
# #### Heatmap of normalized t-score data

# %%
sns.set_context('notebook')
plt.figure(figsize = (20,14))
plt.rc('xtick', labelsize = 16)
plt.rc('ytick', labelsize = 16) 
ax = sns.heatmap(data = full_heatmap_normalized, 
                 annot = False, 
                 linewidth = 0.5, 
                 square = True, 
                 cmap = "vlag", 
                 center = 0, 
                 vmax = 3,
                 vmin = -3, 
                 # xticklabels = 1,
                 xticklabels = ['Length', 'Midline', 'Width', 'Morphwidth', 'Area',
                                'Speed (Off Food)', 'Angular Speed (Off Food)', 'Bias (Off Food)',
                                'Curve (Off Food)', 'Crab (Off Food)', 'Kink (Off Food)',
                                'Speed (On Food)', 'Angular Speed (On Food)', 'Bias (On Food)',
                                'Curve (On Food)', 'Crab (On Food)', 'Kink (On Food)',
                                'Speed (Difference)', 'Angular Speed (Difference)', 'Bias (Difference)',
                                'Curve (Difference)', 'Crab (Difference)', 'Kink (Difference)'],
                 yticklabels = 1,
                 cbar_kws = {"shrink": .5,
                             # "label": "Normalized Behaviour Score"
                            })
ax.set_ylabel('Genotype', fontsize = 24)
ax.set_xlabel('Phenotype', fontsize = 24)
ax.set_title('Phenotype Heatmap', fontsize = 24)
# plt.savefig('BehaviourScore_GENE_normalized2_square.jpg', format='jpg', dpi=450, bbox_inches = "tight")
plt.savefig('Complete_GENE_heatmap_normalized_square.jpg', format = 'jpg', dpi = 450, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Everything below not intended for large scale analysis of many strains, and include bugs that would need to be fixed (commented out so notebook can be run start to finish)

# %% [markdown]
# # Graphing Bar Graphs

# %% [markdown]
# ## Speed Barplots Comparison

# %%
# # Valid Measurement inputs(change var)
# # 1:'speed', <---
# # 2: "x",
# # 3: "y",
# # 4: "angularspeed", <-----
# # 5: "pathlength",
# # 6: "kink",  <---
# # 7: "bias", <----
# # 8: "curve", <---
# # 9: "dir",<----
# # 10: "crab",<----
# # 11: "length",<---
# # 12: "midline",<----
# # 13: "width",<----
# # 14: "morphwidth",<----
# # 15: "area"<----

# start = 200
# point = 400
# var = "area"
# chunkeddata0 = TotalConcatenated[TotalConcatenated["time"] >= start]
# chunkeddata = chunkeddata0[chunkeddata0["time"] <= point]
# chunkeddata_mean = chunkeddata.groupby(["Strain","worm"], as_index=False).mean()
# chunkeddata_mean[['Genotype', 'Treatment']] = chunkeddata_mean['Strain'].str.split(' - ', 1, expand=True)

# Title = f"{var} - {start}-{point} seconds" #<---------------- Input Here -----------------
# sns.set_context("talk")
# plt.figure(linewidth = 2.5)
# plt.figure(figsize=(15, 3))
# plt.gca().xaxis.grid(False)
# ax = sns.barplot(x="Genotype", 
#              y = var, 
#              data = chunkeddata_mean, #<--------------- Input Here -------------
#              hue = 'Treatment',
#              edgecolor="black",
#              linewidth = 2.5,
# #              seed=5,
#              ci = 95, # 'sd' for SD, '68' for SEM
#              palette = ['grey',
#                         'black'
#                        ]
#                 )
# plt.xlabel("Strain and Condition")
# # plt.ylabel("Average Speed (mm/s)")
# plt.title(Title)
# plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
# plt.savefig(f'{Title}.png', format='png', dpi=450, bbox_inches = 'tight')
# plt.show()

# %%
# Test Cell
# chunkeddata_mean

# %%
# Test Cell
# TotalConcatenated.describe()
# chunkeddata0
# chunkeddata

# %% [markdown]
# ## Bias Barplots Comparison

# %%
# point = 420
# var = "bias"
# chunkeddata0 = TotalConcatenated[TotalConcatenated["time"] >= 0]
# chunkeddata = chunkeddata0[chunkeddata0["time"] <= point]

# Title = f"{var} - First {point} seconds" #<---------------- Input Here -----------------
# sns.set_context("talk")
# plt.figure(linewidth = 2.5)
# plt.figure(figsize=(15, 5))
# plt.gca().xaxis.grid(False)
# ax = sns.barplot(x="Genotype", 
#              y = var, 
#              data = chunkeddata, #<--------------- Input Here -------------
#              hue = 'Treatment',
#              edgecolor="black",
#              linewidth = 2.5,
#              ci = None,
#              palette = ['black',
#                         'grey'
#                        ]
#                 )
# plt.xlabel("Strain and Condition")
# # plt.ylabel("Average Speed (mm/s)")
# plt.title(Title)
# plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
# # plt.savefig(f'{Title}.png', format='png', dpi=450, bbox_inches = 'tight')
# plt.show()
