# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import seaborn as sns #<- package used to plot graphs
from matplotlib import pyplot as plt #<- package used to plot graphs
from pandasgui import show
import plotly.graph_objects as go
import plotly.express as px
import os

# %%
df = pd.read_csv('/Users/Joseph/Desktop/DermBiome_Raw.csv')
gui = show(df)

# %%
df = pd.read_csv('/Users/Joseph/Desktop/DermBiome_Raw_Final.csv')
os.chdir('/Users/Joseph/Desktop')
sns.color_palette("colorblind")
sns.set(rc={'figure.figsize':(16,10)})
sns.set_context("talk")
plt.figure(linewidth = 2.5)#<- Make your figure lines THICCCC for clean display (posters)
ax = sns.relplot(x="Day",
                y="% Alive", 
                data = df,
                hue = 'Treatment',
                 style='Plate',
               dashes=False,
               markers=True,
                 col='Drug',
                 row='Concentration',
               kind="line",
                palette=['black',
                        'darkgrey',
                        'maroon',
                        'red',
                        'sienna']
                )
plt.ylabel("% Alive")#<- Y-Axis title
plt.title("")#<- Figure Title
plt.ylim(bottom = -5)
plt.savefig('Drug_Lifespan.png', format='png', dpi=450)
plt.show()

# %%
df = pd.read_csv('/Users/Joseph/Desktop/DermBiome_Raw_Total_Final.csv')
os.chdir('/Users/Joseph/Desktop')
sns.color_palette("colorblind")
sns.set_context("talk")
plt.figure(linewidth = 2.5)#<- Make your figure lines THICCCC for clean display (posters)
plt.figure(figsize=(5,20))#<- set your figure size (width, length)
ax = sns.relplot(x="Day",
                y="% Alive", 
                data = df,
                hue = 'Concentration',
               dashes=False,
               markers=True,
                 col='Drug',
               kind="line",
                palette=['black',
                        'darkgrey',
                        'blueviolet',
                        'mediumblue',
                        'dodgerblue',
                        'skyblue'])
plt.ylabel("% Alive")#<- Y-Axis title
plt.title("")#<- Figure Title
plt.ylim(bottom = 0)
plt.savefig('Drug_Lifespan.png', format='png', dpi=450)
plt.show()

# %%
df = pd.read_csv('/Users/Joseph/Desktop/ASH_0205_Quants.csv')
gui = show(df)

# %% [markdown]
# # Quantifications by Individual Strains

# %% [markdown]
# # Bar Graphs

# %% [markdown]
# ## Unique Object Count

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_SEM.csv')
fig = px.bar(df, 
                y='Count_Mean', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Count_Mean": "Unique Object Count, lower is better",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey'],
                error_y="Count_STDEV",
            barmode = "group")
# fig.update_traces(marker_color=['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD'], showlegend=False)
# fig.update_traces(textposition="inside", textangle=1)
# fig.update_layout(uniformtext_minsize=7, uniformtext_mode='show')
fig.show()

# %% [markdown]
# ## Total Area

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_SEM.csv')
fig = px.bar(df, 
                y='Total_Area_Mean', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Total_Area_Mean": "Total Area (uM^2), higher is better",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey'],
                error_y="Total_Area_STDEV",
            barmode = "group")
# fig.update_traces(marker_color=['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD'], showlegend=False)
# fig.update_traces(textposition="inside", textangle=1)
# fig.update_layout(uniformtext_minsize=7, uniformtext_mode='show')
fig.show()

# %% [markdown]
# ## Average Object Size

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_SEM.csv')
fig = px.bar(df, 
                y='AVG_Size_Mean', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "AVG_Size_Mean": "Average Object Size (uM^2)",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey'],
                error_y="Count_SEM",
            barmode = "group")
# fig.update_traces(marker_color=['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD'], showlegend=False)
# fig.update_traces(textposition="inside", textangle=1)
# fig.update_layout(uniformtext_minsize=7, uniformtext_mode='show')
fig.show()

# %% [markdown]
# # Boxplots

# %% [markdown]
# ## Object Count

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Long.csv')
fig = px.box(df, 
                y='Count', 
                x='Line', 
                color = 'Drug', 
                labels={
                   "Count": "Unique Object Count, lower is better",
                    "Line": "Strain"
               },
                color_discrete_sequence=['black','grey']
            )

fig.show()

# %% [markdown]
# ## Total Area

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Long.csv')
fig = px.box(df, 
                y='Total Area', 
                x='Line', 
                color = 'Drug', 
                labels={
                   "Total Area": "Total Area (uM^2), higher is better",
                    "Line": "Strain"
               },
                color_discrete_sequence=['black','grey']
            )

fig.show()

# %% [markdown]
# ## Average Object Size

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Long.csv')
fig = px.box(df, 
                y='Average Size', 
                x='Line', 
                color = 'Drug', 
                labels={
                   "Average Size": "Average Object Size",
                    "Line": "Strain"
               },
                color_discrete_sequence=['black','grey']
            )

fig.show()

# %% [markdown]
# # Quantifications Altogether

# %% [markdown]
# # Barplots

# %% [markdown]
# ## Unique Object Count

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Altogether_SEM.csv')
fig = px.bar(df, 
                y='Count_Mean', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Count_Mean": "Unique Object Count, lower is better",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey'],
                error_y="Count_STDEV",
            barmode = "group")
# fig.update_traces(marker_color=['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD'], showlegend=False)
# fig.update_traces(textposition="inside", textangle=1)
# fig.update_layout(uniformtext_minsize=7, uniformtext_mode='show')
fig.show()

# %% [markdown]
# ## Total Area

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Altogether_SEM.csv')
fig = px.bar(df, 
                y='Total_Area_Mean', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Total_Area_Mean": "Total Area (uM^2), higher is better",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey'],
                error_y="Total_Area_STDEV",
            barmode = "group")
# fig.update_traces(marker_color=['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD'], showlegend=False)
# fig.update_traces(textposition="inside", textangle=1)
# fig.update_layout(uniformtext_minsize=7, uniformtext_mode='show')
fig.show()

# %% [markdown]
# ## Unique Object Size

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Altogether_SEM.csv')
fig = px.bar(df, 
                y='AVG_Size_Mean', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "AVG_Size_Mean": "Average Object Size (uM^2)",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey'],
                error_y="Count_SEM",
            barmode = "group")
# fig.update_traces(marker_color=['#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD'], showlegend=False)
# fig.update_traces(textposition="inside", textangle=1)
# fig.update_layout(uniformtext_minsize=7, uniformtext_mode='show')
fig.show()

# %% [markdown]
# # Boxplots

# %% [markdown]
# ## Object Count

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Long.csv')
fig = px.box(df, 
                y='Count', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Count": "Unique Object Count, lower is better",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey']
            )

fig.show()

# %% [markdown]
# ## Total Area

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Long.csv')
fig = px.box(df, 
                y='Total Area', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Total Area": "Total Area (uM^2), higher is better",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey']
            )

fig.show()

# %% [markdown]
# ## Average Object Size

# %%
df = pd.read_csv('/Users/Joseph/Desktop/Quants_Long.csv')
fig = px.box(df, 
                y='Average Size', 
                x='Gene', 
                color = 'Drug', 
                labels={
                   "Average Size": "Average Object Size",
                    "Gene": "Strain"
               },
                color_discrete_sequence=['black','grey']
            )

fig.show()
