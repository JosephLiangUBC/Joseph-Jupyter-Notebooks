# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import os #<- package used to work with system filepaths
import subprocess
from ipywidgets import widgets #<- widget tool to generate button
from IPython.display import display #<- displays button
from tkinter import Tk, filedialog #<- Tkinter is a GUI package
from tqdm.notebook import tqdm

print("done step 1")
# Out:
# done step 1

# %%
### Select Folder App - After you run, you can select your folder for filepath
button = widgets.Button(description = 'Select Folder') #<- creates a button variable
display(button) #<- displays the button in output

def select_folder(b): #<- defines an action. This action requires a variable, so an arbitrary one 'b' is there
    global folder_path #<- sets a variable as a global variable, not just within this action
    #Tk().withdraw() #<- Tkinter likes to create annoying empty windows. This removes them
    folder_path = filedialog.askdirectory() #<- Opens up a file explorer window, and determines folder path
    #Tk().update() #<- below
    #Tk().destroy() #<- this and the line above it removes the file explorer window after a selection is made
    print(folder_path) #<- this helps confirm that this action was performed
    print('done step 2')
button.on_click(select_folder)
# Out:
# Button(description='Select Folder', style=ButtonStyle())
# /Volumes/JOSEPH/PD_Screen
# done step 2

# %%
print(folder_path)
# Out:
# /Volumes/JOSEPH/PD_Screen

# %%
#folder_path = '/Users/Joseph/Desktop/lrk1_ATR_NoATR_08_15_2019'
print(folder_path)
os.chdir(folder_path) #<- setting your working directory so that your images will be saved here

filelist = list() #<- empty list
for root, dirs, files in os.walk(folder_path): #<- this for loop goes through your folder 
    for name in files:
        if name.endswith('.zip'): #<- and takes out all files with a .dat (file that contains your data)
            filepath = os.path.join(root, name) #<- Notes down the file path of each data file
            filelist.append(filepath) #<- saves it into the list
    
print(filelist)
print('done step 3')
# Out:
# /Volumes/JOSEPH/PD_Screen
# ['/Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_093557.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_113141.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_091759.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_111159.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_112352.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_103216.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_104010.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_105433.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_123426.zip', '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_124913.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_110611.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_123540.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_105117.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_105933.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_124939.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_200145.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_181739.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_191217.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_193434_babies.zip', '/Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_211836.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_190557.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_190557.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_205607.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_205607.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_180925.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_180925.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_200412.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_200412.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_202529.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_202529.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_181819.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_201238.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_191913.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_194102.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_213039.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_195051.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_185808.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_204742.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_191916.zip', '/Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_210847.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_103040.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_103040.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_122029.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_122029.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_123250.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_123250.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_123505.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_123505.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_104829.zip', '/Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_104829.zip', '/Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_203346.zip', '/Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_184407.zip', '/Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_194231.zip', '/Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_200156.zip', '/Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_215121.zip', '/Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_100406.zip', '/Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_121921.zip', '/Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_110836.zip', '/Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_133646.zip', '/Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_123917.zip', '/Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_133207.zip', '/Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_133207.zip', '/Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_123554.zip', '/Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_123554.zip', '/Volumes/JOSEPH/PD_Screen/dop-1_v ...
# done step 3

# %%
# for speed
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', 
                     '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-N', 'all', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S', 
                     '-o', 'sxySPkbcdrlmwMe', 
                     f'{f}'])

# %%
# for tap habituation
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S' ,
                     '-o', 'nNss*b12xyMmeSakcr', 
                     '--plugin', 'Reoutline::exp',
                     '--plugin', 'Respine',
                     '--plugin', 'MeasureReversal::tap::dt=1::collect=0.5::postfix=trv',
                     '--plugin', 'MeasureReversal::puff::dt=3::collect=0.5::postfix=prv',
                     '--plugin', 'MeasureReversal::postfix=txt',
                     f'{f}'])
# Out:
#   0%|          | 0/370 [00:00<?, ?it/s]
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 15287 data points.
#   962 out of 13609 objects meet criteria.
# Took 16.994 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_093557/MT7988_10x2_f72h20C_600s31x10s10s_C0829bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15557 data points.
#   1038 out of 4146 objects meet criteria.
# Took 19.083 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_113141/MT7988_10x2_f72h20C_600s31x10s10s_C0829be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14408 data points.
#   1320 out of 8791 objects meet criteria.
# Took 21.689 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_091759/MT7988_10x2_f72h20C_600s31x10s10s_B0829ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 15808 data points.
#   1122 out of 9150 objects meet criteria.
# Took 17.950 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_111159/MT7988_10x2_f72h20C_600s31x10s10s_B0829bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 21229 data points.
#   997 out of 9562 objects meet criteria.
# Took 27.803 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_ad446/20220829_112352/MT7988_10x2_f96h20C_600s31x10s10s_A0829bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 15576 data points.
#   894 out of 5892 objects meet criteria.
# Took 16.245 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_103216/LC33_10x2_f72h20C_600s31x10s10s_B0809db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 28243 data points.
#   394 out of 9045 objects meet criteria.
# Took 18.426 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_104010/LC33_10x2_f96h20C_600s31x10s10s_A0809da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28456 data points.
#   615 out of 2560 objects meet criteria.
# Took 20.441 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_105433/LC33_10x2_f72h20C_600s31x10s10s_C0809dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 19961 data points.
#   624 out of 3486 objects meet criteria.
# Took 14.351 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_123426/LC33_10x2_f72h20C_600s31x10s10s_B0809de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 27888 data points.
#   698 out of 9165 objects meet criteria.
# Took 22.853 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_124913/LC33_10x2_f96h20C_600s31x10s10s_A0809dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 15210 data points.
#   995 out of 14661 objects meet criteria.
# Took 19.614 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_110611/E1111_10x2_f72h20C_600s31x10s10s_C0721dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 13700 data points.
#   707 out of 7678 objects meet criteria.
# Took 19.794 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_123540/E1111_10x2_f72h20C_600s31x10s10s_B0721de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 15388 data points.
#   543 out of 7824 objects meet criteria.
# Took 14.411 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_105117/E1111_10x2_f72h20C_600s31x10s10s_B0721db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 35 object.
#   Summary file has 19218 data points.
#   720 out of 35924 objects meet criteria.
# Took 24.284 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_105933/E1111_10x2_f96h20C_600s30x10s10s_A0721da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 28095 data points.
#   267 out of 13305 objects meet criteria.
# Took 15.342 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_e1111/20220725_124939/E1111_10x2_f96h20C_600s30x10s10s_A0721dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15709 data points.
#   721 out of 3495 objects meet criteria.
# Took 15.241 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_200145/RB681_10x2_f72h20C_600s31x10s10s_B0507ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15683 data points.
#   685 out of 4226 objects meet criteria.
# Took 14.985 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_181739/RB681_10x2_f72h20C_600s31x10s10s_B0507ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15483 data points.
#   876 out of 3577 objects meet criteria.
# Took 16.591 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_191217/RB681_10x2_f72h20C_600s31x10s10s_C0507ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 15369 data points.
#   1686 out of 15700 objects meet criteria.
# Took 27.817 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_193434_babies/RB681_10x2_f96h20C_600s30x10s10s_A0507eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28046 data points.
#   399 out of 3671 objects meet criteria.
# Took 16.574 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-1_ok411/20220511_211836/RB681_10x2_f96h20C_600s30x10s10s_A0507ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15016 data points.
#   751 out of 3865 objects meet criteria.
# Took 13.943 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_190557/CB1112_10x2_f72h20C_600s31x10s10s_B0506cb.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_190557.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 12975 data points.
#   1157 out of 6035 objects meet criteria.
# Took 15.844 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_205607/CB1112_10x2_f72h20C_600s31x10s10s_B0506ce.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_205607.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27537 data points.
#   487 out of 2605 objects meet criteria.
# Took 17.793 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_180925/CB1112_10x2_f72h20C_600s31x10s10s_C0506ca.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_180925.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27267 data points.
#   539 out of 3042 objects meet criteria.
# Took 18.853 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_200412/CB1112_10x2_f72h20C_600s31x10s10s_C0506cd.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_200412.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28072 data points.
#   420 out of 4261 objects meet criteria.
# Took 16.632 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_e1112/20220510_202529/CB1112_10x2_f96h20C_600s30x10s10s_A0506cc.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cat-2_e1112/._20220510_202529.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15599 data points.
#   586 out of 3962 objects meet criteria.
# Took 12.574 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_181819/MT15620_10x2_f72h20C_600s31x10s10s_B0506ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16114 data points.
#   633 out of 3062 objects meet criteria.
# Took 12.598 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_201238/MT15620_10x2_f72h20C_600s31x10s10s_B0506bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 24178 data points.
#   603 out of 4237 objects meet criteria.
# Took 18.129 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_191913/MT15620_10x2_f72h20C_600s31x10s10s_C0506bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 28074 data points.
#   459 out of 4519 objects meet criteria.
# Took 23.605 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_194102/MT15620_10x2_f96h20C_600s30x10s10s_A0506bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 27922 data points.
#   591 out of 5697 objects meet criteria.
# Took 24.447 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_n4547/20220510_213039/MT15620_10x2_f96h20C_600s30x10s10s_A0506be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 19795 data points.
#   386 out of 2380 objects meet criteria.
# Took 12.039 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_195051/FX17845_10x2_f72h20C_600s31x10s10s_B0506dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28909 data points.
#   369 out of 2090 objects meet criteria.
# Took 18.927 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_185808/FX17845_10x2_f72h20C_600s31x10s10s_C0506db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 16080 data points.
#   656 out of 5150 objects meet criteria.
# Took 15.492 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_204742/FX17845_10x2_f72h20C_600s31x10s10s_C0506de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29399 data points.
#   201 out of 3028 objects meet criteria.
# Took 11.583 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_191916/FX17845_10x2_f96h20C_600s30x10s10s_A0506da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 27721 data points.
#   564 out of 6334 objects meet criteria.
# Took 25.845 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cat-2_tm2261/20220510_210847/FX17845_10x2_f96h20C_600s30x10s10s_A0506dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15756 data points.
#   462 out of 2271 objects meet criteria.
# Took 15.148 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_103040/RB1262_10x2_f72h20C_600s31x10s10s_B0520ba.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_103040.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 23186 data points.
#   121 out of 1720 objects meet criteria.
# Took 10.955 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_122029/RB1262_10x2_f72h20C_600s31x10s10s_B0520bd.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_122029.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 29278 data points.
#   100 out of 4674 objects meet criteria.
# Took 11.960 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_123250/RB1262_10x2_f96h20C_600s30x10s10s_A0520bc.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_123250.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29409 data points.
#   173 out of 1610 objects meet criteria.
# Took 13.244 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_123505/RB1262_10x2_f72h20C_600s31x10s10s_C0520be.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_123505.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29634 data points.
#   86 out of 942 objects meet criteria.
# Took 9.228 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/20220524_104829/RB1262_10x2_f72h20C_600s31x10s10s_C0520bb.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/cpr-1_ok1344/._20220524_104829.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 13779 data points.
#   655 out of 4195 objects meet criteria.
# Took 15.559 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_203346/RM2702_10x2_f72h20C_600s31x10s10s_B0506ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 13180 data points.
#   609 out of 5150 objects meet criteria.
# Took 17.091 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_184407/RM2702_10x2_f72h20C_600s31x10s10s_B0506ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 18576 data points.
#   465 out of 3438 objects meet criteria.
# Took 16.800 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_194231/RM2702_10x2_f72h20C_600s31x10s10s_C0506ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 26969 data points.
#   591 out of 7119 objects meet criteria.
# Took 26.744 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_200156/RM2702_10x2_f96h20C_600s30x10s10s_A0506eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28527 data points.
#   205 out of 2793 objects meet criteria.
# Took 15.338 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dat-1_ok157/20220510_215121/RM2702_10x2_f96h20C_600s30x10s10s_A0506ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16185 data points.
#   427 out of 3143 objects meet criteria.
# Took 15.802 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_100406/TM1346_10x2_f72h20C_600s31x10s10s_C0623ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 24142 data points.
#   330 out of 1888 objects meet criteria.
# Took 18.581 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_121921/TM1346_10x2_f72h20C_600s31x10s10s_C0623cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15022 data points.
#   646 out of 3662 objects meet criteria.
# Took 17.578 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_110836/TM1346_10x2_f72h20C_600s31x10s10s_B0623cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 18367 data points.
#   635 out of 3163 objects meet criteria.
# Took 18.049 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_133646/TM1346_10x2_f72h20C_600s31x10s10s_B0623ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28074 data points.
#   276 out of 3044 objects meet criteria.
# Took 16.282 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/djr-1.2_tm1346/20220627_123917/TM1346_10x2_f96h20C_600s30x10s10s_A0623cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 15339 data points.
#   226 out of 1443 objects meet criteria.
# Took 9.012 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_133207/LX636_10x2_f72h20C_600s31x10s10s_B0509dc.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_133207.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29318 data points.
#   209 out of 1028 objects meet criteria.
# Took 15.834 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_123554/LX636_10x2_f72h20C_600s31x10s10s_C0509db.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_123554.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16432 data points.
#   437 out of 2747 objects meet criteria.
# Took 13.852 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_144448/LX636_10x2_f72h20C_600s31x10s10s_C0509de.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_144448.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28007 data points.
#   316 out of 3332 objects meet criteria.
# Took 29.857 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_125759/LX636_10x2_f96h20C_600s30x10s10s_A0509da.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_125759.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29740 data points.
#   109 out of 869 objects meet criteria.
# Took 10.368 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-1_vs101/20220513_150434/LX636_10x2_f96h20C_600s30x10s10s_A0509dd.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/dop-1_vs101/._20220513_150434.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15816 data points.
#   359 out of 2388 objects meet criteria.
# Took 12.288 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_ok295/20220513_122149/BZ873_10x2_f72h20C_600s31x10s10s_B0509ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 14261 data points.
#   586 out of 9158 objects meet criteria.
# Took 11.709 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_ok295/20220513_142826/BZ873_10x2_f72h20C_600s31x10s10s_B0509ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 18593 data points.
#   358 out of 4310 objects meet criteria.
# Took 12.831 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_ok295/20220513_132223/BZ873_10x2_f72h20C_600s31x10s10s_C0509ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 27686 data points.
#   349 out of 11429 objects meet criteria.
# Took 20.512 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_ok295/20220513_134516/BZ873_10x2_f96h20C_600s30x10s10s_A0509eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 23682 data points.
#   586 out of 7158 objects meet criteria.
# Took 19.876 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_ok295/20220513_155148/BZ873_10x2_f96h20C_600s30x10s10s_A0509ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27975 data points.
#   549 out of 3074 objects meet criteria.
# Took 16.571 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_tm1356/20220913_175328/FX01355_10x2_f96h20C_600s31x10s10s_A0913bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 19563 data points.
#   816 out of 4227 objects meet criteria.
# Took 17.395 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_tm1356/20220913_162106/FX01355_10x2_f72h20C_600s31x10s10s_B0913ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 14109 data points.
#   1258 out of 15524 objects meet criteria.
# Took 20.992 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_tm1356/20220913_181321/FX01355_10x2_f72h20C_600s31x10s10s_B0913bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 18410 data points.
#   801 out of 4805 objects meet criteria.
# Took 16.792 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dop-3_tm1356/20220913_193233/FX01355_10x2_f72h20C_600s31x10s10s_B0913bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29795 data points.
#   28 out of 569 objects meet criteria.
# Took 4.426 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_e652/20220725_101126/E652_10x2_f72h20C_600s31x10s10s_C0721bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29805 data points.
#   35 out of 989 objects meet criteria.
# Took 5.538 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_e652/20220725_120131/E652_10x2_f72h20C_600s31x10s10s_C0721be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 22411 data points.
#   30 out of 723 objects meet criteria.
# Took 3.713 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_e652/20220725_114415/E652_10x2_f72h20C_600s31x10s10s_B0721bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 25234 data points.
#   20 out of 166 objects meet criteria.
# Took 2.195 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_e652/20220725_095335/E652_10x2_f72h20C_600s31x10s10s_B0721ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29930 data points.
#   39 out of 903 objects meet criteria.
# Took 7.173 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_e652/20220725_115415/E652_10x2_f96h20C_600s30x10s10s_A0721bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29827 data points.
#   4 out of 32 objects meet criteria.
# Took 1.485 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_sy622/20220627_104042/SY622_10x2_f72h20C_600s31x10s10s_B0623ea.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/dpy-22_sy622/._20220627_104042.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 23033 data points.
#   143 out of 1733 objects meet criteria.
# Took 17.437 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_sy622/20220627_115234/PS4087_10x2_f72h20C_600s31x10s10s_C0623ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 28637 data points.
#   73 out of 5183 objects meet criteria.
# Took 14.992 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_sy622/20220627_121337/PS4087_10x2_f96h20C_600s30x10s10s_A0623eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 24082 data points.
#   117 out of 828 objects meet criteria.
# Took 9.605 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_sy622/20220627_131006/PS4087_10x2_f72h20C_600s31x10s10s_B0623ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29322 data points.
#   73 out of 1635 objects meet criteria.
# Took 10.369 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_sy622/20220627_144944/PS4087_10x2_f96h20C_600s30x10s10s_A0623ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 28392 data points.
#   178 out of 921 objects meet criteria.
# Took 16.545 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_tm12356/20220806_143025/FX31749_10x2_f72h20C_600s31x10s10s_C0802ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 14903 data points.
#   377 out of 2664 objects meet criteria.
# Took 17.672 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_tm12356/20220806_154417/FX31749_10x2_f72h20C_600s31x10s10s_B0802cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 27669 data points.
#   352 out of 2724 objects meet criteria.
# Took 24.019 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_tm12356/20220806_160021/FX31749_10x2_f96h20C_600s31x10s10s_A0802cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 14928 data points.
#   364 out of 2811 objects meet criteria.
# Took 11.310 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_tm12356/20220806_160501/FX31749_10x2_f72h20C_600s31x10s10s_B0802cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27626 data points.
#   298 out of 3223 objects meet criteria.
# Took 22.383 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/dpy-22_tm12356/20220806_170345/FX31749_10x2_f96h20C_600s31x10s10s_A0802ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 15264 data points.
#   684 out of 5719 objects meet criteria.
# Took 12.560 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_141642/ZE1_10x2_f72h20C_600s31x10s10s_B0520ba.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/._20220524_141642.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 13795 data points.
#   1037 out of 5422 objects meet criteria.
# Took 15.089 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_160812/ZE1_10x2_f72h20C_600s31x10s10s_B0520bd.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/._20220524_160812.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 28850 data points.
#   336 out of 6277 objects meet criteria.
# Took 13.132 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_171947/ZE1_10x2_f96h20C_600s30x10s10s_A0520be.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/._20220524_171947.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27877 data points.
#   543 out of 3652 objects meet criteria.
# Took 19.318 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_161221/ZE1_10x2_f96h20C_600s30x10s10s_A0520bc.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/._20220524_161221.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 16003 data points.
#   747 out of 3813 objects meet criteria.
# Took 13.298 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_143039/ZE1_10x2_f72h20C_600s31x10s10s_C0520bb.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/._20220524_143039.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 10168 data points.
#   1317 out of 13740 objects meet criteria.
# Took 19.410 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-1_tm3816/20220928_111511/FX03816_10x2_f72h20C_600s31x10s10s_B0928ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 11480 data points.
#   1094 out of 10838 objects meet criteria.
# Took 20.808 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-1_tm3816/20220928_125344/FX03816_10x2_f72h20C_600s31x10s10s_B0928bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 14214 data points.
#   1143 out of 10181 objects meet criteria.
# Took 25.720 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-1_tm3816/20220928_115808/FX03816_10x2_f72h20C_600s31x10s10s_C0928bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 15603 data points.
#   1091 out of 10851 objects meet criteria.
# Took 35.520 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-1_tm3816/20220928_121613/FX03816_10x2_f96h20C_600s31x10s10s_A0928bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 19186 data points.
#   509 out of 14341 objects meet criteria.
# Took 23.521 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-1_tm3816/20220928_142035/FX03816_10x2_f96h20C_600s31x10s10s_A0928be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 11408 data points.
#   1105 out of 14524 objects meet criteria.
# Took 16.901 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4623/20220928_114249/FX04623_10x2_f72h20C_600s31x10s10s_B0928ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 13274 data points.
#   1290 out of 14870 objects meet criteria.
# Took 23.189 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4623/20220928_113402/FX04623_10x2_f72h20C_600s31x10s10s_C0928ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14515 data points.
#   882 out of 7254 objects meet criteria.
# Took 20.641 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4623/20220928_131204/FX04623_10x2_f72h20C_600s31x10s10s_C0928ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 13470 data points.
#   1287 out of 15291 objects meet criteria.
# Took 27.478 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4623/20220928_115052/FX04623_10x2_f96h20C_600s31x10s10s_A0928aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 18571 data points.
#   759 out of 10021 objects meet criteria.
# Took 24.212 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4623/20220928_133054/FX04623_10x2_f96h20C_600s31x10s10s_A0928ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28030 data points.
#   275 out of 2199 objects meet criteria.
# Took 16.738 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4808/20220920_175102/FX04808_10x2_f96h20C_600s31x10s10s_A0920da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28046 data points.
#   252 out of 2060 objects meet criteria.
# Took 17.080 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4808/20220920_202535/FX04808_10x2_f96h20C_600s31x10s10s_A0920dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15809 data points.
#   484 out of 2551 objects meet criteria.
# Took 12.789 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4808/20220920_184603/FX04808_10x2_f72h20C_600s31x10s10s_B0920dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14678 data points.
#   857 out of 6091 objects meet criteria.
# Took 17.315 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4808/20220920_173136/FX04808_10x2_f72h20C_600s31x10s10s_C0920db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 27647 data points.
#   354 out of 1923 objects meet criteria.
# Took 16.757 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-2_tm4808/20220920_200259/FX04808_10x2_f72h20C_600s31x10s10s_C0920de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15886 data points.
#   422 out of 2633 objects meet criteria.
# Took 11.531 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_gk3287/20220524_115629/VC3135_10x2_f72h20C_600s31x10s10s_B0520cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 27872 data points.
#   345 out of 5443 objects meet criteria.
# Took 18.116 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_gk3287/20220524_120155/VC3135_10x2_f96h20C_600s30x10s10s_A0520cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 23725 data points.
#   667 out of 5450 objects meet criteria.
# Took 20.999 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_gk3287/20220524_134314/VC3135_10x2_f96h20C_600s30x10s10s_A0520ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 20906 data points.
#   449 out of 3465 objects meet criteria.
# Took 15.138 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_gk3287/20220524_102050/VC3135_10x2_f72h20C_600s31x10s10s_C0520ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 15424 data points.
#   585 out of 10435 objects meet criteria.
# Took 13.368 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_gk3287/20220524_121047/VC3135_10x2_f72h20C_600s31x10s10s_C0520cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 26644 data points.
#   75 out of 609 objects meet criteria.
# Took 8.063 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_tm3302/20220808_095158/TM3302_10x2_f72h20C_600s31x10s10s_B0804ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29507 data points.
#   131 out of 525 objects meet criteria.
# Took 11.158 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_tm3302/20220808_103540/TM3302_10x2_f72h20C_600s31x10s10s_C0804bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 30593 data points.
#   63 out of 936 objects meet criteria.
# Took 6.095 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_tm3302/20220808_105848/TM3302_10x2_f96h20C_600s31x10s10s_A0804bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 23510 data points.
#   179 out of 852 objects meet criteria.
# Took 9.415 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gba-3_tm3302/20220808_111234/TM3302_10x2_f72h20C_600s31x10s10s_B0804bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27897 data points.
#   389 out of 2694 objects meet criteria.
# Took 18.471 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220913_201234/FX01223_10x2_f96h20C_600s31x10s10s_A0913ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16554 data points.
#   389 out of 3164 objects meet criteria.
# Took 13.470 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220913_171419/FX01223_10x2_f72h20C_600s31x10s10s_B0913cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14782 data points.
#   584 out of 4264 objects meet criteria.
# Took 14.074 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220920_163537/FX01223_10x2_f72h20C_600s31x10s10s_B0920ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 27103 data points.
#   283 out of 2123 objects meet criteria.
# Took 16.006 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220920_180329/FX01223_10x2_f72h20C_600s31x10s10s_C0920bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27998 data points.
#   268 out of 1991 objects meet criteria.
# Took 16.544 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220920_182313/FX01223_10x2_f96h20C_600s31x10s10s_A0920bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15016 data points.
#   573 out of 3349 objects meet criteria.
# Took 12.995 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220920_191529/FX01223_10x2_f72h20C_600s31x10s10s_B0920bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 24624 data points.
#   627 out of 3854 objects meet criteria.
# Took 23.222 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1223/20220920_205248/FX01223_10x2_f96h20C_600s31x10s10s_A0920be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15121 data points.
#   753 out of 4076 objects meet criteria.
# Took 16.664 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1296/20220820_113436/EV232_10x2_f72h20C_600s31x10s10s_C0816bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15227 data points.
#   847 out of 3387 objects meet criteria.
# Took 16.456 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1296/20220820_131341/EV232_10x2_f72h20C_600s31x10s10s_C0816be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 27654 data points.
#   540 out of 6294 objects meet criteria.
# Took 22.996 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1296/20220820_131856/EV232_10x2_f96h20C_600s31x10s10s_A0816bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 14769 data points.
#   380 out of 2387 objects meet criteria.
# Took 13.327 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1296/20220820_112203/EV232_10x2_f72h20C_600s31x10s10s_B0816ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 13980 data points.
#   830 out of 5452 objects meet criteria.
# Took 15.291 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/gck-3_tm1296/20220820_130218/EV232_10x2_f72h20C_600s31x10s10s_B0816bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 29706 data points.
#   78 out of 3766 objects meet criteria.
# Took 8.214 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220726_165510/FX16792_10x2_f96h20C_600s30x10s10s_A0726bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 19777 data points.
#   218 out of 1267 objects meet criteria.
# Took 8.486 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220726_170141/FX16792_10x2_f72h20C_600s31x10s10s_B0726bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 20089 data points.
#   101 out of 346 objects meet criteria.
# Took 6.326 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220726_154437/FX16792_10x2_f72h20C_600s31x10s10s_B0726ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 19501 data points.
#   59 out of 118 objects meet criteria.
# Took 3.794 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220726_172957/FX16792_10x2_f72h20C_600s31x10s10s_B0726be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 23201 data points.
#   83 out of 226 objects meet criteria.
# Took 8.162 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220806_112406/FX16792_10x2_f72h20C_600s31x10s10s_B0802db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29624 data points.
#   87 out of 332 objects meet criteria.
# Took 8.591 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220806_113605/FX16792_10x2_f72h20C_600s31x10s10s_C0802dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29994 data points.
#   46 out of 272 objects meet criteria.
# Took 7.734 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220806_113958/FX16792_10x2_f96h20C_600s31x10s10s_A0802da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 19151 data points.
#   159 out of 465 objects meet criteria.
# Took 8.035 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220806_120635/FX16792_10x2_f72h20C_600s31x10s10s_B0802dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29631 data points.
#   78 out of 242 objects meet criteria.
# Took 8.121 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220806_121804/FX16792_10x2_f72h20C_600s31x10s10s_C0802de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29017 data points.
#   281 out of 2315 objects meet criteria.
# Took 15.935 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220809_092208/FX16792_10x2_f72h20C_600s31x10s10s_C0809ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 17956 data points.
#   311 out of 1244 objects meet criteria.
# Took 11.072 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220809_110414/FX16792_10x2_f72h20C_600s31x10s10s_B0809cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 27824 data points.
#   327 out of 13012 objects meet criteria.
# Took 18.928 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220809_111018/FX16792_10x2_f96h20C_600s31x10s10s_A0809cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16338 data points.
#   433 out of 2110 objects meet criteria.
# Took 14.653 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220809_112919/FX16792_10x2_f72h20C_600s31x10s10s_C0809cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27696 data points.
#   401 out of 4704 objects meet criteria.
# Took 20.619 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm3240/20220809_131112/FX16792_10x2_f96h20C_600s31x10s10s_A0809ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28003 data points.
#   306 out of 2035 objects meet criteria.
# Took 16.823 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm15275/20220920_185329/FX31756_10x2_f96h20C_600s31x10s10s_A0920eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28042 data points.
#   264 out of 1759 objects meet criteria.
# Took 16.281 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm15275/20220920_211502/FX31756_10x2_f96h20C_600s31x10s10s_A0920ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15454 data points.
#   507 out of 3833 objects meet criteria.
# Took 12.983 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm15275/20220920_171141/FX31756_10x2_f72h20C_600s31x10s10s_B0920ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 19442 data points.
#   284 out of 1731 objects meet criteria.
# Took 14.239 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm15275/20220920_194612/FX31756_10x2_f72h20C_600s31x10s10s_B0920ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 17067 data points.
#   429 out of 2272 objects meet criteria.
# Took 14.189 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_tm15275/20220920_183559/FX31756_10x2_f72h20C_600s31x10s10s_C0920ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 17449 data points.
#   436 out of 2033 objects meet criteria.
# Took 13.134 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_zu391/20220806_103007/JJ1271_10x2_f72h20C_600s31x10s10s_C0802ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14374 data points.
#   761 out of 5500 objects meet criteria.
# Took 14.427 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_zu391/20220806_114523/JJ1271_10x2_f72h20C_600s31x10s10s_B0802cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 19033 data points.
#   385 out of 1885 objects meet criteria.
# Took 13.494 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_zu391/20220806_115715/JJ1271_10x2_f72h20C_600s31x10s10s_C0802cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 27973 data points.
#   307 out of 2256 objects meet criteria.
# Took 17.216 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_zu391/20220806_120124/JJ1271_10x2_f96h20C_600s31x10s10s_A0802cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27425 data points.
#   446 out of 3420 objects meet criteria.
# Took 21.708 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/glo-1_zu391/20220806_130444/JJ1271_10x2_f96h20C_600s31x10s10s_A0802ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 16109 data points.
#   1233 out of 13305 objects meet criteria.
# Took 24.321 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/hipr-1_ok1081/20220920_171445/RB1102_10x2_f96h20C_600s31x10s10s_A0920aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 24 object.
#   Summary file has 17673 data points.
#   1086 out of 23607 objects meet criteria.
# Took 21.541 seconds to load data
# ...
#   Summary file has 25623 data points.
#   479 out of 6386 objects meet criteria.
# Took 21.348 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/pink-1_tm1779/20220627_114543/TM1779_10x2_f96h20C_600s30x10s10s_A0623bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 25275 data points.
#   523 out of 6681 objects meet criteria.
# Took 19.441 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/pink-1_tm1779/20220627_141357/TM1779_10x2_f96h20C_600s30x10s10s_A0623be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14827 data points.
#   986 out of 8028 objects meet criteria.
# Took 14.546 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sac-2_ok2743/20220820_123127/RB2077_10x2_f72h20C_600s31x10s10s_C0816dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 26802 data points.
#   708 out of 6782 objects meet criteria.
# Took 21.662 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sac-2_ok2743/20220820_140045/RB2077_10x2_f96h20C_600s31x10s10s_A0816dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 20218 data points.
#   907 out of 8284 objects meet criteria.
# Took 19.786 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sac-2_ok2743/20220820_122202/RB2077_10x2_f96h20C_600s31x10s10s_A0816da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14912 data points.
#   785 out of 8197 objects meet criteria.
# Took 12.719 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sac-2_ok2743/20220820_122017/RB2077_10x2_f72h20C_600s31x10s10s_B0816db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14013 data points.
#   832 out of 4983 objects meet criteria.
# Took 13.161 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sac-2_ok2743/20220820_134401/RB2077_10x2_f72h20C_600s31x10s10s_B0816de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 20 object.
#   Summary file has 13890 data points.
#   1025 out of 21192 objects meet criteria.
# Took 23.767 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/set-2_ok952/20221012_111358/RB1025_10x2_f96h20C_600s31x10s10s_A1012bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 24 object.
#   Summary file has 11968 data points.
#   1467 out of 24711 objects meet criteria.
# Took 24.597 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/set-2_ok952/20221012_113708/RB1025_10x2_f96h20C_600s31x10s10s_A1012be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 10973 data points.
#   1244 out of 14313 objects meet criteria.
# Took 18.924 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/set-2_ok952/20221012_094305/RB1025_10x2_f72h20C_600s31x10s10s_B01012ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 22 object.
#   Summary file has 11449 data points.
#   993 out of 23008 objects meet criteria.
# Took 17.170 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/set-2_ok952/20221012_110113/RB1025_10x2_f72h20C_600s31x10s10s_B01012bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 13669 data points.
#   1151 out of 12698 objects meet criteria.
# Took 20.896 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/set-2_ok952/20221012_102903/RB1025_10x2_f72h20C_600s31x10s10s_C1012bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16217 data points.
#   509 out of 2214 objects meet criteria.
# Took 11.201 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sipa-1_ok879/20220524_164318/RB975_10x2_f72h20C_600s31x10s10s_B0520ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14140 data points.
#   654 out of 3346 objects meet criteria.
# Took 12.702 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sipa-1_ok879/20220524_153551/RB975_10x2_f72h20C_600s31x10s10s_B0520cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27799 data points.
#   447 out of 4232 objects meet criteria.
# Took 18.244 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sipa-1_ok879/20220524_154911/RB975_10x2_f96h20C_600s30x10s10s_A0520cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15787 data points.
#   477 out of 3802 objects meet criteria.
# Took 11.491 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sipa-1_ok879/20220524_140653/RB975_10x2_f72h20C_600s31x10s10s_C0520ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 15305 data points.
#   620 out of 7029 objects meet criteria.
# Took 12.920 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/sipa-1_ok879/20220524_154902/RB975_10x2_f72h20C_600s31x10s10s_C0520cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 15948 data points.
#   205 out of 574 objects meet criteria.
# Took 6.964 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/snb-5_ok1434/20220513_124557/VC885_10x2_f72h20C_600s31x10s10s_B0509cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 14857 data points.
#   321 out of 1686 objects meet criteria.
# Took 8.820 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/snb-5_ok1434/20220513_145430/VC885_10x2_f72h20C_600s31x10s10s_B0509ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29492 data points.
#   152 out of 2204 objects meet criteria.
# Took 9.219 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/snb-5_ok1434/20220513_114921/VC885_10x2_f72h20C_600s31x10s10s_C0509ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29454 data points.
#   186 out of 1100 objects meet criteria.
# Took 9.686 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/snb-5_ok1434/20220513_135455/VC885_10x2_f72h20C_600s31x10s10s_C0509cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29677 data points.
#   127 out of 892 objects meet criteria.
# Took 10.262 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/snb-5_ok1434/20220513_140815/VC885_10x2_f96h20C_600s30x10s10s_A0509cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29274 data points.
#   19 out of 76 objects meet criteria.
# Took 2.242 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/src-1_ok2685/20220906_175225/RB2027_10x2_f72h20C_600s31x10s10s_B0906ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 29343 data points.
#   92 out of 6123 objects meet criteria.
# Took 9.672 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/src-1_ok2685/20220906_181210/RB2027_10x2_f72h20C_600s31x10s10s_C0906bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29875 data points.
#   1 out of 2 objects meet criteria.
# Took 0.695 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/src-1_ok2685/20220906_191634/RB2027_10x2_f72h20C_600s31x10s10s_B0906bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 27005 data points.
#   38 out of 328 objects meet criteria.
# Took 2.937 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/src-1_ok2685/20220906_194414/RB2027_10x2_f72h20C_600s31x10s10s_B0906be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 33464 data points.
#   10 out of 134 objects meet criteria.
# Took 2.893 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/src-1_ok2685/20220906_195515/RB2027_10x2_f96h20C_600s31x10s10s_A0906bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 16869 data points.
#   83 out of 787 objects meet criteria.
# Took 5.700 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-10_ad591/20220513_115851/DA591_10x2_f72h20C_600s31x10s10s_B0509ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 18161 data points.
#   73 out of 403 objects meet criteria.
# Took 6.937 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-10_ad591/20220513_140438/DA591_10x2_f72h20C_600s31x10s10s_B0509bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29769 data points.
#   39 out of 163 objects meet criteria.
# Took 7.580 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-10_ad591/20220513_125927/DA591_10x2_f72h20C_600s31x10s10s_C0509bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29713 data points.
#   88 out of 668 objects meet criteria.
# Took 10.920 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-10_ad591/20220513_132225/DA591_10x2_f96h20C_600s30x10s10s_A0509bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 28756 data points.
#   112 out of 1139 objects meet criteria.
# Took 14.304 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-10_ad591/20220513_153039/DA591_10x2_f96h20C_600s30x10s10s_A0509be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29124 data points.
#   92 out of 1905 objects meet criteria.
# Took 10.028 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e261/20221012_104921/CB261_10x2_f96h20C_600s31x10s10s_A1012da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28981 data points.
#   126 out of 1647 objects meet criteria.
# Took 11.734 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e261/20221012_125037/CB261_10x2_f96h20C_600s31x10s10s_A1012dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 19651 data points.
#   271 out of 1534 objects meet criteria.
# Took 9.929 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e261/20221012_112357/CB261_10x2_f72h20C_600s31x10s10s_B01012dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 15831 data points.
#   352 out of 1753 objects meet criteria.
# Took 13.605 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e261/20221012_105237/CB261_10x2_f72h20C_600s31x10s10s_C1012db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 15684 data points.
#   435 out of 2009 objects meet criteria.
# Took 13.427 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e261/20221012_114117/CB261_10x2_f72h20C_600s31x10s10s_C1012de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14474 data points.
#   255 out of 5352 objects meet criteria.
# Took 10.293 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e1005/20220928_132047/CB1005_10x2_f72h20C_600s31x10s10s_B0928dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15503 data points.
#   276 out of 3390 objects meet criteria.
# Took 14.022 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e1005/20220928_122150/CB1005_10x2_f72h20C_600s31x10s10s_C0928db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29398 data points.
#   114 out of 1128 objects meet criteria.
# Took 11.199 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e1005/20220928_133508/CB1005_10x2_f72h20C_600s31x10s10s_C0928de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 27 object.
#   Summary file has 28021 data points.
#   140 out of 25597 objects meet criteria.
# Took 18.984 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e1005/20220928_124128/CB1005_10x2_f96h20C_600s31x10s10s_A0928da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 27828 data points.
#   256 out of 4489 objects meet criteria.
# Took 18.142 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/unc-59_e1005/20220928_144505/CB1005_10x2_f96h20C_600s31x10s10s_A0928dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 19092 data points.
#   253 out of 5551 objects meet criteria.
# Took 9.732 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/vps-35_ok1880/20220809_093226/VC1390_10x2_f72h20C_600s31x10s10s_B0809ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28150 data points.
#   207 out of 4585 objects meet criteria.
# Took 15.527 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/vps-35_ok1880/20220809_114206/VC1390_10x2_f96h20C_600s31x10s10s_A0809bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29459 data points.
#   121 out of 1955 objects meet criteria.
# Took 14.598 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/vps-35_ok1880/20220809_120049/VC1390_10x2_f72h20C_600s31x10s10s_C0809be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28551 data points.
#   239 out of 2458 objects meet criteria.
# Took 13.283 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/vps-35_ok1880/20220913_172646/VC1390_10x2_f96h20C_600s31x10s10s_A0913da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15796 data points.
#   538 out of 5134 objects meet criteria.
# Took 14.662 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/vps-35_ok1880/20220913_174619/VC1390_10x2_f72h20C_600s31x10s10s_B0913dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29146 data points.
#   213 out of 1481 objects meet criteria.
# Took 11.735 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/vps-35_ok1880/20220913_192234/VC1390_10x2_f96h20C_600s31x10s10s_A0913dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14263 data points.
#   808 out of 4315 objects meet criteria.
# Took 13.552 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/Y18D10A.22_ok3535/20220928_120638/RB2545_10x2_f72h20C_600s31x10s10s_B0928ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 12246 data points.
#   828 out of 6678 objects meet criteria.
# Took 12.496 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/Y18D10A.22_ok3535/20220928_134302/RB2545_10x2_f72h20C_600s31x10s10s_B0928ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14607 data points.
#   1136 out of 7506 objects meet criteria.
# Took 18.128 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/Y18D10A.22_ok3535/20220928_124518/RB2545_10x2_f72h20C_600s31x10s10s_C0928ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 18862 data points.
#   649 out of 14493 objects meet criteria.
# Took 22.817 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/Y18D10A.22_ok3535/20220928_130637/RB2545_10x2_f96h20C_600s31x10s10s_A0928eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27152 data points.
#   525 out of 4363 objects meet criteria.
# Took 21.240 seconds to load data
# Writing summary file /Volumes/JOSEPH/PD_Screen/Y18D10A.22_ok3535/20220928_151613/RB2545_10x2_f96h20C_600s31x10s10s_A0928ee.dat
#   Write successful.
