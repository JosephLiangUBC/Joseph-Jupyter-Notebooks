# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import os #<- package used to work with system filepaths
import subprocess
from ipywidgets import widgets #<- widget tool to generate button
from IPython.display import display #<- displays button
# from tkinter import Tk, filedialog #<- Tkinter is a GUI package
from tqdm.notebook import tqdm
from ipyfilechooser import FileChooser

print("done step 1")
# Out:
# done step 1

# %%
starting_directory='/Users/Joseph/Desktop/'
chooser=FileChooser(starting_directory)
display(chooser)
# Out:
# FileChooser(path='/Users/Joseph/Desktop', filename='', title='', show_hidden=False, select_desc='Select', chan…

# %%
folder_path=chooser.selected_path
print(folder_path)
# Out:
# /Volumes/JosephSSD2T/PD_Screen_Pt2

# %%
# *************************************Redundant
# ### Select Folder App - After you run, you can select your folder for filepath
# button = widgets.Button(description = 'Select Folder') #<- creates a button variable
# display(button) #<- displays the button in output

# def select_folder(b): #<- defines an action. This action requires a variable, so an arbitrary one 'b' is there
#     global folder_path #<- sets a variable as a global variable, not just within this action
#     #Tk().withdraw() #<- Tkinter likes to create annoying empty windows. This removes them
#     folder_path = filedialog.askdirectory() #<- Opens up a file explorer window, and determines folder path
#     #Tk().update() #<- below
#     #Tk().destroy() #<- this and the line above it removes the file explorer window after a selection is made
#     print(folder_path) #<- this helps confirm that this action was performed
#     print('done step 2')
# button.on_click(select_folder)

# %%
#folder_path = '/Users/Joseph/Desktop/lrk1_ATR_NoATR_08_15_2019'
print(folder_path)
os.chdir(folder_path) #<- setting your working directory so that your images will be saved here

filelist = list() #<- empty list
for root, dirs, files in os.walk(folder_path): #<- this for loop goes through your folder 
    for name in files:
        if name.endswith('.zip'): #<- and takes out all files with a .dat (file that contains your data)
            filepath = os.path.join(root, name) #<- Notes down the file path of each data file
            filelist.append(filepath) #<- saves it into the list
    
print(filelist)
print('done step 3')
# Out:
# /Volumes/JosephSSD2T/PD_Screen_Pt2
# ['/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_144810.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_153132.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_135938.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_132201.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_145544.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_191355.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_171723.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_204042.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_204054.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_170030.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_122509.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_123334.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_111603.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_113501.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_125358.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_122357.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_110652.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_125107.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_123259.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_134206.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_151831.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_145506.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_171408.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_173141.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_170259.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_145347.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_164653.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_150427.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_165853.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_152409.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_112004.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_104740.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_120239.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_124958.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_142719.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_162139.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_143821.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_163128.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_145647.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_113502.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_114403.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_120916.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_132504.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_133323.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_160923.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_163539.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_183054.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_195508.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_201601.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_113134.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_114118.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_115919.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_124934.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_125808.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_151046.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_152617.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_154221.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_172948.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_173926.zip', '/Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231115_105 ...
# done step 3

# %% [markdown]
# # For Analyzing Basal Slowing Statistics

# %%
# for speed
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', 
                     '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-N', 'all', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S', 
                     '-o', 'sxySPkbcdrlmwMe', 
                     f'{f}'])

# %% [markdown]
# # For Analyzing Tap Habituation Statistics

# %%
# for tap habituation
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S' ,
                     '-o', 'nNss*b12xyMmeSakcr', 
                     '--plugin', 'Reoutline::exp',
                     '--plugin', 'Respine',
                     '--plugin', 'MeasureReversal::tap::dt=1::collect=0.5::postfix=trv',
                     '--plugin', 'MeasureReversal::puff::dt=3::collect=0.5::postfix=prv',
                     '--plugin', 'MeasureReversal::postfix=txt',
                     f'{f}'])
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28049 data points.
#   286 out of 1794 objects meet criteria.
# Took 9.320 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_144810/VC3230_10x2_f96h20C_600s31x10s10s_A1112cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 17278 data points.
#   381 out of 2545 objects meet criteria.
# Took 5.809 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_153132/VC3230_10x2_f96H20C_600s31x10s10s_B1112ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16070 data points.
#   418 out of 2478 objects meet criteria.
# Took 6.605 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_135938/VC3230_10x2_f96H20C_600s31x10s10s_B1112cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29656 data points.
#   65 out of 417 objects meet criteria.
# Took 3.726 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_132201/VC3230_9x2_f96h20C_600s31x10s10s_C1112ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16751 data points.
#   453 out of 2335 objects meet criteria.
# Took 6.600 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-5_gk3119/20231116_145544/VC3230_10x2_f96h20C_600s31x10s10s_C1112cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 12980 data points.
#   852 out of 11796 objects meet criteria.
# Took 9.080 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_191355/RB1241_10x2_f96h20C_600s31x10s10s_B1211dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 14603 data points.
#   894 out of 9596 objects meet criteria.
# Took 10.007 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_171723/RB1241_9X2_f96h20C_600s31x10s10s_C1211db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 45 object.
#   Summary file has 13338 data points.
#   1017 out of 45165 objects meet criteria.
# Took 10.806 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_204042/RB1241_10X2_f96h20C_600s31x10s10s_C1211de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 18368 data points.
#   1037 out of 20811 objects meet criteria.
# Took 12.952 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_204054/RB1241_10x2_f96h20C_600s31x10s10s_A1211dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 20436 data points.
#   614 out of 8847 objects meet criteria.
# Took 11.681 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klu-1_ok1306/20231215_170030/RB1241_10x2_f96h20C_600s31x10s10s_A1211da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 26846 data points.
#   334 out of 3737 objects meet criteria.
# Took 13.201 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_122509/FX02366_9x2_f96h20C_600s31x10s10s_A1129bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 17717 data points.
#   554 out of 3576 objects meet criteria.
# Took 9.834 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_123334/FX02366_9x2_f72h20C_600s31x10s10s_B1129bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 27244 data points.
#   98 out of 1340 objects meet criteria.
# Took 5.371 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_111603/FX02366_9x2_f72h20C_600s31x10s10s_B1129ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29272 data points.
#   164 out of 571 objects meet criteria.
# Took 8.824 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_113501/FX02366_9x2_f96h20C_600s31x10s10s_C1129bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16596 data points.
#   436 out of 2214 objects meet criteria.
# Took 8.610 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm2366/20231129_125358/FX02366_9x2_f96h20C_600s31x10s10s_C1129be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 25912 data points.
#   377 out of 4381 objects meet criteria.
# Took 13.965 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_122357/FX04438_12x2_f96h20C_600s31x10s10s_A1220da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14645 data points.
#   775 out of 5423 objects meet criteria.
# Took 10.510 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_110652/FX04438_12X2_f96h20C_600s31x10s10s_C1220ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 14880 data points.
#   573 out of 2911 objects meet criteria.
# Took 9.023 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_125107/FX04438_12X2_f96h20C_600s31x10s10s_C1220cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 13917 data points.
#   560 out of 4936 objects meet criteria.
# Took 8.188 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_123259/FX04438_12x2_f72h20C_600s31x10s10s_B1220cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 18687 data points.
#   761 out of 8869 objects meet criteria.
# Took 13.270 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/catp-7_tm4438/20231220_134206/FX04438_12x2_f96h20C_600s31x10s10s_A1220ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29097 data points.
#   263 out of 1624 objects meet criteria.
# Took 7.385 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_151831/VC879_9x2_f96h20C_600s31x10s10s_C1029bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 23343 data points.
#   180 out of 743 objects meet criteria.
# Took 5.513 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_145506/VC879_9x2_f96H20C_600s31x10s10s_B1029ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 18077 data points.
#   275 out of 1336 objects meet criteria.
# Took 4.940 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_171408/VC879_9x2_f96H20C_600s31x10s10s_B1029bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29252 data points.
#   269 out of 1680 objects meet criteria.
# Took 6.670 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_173141/VC879_9x2_f96h20C_600s31x10s10s_C1029be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28051 data points.
#   260 out of 1450 objects meet criteria.
# Took 8.896 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/gly-7_gk374/20231102_170259/VC879_9x2_f96h20C_600s31x10s10s_A1029bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 17511 data points.
#   1043 out of 13254 objects meet criteria.
# Took 14.096 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_145347/VC3169_10x2_f96h20C_600s31x10s10s_A1021da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 18522 data points.
#   795 out of 15387 objects meet criteria.
# Took 13.431 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_164653/VC3169_10x2_f96h20C_600s31x10s10s_A1021dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 13963 data points.
#   1099 out of 8521 objects meet criteria.
# Took 14.747 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_150427/VC3169_10x2_f96H20C_600s31x10s10s_B1021db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 14014 data points.
#   1355 out of 11758 objects meet criteria.
# Took 12.165 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_165853/VC3169_10x2_f96H20C_600s31x10s10s_B1021de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14769 data points.
#   740 out of 6120 objects meet criteria.
# Took 8.384 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/har-1_gk3124/20231025_152409/VC3169_10x2_f96h20C_600s31x10s10s_C1021dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14573 data points.
#   751 out of 5953 objects meet criteria.
# Took 8.367 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_112004/FX05176_9x2_f96H20C_600s31x10s10s_B1115cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15450 data points.
#   437 out of 2566 objects meet criteria.
# Took 7.936 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_104740/FX05176_9x2_f96h20C_600s31x10s10s_C1115ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14982 data points.
#   544 out of 3391 objects meet criteria.
# Took 8.197 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_120239/FX05176_9x2_f96h20C_600s31x10s10s_C1115cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 22408 data points.
#   537 out of 7194 objects meet criteria.
# Took 11.316 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm5176/20231115_124958/FX05176_9x2_f96h20C_600s31x10s10s_A1115ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 19623 data points.
#   508 out of 4510 objects meet criteria.
# Took 22.410 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_142719/N2_9x2_f96h20C_600s31x10s10s_A1021aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 22134 data points.
#   448 out of 7834 objects meet criteria.
# Took 10.772 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_162139/N2_9x2_f96h20C_600s31x10s10s_A1021ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14938 data points.
#   865 out of 6805 objects meet criteria.
# Took 9.034 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_143821/N2_9x2_f96H20C_600s31x10s10s_B1021ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14426 data points.
#   713 out of 6968 objects meet criteria.
# Took 7.747 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_163128/N2_9x2_f96H20C_600s31x10s10s_B1021ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 16040 data points.
#   423 out of 4105 objects meet criteria.
# Took 6.362 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231025_145647/N2_9x2_f96h20C_600s31x10s10s_C1021ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 26150 data points.
#   516 out of 8423 objects meet criteria.
# Took 14.992 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_113502/N2_9x2_f96h20C_600s31x10s10s_A1206aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14920 data points.
#   755 out of 8072 objects meet criteria.
# Took 11.239 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_114403/N2_9x2_f72h20C_600s31x10s10s_B1206ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14942 data points.
#   783 out of 5920 objects meet criteria.
# Took 12.421 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_120916/N2_9x2_f96h20C_600s31x10s10s_C1206ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 19663 data points.
#   676 out of 6771 objects meet criteria.
# Took 11.889 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_132504/N2_9x2_f96h20C_600s31x10s10s_A1206ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 15024 data points.
#   732 out of 9897 objects meet criteria.
# Took 12.262 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231206_133323/N2_9x2_f72h20C_600s31x10s10s_B1206ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 20072 data points.
#   635 out of 7553 objects meet criteria.
# Took 14.646 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_160923/N2_9x2_f96h20C_600s31x10s10s_A1211aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14524 data points.
#   854 out of 8334 objects meet criteria.
# Took 10.936 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_163539/N2_9X2_f96h20C_600s31x10s10s_C1211ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 14443 data points.
#   883 out of 9103 objects meet criteria.
# Took 10.329 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_183054/N2_9x2_f96h20C_600s31x10s10s_B1211ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 18 object.
#   Summary file has 18381 data points.
#   972 out of 17116 objects meet criteria.
# Took 16.128 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_195508/N2_9x2_f96h20C_600s31x10s10s_A1211ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 40 object.
#   Summary file has 14488 data points.
#   826 out of 41121 objects meet criteria.
# Took 12.257 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231215_201601/N2_9X2_f96h20C_600s31x10s10s_C1211ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 21881 data points.
#   518 out of 6802 objects meet criteria.
# Took 17.685 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_113134/N2_9x2_f96h20C_600s31x10s10s_A1220aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 12797 data points.
#   1100 out of 7911 objects meet criteria.
# Took 9.967 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_114118/N2_9x2_f72h20C_600s31x10s10s_B1220ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 14302 data points.
#   978 out of 9790 objects meet criteria.
# Took 11.495 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_115919/N2_9X2_f96h20C_600s31x10s10s_C1220ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 19221 data points.
#   619 out of 8694 objects meet criteria.
# Took 14.576 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_124934/N2_9x2_f96h20C_600s31x10s10s_A1220ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 13103 data points.
#   777 out of 7404 objects meet criteria.
# Took 11.680 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231220_125808/N2_9x2_f72h20C_600s31x10s10s_B1220ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 28167 data points.
#   219 out of 4142 objects meet criteria.
# Took 8.030 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_151046/N2_9x2_f96h20C_600s31x10s10s_A1029aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 17788 data points.
#   345 out of 2024 objects meet criteria.
# Took 5.893 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_152617/N2_9x2_f96H20C_600s31x10s10s_B1029ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29381 data points.
#   156 out of 1458 objects meet criteria.
# Took 7.650 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_154221/N2_9x2_f96h20C_600s31x10s10s_C1029ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29647 data points.
#   93 out of 2011 objects meet criteria.
# Took 10.905 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_172948/N2_9x2_f96h20C_600s31x10s10s_A1029ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 22940 data points.
#   284 out of 1262 objects meet criteria.
# Took 6.991 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231102_173926/N2_9x2_f96H20C_600s31x10s10s_B1029ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 20240 data points.
#   171 out of 1004 objects meet criteria.
# Took 3.359 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231115_105519/N2_9x2_f96H20C_600s31x10s10s_B1115ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28797 data points.
#   200 out of 2875 objects meet criteria.
# Took 8.506 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231115_111044/N2_9x2_f96h20C_600s31x10s10s_A1115aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29237 data points.
#   180 out of 1560 objects meet criteria.
# Took 20.280 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231115_113818/N2_9x2_f96h20C_600s31x10s10s_C1115ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 21277 data points.
#   234 out of 1028 objects meet criteria.
# Took 5.625 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231115_121019/N2_9x2_f96H20C_600s31x10s10s_B1115ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28877 data points.
#   184 out of 1965 objects meet criteria.
# Took 7.835 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231115_122547/N2_9x2_f96h20C_600s31x10s10s_A1115ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29535 data points.
#   106 out of 1770 objects meet criteria.
# Took 6.207 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231116_134554/N2_9x2_f96h20C_600s31x10s10s_A1112aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15373 data points.
#   551 out of 2819 objects meet criteria.
# Took 9.650 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231116_135146/N2_9x2_f96h20C_600s31x10s10s_C1112ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 13550 data points.
#   712 out of 5336 objects meet criteria.
# Took 9.698 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231116_143210/N2_9x2_f96H20C_600s31x10s10s_B1112ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 21679 data points.
#   562 out of 3480 objects meet criteria.
# Took 11.633 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231116_151938/N2_9x2_f96h20C_600s31x10s10s_A1112ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 16432 data points.
#   353 out of 1858 objects meet criteria.
# Took 6.834 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231116_152340/N2_9x2_f96h20C_600s31x10s10s_C1112ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 18892 data points.
#   659 out of 13228 objects meet criteria.
# Took 17.289 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231120_153341/N2_9x2_f96h20C_600s31x10s10s_A1116aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14560 data points.
#   801 out of 8091 objects meet criteria.
# Took 14.269 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231120_154051/N2_9x2_f96h20C_600s31x10s10s_C1116ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 13258 data points.
#   794 out of 11245 objects meet criteria.
# Took 9.581 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231120_165130/N2_9x2_f72h20C_600s31x10s10s_B1116ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 25 object.
#   Summary file has 17318 data points.
#   910 out of 25331 objects meet criteria.
# Took 12.639 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231120_181141/N2_9x2_f96h20C_600s31x10s10s_A1116ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 34 object.
#   Summary file has 14486 data points.
#   812 out of 35555 objects meet criteria.
# Took 10.201 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231120_181253/N2_9x2_f96h20C_600s31x10s10s_C1116ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 17892 data points.
#   369 out of 2051 objects meet criteria.
# Took 6.843 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231122_103739/N2_9x2_f96h20C_600s31x10s10s_C1122ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 27710 data points.
#   249 out of 3725 objects meet criteria.
# Took 11.027 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231122_110104/N2_9x2_f96h20C_600s31x10s10s_A1122aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14337 data points.
#   741 out of 6237 objects meet criteria.
# Took 18.891 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231122_111254/N2_9x2_f72h20C_600s31x10s10s_B1122ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 21632 data points.
#   554 out of 15065 objects meet criteria.
# Took 17.953 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231122_115339/N2_9x2_f96h20C_600s31x10s10s_A1122ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 19967 data points.
#   512 out of 6219 objects meet criteria.
# Took 13.806 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231129_113132/N2_9x2_f96h20C_600s31x10s10s_A1129aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15466 data points.
#   863 out of 4992 objects meet criteria.
# Took 10.506 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231129_113939/N2_9x2_f72h20C_600s31x10s10s_B1129ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 17260 data points.
#   532 out of 2921 objects meet criteria.
# Took 7.832 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231129_115958/N2_9x2_f96h20C_600s31x10s10s_C1129ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 23557 data points.
#   608 out of 4930 objects meet criteria.
# Took 12.297 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231129_125027/N2_9x2_f96h20C_600s31x10s10s_A1129ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14987 data points.
#   896 out of 7861 objects meet criteria.
# Took 11.183 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/N2/20231129_130240/N2_9x2_f72h20C_600s31x10s10s_B1129ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 13562 data points.
#   682 out of 7878 objects meet criteria.
# Took 9.517 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/F35C8_tm4028/20231120_184601/FX4028_9x2_f96h20C_600s31x10s10s_B1116ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 13702 data points.
#   643 out of 8110 objects meet criteria.
# Took 9.481 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/F35C8_tm4028/20231120_162540/FX4028_9x2_f72h20C_600s31x10s10s_B1116cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15448 data points.
#   429 out of 2145 objects meet criteria.
# Took 10.392 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/F35C8_tm4028/20231120_150943/FX4028_9x2_f96h20C_600s31x10s10s_C1116ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14520 data points.
#   783 out of 7742 objects meet criteria.
# Took 12.064 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/F35C8_tm4028/20231120_174738/FX4028_9x2_f96h20C_600s31x10s10s_C1116cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 19290 data points.
#   513 out of 4420 objects meet criteria.
# Took 12.981 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/F35C8_tm4028/20231120_174546/FX4028_9x2_f96h20C_600s31x10s10s_A1116cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 19054 data points.
#   720 out of 8445 objects meet criteria.
# Took 16.318 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/scav-5_ok1606/20231025_154717/RB1409_10x2_f96h20C_600s31x10s10s_A1021bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14736 data points.
#   953 out of 5532 objects meet criteria.
# Took 9.742 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/scav-5_ok1606/20231025_141153/RB1409_10x2_f96H20C_600s31x10s10s_B1021ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15295 data points.
#   1021 out of 4930 objects meet criteria.
# Took 9.617 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/scav-5_ok1606/20231025_160613/RB1409_10x2_f96H20C_600s31x10s10s_B1021bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14764 data points.
#   817 out of 4198 objects meet criteria.
# Took 8.880 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/scav-5_ok1606/20231025_162347/RB1409_10x2_f96h20C_600s31x10s10s_C1021be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14699 data points.
#   996 out of 4529 objects meet criteria.
# Took 9.773 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/scav-5_ok1606/20231025_143041/RB1409_10x2_f96h20C_600s31x10s10s_C1021bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29841 data points.
#   25 out of 3327 objects meet criteria.
# Took 4.341 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/imp-1_ok2362/20231122_112821/RB1825_25x2_f96h20C_600s31x10s10s_A1122bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16585 data points.
#   81 out of 2166 objects meet criteria.
# Took 5.608 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/imp-1_ok2362/20231122_113745/RB1825_25x2_f72h20C_600s31x10s10s_B1122bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 17578 data points.
#   76 out of 2599 objects meet criteria.
# Took 5.167 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/imp-1_ok2362/20231122_104522/RB1825_25x2_f72h20C_600s31x10s10s_B1122ba.dat
#   Write successful.
# Error Finding Files
#   /Volumes/JosephSSD2T/PD_Screen_Pt2/imp-1_ok2362/._20231122_104522.zip could not be opened for reading as a zip file.
# java.util.zip.ZipException: zip END header not found
#
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 27465 data points.
#   91 out of 1171 objects meet criteria.
# Took 13.690 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/imp-1_ok2362/20231122_110510/RB1825_25x2_f96h20C_600s31x10s10s_C1122bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29841 data points.
#   19 out of 336 objects meet criteria.
# Took 6.169 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/imp-1_ok2362/20231122_113002/RB1825_25x2_f96h20C_600s31x10s10s_C1122be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 19361 data points.
#   266 out of 5631 objects meet criteria.
# Took 15.811 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/unc-70_e524/20231025_171419/CB524_10x2_f96h20C_600s31x10s10s_A1021ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 20386 data points.
#   328 out of 5410 objects meet criteria.
# Took 12.798 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/unc-70_e524/20231025_151954/CB524_10x2_f96h20C_600s31x10s10s_A1021cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 20753 data points.
#   144 out of 1373 objects meet criteria.
# Took 7.956 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/unc-70_e524/20231025_153150/CB524_10x2_f96H20C_600s31x10s10s_B1021cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15014 data points.
#   311 out of 3815 objects meet criteria.
# Took 9.381 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/unc-70_e524/20231025_140413/CB524_10x2_f96h20C_600s31x10s10s_C1021ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15536 data points.
#   268 out of 3361 objects meet criteria.
# Took 10.105 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/unc-70_e524/20231025_155832/CB524_10x2_f96h20C_600s31x10s10s_C1021cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15849 data points.
#   303 out of 2665 objects meet criteria.
# Took 9.760 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm1730/20231206_113612/FX01730_9x2_f96h20C_600s31x10s10s_C1206bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15579 data points.
#   342 out of 2495 objects meet criteria.
# Took 24.815 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm1730/20231206_132500/FX01730_9x2_f96h20C_600s31x10s10s_C1206be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 17682 data points.
#   279 out of 5180 objects meet criteria.
# Took 9.050 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm1730/20231206_111857/FX01730_9x2_f72h20C_600s31x10s10s_B1206ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 17229 data points.
#   442 out of 4855 objects meet criteria.
# Took 11.001 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm1730/20231206_130843/FX01730_9x2_f72h20C_600s31x10s10s_B1206bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28180 data points.
#   180 out of 2735 objects meet criteria.
# Took 9.731 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm1730/20231206_125858/FX01730_9x2_f96h20C_600s31x10s10s_A1206bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29406 data points.
#   156 out of 1329 objects meet criteria.
# Took 7.389 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm11505/20231206_123455/FX21503_10x2_f96h20C_600s31x10s10s_C1206dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 19510 data points.
#   315 out of 2381 objects meet criteria.
# Took 6.766 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm11505/20231206_121704/FX21503_10x2_f72h20C_600s31x10s10s_B1206db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 22617 data points.
#   177 out of 1610 objects meet criteria.
# Took 8.339 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm11505/20231206_135702/FX21503_10x2_f72h20C_600s31x10s10s_B1206de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 30828 data points.
#   55 out of 771 objects meet criteria.
# Took 4.733 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/immt-1_tm11505/20231206_141355/FX21503_10x2_f96h20C_600s31x10s10s_A1206dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 21805 data points.
#   154 out of 2091 objects meet criteria.
# Took 6.234 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231206_124241/FX25618_10x2_f72h20C_600s31x10s10s_B1206cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29745 data points.
#   113 out of 1256 objects meet criteria.
# Took 8.660 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231206_123325/FX25618_10x2_f96h20C_600s31x10s10s_A1206cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27804 data points.
#   426 out of 3968 objects meet criteria.
# Took 14.141 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231206_135020/FX25618_10x2_f96h20C_600s31x10s10s_A1206ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 13820 data points.
#   708 out of 4651 objects meet criteria.
# Took 8.539 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231220_111452/FX25618_12x2_f72h20C_600s31x10s10s_B1220ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14554 data points.
#   1258 out of 7542 objects meet criteria.
# Took 11.522 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231220_113231/FX25618_12X2_f96h20C_600s31x10s10s_C1220bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 20459 data points.
#   582 out of 6705 objects meet criteria.
# Took 12.740 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231220_131642/FX25618_12x2_f96h20C_600s31x10s10s_A1220bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 14928 data points.
#   598 out of 2776 objects meet criteria.
# Took 9.683 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231220_131739/FX25618_12X2_f96h20C_600s31x10s10s_C1220be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 13844 data points.
#   832 out of 5014 objects meet criteria.
# Took 8.794 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/klp-12_tm15618/20231220_132526/FX25618_12x2_f72h20C_600s31x10s10s_B1220bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 13029 data points.
#   653 out of 6982 objects meet criteria.
# Took 10.737 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231215_172531/FX31750_10x2_f96h20C_600s31x10s10s_B1211cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 15991 data points.
#   497 out of 6891 objects meet criteria.
# Took 7.992 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231215_204847/FX31750_10x2_f96h20C_600s31x10s10s_B1211ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14679 data points.
#   553 out of 4466 objects meet criteria.
# Took 12.267 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231215_154431/FX31750_10X2_f96h20C_600s31x10s10s_C1211ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14623 data points.
#   783 out of 6670 objects meet criteria.
# Took 11.989 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231215_193015/FX31750_10X2_f96h20C_600s31x10s10s_C1211cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 18889 data points.
#   686 out of 13274 objects meet criteria.
# Took 13.072 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231215_193042/FX31750_10x2_f96h20C_600s31x10s10s_A1211cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 23586 data points.
#   131 out of 883 objects meet criteria.
# Took 6.412 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231116_132953/FX31750_10x2_f96H20C_600s31x10s10s_B1112ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 28329 data points.
#   115 out of 925 objects meet criteria.
# Took 6.974 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231116_141539/FX31750_10x2_f96h20C_600s31x10s10s_A1112bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29282 data points.
#   141 out of 1291 objects meet criteria.
# Took 8.458 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231116_142419/FX31750_9x2_f96h20C_600s31x10s10s_C1112bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 23285 data points.
#   236 out of 1706 objects meet criteria.
# Took 5.917 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231116_150337/FX31750_10x2_f96H20C_600s31x10s10s_B1112bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28185 data points.
#   119 out of 1540 objects meet criteria.
# Took 18.976 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mig-15_tm13123/20231116_154734/FX31750_10x2_f96h20C_600s31x10s10s_A1112be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 23613 data points.
#   91 out of 749 objects meet criteria.
# Took 5.827 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/smrc-1_tm13785/20231215_155237/FX23784_10x2_f96h20C_600s31x10s10s_B1211ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 21327 data points.
#   138 out of 560 objects meet criteria.
# Took 8.392 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/smrc-1_tm13785/20231215_193822/FX23784_10x2_f96h20C_600s31x10s10s_B1211bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29455 data points.
#   125 out of 1052 objects meet criteria.
# Took 7.821 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/smrc-1_tm13785/20231215_182249/FX23784_10X2_f96h20C_600s31x10s10s_C1211bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 30682 data points.
#   69 out of 1634 objects meet criteria.
# Took 3.928 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/smrc-1_tm13785/20231215_210534/FX23784_10x2_f96h20C_600s31x10s10s_A1211be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29526 data points.
#   100 out of 1365 objects meet criteria.
# Took 8.044 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/smrc-1_tm13785/20231215_174218/FX23784_10x2_f96h20C_600s31x10s10s_A1211bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14255 data points.
#   407 out of 3937 objects meet criteria.
# Took 7.970 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-1_tm526/20231215_202408/TM526_10x2_f96h20C_600s31x10s10s_B1211ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 17 object.
#   Summary file has 10448 data points.
#   1253 out of 16623 objects meet criteria.
# Took 12.888 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-1_tm526/20231215_164345/TM526_10x2_f96h20C_600s31x10s10s_B1211ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14680 data points.
#   624 out of 7315 objects meet criteria.
# Took 10.253 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-1_tm526/20231215_190550/TM526_10X2_f96h20C_600s31x10s10s_C1211ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 20052 data points.
#   424 out of 4438 objects meet criteria.
# Took 13.133 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-1_tm526/20231215_184739/TM526_10x2_f96h20C_600s31x10s10s_A1211eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 19856 data points.
#   615 out of 12863 objects meet criteria.
# Took 14.987 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-1_tm526/20231215_212859/TM526_10x2_f96h20C_600s31x10s10s_A1211ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 30802 data points.
#   109 out of 1545 objects meet criteria.
# Took 4.159 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/miro-1_tm1966/20231220_115800/FX01996_9x2_f96h20C_600s31x10s10s_A1220da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16440 data points.
#   507 out of 2314 objects meet criteria.
# Took 7.680 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/miro-1_tm1966/20231220_122500/FX01996_9X2_f96h20C_600s31x10s10s_C1220dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15533 data points.
#   530 out of 2319 objects meet criteria.
# Took 7.613 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/miro-1_tm1966/20231220_134052/FX01996_12X2_f96h20C_600s31x10s10s_C1220dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 16479 data points.
#   386 out of 1934 objects meet criteria.
# Took 7.290 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/miro-1_tm1966/20231220_120717/FX01996_9x2_f72h20C_600s31x10s10s_B1220db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 19801 data points.
#   387 out of 1847 objects meet criteria.
# Took 7.592 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/miro-1_tm1966/20231220_135804/FX01996_12x2_f72h20C_600s31x10s10s_B1220de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29206 data points.
#   169 out of 1797 objects meet criteria.
# Took 11.191 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-2_tm2267/20231102_163938/FX02267_9x2_f96h20C_600s31x10s10s_C1029dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 17791 data points.
#   320 out of 1748 objects meet criteria.
# Took 8.274 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-2_tm2267/20231102_155006/FX02267_9x2_f96H20C_600s31x10s10s_B1029db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 17962 data points.
#   354 out of 2175 objects meet criteria.
# Took 9.223 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-2_tm2267/20231102_180152/FX02267_9x2_f96H20C_600s31x10s10s_B1029de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27670 data points.
#   323 out of 2523 objects meet criteria.
# Took 12.820 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-2_tm2267/20231102_154156/FX02267_9x2_f96h20C_600s31x10s10s_A1029da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27739 data points.
#   327 out of 2562 objects meet criteria.
# Took 12.798 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-2_tm2267/20231102_175506/FX02267_9x2_f96h20C_600s31x10s10s_A1029dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 18922 data points.
#   246 out of 2003 objects meet criteria.
# Took 7.793 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-3_tm2550/20231102_170623/FX02550_9x2_f96h20C_600s31x10s10s_C1029cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 26480 data points.
#   216 out of 1286 objects meet criteria.
# Took 8.057 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-3_tm2550/20231102_144723/FX02550_10x2_f96h20C_600s31x10s10s_C1029ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 17686 data points.
#   302 out of 1700 objects meet criteria.
# Took 7.842 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-3_tm2550/20231102_164721/FX02550_9x2_f96H20C_600s31x10s10s_B1029cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28090 data points.
#   209 out of 1462 objects meet criteria.
# Took 9.195 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-3_tm2550/20231102_160546/FX02550_9x2_f96h20C_600s31x10s10s_A1029cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27411 data points.
#   509 out of 3581 objects meet criteria.
# Took 15.185 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ubh-3_tm2550/20231102_181732/FX02550_9x2_f96h20C_600s31x10s10s_A1029ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 15054 data points.
#   295 out of 1534 objects meet criteria.
# Took 6.153 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mbk-1_ok402/20231115_114545/RB677_10x2_f96H20C_600s31x10s10s_B1115bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15352 data points.
#   481 out of 2738 objects meet criteria.
# Took 8.136 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mbk-1_ok402/20231115_111226/RB677_10x2_f96h20C_600s31x10s10s_C1115bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15043 data points.
#   544 out of 2772 objects meet criteria.
# Took 8.672 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mbk-1_ok402/20231115_122536/RB677_10x2_f96h20C_600s31x10s10s_C1115be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27656 data points.
#   333 out of 3208 objects meet criteria.
# Took 13.016 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/mbk-1_ok402/20231115_120114/RB677_10x2_f96h20C_600s31x10s10s_A1115bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14228 data points.
#   629 out of 6262 objects meet criteria.
# Took 11.751 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ipla-3_tm1584/20231120_182049/FX01584_9x2_f96h20C_600s31x10s10s_B1116ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 15634 data points.
#   357 out of 1629 objects meet criteria.
# Took 8.313 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ipla-3_tm1584/20231120_154846/FX01584_9x2_f72h20C_600s31x10s10s_B1116ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14596 data points.
#   827 out of 7327 objects meet criteria.
# Took 11.040 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ipla-3_tm1584/20231120_172146/FX01584_9x2_f96h20C_600s31x10s10s_C1116ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 14518 data points.
#   978 out of 9078 objects meet criteria.
# Took 11.711 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ipla-3_tm1584/20231120_190141/FX01584_9x2_f96h20C_600s31x10s10s_C1116ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 18626 data points.
#   755 out of 7744 objects meet criteria.
# Took 13.495 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/ipla-3_tm1584/20231120_170738/FX01584_9x2_f96h20C_600s31x10s10s_A1116eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 11200 data points.
#   792 out of 14114 objects meet criteria.
# Took 11.241 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/sek-4_gk3642/20231120_175533/VC3694_9x2_f96h20C_600s31x10s10s_B1116bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15459 data points.
#   395 out of 2980 objects meet criteria.
# Took 7.183 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/sek-4_gk3642/20231120_151734/VC3694_9x2_f72h20C_600s31x10s10s_B1116ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 14270 data points.
#   1122 out of 13829 objects meet criteria.
# Took 11.784 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/sek-4_gk3642/20231120_164335/VC3694_9x2_f96h20C_600s31x10s10s_C1116bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 17482 data points.
#   771 out of 20572 objects meet criteria.
# Took 12.659 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/sek-4_gk3642/20231120_164147/VC3694_9x2_f96h20C_600s31x10s10s_A1116bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 24 object.
#   Summary file has 16351 data points.
#   2591 out of 25047 objects meet criteria.
# Took 18.249 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/sek-4_gk3642/20231120_192321/VC3694_9x2_f96h20C_600s31x10s10s_A1116be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 10375 data points.
#   851 out of 10639 objects meet criteria.
# Took 8.653 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/T01G9_tm5159/20231120_172941/FX05159_9x2_f96h20C_600s31x10s10s_B1116dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 14680 data points.
#   722 out of 14955 objects meet criteria.
# Took 10.145 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/T01G9_tm5159/20231120_161748/FX05159_9x2_f96h20C_600s31x10s10s_C1116db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 22 object.
#   Summary file has 14197 data points.
#   1044 out of 22732 objects meet criteria.
# Took 11.614 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/T01G9_tm5159/20231120_183805/FX05159_9x2_f96h20C_600s31x10s10s_C1116de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 19677 data points.
#   489 out of 10133 objects meet criteria.
# Took 10.705 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/T01G9_tm5159/20231120_160454/FX05159_9x2_f96h20C_600s31x10s10s_A1116da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 16034 data points.
#   751 out of 20588 objects meet criteria.
# Took 13.046 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/T01G9_tm5159/20231120_183656/FX05159_9x2_f96h20C_600s31x10s10s_A1116dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 54 object.
#   Summary file has 29661 data points.
#   46 out of 52689 objects meet criteria.
# Took 3.197 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/rme-8_b1023/20231129_115529/DH1206_50x2_f96h20C_600s31x10s10s_A1129cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 48 object.
#   Summary file has 28915 data points.
#   95 out of 40742 objects meet criteria.
# Took 4.914 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/rme-8_b1023/20231129_131848/DH1206_50x2_f96h20C_600s31x10s10s_A1129ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 26437 data points.
#   47 out of 2582 objects meet criteria.
# Took 10.627 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/rme-8_b1023/20231129_120817/DH1206_50x2_f72h20C_600s31x10s10s_B1129cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 29633 data points.
#   54 out of 4027 objects meet criteria.
# Took 7.920 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/rme-8_b1023/20231129_111304/DH1206_50x2_f96h20C_600s31x10s10s_C1129ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29750 data points.
#   50 out of 1214 objects meet criteria.
# Took 1.523 seconds to load data
# Writing summary file /Volumes/JosephSSD2T/PD_Screen_Pt2/rme-8_b1023/20231129_122520/DH1206_50x2_f96h20C_600s31x10s10s_C1129cd.dat
#   Write successful.
