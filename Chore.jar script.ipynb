# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import os #<- package used to work with system filepaths
import subprocess
from ipywidgets import widgets #<- widget tool to generate button
from IPython.display import display #<- displays button
from tkinter import Tk, filedialog #<- Tkinter is a GUI package
from tqdm.notebook import tqdm

print("done step 1")
# Out:
# done step 1

# %%
### Select Folder App - After you run, you can select your folder for filepath
button = widgets.Button(description = 'Select Folder') #<- creates a button variable
display(button) #<- displays the button in output

def select_folder(b): #<- defines an action. This action requires a variable, so an arbitrary one 'b' is there
    global folder_path #<- sets a variable as a global variable, not just within this action
    #Tk().withdraw() #<- Tkinter likes to create annoying empty windows. This removes them
    folder_path = filedialog.askdirectory() #<- Opens up a file explorer window, and determines folder path
    #Tk().update() #<- below
    #Tk().destroy() #<- this and the line above it removes the file explorer window after a selection is made
    print(folder_path) #<- this helps confirm that this action was performed
    print('done step 2')
button.on_click(select_folder)
# Out:
# Button(description='Select Folder', style=ButtonStyle())
# 1   HIToolbox                           0x0000000192c685c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x0000000192c68188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x0000000192c0b310 SetMenuBarObscured + 372
# 4   HIToolbox                           0x0000000192c0aee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 5   HIToolbox                           0x0000000192c04fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 6   HIToolbox                           0x0000000192bcbcd0 _NotifyEventLoopObservers + 176
# 7   HIToolbox                           0x0000000192c0496c AcquireEventFromQueue + 432
# 8   HIToolbox                           0x0000000192bf3c84 ReceiveNextEventCommon + 320
# 9   HIToolbox                           0x0000000192bf3b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 10  AppKit                              0x000000018c799838 _DPSNextEvent + 632
# 11  AppKit                              0x000000018c7989c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 12  libtk8.6.dylib                      0x00000001262c4ac8 TkMacOSXEventsCheckProc + 308
# 13  libtcl8.6.dylib                     0x0000000126591050 Tcl_DoOneEvent + 268
# 14  libtk8.6.dylib                      0x00000001262bc480 -[TKApplication(TKInit) applicationDidFinishLaunching:] + 212
# 15  CoreFoundation                      0x000000018950a560 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 16  CoreFoundation                      0x00000001895a8044 ___CFXRegistrationPost_block_invoke + 88
# 17  CoreFoundation                      0x00000001895a7f8c _CFXRegistrationPost + 440
# 18  CoreFoundation                      0x00000001894dbb64 _CFXNotificationPost + 708
# 19  Foundation                          0x000000018a3cb38c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 20  AppKit                              0x000000018c7a0c24 -[NSApplication _postDidFinishNotification] + 284
# 21  AppKit                              0x000000018c7a09d4 -[NSApplication _sendFinishLaunchingNotification] + 172
# 22  AppKit                              0x000000018c799bdc _DPSNextEvent + 1564
# 23  AppKit                              0x000000018c7989c8 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 24  libtk8.6.dylib                      0x00000001262c4900 TkMacOSXEventsSetupProc + 152
# 25  libtcl8.6.dylib                     0x0000000126591008 Tcl_DoOneEvent + 196
# 26  libtk8.6.dylib                      0x00000001262bcb28 TkpInit + 416
# 27  libtk8.6.dylib                      0x000000012623407c Initialize + 2292
# 28  _tkinter.cpython-311-darwin.so      0x00000001101d6368 Tcl_AppInit + 92
# 29  _tkinter.cpython-311-darwin.so      0x00000001101d6000 Tkapp_New + 548
# 30  _tkinter.cpython-311-darwin.so      0x00000001101d5dd8 _tkinter_create_impl + 268
# 31  _tkinter.cpython-311-darwin.so      0x00000001101d5a10 _tkinter_create + 240
# 32  Python                              0x00000001032464e4 cfunction_vectorcall_FASTCALL + 80
# 33  Python                              0x0000000103304d4c _PyEval_EvalFrameDefault + 52772
# 34  Python                              0x000000010330a89c _PyEval_Vector + 156
# 35  Python                              0x00000001031e1db4 _PyObject_FastCallDictTstate + 96
# 36  Python                              0x000000010326ecfc slot_tp_init + 180
# 37  Python                              0x0000000103265678 type_call + 136
# 38  Python                              0x00000001031e1a94 _PyObject_MakeTpCall + 128
# 39  Python                              0x0000000103304e34 _PyEval_EvalFrameDefault + 53004
# 40  Python                              0x000000010330a89c _PyEval_Vector + 156
# 41  Python                              0x0000000103307980 _PyEval_EvalFrameDefault + 64088
# 42  Python                              0x000000010330a89c _PyEval_Vector + 156
# 43  Python                              0x00000001031e1db4 _PyObject_FastCallDictTstate + 96
# 44  Python                              0x000000010326d340 slot_tp_call + 180
# 45  Python                              0x00000001031e1a94 _PyObject_MakeTpCall + 128
# 46  Python                              0x0000000103304e34 _PyEval_EvalFrameDefault + 53004
# 47  Python                              0x000000010330a89c _PyEval_Vector + 156
# 48  Python                              0x00000001031e5d6c method_vectorcall + 164
# 49  Python                              0x0000000103307980 _PyEval_EvalFrameDefault + 64088
# 50  Python                              0x000000010330a89c _PyEval_Vector + 156
# 51  Python                              0x00000001031e1db4 _PyObject_FastCallDictTstate + 96
# 52  Python                              0x000000010326d340 slot_tp_call + 180
# 53  Python                              0x00000001031e1a94 _PyObject_MakeTpCall + 128
# 54  Python                              0x0000000103304e34 _PyEval_EvalFrameDefault + 53004
# 55  Python                              0x000000010330a89c _PyEval_Vector + 156
# 56  Python                              0x0000000103307980 _PyEval_EvalFrameDefault + 64088
# 57  Python                              0x00000001032003e4 gen_send_ex2 + 204
# 58  Python                              0x00000001032fba7c _PyEval_EvalFrameDefault + 15188
# 59  Python                              0x00000001032003e4 gen_send_ex2 + 204
# 60  Python                              0x00000001032fba7c _PyEval_EvalFrameDefault + 15188
# 61  Python                              0x00000001032003e4 gen_send_ex2 + 204
# 62  _asyncio.cpython-311-darwin.so      0x0000000102c404e8 task_step_impl + 440
# 63  _asyncio.cpython-311-darwin.so      0x0000000102c402bc task_step + 52
# 64  _asyncio.cpython-311-darwin.so      0x0000000102c40d5c task_wakeup + 148
# 65  Python                              0x0000000103246904 cfunction_vectorcall_O + 92
# 66  Python                              0x00000001033304f4 _PyObject_VectorcallTstate.4587 + 96
# 67  Python                              0x00000001033303dc context_run + 216
# 68  Python                              0x0000000103246644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 69  Python                              0x0000000103307980 _PyEval_EvalFrameDefault + 64088
# 70  Python                              0x00000001032f6cac PyEval_EvalCode + 276
# 71  Python                              0x00000001032f150c builtin_exec + 428
# 72  Python                              0x0000000103246644 cfunction_vectorcall_FASTCALL_KEYWORDS + 80
# 73  Python                              0x0000000103304d4c _PyEval_EvalFrameDefault + 52772
# 74  Python                              0x000000010330a89c _PyEval_Vector + 156
# 75  Python                              0x000000010339784c pymain_run_module + 256
# 76  Python                              0x00000001033972ec Py_RunMain + 1784
# 77  Python                              0x000000010339849c pymain_main + 52
# 78  Python                              0x0000000103398cd4 Py_BytesMain + 40
# 79  dyld                                0x000000018910be50 start + 2544
# 2023-06-16 15:57:10.123 Python[85969:11114326] +[CATransaction synchronize] called within transaction
# /Users/Joseph/Desktop/Anushka
# done step 2

# %%
print(folder_path)

# %%
#folder_path = '/Users/Joseph/Desktop/lrk1_ATR_NoATR_08_15_2019'
print(folder_path)
os.chdir(folder_path) #<- setting your working directory so that your images will be saved here

filelist = list() #<- empty list
for root, dirs, files in os.walk(folder_path): #<- this for loop goes through your folder 
    for name in files:
        if name.endswith('.zip'): #<- and takes out all files with a .dat (file that contains your data)
            filepath = os.path.join(root, name) #<- Notes down the file path of each data file
            filelist.append(filepath) #<- saves it into the list
    
print(filelist)
print('done step 3')
# Out:
# /Users/Joseph/Desktop/Anushka
# ['/Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_162228.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_150248.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_172658.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_173826.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_183555.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_145438.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_160118.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_161915.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_163708.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_151353.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_172608.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_163449.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_162019.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_153558.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_154943.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_145554.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_164932.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_174826.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_153630.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_153801.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_190810.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_171153.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_170047.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_181020.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_165930.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_170753.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_180515.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_144823.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_155537.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_163154.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_150833.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_184521.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_174407.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_164536.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_160535.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_171401.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_145406.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_181512.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_161631.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_181945.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_183012.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_171734.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_161645.zip', '/Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_154709.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_150445.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_151756.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_151952.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_150531.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_150354.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_165121.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_180436.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_164341.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_175333.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_164155.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_162219.zip', '/Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_153247.zip ...
# done step 3

# %%
# for speed
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', 
                     '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-N', 'all', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S', 
                     '-o', 'sxySPkbcdrlmwMe', 
                     f'{f}'])

# %%
# for tap habituation
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S' ,
                     '-o', 'nNss*b12xyMmeSakcr', 
                     '--plugin', 'Reoutline::exp',
                     '--plugin', 'Respine',
                     '--plugin', 'MeasureReversal::tap::dt=1::collect=0.5::postfix=trv',
                     '--plugin', 'MeasureReversal::puff::dt=3::collect=0.5::postfix=prv',
                     '--plugin', 'MeasureReversal::postfix=txt',
                     f'{f}'])
# Out:
#   0%|          | 0/169 [00:00<?, ?it/s]
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14538 data points.
#   200 out of 3893 objects meet criteria.
# Took 8.919 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_162228/NM1378_9x3_f96H20C_600s31x10s10s_B0303cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 12688 data points.
#   307 out of 3219 objects meet criteria.
# Took 8.104 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_150248/NM1378_9x3_f96h20C_600s31x10s10s_C0303ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 18918 data points.
#   371 out of 6277 objects meet criteria.
# Took 16.517 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_172658/NM1378_9X3_f96h20C_600s31x10s10s_A0303cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16348 data points.
#   172 out of 2130 objects meet criteria.
# Took 7.713 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_173826/NM1378_9x3_f96h20C_600s31x10s10s_C0303cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14528 data points.
#   214 out of 6482 objects meet criteria.
# Took 8.680 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_js125/20230307_183555/NM1378_9x3_f96H20C_600s31x10s10s_B0303ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 18 object.
#   Summary file has 9075 data points.
#   870 out of 18538 objects meet criteria.
# Took 7.538 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_145438/VC1052_9x2_f96H20C_600s31x10s10s_B0331ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 20 object.
#   Summary file has 17737 data points.
#   792 out of 19487 objects meet criteria.
# Took 14.048 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_160118/VC1052_9X2_f96h20C_600s31x10s10s_A0331bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 19 object.
#   Summary file has 10386 data points.
#   712 out of 18624 objects meet criteria.
# Took 7.294 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_161915/VC1052_9x2_f96H20C_600s31x10s10s_B0331bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 14287 data points.
#   1348 out of 10813 objects meet criteria.
# Took 12.493 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_163708/VC1052_9x2_f96h20C_600s31x10s10s_C0331be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14667 data points.
#   631 out of 5481 objects meet criteria.
# Took 10.296 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_gk452/20230404_151353/VC1052_9x2_f96h20C_600s31x10s10s_C0331bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14677 data points.
#   656 out of 4333 objects meet criteria.
# Took 10.565 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_172608/FX02945_10x2_f96h20C_600s31x10s10s_C0518be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14537 data points.
#   606 out of 5112 objects meet criteria.
# Took 9.627 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_163449/FX02945_10x2_f96H20C_600s31x10s10s_B0518bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 17181 data points.
#   650 out of 10413 objects meet criteria.
# Took 14.678 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_162019/FX02945_10x2_f96h20C_600s31x10s10s_A0518bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 23 object.
#   Summary file has 15391 data points.
#   772 out of 23294 objects meet criteria.
# Took 13.224 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_153558/FX02945_9X3_f96h20C_600s31x10s10s_A0324da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 14461 data points.
#   944 out of 12116 objects meet criteria.
# Took 12.093 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_154943/FX02945_9x3_f96h20C_600s31x10s10s_C0328db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 21796 data points.
#   287 out of 4566 objects meet criteria.
# Took 8.553 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_145554/FX02945_10x2_f96H20C_600s31x10s10s_B0518ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 24 object.
#   Summary file has 11070 data points.
#   1046 out of 23990 objects meet criteria.
# Took 10.810 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_164932/FX02945_9x3_f96H20C_600s31x10s10s_B0324dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 16830 data points.
#   850 out of 15790 objects meet criteria.
# Took 14.315 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230328_174826/FX02945_9X3_f96h20C_600s31x10s10s_A0324dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15045 data points.
#   512 out of 4176 objects meet criteria.
# Took 9.237 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2945/20230522_153630/FX02945_10x2_f96h20C_600s31x10s10s_C0518bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14277 data points.
#   330 out of 7037 objects meet criteria.
# Took 9.009 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_153801/MT2598_9x3_f96H20C_600s31x10s10s_B0303ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 20649 data points.
#   280 out of 6279 objects meet criteria.
# Took 13.431 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_190810/MT2598_9X3_f96h20C_600s31x10s10s_A0303ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 16228 data points.
#   339 out of 6584 objects meet criteria.
# Took 8.612 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_171153/MT2598_9x3_f96h20C_600s31x10s10s_C0303ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 26350 data points.
#   241 out of 5416 objects meet criteria.
# Took 14.953 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_170047/MT2598_9X3_f96h20C_600s31x10s10s_A0303eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 18 object.
#   Summary file has 8921 data points.
#   809 out of 16627 objects meet criteria.
# Took 11.321 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1178/20230307_181020/MT2598_9x3_f96H20C_600s31x10s10s_B0303ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 23558 data points.
#   457 out of 6033 objects meet criteria.
# Took 11.988 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_165930/FX02854_9X3_f96h20C_600s31x10s10s_A0324cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 22823 data points.
#   421 out of 6962 objects meet criteria.
# Took 8.032 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_170753/FX02854_9x3_f96h20C_600s31x10s10s_C0328cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 23 object.
#   Summary file has 13478 data points.
#   790 out of 22695 objects meet criteria.
# Took 9.644 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_180515/FX02854_9x3_f96H20C_600s31x10s10s_B0324ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14981 data points.
#   588 out of 4346 objects meet criteria.
# Took 8.628 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_144823/FX02854_9x3_f96h20C_600s31x10s10s_C0328ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14571 data points.
#   574 out of 8074 objects meet criteria.
# Took 8.381 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2854/20230328_155537/FX02854_9x3_f96H20C_600s31x10s10s_B0324cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 48 object.
#   Summary file has 9096 data points.
#   967 out of 49891 objects meet criteria.
# Took 12.507 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_163154/JT200_9X3_f96h20C_600s31x10s10s_A0303bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 13871 data points.
#   386 out of 5460 objects meet criteria.
# Took 8.045 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_150833/JT200_9x3_f96H20C_600s31x10s10s_B0303ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 20254 data points.
#   422 out of 6859 objects meet criteria.
# Took 12.260 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_184521/JT200_9X3_f96h20C_600s31x10s10s_A0303be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 9979 data points.
#   669 out of 11571 objects meet criteria.
# Took 8.309 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_174407/JT200_9x3_f96H20C_600s31x10s10s_B0303bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14806 data points.
#   586 out of 5084 objects meet criteria.
# Took 9.822 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_sa200/20230307_164536/JT200_9x3_f96h20C_600s31x10s10s_C0303bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 18512 data points.
#   663 out of 9976 objects meet criteria.
# Took 13.916 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_160535/FX02012_9X3_f96h20C_600s31x10s10s_A0324bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 13151 data points.
#   878 out of 14249 objects meet criteria.
# Took 10.047 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_171401/FX02012_9x3_f96H20C_600s31x10s10s_B0324bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 12412 data points.
#   898 out of 12422 objects meet criteria.
# Took 11.112 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_145406/FX02012_9x3_f96H20C_600s31x10s10s_B0324ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 17873 data points.
#   940 out of 10095 objects meet criteria.
# Took 15.811 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_181512/FX02012_9X3_f96h20C_600s31x10s10s_A0324be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14674 data points.
#   749 out of 5790 objects meet criteria.
# Took 10.183 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_tm2012/20230328_161631/FX02012_9x3_f96h20C_600s31x10s10s_C0328bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28284 data points.
#   84 out of 2797 objects meet criteria.
# Took 11.449 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_181945/CB408_9X3_f96h20C_600s31x10s10s_A0303dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 16167 data points.
#   108 out of 3611 objects meet criteria.
# Took 6.895 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_183012/CB408_9x3_f96h20C_600s31x10s10s_C0303de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14656 data points.
#   107 out of 4742 objects meet criteria.
# Took 7.967 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_171734/CB408_9x3_f96H20C_600s31x10s10s_B0303dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 19764 data points.
#   99 out of 1551 objects meet criteria.
# Took 7.143 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_161645/CB408_9x3_f96h20C_600s31x10s10s_C0303db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28397 data points.
#   79 out of 3643 objects meet criteria.
# Took 9.333 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_e408/20230307_154709/CB408_9X3_f96h20C_600s31x10s10s_A0303da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 19 object.
#   Summary file has 18290 data points.
#   789 out of 17951 objects meet criteria.
# Took 13.485 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_150445/N2_9X2_f96h20C_600s31x10s10s_A0331aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 20 object.
#   Summary file has 14541 data points.
#   948 out of 19631 objects meet criteria.
# Took 13.508 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_151756/N2_9X3_f96h20C_600s31x10s10s_A0303aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 18 object.
#   Summary file has 13125 data points.
#   809 out of 18202 objects meet criteria.
# Took 9.601 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_151952/N2_9x2_f96H20C_600s31x10s10s_B0331ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 18456 data points.
#   706 out of 8270 objects meet criteria.
# Took 14.796 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_150531/N2_10x2_f96h20C_600s31x10s10s_A0518aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 19102 data points.
#   476 out of 10603 objects meet criteria.
# Took 11.863 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_150354/N2_9X3_f96h20C_600s31x10s10s_A0324aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 12645 data points.
#   803 out of 9859 objects meet criteria.
# Took 9.201 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_165121/N2_9x3_f96H20C_600s31x10s10s_B0303ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15827 data points.
#   640 out of 3354 objects meet criteria.
# Took 8.116 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_180436/N2_9x3_f96h20C_600s31x10s10s_C0303ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 18055 data points.
#   860 out of 10389 objects meet criteria.
# Took 14.977 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_164341/N2_10x2_f96h20C_600s31x10s10s_A0518ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 19816 data points.
#   552 out of 6568 objects meet criteria.
# Took 12.357 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_175333/N2_9X3_f96h20C_600s31x10s10s_A0303ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 17 object.
#   Summary file has 13418 data points.
#   882 out of 16430 objects meet criteria.
# Took 9.406 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_164155/N2_9x2_f96H20C_600s31x10s10s_B0331ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 12161 data points.
#   729 out of 15525 objects meet criteria.
# Took 9.478 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_162219/N2_9x3_f96H20C_600s31x10s10s_B0324ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15031 data points.
#   776 out of 3915 objects meet criteria.
# Took 9.046 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230307_153247/N2_9x3_f96h20C_600s31x10s10s_C0303ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 15784 data points.
#   702 out of 14500 objects meet criteria.
# Took 13.986 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_172414/N2_9X3_f96h20C_600s31x10s10s_A0324ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 13208 data points.
#   693 out of 20314 objects meet criteria.
# Took 9.913 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_152010/N2_10x2_f96H20C_600s31x10s10s_B0518ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 17579 data points.
#   735 out of 20317 objects meet criteria.
# Took 14.430 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_162923/N2_9X2_f96h20C_600s31x10s10s_A0331ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14697 data points.
#   765 out of 7793 objects meet criteria.
# Took 9.696 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230404_154513/N2_9x2_f96h20C_600s31x10s10s_C0331ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 24 object.
#   Summary file has 9619 data points.
#   1564 out of 24460 objects meet criteria.
# Took 12.676 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_152003/N2_9x3_f96h20C_600s31x10s10s_C0328ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 15696 data points.
#   526 out of 6946 objects meet criteria.
# Took 8.160 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_170002/N2_10x2_f96H20C_600s31x10s10s_B0518ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14751 data points.
#   665 out of 4840 objects meet criteria.
# Took 9.765 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230522_161132/N2_10x2_f96h20C_600s31x10s10s_C0518ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 14526 data points.
#   1092 out of 9590 objects meet criteria.
# Took 11.781 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/N2/20230328_173233/N2_9x3_f96h20C_600s31x10s10s_C0328ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 35270 data points.
#   4 out of 53 objects meet criteria.
# Took 0.532 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498/20230328_163207/MT1092_9X3_f96h20C_600s31x10s10s_A0324eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29871 data points.
#   5 out of 72 objects meet criteria.
# Took 0.929 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498/20230328_180215/MT1092_9x3_f96h20C_600s31x10s10s_C0328ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29865 data points.
#   5 out of 25 objects meet criteria.
# Took 0.761 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498/20230328_164336/MT1092_9x3_f96h20C_600s31x10s10s_C0328ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 26350 data points.
#   8 out of 46 objects meet criteria.
# Took 0.754 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498/20230328_152559/MT1092_9x3_f96H20C_600s31x10s10s_B0324ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 23218 data points.
#   4 out of 4003 objects meet criteria.
# Took 0.982 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498/20230328_173828/MT1092_9x3_f96H20C_600s31x10s10s_B0324ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 15237 data points.
#   178 out of 4840 objects meet criteria.
# Took 8.575 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1186/20230404_161316/MT2605_9x2_f96h20C_600s31x10s10s_C0331cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 11984 data points.
#   203 out of 9403 objects meet criteria.
# Took 5.896 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1186/20230404_155113/MT2605_9x2_f96H20C_600s31x10s10s_B0331cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14848 data points.
#   223 out of 5385 objects meet criteria.
# Took 9.192 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1186/20230404_144839/MT2605_9x2_f96h20C_600s31x10s10s_C0331ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 19693 data points.
#   175 out of 8739 objects meet criteria.
# Took 12.065 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1186/20230404_152959/MT2605_9X2_f96h20C_600s31x10s10s_A0331cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 26483 data points.
#   135 out of 6632 objects meet criteria.
# Took 12.275 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-43/unc-43_n498n1186/20230404_165501/MT2605_9X2_f96h20C_600s31x10s10s_A0331ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 13549 data points.
#   446 out of 13206 objects meet criteria.
# Took 11.955 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230607_205603/CB102_15X2_f96H20C_600s31x10s10s_B0603bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 22310 data points.
#   194 out of 1761 objects meet criteria.
# Took 9.629 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230510_100659/CB102_8x3_f96h20C_600s31x10s10s_C0506bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 16748 data points.
#   151 out of 3883 objects meet criteria.
# Took 6.463 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230510_094505/CB102_8x3_f96H20C_600s31x10s10s_B0506ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 15633 data points.
#   150 out of 5003 objects meet criteria.
# Took 6.893 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230510_113120/CB102_8x3_f96H20C_600s31x10s10s_B0506bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14501 data points.
#   519 out of 7131 objects meet criteria.
# Took 13.065 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230607_212052/CB102_15x2_f96h20C_600s31x10s10s_C0603bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 16000 data points.
#   227 out of 1701 objects meet criteria.
# Took 8.223 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230510_120255/CB102_8x3_f96h20C_600s31x10s10s_C0506be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27764 data points.
#   174 out of 2473 objects meet criteria.
# Took 11.395 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230510_110609/CB102_8X3_f96h20C_600s31x10s10s_A0506bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 14558 data points.
#   385 out of 9961 objects meet criteria.
# Took 12.291 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230607_191007/CB102_15x2_f96h20C_600s31x10s10s_C0603bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 17 object.
#   Summary file has 18134 data points.
#   466 out of 17628 objects meet criteria.
# Took 16.249 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230607_203653/CB102_15x2_f96h20C_600s31x10s10s_A0603bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14011 data points.
#   451 out of 6145 objects meet criteria.
# Took 11.918 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_e102/20230607_184751/CB102_15X2_f96H20C_600s31x10s10s_B0603ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 18872 data points.
#   539 out of 14310 objects meet criteria.
# Took 15.167 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_md1117/20230522_173529/NM1657_10x2_f96h20C_600s31x10s10s_A0518ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14538 data points.
#   571 out of 6480 objects meet criteria.
# Took 12.408 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_md1117/20230522_170019/NM1657_10x2_f96h20C_600s31x10s10s_C0518cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14806 data points.
#   449 out of 6603 objects meet criteria.
# Took 10.215 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_md1117/20230522_161048/NM1657_10x2_f96H20C_600s31x10s10s_B0518cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 27564 data points.
#   271 out of 10124 objects meet criteria.
# Took 13.871 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_md1117/20230522_155614/NM1657_10x2_f96h20C_600s31x10s10s_A0518cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15662 data points.
#   318 out of 3412 objects meet criteria.
# Took 9.350 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/unc-10_md1117/20230522_150846/NM1657_10x2_f96h20C_600s31x10s10s_C0518ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 26094 data points.
#   547 out of 5589 objects meet criteria.
# Took 12.918 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230510_095447/N2_8X3_f96h20C_600s31x10s10s_A0506aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15508 data points.
#   474 out of 4994 objects meet criteria.
# Took 8.038 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230607_191636/N2_9X2_f96H20C_600s31x10s10s_B0603ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 27787 data points.
#   272 out of 6361 objects meet criteria.
# Took 10.028 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230607_185939/N2_9x2_f96h20C_600s31x10s10s_A0603aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14896 data points.
#   745 out of 4719 objects meet criteria.
# Took 9.006 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230510_103543/N2_8x3_f96h20C_600s31x10s10s_C0506ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 18456 data points.
#   706 out of 8270 objects meet criteria.
# Took 14.231 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230522_150531/N2_10x2_f96h20C_600s31x10s10s_A0518aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14057 data points.
#   906 out of 5802 objects meet criteria.
# Took 9.111 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230510_101035/N2_8x3_f96H20C_600s31x10s10s_B0506ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 11 object.
#   Summary file has 18055 data points.
#   860 out of 10389 objects meet criteria.
# Took 14.584 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230522_164341/N2_10x2_f96h20C_600s31x10s10s_A0518ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 18470 data points.
#   702 out of 8526 objects meet criteria.
# Took 13.434 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230510_113902/N2_8X3_f96h20C_600s31x10s10s_A0506ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 17781 data points.
#   489 out of 4509 objects meet criteria.
# Took 8.066 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230607_212723/N2_9X2_f96H20C_600s31x10s10s_B0603ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 13208 data points.
#   693 out of 20314 objects meet criteria.
# Took 9.826 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230522_152010/N2_10x2_f96H20C_600s31x10s10s_B0518ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 15345 data points.
#   490 out of 17337 objects meet criteria.
# Took 6.605 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230607_194156/N2_9x2_f96h20C_600s31x10s10s_C0603ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 18972 data points.
#   710 out of 12709 objects meet criteria.
# Took 10.339 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230607_210749/N2_9x2_f96h20C_600s31x10s10s_A0603ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14112 data points.
#   735 out of 6550 objects meet criteria.
# Took 8.494 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230510_120752/N2_8x3_f96H20C_600s31x10s10s_B0506ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 15696 data points.
#   526 out of 6946 objects meet criteria.
# Took 8.171 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230522_170002/N2_10x2_f96H20C_600s31x10s10s_B0518ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14751 data points.
#   665 out of 4840 objects meet criteria.
# Took 9.849 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/unc-10/N2/20230522_161132/N2_10x2_f96h20C_600s31x10s10s_C0518ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 20145 data points.
#   169 out of 946 objects meet criteria.
# Took 4.198 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230510_123120/VC1311_8x3_f96H20C_600s31x10s10s_B0506de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28100 data points.
#   288 out of 3632 objects meet criteria.
# Took 8.509 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230523_095300/VC1311_12x2_f96h20C_600s31x10s10s_A0519bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29731 data points.
#   123 out of 680 objects meet criteria.
# Took 5.600 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230510_101845/VC1311_8X3_f96h20C_600s31x10s10s_A0506da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28997 data points.
#   285 out of 6063 objects meet criteria.
# Took 7.848 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230523_105131/VC1311_12x2_f96h20C_600s31x10s10s_C0519be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29674 data points.
#   123 out of 890 objects meet criteria.
# Took 5.730 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230510_121749/VC1311_8X3_f96h20C_600s31x10s10s_A0506dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15810 data points.
#   212 out of 2775 objects meet criteria.
# Took 4.685 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230523_085027/VC1311_12x2_f96H20C_600s31x10s10s_B0519ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29614 data points.
#   97 out of 450 objects meet criteria.
# Took 4.280 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230510_105934/VC1311_8x3_f96h20C_600s31x10s10s_C0506dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 17279 data points.
#   330 out of 1949 objects meet criteria.
# Took 5.433 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230510_103957/VC1311_8x3_f96H20C_600s31x10s10s_B0506db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29064 data points.
#   235 out of 2311 objects meet criteria.
# Took 8.370 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230523_090951/VC1311_12x2_f96h20C_600s31x10s10s_C0519bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 15615 data points.
#   500 out of 7405 objects meet criteria.
# Took 6.695 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-3_ok1788/20230523_102953/VC1311_12x2_f96H20C_600s31x10s10s_B0519bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 18209 data points.
#   364 out of 1905 objects meet criteria.
# Took 6.257 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_ok3370/20230607_194827/VC2662_15X2_f96H20C_600s31x10s10s_B0603db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29099 data points.
#   231 out of 2810 objects meet criteria.
# Took 6.830 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_ok3370/20230607_201835_OMIT/VC2662_15x2_f96h20C_600s31x10s10s_C0603dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28532 data points.
#   281 out of 2103 objects meet criteria.
# Took 7.205 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_ok3370/20230607_192822/VC2662_15x2_f96h20C_600s31x10s10s_A0603da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 15668 data points.
#   335 out of 1996 objects meet criteria.
# Took 4.724 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_ok3370/20230607_215643/VC2662_15X2_f96H20C_600s31x10s10s_B0603de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 28040 data points.
#   281 out of 2085 objects meet criteria.
# Took 9.019 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_ok3370/20230607_213910/VC2662_15x2_f96h20C_600s31x10s10s_A0603dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 20060 data points.
#   559 out of 5657 objects meet criteria.
# Took 11.900 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-6_tm12210/20230529_162017/FX31424_11x2_f96h20C_600s31x10s10s_A0525ed.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15977 data points.
#   441 out of 4536 objects meet criteria.
# Took 7.642 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-6_tm12210/20230529_171052/FX31424_11x2_f96h20C_600s31x10s10s_C0525ee.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 21378 data points.
#   508 out of 5961 objects meet criteria.
# Took 12.148 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-6_tm12210/20230529_144217/FX31424_11x2_f96h20C_600s31x10s10s_A0525eb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 13756 data points.
#   672 out of 5789 objects meet criteria.
# Took 9.384 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-6_tm12210/20230529_131005/FX31424_11x2_f96H20C_600s31x10s10s_B0525ea.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14712 data points.
#   619 out of 3584 objects meet criteria.
# Took 9.033 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-6_tm12210/20230529_144707/FX31424_11x2_f96h20C_600s31x10s10s_C0525ec.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14201 data points.
#   648 out of 4343 objects meet criteria.
# Took 9.390 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-8_ok2956/20230529_145334/RB2180_11x2_f96H20C_600s31x10s10s_B0525dc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14695 data points.
#   815 out of 4984 objects meet criteria.
# Took 9.578 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-8_ok2956/20230529_134800/RB2180_11x2_f96h20C_600s31x10s10s_C0525db.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14336 data points.
#   1023 out of 8760 objects meet criteria.
# Took 13.414 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-8_ok2956/20230529_162924/RB2180_11x2_f96h20C_600s31x10s10s_C0525de.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15228 data points.
#   657 out of 4066 objects meet criteria.
# Took 9.403 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-8_ok2956/20230529_160843/RB2180_11x2_f96H20C_600s31x10s10s_B0525dd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 19866 data points.
#   471 out of 4802 objects meet criteria.
# Took 11.751 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-8_ok2956/20230529_132138/RB2180_11x2_f96h20C_600s31x10s10s_A0525da.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14792 data points.
#   750 out of 5637 objects meet criteria.
# Took 8.943 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230523_093512/N2_10x2_f96h20C_600s31x10s10s_C0519ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 26094 data points.
#   547 out of 5589 objects meet criteria.
# Took 13.533 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230510_095447/N2_8X3_f96h20C_600s31x10s10s_A0506aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15508 data points.
#   474 out of 4994 objects meet criteria.
# Took 8.175 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230607_191636/N2_9X2_f96H20C_600s31x10s10s_B0603ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 20 object.
#   Summary file has 21300 data points.
#   520 out of 19465 objects meet criteria.
# Took 10.654 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230529_124724/N2_9x2_f96h20C_600s31x10s10s_A0525aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 27787 data points.
#   272 out of 6361 objects meet criteria.
# Took 10.080 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230607_185939/N2_9x2_f96h20C_600s31x10s10s_A0603aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14896 data points.
#   745 out of 4719 objects meet criteria.
# Took 9.159 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230510_103543/N2_8x3_f96h20C_600s31x10s10s_C0506ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 18707 data points.
#   799 out of 7558 objects meet criteria.
# Took 13.743 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230523_104119/N2_10x2_f96h20C_600s31x10s10s_A0519ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 96 object.
#   Summary file has 13406 data points.
#   559 out of 96604 objects meet criteria.
# Took 9.183 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230529_160217/N2_9x2_f96h20C_600s31x10s10s_C0525ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14057 data points.
#   906 out of 5802 objects meet criteria.
# Took 9.017 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230510_101035/N2_8x3_f96H20C_600s31x10s10s_B0506ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 20 object.
#   Summary file has 12068 data points.
#   1066 out of 20095 objects meet criteria.
# Took 12.705 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230523_091610/N2_10x2_f96H20C_600s31x10s10s_B0519ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 18470 data points.
#   702 out of 8526 objects meet criteria.
# Took 13.982 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230510_113902/N2_8X3_f96h20C_600s31x10s10s_A0506ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 17781 data points.
#   489 out of 4509 objects meet criteria.
# Took 8.077 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230607_212723/N2_9X2_f96H20C_600s31x10s10s_B0603ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 20771 data points.
#   554 out of 6332 objects meet criteria.
# Took 8.779 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230529_143043/N2_9x2_f96H20C_600s31x10s10s_B0525ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 14905 data points.
#   641 out of 13785 objects meet criteria.
# Took 8.095 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230529_130338/N2_9x2_f96h20C_600s31x10s10s_C0525ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 15345 data points.
#   490 out of 17337 objects meet criteria.
# Took 6.640 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230607_194156/N2_9x2_f96h20C_600s31x10s10s_C0603ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 14520 data points.
#   701 out of 7504 objects meet criteria.
# Took 9.251 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230523_105753/N2_10x2_f96H20C_600s31x10s10s_B0519ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 13 object.
#   Summary file has 18972 data points.
#   710 out of 12709 objects meet criteria.
# Took 10.462 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230607_210749/N2_9x2_f96h20C_600s31x10s10s_A0603ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14112 data points.
#   735 out of 6550 objects meet criteria.
# Took 8.692 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230510_120752/N2_8x3_f96H20C_600s31x10s10s_B0506ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 18545 data points.
#   883 out of 9082 objects meet criteria.
# Took 13.896 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230523_090149/N2_10x2_f96h20C_600s31x10s10s_A0519aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 21 object.
#   Summary file has 19733 data points.
#   611 out of 20777 objects meet criteria.
# Took 9.281 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/N2/20230529_154347/N2_9x2_f96h20C_600s31x10s10s_A0525ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 14 object.
#   Summary file has 14420 data points.
#   2438 out of 14847 objects meet criteria.
# Took 14.280 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_tm1759/20230529_142417/FX01759_9x2_f96h20C_600s31x10s10s_C0525bc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 20298 data points.
#   542 out of 7668 objects meet criteria.
# Took 11.194 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_tm1759/20230529_140602/FX01759_9x2_f96h20C_600s31x10s10s_A0525bb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 18205 data points.
#   461 out of 2946 objects meet criteria.
# Took 9.596 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_tm1759/20230529_123550/FX01759_9x2_f96H20C_600s31x10s10s_B0525ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 17 object.
#   Summary file has 18764 data points.
#   746 out of 17254 objects meet criteria.
# Took 12.081 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_tm1759/20230529_164725/FX01759_9x2_f96h20C_600s31x10s10s_A0525be.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14182 data points.
#   766 out of 7399 objects meet criteria.
# Took 8.874 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-9_tm1759/20230529_153213/FX01759_9x2_f96H20C_600s31x10s10s_B0525bd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 14292 data points.
#   1188 out of 7931 objects meet criteria.
# Took 10.116 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230529_135428/RB2473_10x2_f96H20C_600s31x10s10s_B0525cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14793 data points.
#   948 out of 5522 objects meet criteria.
# Took 8.737 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230529_163551/RB2473_10x2_f96H20C_600s31x10s10s_B0525ce.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 19385 data points.
#   512 out of 3109 objects meet criteria.
# Took 8.116 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230529_122923/RB2473_10x2_f96h20C_600s31x10s10s_C0525ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29373 data points.
#   181 out of 1397 objects meet criteria.
# Took 6.129 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230510_094255/RB2473_8x3_f96h20C_600s31x10s10s_C0506ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15910 data points.
#   492 out of 5371 objects meet criteria.
# Took 7.272 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230529_152545/RB2473_10x2_f96h20C_600s31x10s10s_C0525cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29801 data points.
#   89 out of 1473 objects meet criteria.
# Took 3.774 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230510_104223/RB2473_8X3_f96h20C_600s31x10s10s_A0506cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 23524 data points.
#   546 out of 10085 objects meet criteria.
# Took 11.647 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230529_150509/RB2473_10x2_f96h20C_600s31x10s10s_A0525cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29519 data points.
#   150 out of 886 objects meet criteria.
# Took 5.533 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230510_112320/RB2473_8x3_f96h20C_600s31x10s10s_C0506cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 21034 data points.
#   73 out of 425 objects meet criteria.
# Took 2.521 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230510_111010/RB2473_8x3_f96H20C_600s31x10s10s_B0506cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 30526 data points.
#   52 out of 717 objects meet criteria.
# Took 2.586 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-4_ok3413/20230510_124135/RB2473_8X3_f96h20C_600s31x10s10s_A0506.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 15 object.
#   Summary file has 13486 data points.
#   785 out of 15449 objects meet criteria.
# Took 10.204 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-2_ok2833/20230523_094135/RB2129_11x2_f96H20C_600s31x10s10s_B0519cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 18761 data points.
#   807 out of 8691 objects meet criteria.
# Took 12.173 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-2_ok2833/20230523_092733/RB2129_11x2_f96h20C_600s31x10s10s_A0519cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 14534 data points.
#   968 out of 10587 objects meet criteria.
# Took 10.991 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-2_ok2833/20230523_102330/RB2129_11x2_f96h20C_600s31x10s10s_C0519cd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 14638 data points.
#   763 out of 7954 objects meet criteria.
# Took 9.780 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-2_ok2833/20230523_084403/RB2129_11x2_f96h20C_600s31x10s10s_C0519ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 14582 data points.
#   1438 out of 16358 objects meet criteria.
# Took 14.599 seconds to load data
# Writing summary file /Users/Joseph/Desktop/Anushka/cpr (2,3,4,6,8,9)/cpr-2_ok2833/20230523_110918/RB2129_11x2_f96h20C_600s31x10s10s_A0519ce.dat
#   Write successful.
