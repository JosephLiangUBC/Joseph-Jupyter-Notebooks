# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import os #<- package used to work with system filepaths
import subprocess
from ipywidgets import widgets #<- widget tool to generate button
from IPython.display import display #<- displays button
# from tkinter import Tk, filedialog #<- Tkinter is a GUI package
from tqdm.notebook import tqdm
from ipyfilechooser import FileChooser

print("done step 1")
# Out:
# done step 1

# %%
starting_directory='/Users/Joseph/Desktop/'
chooser=FileChooser(starting_directory)
display(chooser)
# Out:
# FileChooser(path='/Users/Joseph/Desktop', filename='', title='', show_hidden=False, select_desc='Select', chan…

# %%
folder_path=chooser.selected_path
print(folder_path)
# Out:
# /Volumes/JOSEPH/Autism_N2

# %%
# *************************************Redundant
# ### Select Folder App - After you run, you can select your folder for filepath
# button = widgets.Button(description = 'Select Folder') #<- creates a button variable
# display(button) #<- displays the button in output

# def select_folder(b): #<- defines an action. This action requires a variable, so an arbitrary one 'b' is there
#     global folder_path #<- sets a variable as a global variable, not just within this action
#     #Tk().withdraw() #<- Tkinter likes to create annoying empty windows. This removes them
#     folder_path = filedialog.askdirectory() #<- Opens up a file explorer window, and determines folder path
#     #Tk().update() #<- below
#     #Tk().destroy() #<- this and the line above it removes the file explorer window after a selection is made
#     print(folder_path) #<- this helps confirm that this action was performed
#     print('done step 2')
# button.on_click(select_folder)

# %%
#folder_path = '/Users/Joseph/Desktop/lrk1_ATR_NoATR_08_15_2019'
print(folder_path)
os.chdir(folder_path) #<- setting your working directory so that your images will be saved here

filelist = list() #<- empty list
for root, dirs, files in os.walk(folder_path): #<- this for loop goes through your folder 
    for name in files:
        if name.endswith('.zip'): #<- and takes out all files with a .dat (file that contains your data)
            filepath = os.path.join(root, name) #<- Notes down the file path of each data file
            filelist.append(filepath) #<- saves it into the list
    
print(filelist)
print('done step 3')
# Out:
# /Volumes/JOSEPH/Autism_N2
# ['/Volumes/JOSEPH/Autism_N2/N2/20150516_111130.zip', '/Volumes/JOSEPH/Autism_N2/N2/20150516_111143.zip', '/Volumes/JOSEPH/Autism_N2/N2/20150516_113617.zip', '/Volumes/JOSEPH/Autism_N2/N2/20150516_111158.zip', '/Volumes/JOSEPH/Autism_N2/N2-2/20160212_145627.zip', '/Volumes/JOSEPH/Autism_N2/N2-2/20160212_145633.zip', '/Volumes/JOSEPH/Autism_N2/N2-2/20160212_145846.zip', '/Volumes/JOSEPH/Autism_N2/N2-2/20160212_151949.zip', '/Volumes/JOSEPH/Autism_N2/N2-2/20160212_152140.zip', '/Volumes/JOSEPH/Autism_N2/N2-3/20150908_105840.zip', '/Volumes/JOSEPH/Autism_N2/N2-3/20150908_104040.zip', '/Volumes/JOSEPH/Autism_N2/N2-3/20150908_103748.zip', '/Volumes/JOSEPH/Autism_N2/N2-4/20150915_081101.zip', '/Volumes/JOSEPH/Autism_N2/N2-4/20150915_080158.zip', '/Volumes/JOSEPH/Autism_N2/N2-4/20150915_082604.zip', '/Volumes/JOSEPH/Autism_N2/N2-4/20150915_083222.zip', '/Volumes/JOSEPH/Autism_N2/N2-4/20150915_081103.zip', '/Volumes/JOSEPH/Autism_N2/N2-5/20160131_130133.zip', '/Volumes/JOSEPH/Autism_N2/N2-5/20160131_130338.zip', '/Volumes/JOSEPH/Autism_N2/N2-5/20160131_132239.zip', '/Volumes/JOSEPH/Autism_N2/N2-5/20160131_132415.zip', '/Volumes/JOSEPH/Autism_N2/N2-5/20160131_132541.zip', '/Volumes/JOSEPH/Autism_N2/N2-6/20151004_122053.zip', '/Volumes/JOSEPH/Autism_N2/N2-6/20151004_124123.zip', '/Volumes/JOSEPH/Autism_N2/N2-6/20151004_122032.zip', '/Volumes/JOSEPH/Autism_N2/N2-6/20151004_124144.zip', '/Volumes/JOSEPH/Autism_N2/N2-6/20151004_122100.zip', '/Volumes/JOSEPH/Autism_N2/N2-7/20151010_114958.zip', '/Volumes/JOSEPH/Autism_N2/N2-7/20151010_115013.zip', '/Volumes/JOSEPH/Autism_N2/N2-7/20151010_121220.zip', '/Volumes/JOSEPH/Autism_N2/N2-7/20151010_115010.zip', '/Volumes/JOSEPH/Autism_N2/N2-7/20151010_121214.zip', '/Volumes/JOSEPH/Autism_N2/N2-8/20151117_093001.zip', '/Volumes/JOSEPH/Autism_N2/N2-8/20151117_090446.zip', '/Volumes/JOSEPH/Autism_N2/N2-8/20151117_090356.zip', '/Volumes/JOSEPH/Autism_N2/N2-8/20151117_090408.zip', '/Volumes/JOSEPH/Autism_N2/N2-9/20151206_104807.zip', '/Volumes/JOSEPH/Autism_N2/N2-9/20151206_102504.zip', '/Volumes/JOSEPH/Autism_N2/N2-9/20151206_102511.zip', '/Volumes/JOSEPH/Autism_N2/N2-9/20151206_102611.zip', '/Volumes/JOSEPH/Autism_N2/N2-9/20151206_104915.zip', '/Volumes/JOSEPH/Autism_N2/N2-10/20150517_105027.zip', '/Volumes/JOSEPH/Autism_N2/N2-10/20150517_112032.zip', '/Volumes/JOSEPH/Autism_N2/N2-10/20150517_105105.zip', '/Volumes/JOSEPH/Autism_N2/N2-10/20150517_105151.zip', '/Volumes/JOSEPH/Autism_N2/N2-11/20160406_150904.zip', '/Volumes/JOSEPH/Autism_N2/N2-11/20160406_152940.zip', '/Volumes/JOSEPH/Autism_N2/N2-11/20160406_150655.zip', '/Volumes/JOSEPH/Autism_N2/N2-11/20160406_150531.zip', '/Volumes/JOSEPH/Autism_N2/N2-12/20160422_101656.zip', '/Volumes/JOSEPH/Autism_N2/N2-12/20160422_095545.zip', '/Volumes/JOSEPH/Autism_N2/N2-12/20160422_095438.zip', '/Volumes/JOSEPH/Autism_N2/N2-12/20160422_095247.zip', '/Volumes/JOSEPH/Autism_N2/N2-13/20160517_094701.zip', '/Volumes/JOSEPH/Autism_N2/N2-13/20160517_092558.zip', '/Volumes/JOSEPH/Autism_N2/N2-13/20160517_092220.zip', '/Volumes/JOSEPH/Autism_N2/N2-13/20160517_094345.zip', '/Volumes/JOSEPH/Autism_N2/N2-13/20160517_091959.zip', '/Volumes/JOSEPH/Autism_N2/N2-14/20160526_183019.zip', '/Volumes/JOSEPH/Autism_N2/N2-14/20160526_185047.zip', '/Volumes/JOSEPH/Autism_N2/N2-14/20160526_183053.zip', '/Volumes/JOSEPH/Autism_N2/N2-14/20160526_185130.zip', '/Volumes/JOSEPH/Autism_N2/N2-15/20160628_130834.zip', '/Volumes/JOSEPH/Autism_N2/N2-15/20160628_130849.zip', '/Volumes/JOSEPH/Autism_N2/N2-15/20160628_130921.zip', '/Volumes/JOSEPH/Autism_N2/N2-15/20160628_133001.zip', '/Volumes/JOSEPH/Autism_N2/N2-16/20160723_101707.zip', '/Volumes/JOSEPH/Autism_N2/N2-16/20160723_104007.zip', '/Volumes/JOSEPH/Autism_N2/N2-16/20160723_101559.zip', '/Volumes/JOSEPH/Autism_N2/N2-16/20160723_103905.zip', '/Volumes/JOSEPH/Autism_N2/N2-16/20160723_101530.zip', '/Volumes/JOSEPH/Autism_N2/N2-17/20160812_121908.zip', '/Volumes/JOSEPH/Autism_N2/N2-17/20160812_115626.zip', '/Volumes/JOSEPH/Autism_N2/N2-17/ ...
# done step 3

# %% [markdown]
# # For Analyzing Basal Slowing Statistics

# %%
# for speed
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', 
                     '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-N', 'all', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S', 
                     '-o', 'sxySPkbcdrlmwMe', 
                     f'{f}'])

# %% [markdown]
# # For Analyzing Tap Habituation Statistics

# %%
# for tap habituation
for f in tqdm(filelist):
    subprocess.call(['java', '-jar', '/users/Joseph/Desktop/Chore.jar', 
                     '-p', '0.027', 
                     '-s', '0.1', 
                     '-t', '20', 
                     '-M', '2', 
                     '--shadowless', 
                     '-S' ,
                     '-o', 'nNss*b12xyMmeSakcr', 
                     '--plugin', 'Reoutline::exp',
                     '--plugin', 'Respine',
                     '--plugin', 'MeasureReversal::tap::dt=1::collect=0.5::postfix=trv',
                     '--plugin', 'MeasureReversal::puff::dt=3::collect=0.5::postfix=prv',
                     '--plugin', 'MeasureReversal::postfix=txt',
                     f'{f}'])
# Out:
#   0%|          | 0/113 [00:00<?, ?it/s]
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 29465 data points.
#   463 out of 14762 objects meet criteria.
# Took 7.959 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2/20150516_111130/N2_5x4_f96h20C_600s30x10s10s_C0516ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 16199 data points.
#   774 out of 12238 objects meet criteria.
# Took 7.748 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2/20150516_111143/N2_5x4_f96h20C_600s31x10s10s_B0516ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 27888 data points.
#   741 out of 20516 objects meet criteria.
# Took 11.333 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2/20150516_113617/N2_5x4_f96h20C_600s31x10s10s_A0516ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 26778 data points.
#   758 out of 23110 objects meet criteria.
# Took 13.930 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2/20150516_111158/N2_5x4_f96h20C_600s31x10s10s_A0516aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29209 data points.
#   412 out of 5720 objects meet criteria.
# Took 10.276 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-2/20160212_145627/n2_5x4_f96h20C_600s30x10s10s_C0212ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29619 data points.
#   103 out of 1681 objects meet criteria.
# Took 3.694 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-2/20160212_145633/N2_5x4_f96h20C_600s31x10s10s_B0212ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 32272 data points.
#   332 out of 4853 objects meet criteria.
# Took 7.966 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-2/20160212_145846/N2_5x4_f96h20C_600s31x10s10s_A0212_aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15723 data points.
#   528 out of 4740 objects meet criteria.
# Took 5.488 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-2/20160212_151949/N2_5x4_f96h20C_600s31x10s10s_B0212ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29495 data points.
#   386 out of 6769 objects meet criteria.
# Took 9.588 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-2/20160212_152140/N2_5x4_f96h20C_600s31x10s10s_A0212_ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 42401 data points.
#   105 out of 4460 objects meet criteria.
# Took 4.756 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-3/20150908_105840/N2_5x4_f96h20C_600s31x10s10s_A0908cc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29827 data points.
#   52 out of 748 objects meet criteria.
# Took 1.650 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-3/20150908_104040/N2_5x4_f96h20C_600s30x10s10s_C0908cb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 27938 data points.
#   245 out of 2810 objects meet criteria.
# Took 4.783 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-3/20150908_103748/N2_5x4_f96h20C_600s31x10s10s_B0908ca.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16776 data points.
#   542 out of 5136 objects meet criteria.
# Took 6.681 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-4/20150915_081101/N2_5x4_f96h20C_600s31x10s10s_B0015ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29178 data points.
#   463 out of 6707 objects meet criteria.
# Took 10.131 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-4/20150915_080158/N2_5x4_f96h20C_600s30x10s10s_C0915aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29443 data points.
#   285 out of 3285 objects meet criteria.
# Took 8.102 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-4/20150915_082604/N2_5x4_f96h20C_600s30x10s10s_C0915ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 30362 data points.
#   288 out of 3530 objects meet criteria.
# Took 8.480 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-4/20150915_083222/N2_5x4_f96h20C_600s31x10s10s_A0915ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29973 data points.
#   362 out of 4435 objects meet criteria.
# Took 7.981 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-4/20150915_081103/N2_5x4_f96h20C_600s31x10s10s_A0915ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 16076 data points.
#   246 out of 2403 objects meet criteria.
# Took 4.840 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-5/20160131_130133/N2_5x4_f96h20C_600s31x10s10s_A0131ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 29673 data points.
#   302 out of 8022 objects meet criteria.
# Took 7.066 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-5/20160131_130338/N2_5x4_f96h20C_600s31x10s10s_A0131aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 15728 data points.
#   359 out of 3153 objects meet criteria.
# Took 4.579 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-5/20160131_132239/N2_5x4_f96h20C_600s31x10s10s_A0131ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 32693 data points.
#   171 out of 4376 objects meet criteria.
# Took 6.977 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-5/20160131_132415/N2_5x4_f96h20C_600s31x10s10s_A0131ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29544 data points.
#   206 out of 3478 objects meet criteria.
# Took 7.003 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-5/20160131_132541/N2_5x4_f96h20C_600s30x10s10s_C1206ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 37280 data points.
#   148 out of 2376 objects meet criteria.
# Took 6.243 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-6/20151004_122053/N2_5x4_f96h20C_600s31x10s10s_A1004aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29660 data points.
#   252 out of 4267 objects meet criteria.
# Took 7.238 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-6/20151004_124123/N2_5x4_f96h20C_600s31x10s10s_A1004ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29433 data points.
#   152 out of 1985 objects meet criteria.
# Took 5.273 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-6/20151004_122032/N2_5x4_f96h20C_600s31x10s10s_B1004ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29592 data points.
#   95 out of 1735 objects meet criteria.
# Took 4.008 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-6/20151004_124144/N2_5x4_f96h20C_600s31x10s10s_B1004ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29697 data points.
#   108 out of 1555 objects meet criteria.
# Took 5.134 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-6/20151004_122100/N2_5x4_f96h20C_600s31x10s10s_C1004ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29410 data points.
#   332 out of 6089 objects meet criteria.
# Took 9.280 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-7/20151010_114958/N2_5x4_f96h20C_600s31x10s10s_C1010ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 28957 data points.
#   155 out of 2710 objects meet criteria.
# Took 4.501 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-7/20151010_115013/N2_5x4_f96h20C_600s31x10s10s_B1010ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 18591 data points.
#   371 out of 3689 objects meet criteria.
# Took 5.728 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-7/20151010_121220/N2_5x4_f96h20C_600s31x10s10s_B1010ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 31333 data points.
#   172 out of 3081 objects meet criteria.
# Took 5.960 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-7/20151010_115010/N2_5x4_f96h20C_600s31x10s10s_A1010aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 18 object.
#   Summary file has 26373 data points.
#   622 out of 21394 objects meet criteria.
# Took 12.521 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-7/20151010_121214/N2_5x4_f96h20C_600s31x10s10s_A1010ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28449 data points.
#   310 out of 6893 objects meet criteria.
# Took 11.223 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-8/20151117_093001/N2_5x4_f96h20C_600s31x10s10s_A1117ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28656 data points.
#   328 out of 5438 objects meet criteria.
# Took 9.950 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-8/20151117_090446/N2_5x4_f96h20C_600s31x10s10s_A1117aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 14736 data points.
#   414 out of 5292 objects meet criteria.
# Took 6.682 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-8/20151117_090356/N2_5x4_f96h20C_600s31x10s10s_B1117ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 23288 data points.
#   653 out of 13264 objects meet criteria.
# Took 13.542 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-8/20151117_090408/N2_5x4_f96h20C_600s30x10s10s_C1117ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 23255 data points.
#   344 out of 3355 objects meet criteria.
# Took 7.916 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-9/20151206_104807/N2_5x4_f96h20C_600s31x10s10s_B1206ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 23435 data points.
#   417 out of 6034 objects meet criteria.
# Took 7.186 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-9/20151206_102504/N2_5x4_f96h20C_600s31x10s10s_B1206ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29616 data points.
#   207 out of 2875 objects meet criteria.
# Took 6.086 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-9/20151206_102511/N2_5x4_f96h20C_600s30x10s10s_C1206ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 34951 data points.
#   172 out of 3538 objects meet criteria.
# Took 7.054 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-9/20151206_102611/N2_5x4_f96h20C_600s31x10s10s_A1206aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 54934 data points.
#   102 out of 2750 objects meet criteria.
# Took 4.709 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-9/20151206_104915/N2_5x4_f96h20C_600s31x10s10s_A1206ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 24471 data points.
#   454 out of 12185 objects meet criteria.
# Took 5.554 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-10/20150517_105027/N2_5x4_f96h20C_600s31x10s10s_B0517ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 17 object.
#   Summary file has 40425 data points.
#   299 out of 20128 objects meet criteria.
# Took 6.908 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-10/20150517_112032/N2_5x4_f96h20C_600s31x10s10s_A0517ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 10 object.
#   Summary file has 29306 data points.
#   402 out of 12874 objects meet criteria.
# Took 7.464 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-10/20150517_105105/N2_5x4_f96h20C_600s30x10s10s_C0517ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 25 object.
#   Summary file has 27037 data points.
#   665 out of 26513 objects meet criteria.
# Took 10.123 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-10/20150517_105151/N2_5x4_f96h20C_600s31x10s10s_A0517aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 34483 data points.
#   129 out of 3283 objects meet criteria.
# Took 5.885 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-11/20160406_150904/N2_5x4_f94h20C_600s30x10s10s_A0406aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 30690 data points.
#   196 out of 2903 objects meet criteria.
# Took 6.127 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-11/20160406_152940/N2_5x4_f94h20C_600s30x10s10s_A0406ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29593 data points.
#   73 out of 1204 objects meet criteria.
# Took 3.292 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-11/20160406_150655/N2_5x4_f94h20C_600s30x10s10s_B0406ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 29798 data points.
#   63 out of 914 objects meet criteria.
# Took 2.456 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-11/20160406_150531/N2_5x4_f94h20C_600s30x10s10s_C0406ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 31876 data points.
#   203 out of 2638 objects meet criteria.
# Took 7.292 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-12/20160422_101656/N2_5x4_f94h20C_600s30x10s10s_A0422ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 30035 data points.
#   222 out of 4283 objects meet criteria.
# Took 7.452 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-12/20160422_095545/N2_5x4_f94h20C_600s30x10s10s_A0422aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 16526 data points.
#   467 out of 5198 objects meet criteria.
# Took 7.992 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-12/20160422_095438/N2_5x4_f96h20C_600s31x10s10s_B0422ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29801 data points.
#   128 out of 3740 objects meet criteria.
# Took 6.973 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-12/20160422_095247/N2_5x4_f96h20C_600s30x10s10s_C0422ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 27931 data points.
#   463 out of 5175 objects meet criteria.
# Took 11.075 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-13/20160517_094701/N2_5x4_f9620C_600s31x10s10s_A0517ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27988 data points.
#   351 out of 4085 objects meet criteria.
# Took 10.611 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-13/20160517_092558/N2_5x4_f9620C_600s31x10s10s_A0517aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15042 data points.
#   401 out of 2754 objects meet criteria.
# Took 6.333 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-13/20160517_092220/N2_5x4_f96h20C_600s31x10s10s_B0517ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 16252 data points.
#   583 out of 4651 objects meet criteria.
# Took 8.676 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-13/20160517_094345/N2_5x4_f96h20C_600s31x10s10s_B0517ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 28067 data points.
#   590 out of 6618 objects meet criteria.
# Took 15.005 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-13/20160517_091959/N2_5x4_f96h20C_600s31x10s10s_C0517ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 13786 data points.
#   667 out of 7116 objects meet criteria.
# Took 8.412 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-14/20160526_183019/N2_5x4_f96h20C_600s30x10s10s_B0526ga.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16364 data points.
#   427 out of 4461 objects meet criteria.
# Took 7.570 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-14/20160526_185047/N2_5x4_f96h20C_600s30x10s10s_B0526gc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28933 data points.
#   548 out of 6308 objects meet criteria.
# Took 16.072 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-14/20160526_183053/N2_5x4_f96h20C_600s30x10s10s_C0526gb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 29270 data points.
#   402 out of 6428 objects meet criteria.
# Took 13.285 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-14/20160526_185130/N2_5x4_f96h20C_600s30x10s10s_C0526gd.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29487 data points.
#   199 out of 2953 objects meet criteria.
# Took 7.481 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-15/20160628_130834/N2_5x4_f96h20C_600s30x10s10s_C0628ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 19386 data points.
#   403 out of 4327 objects meet criteria.
# Took 7.175 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-15/20160628_130849/N2_5x4_f96h20C_600s31x10s10s_B0628ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 32748 data points.
#   176 out of 4253 objects meet criteria.
# Took 6.397 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-15/20160628_130921/N2_5x4_f96h20C_600s31x10s10s_A0628aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28896 data points.
#   366 out of 6004 objects meet criteria.
# Took 9.014 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-15/20160628_133001/N2_5x4_f96h20C_600s31x10s10s_A0628ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 19510 data points.
#   865 out of 7404 objects meet criteria.
# Took 13.004 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-16/20160723_101707/N2_5x4_f96h20C_600s31x10s10s_A0723aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27866 data points.
#   369 out of 4740 objects meet criteria.
# Took 11.295 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-16/20160723_104007/N2_5x4_f96h20C_600s31x10s10s_A0723ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 17654 data points.
#   939 out of 4950 objects meet criteria.
# Took 9.950 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-16/20160723_101559/N2_5x4_f96h20C_600s31x10s10s_B00723ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16248 data points.
#   540 out of 3717 objects meet criteria.
# Took 7.477 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-16/20160723_103905/N2_5x4_f96h20C_600s31x10s10s_B00723ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 28394 data points.
#   732 out of 5397 objects meet criteria.
# Took 17.062 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-16/20160723_101530/N2_5x4_f96h20C_600s31x10s10s_C0723ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 44498 data points.
#   144 out of 5050 objects meet criteria.
# Took 6.257 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-17/20160812_121908/N2_5x4_f96h20C_600s31x10s10s_A0812ad.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 29053 data points.
#   252 out of 6348 objects meet criteria.
# Took 8.008 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-17/20160812_115626/N2_5x4_f96h20C_600s31x10s10s_A1010aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15638 data points.
#   370 out of 5130 objects meet criteria.
# Took 6.850 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-17/20160812_121727/N2_5x4_f96h20C_600s31x10s10s_B0812ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 29210 data points.
#   296 out of 4786 objects meet criteria.
# Took 10.939 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-17/20160812_115405/N2_5x4_f96h20C_600s31x10s10s_C1010ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 2 object.
#   Summary file has 29544 data points.
#   202 out of 3471 objects meet criteria.
# Took 6.921 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-17/20160812_121648/N2_5x4_f96h20C_600s31x10s10s_C1010ae.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 21625 data points.
#   631 out of 11175 objects meet criteria.
# Took 9.711 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-18/20190514_095608/N2_5x4_f96h20C_600s31x10s10s_C0514ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 16992 data points.
#   897 out of 7375 objects meet criteria.
# Took 9.996 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-18/20190514_140535/N2_5x4_f96h20C_600s31x10s10s_C0514kc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 15018 data points.
#   830 out of 8745 objects meet criteria.
# Took 9.370 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-18/20190514_095631/N2_5x4_f96h20C_600s31x10s10s_B0514ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15231 data points.
#   815 out of 7023 objects meet criteria.
# Took 8.779 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-18/20190514_140605/N2_5x4_f96h20C_600s31x10s10s_B0514kb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 25363 data points.
#   697 out of 10305 objects meet criteria.
# Took 14.634 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-18/20190514_095959/N2_5x4_f96h20C_600s31x10s10s_A0514aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 25607 data points.
#   435 out of 4541 objects meet criteria.
# Took 12.246 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-19/20190611_103301/N2_5x4_f96h20C_600s31x10s10s_C0611ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 16098 data points.
#   490 out of 4292 objects meet criteria.
# Took 7.830 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-19/20190611_103329/N2_5x4_f96h20C_600s31x10s10s_B0611ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 8 object.
#   Summary file has 19517 data points.
#   718 out of 10774 objects meet criteria.
# Took 11.569 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-19/20190611_104112/N2_5x4_f96h20C_600s31x10s10s_A0611aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 15633 data points.
#   473 out of 5063 objects meet criteria.
# Took 7.547 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-19/20190611_142854/N2_5x4_f96h20C_600s31x10s10s_B0611jb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 27967 data points.
#   332 out of 6397 objects meet criteria.
# Took 10.084 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-19/20190611_143647/N2_5x4_f96h20C_600s31x10s10s_A0611ja.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 19 object.
#   Summary file has 18660 data points.
#   764 out of 22560 objects meet criteria.
# Took 11.589 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-20/20190626_114106/N2_5x4_f96h20C_600s31x10s10s_A0626ba.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 18 object.
#   Summary file has 19679 data points.
#   918 out of 21694 objects meet criteria.
# Took 12.945 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-20/20190626_110718/N2_5x4_f96h20C_600s31x10s10s_A0626aa.dat
#   Write successful.
# Error Finding Files
#   More than one .summary file found in /Volumes/JOSEPH/Autism_N2/N2-20/20190626_113308.zip
#
# Reading files: 1 summary, 0 reference, 49 object.
#   Summary file has 13443 data points.
#   550 out of 51913 objects meet criteria.
# Took 9.175 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-20/20190626_105907/N2_5x4_f96h20C_600s31x10s10s_B0626ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 25 object.
#   Summary file has 14727 data points.
#   1692 out of 29345 objects meet criteria.
# Took 11.747 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-20/20190626_105828/N2_5x4_f96h20C_600s31x10s10s_C0626ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 15727 data points.
#   518 out of 6168 objects meet criteria.
# Took 9.170 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-21/20190718_095504/N2_5x4_f96h20C_600s31x10s10s_C0718ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 4 object.
#   Summary file has 14863 data points.
#   571 out of 4787 objects meet criteria.
# Took 9.700 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-21/20190718_095607/N2_5x4_f96h20C_600s31x10s10s_B0718ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 14442 data points.
#   366 out of 6926 objects meet criteria.
# Took 8.600 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-21/20190718_142729/N2_5x4_f96h20C_600s31x10s10s_B0718jb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 27877 data points.
#   189 out of 3569 objects meet criteria.
# Took 12.895 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-21/20190718_143619/N2_5x4_f96h20C_600s31x10s10s_A0718ja.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 18786 data points.
#   661 out of 8688 objects meet criteria.
# Took 12.403 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-21/20190718_100513/N2_5x4_f96h20C_600s31x10s10s_A0718aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 28371 data points.
#   338 out of 8090 objects meet criteria.
# Took 9.423 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_090725/N2_5x4_f96h20C_600s31x10s10s_C0723ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 29024 data points.
#   378 out of 7686 objects meet criteria.
# Took 8.181 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_141523/N2_5x4_f96h20C_600s31x10s10s_C0723nc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 18818 data points.
#   354 out of 3588 objects meet criteria.
# Took 7.008 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_121749/N2_5x4_f96h20C_600s31x10s10s_B0723ib.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 1 object.
#   Summary file has 23420 data points.
#   143 out of 1307 objects meet criteria.
# Took 4.684 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_141619/N2_5x4_f96h20C_600s31x10s10s_B0723nb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 19045 data points.
#   562 out of 3913 objects meet criteria.
# Took 7.919 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_090832/N2_5x4_f96h20C_600s31x10s10s_B0723ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 7 object.
#   Summary file has 27900 data points.
#   361 out of 8416 objects meet criteria.
# Took 10.797 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_122649/N2_5x4_f96h20C_600s31x10s10s_A0723ia.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 28504 data points.
#   242 out of 3544 objects meet criteria.
# Took 8.831 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-22/20190723_091746/N2_5x4_f96h20C_600s31x10s10s_A0723aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 28512 data points.
#   290 out of 7993 objects meet criteria.
# Took 9.368 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-23/20190730_155052/N2_5x4_f96h20C_600s31x10s10s_C0730oc.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 15310 data points.
#   637 out of 7757 objects meet criteria.
# Took 8.262 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-23/20190730_094723/N2_5x4_f96h20C_600s31x10s10s_C0730ac.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 24855 data points.
#   449 out of 4755 objects meet criteria.
# Took 8.419 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-23/20190730_142147/N2_5x4_f96h20C_600s31x10s10s_B0730lb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 3 object.
#   Summary file has 22124 data points.
#   456 out of 3282 objects meet criteria.
# Took 7.572 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-23/20190730_094820/N2_5x4_f96h20C_600s31x10s10s_B0730ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 6 object.
#   Summary file has 27898 data points.
#   411 out of 7907 objects meet criteria.
# Took 11.144 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-23/20190730_095732/N2_5x4_f96h20C_600s31x10s10s_A0730aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 9 object.
#   Summary file has 27878 data points.
#   573 out of 14046 objects meet criteria.
# Took 10.256 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-24/20190814_122723/N2_5x4_f96h20C_600s31x10s10s_A0814fa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 16 object.
#   Summary file has 18841 data points.
#   1041 out of 18977 objects meet criteria.
# Took 12.914 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-24/20190814_100550/N2_5x4_f96h20C_600s31x10s10s_A0814aa.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 17 object.
#   Summary file has 14964 data points.
#   655 out of 21768 objects meet criteria.
# Took 8.798 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-24/20190814_121747/N2_5x4_f96h20C_600s31x10s10s_B0814fb.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 5 object.
#   Summary file has 15447 data points.
#   899 out of 8200 objects meet criteria.
# Took 8.362 seconds to load data
# Writing summary file /Volumes/JOSEPH/Autism_N2/N2-24/20190814_095600/N2_5x4_f96h20C_600s31x10s10s_B0814ab.dat
#   Write successful.
# Reading files: 1 summary, 0 reference, 12 object.
#   Summary file has 15064 data points.
#   946 out of 16339 objects meet criteria.
# Took 8.418 seconds to load data
