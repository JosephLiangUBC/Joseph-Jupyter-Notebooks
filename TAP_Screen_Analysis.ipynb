# %% [markdown]
# # Jupyter Notebook UI to graph your TAP data!
#
# Version 1.7 - Joseph Liang, Rankin Lab
# Updated:
# 1. Upgraded folder path selection application
# 2. Upgraded dataset management (less moving parts for end-user)
# 3. output changed from tif -> png
# 4. Added tap-correction function for missing taps (should be working now)
# 5. Added plate column to evaluate plate-discrepancies
# 6. Added separate graphing function for plate-discrepancies
# 7. Added colour palette-setting function
#
# ## Known bug: Step 2 an empty windows displays in Mac. May also apply to linux/windows.
#
# ## Beginner Essentials:
# 1. Shift-Enter to run each cell. After you run, you should see an output "done step #". If not, an error has occured
# 2. When inputting your own code/revising the code, make sure you close all your quotation marks '' and brackets (), [], {}.
# 3. Don't leave any commas (,) hanging! (make sure an object always follows a comma. If there is nothing after a comma, remove the comma!
# 4. Learning to code? Each line of code is annotated to help you understand how this code works!
#
# ## 3. Run all cells/steps sequentially, even the ones that do not need input
#
# ## Steps that require input: #3, #6.1, #7

# %% [markdown]
# # 1. Importing Packages Required (No input required, just run)

# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import math
import os #<- package used to work with system file paths
import seaborn as sns #<- package used to plot graphs
from matplotlib import pyplot as plt #<- another package used to plot graphs
from itertools import cycle #<- package used to iterate down rows (used in step 5 to add tap column)
import ipywidgets as widgets #<- widget tool to generate button and tab for graphs
from IPython.display import display #<- displays widgets
from ipyfilechooser import FileChooser
# from tkinter import Tk, filedialog #<- Tkinter is a GUI package
print("done step 1")
# Out:
# done step 1

# %% [markdown]
# # 2. Pick filepath (just run and click button from output)
#
# Run the following cell and click the button 'Select Folder' to pick a filepath.
#
# ## Important: Later on, this script uses the total file path for each file to import and group data. That means if your folder has whatever your strain is named, the script will not work.
#
# (ex. if your folder has "N2" in it this script sees all files inside this folder as having the "N2" search key)
#
# ## An easy fix is to just rename your folder to something else (make your strains lower-case, or just have the date)

# %%
starting_directory = '/Users/Joseph'
chooser = FileChooser(starting_directory)
display(chooser)
# Out:
# FileChooser(path='/Users/Joseph', filename='', title='', show_hidden=False, select_desc='Select', change_desc=…

# %%
print(chooser.selected_path)
folder_path=chooser.selected_path
# Out:
# /Volumes/JosephDISK/Kristen-aging

# %%
# Obsolete
# ### Select Folder App - After you run, you can select your folder for filepath
# button = widgets.Button(description = 'Select Folder') #<- Creates a button variable
# display(button) #<- displays this button on output
# def select_folder(b): #<- This is an action. Requires a variable, so I put in an arbitrary one 'b'
#     global folder_path #<- sets a variable as a global variable, not just within this action
#     Tk().withdraw() #<- Tkinter likes to create annoying empty windows. This removes them
#     folder_path = filedialog.askdirectory() #<- Opens up a file explorer window, and determines folder path
#     Tk().update()#<- below
#     Tk().destroy()#<- this and the line above it removes the file explorer window after a selection is made
#     print(folder_path) #<- this helps confirm that this action was performed
#     print('done step 2')
# button.on_click(select_folder) #<- describes what happens when you click on this button

# %% [markdown]
# # 3. User Defined Variables (Add input here)
#
# Here, we add some constants to help you blaze through this code.
#
# 3.1: Number of taps is pretty self-explanatory. How any taps does your experiment have? put in that number + 1 (N+1)!
#
# This may be a bit confusing, but this is due to some coding syntax that you don't have to worry about.
#
# 3.2: Change your ISI number. This will be reflected in the name/title of the output figure.

# %%
number_of_taps = 30 ###<------ Taps in your experiment.

number_taps = range(1, number_of_taps + 1)  #<- do not change this


# if you have different ISIs in the same folder, then come back and change this 
# when you are graphing for the second set of data with the other ISI 
# (Generally data from same ISIs are graphed together)
# If changing ISI mid-analysis, you can just skip straight to step 8 after running this cell again

ISI = 10  ### <- What is your ISI? change accordingly
first_tap = 600 ### <- when is your first tap? check your TRV files

#Here, open up one of the trv files to determine the times for each of these taps. 
lower = np.arange(first_tap-2, first_tap-2+(number_of_taps*ISI), ISI) #(first tap, last tap+10s, ISI)
upper = np.arange(first_tap+2, first_tap+2+(number_of_taps*ISI), ISI) #(first tap, last tap+10s, ISI)
tolerances = list(zip(lower, upper)) 
taps = [i for i in range(1,number_of_taps+1)]

#### Add 31st Tap Here --------------------------------------------------<------------
tolerances.append((1188,1191))
taps.append(31)


#assign each tolerance to a tap number
accurate_taps = list((zip(taps, tolerances)))
print(accurate_taps)

for pair in accurate_taps:
   tap = pair[0]
   tolerance = pair[1]
   print("tap "+str(tap), "tolerance="+str(tolerance))

print("done step 3")
# Out:
# [(1, (598, 602)), (2, (608, 612)), (3, (618, 622)), (4, (628, 632)), (5, (638, 642)), (6, (648, 652)), (7, (658, 662)), (8, (668, 672)), (9, (678, 682)), (10, (688, 692)), (11, (698, 702)), (12, (708, 712)), (13, (718, 722)), (14, (728, 732)), (15, (738, 742)), (16, (748, 752)), (17, (758, 762)), (18, (768, 772)), (19, (778, 782)), (20, (788, 792)), (21, (798, 802)), (22, (808, 812)), (23, (818, 822)), (24, (828, 832)), (25, (838, 842)), (26, (848, 852)), (27, (858, 862)), (28, (868, 872)), (29, (878, 882)), (30, (888, 892)), (31, (1188, 1191))]
# tap 1 tolerance=(598, 602)
# tap 2 tolerance=(608, 612)
# tap 3 tolerance=(618, 622)
# tap 4 tolerance=(628, 632)
# tap 5 tolerance=(638, 642)
# tap 6 tolerance=(648, 652)
# tap 7 tolerance=(658, 662)
# tap 8 tolerance=(668, 672)
# tap 9 tolerance=(678, 682)
# tap 10 tolerance=(688, 692)
# tap 11 tolerance=(698, 702)
# tap 12 tolerance=(708, 712)
# tap 13 tolerance=(718, 722)
# tap 14 tolerance=(728, 732)
# tap 15 tolerance=(738, 742)
# tap 16 tolerance=(748, 752)
# tap 17 tolerance=(758, 762)
# tap 18 tolerance=(768, 772)
# tap 19 tolerance=(778, 782)
# tap 20 tolerance=(788, 792)
# tap 21 tolerance=(798, 802)
# tap 22 tolerance=(808, 812)
# tap 23 tolerance=(818, 822)
# tap 24 tolerance=(828, 832)
# tap 25 tolerance=(838, 842)
# tap 26 tolerance=(848, 852)
# tap 27 tolerance=(858, 862)
# tap 28 tolerance=(868, 872)
# tap 29 tolerance=(878, 882)
# tap 30 tolerance=(888, 892)
# tap 31 tolerance=(1188, 1191)
# done step 3

# %% [markdown]
# # 4. Constructing Filelist From Source File/Select File (Just run)

# %%
#folder_path = '/Users/Joseph/Desktop/AVR14_10sISI' #- manual folder path if Tkinter is acting up

os.chdir(folder_path) #<- setting your working directory so that your images will be saved here

filelist = list() #<- empty list
for root, dirs, files in os.walk(folder_path): #<- this for loop goes through your folder 
    for name in files:
        if name.endswith('.trv'): #<- and takes out all files with a .trv (file that contains your data)
            filepath = os.path.join(root, name) #<- Notes down the file path of each data file
            filelist.append(filepath) #<- saves it into the list
    
print(filelist)
print('done step 4')
# Out:
# ['/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_043802/N2_8x2_f96h20C_600s31x10s10s_A0707bb.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_052432/N2_8x2_f96h20C_600s31x10s10s_A0706be.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_112359/N2_8x2_f72h20C_600s31x10s10s_B0706ba.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_121436/N2_8x2_f72h20C_600s31x10s10s_B0706bd.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_054357/N2_7x2_f96h20C_600s31x10s10s_A0720bb.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_060632/N2_7x2_f96h20C_600s31x10s10s_A0720bc.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_065325/N2_7x2_f96h20C_600s31x10s10s_A0720be.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_134220/N2_7x2_f72h20C_600s31x10s10s_B0720bd.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_142615/N2_7x2_f72h20C_600s31x10s10s_B0720bf.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_073624/N2_8x2_f96h20C_600s31x10s10s_A1019bc.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_132858/N2_8x2_f72h20C_600s31x10s10s_B1019ba.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_140124/N2_8X2_f96h20C_600s31x10s10s_C1019bb.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_151008/N2_8x2_f72h20C_600s31x10s10s_B1019bd.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_154120/N2_8X2_f96h20C_600s31x10s10s_C1019be.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_055753/N2_8X2_f96h20C_600s31x10s10s_A1102cb.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_073800/N2_8X2_f96h20C_600s31x10s10s_A1102ce.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_121653/N2_8X2_f96h20C_600s31x10s10s_C1102ca.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_133324/N2_8x2_f72h20C_600s31x10s10s_B1102cc.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_140452/N2_8X2_f96h20C_600s31x10s10s_C1102cd.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_024241/N2_8x2_f96h20C_600s31x10s10s_A1109bc.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_083358/N2_8x2_f72h20C_600s31x10s10s_B1109ba.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_090419/N2_8X2_f96h20C_600s31x10s10s_C1109bb.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_101552/N2_8x2_f72h20C_600s31x10s10s_B1109bd.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_104554/N2_8X2_f96h20C_600s31x10s10s_C1109be.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_041149/N2_8x2_f96h20C_600s31x10s10s_A0707aa.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_050228/N2_8x2_f96h20C_600s31x10s10s_A0706ad.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_113054/N2_8x2_f96h20C_600s31x10s10s_C0707ab.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_115010/N2_8x2_f72h20C_600s31x10s10s_B0706ac.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_122136/N2_8x2_f96h20C_600s31x10s10s_C0706ae.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_051711/N2_8x2_f96h20C_600s31x10s10s_A0720aa.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_063033/N2_8x2_f96h20C_600s31x10s10s_A0720ad.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_125456/N2_8x2_f72h20C_600s31x10s10s_B0720ab.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_131858/N2_8x2_f72h20C_600s31x10s10s_B0720ac.trv', '/Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_140510/N2_8x2_f72h20C_600s31x10s10s_B0720ae.trv', '/Volumes/JosephDISK/ ...
# done step 4

# %%
# string = '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_103216/LC33_10x2_f72h20C_600s31x10s10s_B0809db.trv'
# print(string.split('/')[-3])
# print(string.split('/')[-2].split('_')[0])
# print(string.split('/')[-1].split('_')[-1].split('.')[0])

# %%
genotype=[]
for f in filelist:
    genotype.append(f.split('/')[-3])
# print(np.unique(genotype))
genotypes=np.unique(genotype)
print(genotypes)
print(len(np.unique(genotypes)))
strainNs = enumerate(genotypes,1)
strain_enum=list(strainNs)
print(strain_enum)
StrainNames=dict(strain_enum)
print(StrainNames)
# Out:
# ['LRRK2_G2019S_7days' 'LRRK2_G2019S_96hrs' 'N2_N2_7days' 'N2_N2_96hrs'
#  'catp-7_tm4438_7days' 'catp-7_tm4438_96hrs' 'djr-1.1_tm918_7days'
#  'djr-1.1_tm918_96hrs' 'lrk-1_tm1898_7days' 'lrk-1_tm1898_96hrs'
#  'pdr-1_gk448_7days' 'pdr-1_gk448_96hrs' 'pink-1_ok3538_7days'
#  'pink-1_ok3538_96hrs' 'pink-1_tm1779_7days' 'pink-1_tm1779_96hrs']
# 16
# [(1, 'LRRK2_G2019S_7days'), (2, 'LRRK2_G2019S_96hrs'), (3, 'N2_N2_7days'), (4, 'N2_N2_96hrs'), (5, 'catp-7_tm4438_7days'), (6, 'catp-7_tm4438_96hrs'), (7, 'djr-1.1_tm918_7days'), (8, 'djr-1.1_tm918_96hrs'), (9, 'lrk-1_tm1898_7days'), (10, 'lrk-1_tm1898_96hrs'), (11, 'pdr-1_gk448_7days'), (12, 'pdr-1_gk448_96hrs'), (13, 'pink-1_ok3538_7days'), (14, 'pink-1_ok3538_96hrs'), (15, 'pink-1_tm1779_7days'), (16, 'pink-1_tm1779_96hrs')]
# {1: 'LRRK2_G2019S_7days', 2: 'LRRK2_G2019S_96hrs', 3: 'N2_N2_7days', 4: 'N2_N2_96hrs', 5: 'catp-7_tm4438_7days', 6: 'catp-7_tm4438_96hrs', 7: 'djr-1.1_tm918_7days', 8: 'djr-1.1_tm918_96hrs', 9: 'lrk-1_tm1898_7days', 10: 'lrk-1_tm1898_96hrs', 11: 'pdr-1_gk448_7days', 12: 'pdr-1_gk448_96hrs', 13: 'pink-1_ok3538_7days', 14: 'pink-1_ok3538_96hrs', 15: 'pink-1_tm1779_7days', 16: 'pink-1_tm1779_96hrs'}

# %% [markdown]
# # 5. Process Data Function (Just Run)

# %%
def ProcessData(strain): #<- an example of a user-defined function
    strain_filelist = [x for x in filelist if strain in x] #<- goes through the list and filters for keyword
    Strain_N = len(strain_filelist) #<- N per strain, or number of plates
    Plate_N = 1
    print(f'this strain/treatment has {Strain_N} plates') #<- will output as the first number
    if Strain_N == 0:
        raise AssertionError ('{} is not a good identifier'.format(strain))
    else:
        pass
        print(f'now working on strain {strain}')
        strain_filelist = [file for file in filelist if strain in file]
        df_list=[]
        for file in strain_filelist:
            if file.split('/')[-1].startswith('._'):
                pass
            else:
                print(f"working on file {file}")
                df= pd.read_csv(file, sep=' ', header = None, encoding_errors='ignore')
                df['Plate_id'] = file.split('/')[-1].split('_')[-1].split('.')[0]
                df['Date'] = file.split('/')[-2].split('_')[0]
                df['Screen'] = file.split('/')[-4]
                df_list.append(df)
        DF_Total = pd.concat(df_list, ignore_index = True)
#     for f in strain_filelist:
#         DF_Total = pd.concat(pd.read_csv(f, sep=' ', skiprows = 4, header = None))
        # DF_Total = pd.concat([pd.read_csv(f, sep=' ', header = None, encoding_errors='ignore') for f in strain_filelist],
        #               ignore_index=True) #<- imports your data files
#         DF_Total = DF_Total.dropna(axis = 1) #<- cleans your data
        DF_Total = DF_Total.rename( #<- more cleaning
                    {0:'time',
                    2:'rev_before',
                    3:'no_rev',
                    4:'stim_rev',
                    7:'dist',
                    8:'dist_std',
                    9:'dist_stderr',
                    11:'dist_0th',
                    12:'dist_1st',
                    13:'dist_2nd',
                    14:'dist_3rd',
                    15:'dist_100th',
                    18:'dura',
                    19:'dura_std',
                    20:'dura_stderr',
                    22:'dura_0th',
                    23:'dura_1st',
                    24:'dura_2nd',
                    25:'dura_3rd',
                    26:'dura_100th'}, axis=1)
        #check function here for NaN Columns
        DF_Total['plate'] = 0
        DF_Total['prob'] = DF_Total['stim_rev']/ (DF_Total['no_rev'] + DF_Total['stim_rev']) #<- calculate prob
        DF_Total['speed'] = DF_Total['dist']/DF_Total['dura'] #<- calculate speed
        DF_Total_rows = int(DF_Total.shape[0])
        print(f'this strain/treatment has {DF_Total_rows} total taps') #<- Outputs as the second number. Check if you are missing taps!
        DF_Final = DF_Total[["time", "dura", "dist", "prob", "speed", "plate", "Date","Plate_id","Screen"]].copy()

    return{
            'N': Strain_N,
            'Confirm':DF_Total,
            'Final': DF_Final}
    print('done!')



def assign_taps(DF, tolerances):
    DF['taps'] = np.nan
    for taps, tolerance in enumerate(tolerances): #[(99, 101), (109,111), ...]
        tap_lower,tap_upper = tolerance
        TimesInTapRange = DF['time'].between(tap_lower,tap_upper, inclusive="both")
        DF.loc[TimesInTapRange,'taps'] = taps+1 #set the tap to i where times are between



    
def insert_plates(df):   
    """This function inserts a plate column into a dataframe.
    
    :param df: any dataframe
    :type: pandas.core.frame.DataFrame
    
    :return: dataframe with a plate column
    :type: pandas.core.frame.DataFrame
    """
    df['plate']=(df['taps'] ==1).cumsum()


            
print('done step 5')
# Out:
# done step 5

# %% [markdown]
# # 6.1 Process Data (PLEASE READ, Add input here)

# %% [markdown]
# Here is the hardest part - From your naming convention, you need to pick a unique identifier for each group.
#
# This means that all of names of your files for that strain should have that in common but is not commone with across all other files! If you did a good job naming your files and following a good naming convention, this should be easy.
#
# ## Be careful and really look hard in your naming structure. Note you want an unique identifier in the entire file path for the same group of files. An easy mistake is to have the strain name in the overall folder name, in this case if you use your strain name as a keyword it would include all files in that folder!
#
# For example, if all your N2 files have a certain pattern like "N2_5x4" in this following example:
# '/Users/Joseph/Desktop/AVR14_10sISI_TapHab_0710_2019/N2/20190710_141740/N2_5x4_f94h20c_100s30x10s10s_C0710ab.trv'
#
# Then you need to set that identifier for the strain keyword:
# 'Strain_1' = 'N2_5x4'
#
# ## Depending on how many strains you are running for comparison, you may need to add/delete some lines!
#
# ## You are not naming your data groups here, we have a step for that later!
# ## Here, you want to note down ALL the strains you have in the folder
#
# If you have just 2 strains, add hashtags (#) in front of the lines you do not need.
# If you need more strains, just add more lines, following the same format!

# %%
# #Format: 'Strain_#'' = 'unique_identifier'

# ### Make into dictionary
# StrainNames = {
#     'Strain_1' : 'N2',  #<- each strain will be designated to a unique identifier here
#     'Strain_2' : 'cat-2_e1112',
#     'Strain_3' : 'cat-2_n4547',
#     'Strain_4' : 'cat-2_tm2261',
#     'Strain_5' : 'dat-1_ok157',
#     'Strain_6' : 'cat-1_ok411',
#     'Strain_7' : 'pdr-1_gk448', #<- empty entries are for those hardcore trackers that tracks this many strains
#     'Strain_8' : 'pdr-1_tm395',
#     'Strain_9' : 'pdr-1_tm598',
#     'Strain_10' : 'dop-1_vs101',
#     'Strain_11' : 'dop-3_ok295',
#     'Strain_12' : 'snb-5_ok1434',
#     'Strain_13' : 'unc-10_ad591',
# #     'Strain_14' : '',
# #     'Strain_15' : '',
# }
# #...etc, etc

# print('done step 6.1')

# %%
print(list(StrainNames.values()))
print(type(list(StrainNames.values())))
print(type(list(StrainNames.values())[0]))
# Out:
# ['LRRK2_G2019S_7days', 'LRRK2_G2019S_96hrs', 'N2_N2_7days', 'N2_N2_96hrs', 'catp-7_tm4438_7days', 'catp-7_tm4438_96hrs', 'djr-1.1_tm918_7days', 'djr-1.1_tm918_96hrs', 'lrk-1_tm1898_7days', 'lrk-1_tm1898_96hrs', 'pdr-1_gk448_7days', 'pdr-1_gk448_96hrs', 'pink-1_ok3538_7days', 'pink-1_ok3538_96hrs', 'pink-1_tm1779_7days', 'pink-1_tm1779_96hrs']
# <class 'list'>
# <class 'numpy.str_'>

# %% [markdown]
# # 6.2 Process Data (just run this cell)

# %%
# print(ProcessData('F53B2.5_ok226')['Final'])

# %%
# with open('/Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_141642/ZE1_10x2_f72h20C_600s31x10s10s_B0520ba.trv') as f:
#     print(f)

# %%
# import threading

# %%
DataLists = [0]  #<- generates empty list. 0 is there to account for python's index starting at 0. 
# we want indexing to start at 1 (when I say #1 I want the first point, not the second point)

for s in list(StrainNames.values()): #<- goes through the dictionary in step 6.1 and processes data
    if not s == '':
#         threading.Thread(target=DataLists.append(ProcessData(s)['Final'])).start()
        DataLists.append(ProcessData(s)['Final']) #<- appends all data into a list of dataframes


for df in DataLists[1:]: 
    assign_taps(df, tolerances)
for df in DataLists[1:]:    
    insert_plates(df)

# print(x)
# print(DataLists[0])
# print(DataLists[1])
#print(DataLists[2])
#print(len(DataLists))        
print('done step 6.2')
# Out:
# this strain/treatment has 5 plates
# now working on strain LRRK2_G2019S_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_7days/20250315_034050/WLZ3_8x2_f96h20C_600s31x10s10s_A0315dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_7days/20250315_045908/WLZ3_8x2_f96h20C_600s31x10s10s_A0315da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_7days/20250315_110557/WLZ3_8x2_f72h20C_600s31x10s10s_B0315de.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_7days/20250315_113356/WLZ3_8X2_f96h20C_600s31x10s10s_C0315dc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_7days/20250315_124913/WLZ3_8x2_f72h20C_600s31x10s10s_B0315db.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 5 plates
# now working on strain LRRK2_G2019S_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_96hrs/20250315_043155/WLZ3_8x2_f96h20C_600s31x10s10s_A0315cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_96hrs/20250315_061133/WLZ3_8x2_f96h20C_600s31x10s10s_A0315ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_96hrs/20250315_110939/WLZ3_8X2_f96h20C_600s31x10s10s_C0315ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_96hrs/20250315_122413/WLZ3_8x2_f72h20C_600s31x10s10s_B0315cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/LRRK2_G2019S_96hrs/20250315_125321/WLZ3_8X2_f96h20C_600s31x10s10s_C0315cd.trv
# this strain/treatment has 154 total taps
# this strain/treatment has 58 plates
# now working on strain N2_N2_7days
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_043802/N2_8x2_f96h20C_600s31x10s10s_A0707bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_052432/N2_8x2_f96h20C_600s31x10s10s_A0706be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_112359/N2_8x2_f72h20C_600s31x10s10s_B0706ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240706_121436/N2_8x2_f72h20C_600s31x10s10s_B0706bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_054357/N2_7x2_f96h20C_600s31x10s10s_A0720bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_060632/N2_7x2_f96h20C_600s31x10s10s_A0720bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_065325/N2_7x2_f96h20C_600s31x10s10s_A0720be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_134220/N2_7x2_f72h20C_600s31x10s10s_B0720bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20240720_142615/N2_7x2_f72h20C_600s31x10s10s_B0720bf.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_073624/N2_8x2_f96h20C_600s31x10s10s_A1019bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_132858/N2_8x2_f72h20C_600s31x10s10s_B1019ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_140124/N2_8X2_f96h20C_600s31x10s10s_C1019bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_151008/N2_8x2_f72h20C_600s31x10s10s_B1019bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241019_154120/N2_8X2_f96h20C_600s31x10s10s_C1019be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_055753/N2_8X2_f96h20C_600s31x10s10s_A1102cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_073800/N2_8X2_f96h20C_600s31x10s10s_A1102ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_121653/N2_8X2_f96h20C_600s31x10s10s_C1102ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_133324/N2_8x2_f72h20C_600s31x10s10s_B1102cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241102_140452/N2_8X2_f96h20C_600s31x10s10s_C1102cd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_024241/N2_8x2_f96h20C_600s31x10s10s_A1109bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_083358/N2_8x2_f72h20C_600s31x10s10s_B1109ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_090419/N2_8X2_f96h20C_600s31x10s10s_C1109bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_101552/N2_8x2_f72h20C_600s31x10s10s_B1109bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_7days/20241109_104554/N2_8X2_f96h20C_600s31x10s10s_C1109be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_7days/20250402_065253/N2_8x2_f96h20C_600s31x10s10s_A0402bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_7days/20250402_131402/N2_8x2_f96h20C_600s31x10s10s_B0402ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_7days/20250402_135018/N2_8x2_f96h20C_600s31x10s10s_C0402bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_7days/20250402_150836/N2_8x2_f96h20C_600s31x10s10s_B0402bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_7days/20250402_154316/N2_8x2_f96h20C_600s31x10s10s_C0402be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_7days/20250315_052358/N2_8x2_f96h20C_600s31x10s10s_A0315bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_7days/20250315_113014/N2_8x2_f72h20C_600s31x10s10s_B0315ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_7days/20250315_120044/N2_8X2_f96h20C_600s31x10s10s_C0315bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_7days/20250315_131403/N2_8x2_f72h20C_600s31x10s10s_B0315bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_7days/20250315_131752/N2_8X2_f96h20C_600s31x10s10s_C0315be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_7days/20250319_032429/N2_8x2_f96h20C_600s31x10s10s_A0319bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_7days/20250319_093206/N2_8x2_f96h20C_600s31x10s10s_B0319ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_7days/20250319_100044/N2_8x2_f96h20C_600s31x10s10s_C0319bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_7days/20250319_111404/N2_8x2_f96h20C_600s31x10s10s_B0319bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_7days/20250319_114705/N2_8x2_f96h20C_600s31x10s10s_C0319be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_7days/20241123_114101/N2_8x2_f72h20C_600s31x10s10s_B1123ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_7days/20241123_121022/N2_8X2_f96h20C_600s31x10s10s_C1123bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_7days/20241123_132531/N2_8x2_f72h20C_600s31x10s10s_B1123bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_7days/20241123_135802/N2_8X2_f96h20C_600s31x10s10s_C1123be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_7days/20241102_055753/N2_8X2_f96h20C_600s31x10s10s_A1102cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_7days/20241102_073800/N2_8X2_f96h20C_600s31x10s10s_A1102ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_7days/20241102_121653/N2_8X2_f96h20C_600s31x10s10s_C1102ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_7days/20241102_133324/N2_8x2_f72h20C_600s31x10s10s_B1102cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_7days/20241102_140452/N2_8X2_f96h20C_600s31x10s10s_C1102cd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_7days/20241109_024241/N2_8x2_f96h20C_600s31x10s10s_A1109bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_7days/20241109_083358/N2_8x2_f72h20C_600s31x10s10s_B1109ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_7days/20241109_090419/N2_8X2_f96h20C_600s31x10s10s_C1109bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_7days/20241109_101552/N2_8x2_f72h20C_600s31x10s10s_B1109bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_7days/20241109_104554/N2_8X2_f96h20C_600s31x10s10s_C1109be.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_7days/20241019_073624/N2_8x2_f96h20C_600s31x10s10s_A1019bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_7days/20241019_132858/N2_8x2_f72h20C_600s31x10s10s_B1019ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_7days/20241019_140124/N2_8X2_f96h20C_600s31x10s10s_C1019bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_7days/20241019_151008/N2_8x2_f72h20C_600s31x10s10s_B1019bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_7days/20241019_154120/N2_8X2_f96h20C_600s31x10s10s_C1019be.trv
# this strain/treatment has 1796 total taps
# this strain/treatment has 59 plates
# now working on strain N2_N2_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_041149/N2_8x2_f96h20C_600s31x10s10s_A0707aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_050228/N2_8x2_f96h20C_600s31x10s10s_A0706ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_113054/N2_8x2_f96h20C_600s31x10s10s_C0707ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_115010/N2_8x2_f72h20C_600s31x10s10s_B0706ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240706_122136/N2_8x2_f96h20C_600s31x10s10s_C0706ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_051711/N2_8x2_f96h20C_600s31x10s10s_A0720aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_063033/N2_8x2_f96h20C_600s31x10s10s_A0720ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_125456/N2_8x2_f72h20C_600s31x10s10s_B0720ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_131858/N2_8x2_f72h20C_600s31x10s10s_B0720ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20240720_140510/N2_8x2_f72h20C_600s31x10s10s_B0720ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241019_061931/N2_8x2_f96h20C_600s31x10s10s_A1019aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241019_080041/N2_8x2_f96h20C_600s31x10s10s_A1019ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241019_135620/N2_8x2_f72h20C_600s31x10s10s_B1019ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241019_142509/N2_8X2_f96h20C_600s31x10s10s_C1019ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241019_153613/N2_8x2_f72h20C_600s31x10s10s_B1019ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241102_050250/N2_8X2_f96h20C_600s31x10s10s_A1102aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241102_065039/N2_8X2_f96h20C_600s31x10s10s_A1102ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241102_123946/N2_8x2_f72h20C_600s31x10s10s_B1102ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241102_131202/N2_8X2_f96h20C_600s31x10s10s_C1102ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241102_142409/N2_8x2_f72h20C_600s31x10s10s_B1102ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241109_012502/N2_8x2_f96h20C_600s31x10s10s_A1109aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241109_030652/N2_8x2_f96h20C_600s31x10s10s_A1109bad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241109_085923/N2_8x2_f72h20C_600s31x10s10s_B1109ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241109_093046/N2_8X2_f96h20C_600s31x10s10s_C1109ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/Kristen-N2/N2_N2_96hrs/20241109_104055/N2_8x2_f72h20C_600s31x10s10s_B1109ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_96hrs/20250402_054921/N2_8x2_f96h20C_600s31x10s10s_A0402aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_96hrs/20250402_071938/N2_8x2_f96h20C_600s31x10s10s_A0402ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_96hrs/20250402_134115/N2_8x2_f96h20C_600s31x10s10s_B0402ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_96hrs/20250402_142107/N2_8x2_f96h20C_600s31x10s10s_C0402ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/N2_N2_96hrs/20250402_154620/N2_8x2_f96h20C_600s31x10s10s_B0402ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_96hrs/20250315_040507/N2_8x2_f96h20C_600s31x10s10s_A0315aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_96hrs/20250315_054857/N2_8x2_f96h20C_600s31x10s10s_A0315ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_96hrs/20250315_115659/N2_8x2_f72h20C_600s31x10s10s_B0315ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_96hrs/20250315_122811/N2_8X2_f96h20C_600s31x10s10s_C0315ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar15_2025/N2_N2_96hrs/20250315_133644/N2_8x2_f72h20C_600s31x10s10s_B0315ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_96hrs/20250319_020704/N2_8x2_f96h20C_600s31x10s10s_A0319aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_96hrs/20250319_034906/N2_8x2_f96h20C_600s31x10s10s_A0319ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_96hrs/20250319_095703/N2_8x2_f96h20C_600s31x10s10s_B0319ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_96hrs/20250319_102604/N2_8x2_f96h20C_600s31x10s10s_C0319ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/N2_N2_96hrs/20250319_114316/N2_8x2_f96h20C_600s31x10s10s_B0319ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_96hrs/20241123_043228/N2_8x2_f96h20C_600s31x10s10s_A1123aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_96hrs/20241123_120531/N2_8x2_f72h20C_600s31x10s10s_B1123ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_96hrs/20241123_123722/N2_8X2_f96h20C_600s31x10s10s_C1123ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/N2_N2_96hrs/20241123_135313/N2_8x2_f72h20C_600s31x10s10s_B1123ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_96hrs/20241102_050250/N2_8X2_f96h20C_600s31x10s10s_A1102aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_96hrs/20241102_065039/N2_8X2_f96h20C_600s31x10s10s_A1102ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_96hrs/20241102_123946/N2_8x2_f72h20C_600s31x10s10s_B1102ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_96hrs/20241102_131202/N2_8X2_f96h20C_600s31x10s10s_C1102ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/N2_N2_96hrs/20241102_142409/N2_8x2_f72h20C_600s31x10s10s_B1102ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_96hrs/20241109_012502/N2_8x2_f96h20C_600s31x10s10s_A1109aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_96hrs/20241109_030652/N2_8x2_f96h20C_600s31x10s10s_A1109bad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_96hrs/20241109_085923/N2_8x2_f72h20C_600s31x10s10s_B1109ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_96hrs/20241109_093046/N2_8X2_f96h20C_600s31x10s10s_C1109ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/N2_N2_96hrs/20241109_104055/N2_8x2_f72h20C_600s31x10s10s_B1109ae.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_96hrs/20241019_061931/N2_8x2_f96h20C_600s31x10s10s_A1019aa.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_96hrs/20241019_080041/N2_8x2_f96h20C_600s31x10s10s_A1019ad.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_96hrs/20241019_135620/N2_8x2_f72h20C_600s31x10s10s_B1019ab.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_96hrs/20241019_142509/N2_8X2_f96h20C_600s31x10s10s_C1019ac.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/N2_N2_96hrs/20241019_153613/N2_8x2_f72h20C_600s31x10s10s_B1019ae.trv
# this strain/treatment has 1825 total taps
# this strain/treatment has 5 plates
# now working on strain catp-7_tm4438_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_7days/20250319_023201/FX04438_8x2_f96h20C_600s31x10s10s_A0319da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_7days/20250319_041819/FX04438_8x2_f96h20C_600s31x10s10s_A0319dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_7days/20250319_102217/FX04438_8x2_f96h20C_600s31x10s10s_B0319db.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_7days/20250319_105320/FX04438_8x2_f96h20C_600s31x10s10s_C0319dc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_7days/20250319_120836/FX04438_8x2_f96h20C_600s31x10s10s_B0319de.trv
# this strain/treatment has 154 total taps
# this strain/treatment has 5 plates
# now working on strain catp-7_tm4438_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_96hrs/20250319_025716/FX04438_8x2_f96h20C_600s31x10s10s_A0319cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_96hrs/20250319_044336/FX04438_8x2_f96h20C_600s31x10s10s_A0319ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_96hrs/20250319_093548/FX04438_8x2_f96h20C_600s31x10s10s_C0319ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_96hrs/20250319_104940/FX04438_8x2_f96h20C_600s31x10s10s_B0319cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Mar19_2025/catp-7_tm4438_96hrs/20250319_111741/FX04438_8x2_f96h20C_600s31x10s10s_C0319cd.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 4 plates
# now working on strain djr-1.1_tm918_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_7days/20250402_061631/FX00918_8x2_f96h20C_600s31x10s10s_A0402da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_7days/20250402_074357/FX00918_8x2_f96h20C_600s31x10s10s_A0402dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_7days/20250402_141735/FX00918_8x2_f96h20C_600s31x10s10s_B0402db.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_7days/20250402_144759/FX00918_8x2_f96h20C_600s31x10s10s_C0402dc.trv
# this strain/treatment has 124 total taps
# this strain/treatment has 4 plates
# now working on strain djr-1.1_tm918_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_96hrs/20250402_081614/FX00918_8x2_f96h20C_600s31x10s10s_A0402ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_96hrs/20250402_132617/FX00918_8x2_f96h20C_600s31x10s10s_C0402ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_96hrs/20250402_144425/FX00918_8x2_f96h20C_600s31x10s10s_B0402cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Apr2_2025/djr-1.1_tm918_96hrs/20250402_151210/FX00918_8x2_f96h20C_600s31x10s10s_C0402cd.trv
# this strain/treatment has 124 total taps
# this strain/treatment has 5 plates
# now working on strain lrk-1_tm1898_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_7days/20241102_053036/FX01898_8X2_f96h20C_600s31x10s10s_A1102da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_7days/20241102_071453/FX01898_8X2_f96h20C_600s31x10s10s_A1102dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_7days/20241102_130656/FX01898_8x2_f72h20C_600s31x10s10s_B1102db.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_7days/20241102_133821/FX01898_8X2_f96h20C_600s31x10s10s_C1102dc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_7days/20241102_144708/FX01898_8x2_f72h20C_600s31x10s10s_B1102de.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 5 plates
# now working on strain lrk-1_tm1898_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_96hrs/20241102_062418/FX01898_8X2_f96h20C_600s31x10s10s_A1102bc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_96hrs/20241102_121159/FX01898_8x2_f72h20C_600s31x10s10s_B1102ba.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_96hrs/20241102_124447/FX01898_8X2_f96h20C_600s31x10s10s_C1102bb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_96hrs/20241102_135948/FX01898_8x2_f72h20C_600s31x10s10s_B1102bd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov2_2024/lrk-1_tm1898_96hrs/20241102_142908/FX01898_8X2_f96h20C_600s31x10s10s_C1102be.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 5 plates
# now working on strain pdr-1_gk448_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_7days/20241123_052341/VC1024_8x2_f96h20C_600s31x10s10s_A1123cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_7days/20241123_070956/VC1024_8x2_f96h20C_600s31x10s10s_A1123ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_7days/20241123_114550/VC1024_8X2_f96h20C_600s31x10s10s_C1123ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_7days/20241123_125854/VC1024_8x2_f72h20C_600s31x10s10s_B1123cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_7days/20241123_133018/VC1024_8X2_f96h20C_600s31x10s10s_C1123cd.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 4 plates
# now working on strain pdr-1_gk448_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_96hrs/20241123_045654/VC1024_8x2_f96h20C_600s31x10s10s_A1123da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_96hrs/20241123_064437/VC1024_8x2_f96h20C_600s31x10s10s_A1123dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_96hrs/20241123_123222/VC1024_8x2_f72h20C_600s31x10s10s_B1123db.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov23_2024/pdr-1_gk448_96hrs/20241123_141831/VC1024_8x2_f72h20C_600s31x10s10s_B1123de.trv
# this strain/treatment has 124 total taps
# this strain/treatment has 5 plates
# now working on strain pink-1_ok3538_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_7days/20241019_064642/RB2547_11x2_f96h20C_600s31x10s10s_A1019da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_7days/20241019_082644/RB2547_11x2_f96h20C_600s31x10s10s_A1019dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_7days/20241019_141958/RB2547_11x2_f72h20C_600s31x10s10s_B1019db.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_7days/20241019_145104/RB2547_11X2_f96h20C_600s31x10s10s_C1019dc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_7days/20241019_160023/RB2547_11x2_f72h20C_600s31x10s10s_B1019de.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 5 plates
# now working on strain pink-1_ok3538_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_96hrs/20241019_071026/RB2547_10x2_f96h20C_600s31x10s10s_A1019cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_96hrs/20241019_085134/RB2547_10x2_f96h20C_600s31x10s10s_A1019ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_96hrs/20241019_133403/RB2547_11X2_f96h20C_600s31x10s10s_C1019ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_96hrs/20241019_144556/RB2547_10x2_f72h20C_600s31x10s10s_B1019cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Oct19_2024/pink-1_ok3538_96hrs/20241019_151514/RB2547_10X2_f96h20C_600s31x10s10s_C1019cd.trv
# this strain/treatment has 154 total taps
# this strain/treatment has 5 plates
# now working on strain pink-1_tm1779_7days
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_7days/20241109_015026/FX01779_10x2_f96h20C_600s31x10s10s_A1109da.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_7days/20241109_033200/FX01779_10x2_f96h20C_600s31x10s10s_A1109dd.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_7days/20241109_092547/FX01779_10x2_f72h20C_600s31x10s10s_B1109db.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_7days/20241109_095633/FX01779_10X2_f96h20C_600s31x10s10s_C1109dc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_7days/20241109_110412/FX01779_10x2_f72h20C_600s31x10s10s_B1109de.trv
# this strain/treatment has 155 total taps
# this strain/treatment has 5 plates
# now working on strain pink-1_tm1779_96hrs
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_96hrs/20241109_021642/FX01779_10x2_f96h20C_600s31x10s10s_A1109cb.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_96hrs/20241109_035518/FX01779_10x2_f96h20C_600s31x10s10s_A1109ce.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_96hrs/20241109_083854/FX01779_10X2_f96h20C_600s31x10s10s_C1109ca.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_96hrs/20241109_095136/FX01779_10x2_f72h20C_600s31x10s10s_B1109cc.trv
# working on file /Volumes/JosephDISK/Kristen-aging/PD_Age_TabHab_Nov9_2024/pink-1_tm1779_96hrs/20241109_102106/FX01779_10X2_f96h20C_600s31x10s10s_C1109cd.trv
# this strain/treatment has 155 total taps
# done step 6.2

# %%
# DataLists.append(ProcessData('vps-35_ok1880')['Final'])

# %%
print(DataLists[1])
# print(StrainNames.get(1))
# Out:
#          time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     599.975  1.97  0.486  0.880000  0.246701      1  20250315  A0315dd
# 1     609.951  1.50  0.341  0.812500  0.227333      1  20250315  A0315dd
# 2     619.969  1.35  0.329  0.764706  0.243704      1  20250315  A0315dd
# 3     629.976  1.03  0.239  0.708333  0.232039      1  20250315  A0315dd
# 4     639.980  0.60  0.133  0.684211  0.221667      1  20250315  A0315dd
# ..        ...   ...    ...       ...       ...    ...       ...      ...
# 150   859.958  0.91  0.161  0.387755  0.176923      5  20250315  B0315db
# 151   869.964  0.81  0.173  0.403509  0.213580      5  20250315  B0315db
# 152   879.959  0.43  0.079  0.365079  0.183721      5  20250315  B0315db
# 153   889.990  0.67  0.142  0.280702  0.211940      5  20250315  B0315db
# 154  1189.965  3.13  0.678  0.565217  0.216613      5  20250315  B0315db
#
#                        Screen  taps
# 0    PD_Age_TabHab_Mar15_2025   1.0
# 1    PD_Age_TabHab_Mar15_2025   2.0
# 2    PD_Age_TabHab_Mar15_2025   3.0
# 3    PD_Age_TabHab_Mar15_2025   4.0
# 4    PD_Age_TabHab_Mar15_2025   5.0
# ..                        ...   ...
# 150  PD_Age_TabHab_Mar15_2025  27.0
# 151  PD_Age_TabHab_Mar15_2025  28.0
# 152  PD_Age_TabHab_Mar15_2025  29.0
# 153  PD_Age_TabHab_Mar15_2025  30.0
# 154  PD_Age_TabHab_Mar15_2025  31.0
#
# [155 rows x 10 columns]

# %%
print(len(genotypes))
print(len(np.unique(genotypes)))
print(len(DataLists))
# Out:
# 26
# 26
# 27

# %% [markdown]
# # 7. Grouping Data and Naming (Optional: Add input here)
#
# Here, you get to name your data groups/strain! Name your groups however you like under between the quotation marks for each strain.
#
# For example: If your Strain1 is N2 and you wish for the group to be called N2,
# your line should look like:
#
# DataLists[x].assign(dataset = 'N2')
#
# ## Go back to step 6.1 to check which strain is which item on the DataLists.
# In this example, the first item on DataLists is N2.
#
#
# ## Remember: Put your name in quotes. (ex: 'N2' and not N2)
#
# As default, the names are set to the unique identifier labels.
#
# ## Depending on the number of strains you are running the comparison, you may have to delete/add lines of code (following the same format).
# ## Remember to add/delete commas too.
#
# # If you want to change your groups, you do that here.
# For example, if you have 5 strains in your folder but only want to compare between 2 or 3 strains, designate that here and follow through with steps 6 and 7. Once you are done, come back to step 6 and change your groups again (You are going to have to change your graph titles for the second run-through though)!

# %%
TotalConcatenated=pd.DataFrame()
for d in range(1,len(np.unique(genotypes))+1):
    # print(d)
    TotalConcatenated=pd.concat([TotalConcatenated,
                                 DataLists[d].assign(dataset=StrainNames.get(d))])



# TotalConcatenated = pd.concat([ #<- this function joins your data together with an extra column for which group 
#                           DataLists[1].assign(dataset = "Wildtype (N2)"), 
#                           DataLists[2].assign(dataset = "cat-2 (e1112)"),
#                           DataLists[3].assign(dataset = "cat-2 (n4547)"),
#                           DataLists[4].assign(dataset = "cat-2 (tm2261)"),
#                           DataLists[5].assign(dataset = "dat-1 (ok157)"),
#                           DataLists[6].assign(dataset = "cat-1 (ok441)"),
#                           DataLists[7].assign(dataset = "pdr-1 (gk448)"),
#                           DataLists[8].assign(dataset = "pdr-1 (tm395)"),
#                           DataLists[9].assign(dataset = "pdr-1 (tm598)"),
#                           DataLists[10].assign(dataset = "dop-1 (vs101)"),
#                           DataLists[11].assign(dataset = "dop-3 (ok295)"),
#                           DataLists[12].assign(dataset = "snb-5 (ok1434)"),
#                           DataLists[13].assign(dataset = "unc-10 (ad591)"),
# #                           DataLists[14].assign(dataset = "GOA1 Mutant (n3055)"),
# #                           DataLists[5].assign(dataset = StrainNames.get("Strain_5")),
# #                         DataLists[5].assign(dataset = "StrainNameOnePoster"), #<----- example of custom name
                          
# ])
# # ...etc etc
TotalConcatenated.reset_index(inplace=False)
print(TotalConcatenated)

#if TotalConcatenated["taps"].loc[ind] is not 1:
#   TotalConcatenated["taps"].loc[ind:indices[c+1]] = list(range(1,len(TotalConcatenated["taps"].loc[ind:indices[c+1]])+1))
# missing_taps(TotalConcatenated, accurate_taps, tolerances)

print('done step 7')
# Out:
#          time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     599.975  1.97  0.486  0.880000  0.246701      1  20250315  A0315dd
# 1     609.951  1.50  0.341  0.812500  0.227333      1  20250315  A0315dd
# 2     619.969  1.35  0.329  0.764706  0.243704      1  20250315  A0315dd
# 3     629.976  1.03  0.239  0.708333  0.232039      1  20250315  A0315dd
# 4     639.980  0.60  0.133  0.684211  0.221667      1  20250315  A0315dd
# ..        ...   ...    ...       ...       ...    ...       ...      ...
# 150   859.982  0.97  0.216  0.312500  0.222680      5  20241109  C1109cd
# 151   869.982  1.07  0.247  0.347826  0.230841      5  20241109  C1109cd
# 152   879.981  1.08  0.224  0.372093  0.207407      5  20241109  C1109cd
# 153   889.980  0.72  0.159  0.232558  0.220833      5  20241109  C1109cd
# 154  1189.974  1.80  0.476  0.848485  0.264444      5  20241109  C1109cd
#
#                        Screen  taps              dataset
# 0    PD_Age_TabHab_Mar15_2025   1.0   LRRK2_G2019S_7days
# 1    PD_Age_TabHab_Mar15_2025   2.0   LRRK2_G2019S_7days
# 2    PD_Age_TabHab_Mar15_2025   3.0   LRRK2_G2019S_7days
# 3    PD_Age_TabHab_Mar15_2025   4.0   LRRK2_G2019S_7days
# 4    PD_Age_TabHab_Mar15_2025   5.0   LRRK2_G2019S_7days
# ..                        ...   ...                  ...
# 150   PD_Age_TabHab_Nov9_2024  27.0  pink-1_tm1779_96hrs
# 151   PD_Age_TabHab_Nov9_2024  28.0  pink-1_tm1779_96hrs
# 152   PD_Age_TabHab_Nov9_2024  29.0  pink-1_tm1779_96hrs
# 153   PD_Age_TabHab_Nov9_2024  30.0  pink-1_tm1779_96hrs
# 154   PD_Age_TabHab_Nov9_2024  31.0  pink-1_tm1779_96hrs
#
# [5695 rows x 11 columns]
# done step 7

# %% [markdown]
# # Setting Colour Palette - Only run the below cell ONCE
#
# The following code sets the colour palette for the whole experiment - and then designate one colour to each strain. After this, if as you are graphing you take away some strains, you can do so with the colours still matching accordingly.

# %%
# print(TotalConcatenated['dataset'].str.split("_", n=1, expand=True))
TotalConcatenated['Screen']='PD_Screen'
# TotalConcatenated['Screen']='PD_Aging'
print(TotalConcatenated)
# Out:
#          time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     599.975  1.97  0.486  0.880000  0.246701      1  20250315  A0315dd
# 1     609.951  1.50  0.341  0.812500  0.227333      1  20250315  A0315dd
# 2     619.969  1.35  0.329  0.764706  0.243704      1  20250315  A0315dd
# 3     629.976  1.03  0.239  0.708333  0.232039      1  20250315  A0315dd
# 4     639.980  0.60  0.133  0.684211  0.221667      1  20250315  A0315dd
# ..        ...   ...    ...       ...       ...    ...       ...      ...
# 150   859.982  0.97  0.216  0.312500  0.222680      5  20241109  C1109cd
# 151   869.982  1.07  0.247  0.347826  0.230841      5  20241109  C1109cd
# 152   879.981  1.08  0.224  0.372093  0.207407      5  20241109  C1109cd
# 153   889.980  0.72  0.159  0.232558  0.220833      5  20241109  C1109cd
# 154  1189.974  1.80  0.476  0.848485  0.264444      5  20241109  C1109cd
#
#        Screen  taps              dataset
# 0    PD_Aging   1.0   LRRK2_G2019S_7days
# 1    PD_Aging   2.0   LRRK2_G2019S_7days
# 2    PD_Aging   3.0   LRRK2_G2019S_7days
# 3    PD_Aging   4.0   LRRK2_G2019S_7days
# 4    PD_Aging   5.0   LRRK2_G2019S_7days
# ..        ...   ...                  ...
# 150  PD_Aging  27.0  pink-1_tm1779_96hrs
# 151  PD_Aging  28.0  pink-1_tm1779_96hrs
# 152  PD_Aging  29.0  pink-1_tm1779_96hrs
# 153  PD_Aging  30.0  pink-1_tm1779_96hrs
# 154  PD_Aging  31.0  pink-1_tm1779_96hrs
#
# [5695 rows x 11 columns]

# %%
TotalConcatenated[['Gene', 'Allele']] = TotalConcatenated['dataset'].str.split('_', n=1, expand=True)
# TotalConcatenated[['Gene', 'Allele','Age']] = TotalConcatenated['dataset'].str.split('_', n=0, expand=True)
print(TotalConcatenated)
# Out:
#          time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     599.975  1.97  0.486  0.880000  0.246701      1  20250315  A0315dd
# 1     609.951  1.50  0.341  0.812500  0.227333      1  20250315  A0315dd
# 2     619.969  1.35  0.329  0.764706  0.243704      1  20250315  A0315dd
# 3     629.976  1.03  0.239  0.708333  0.232039      1  20250315  A0315dd
# 4     639.980  0.60  0.133  0.684211  0.221667      1  20250315  A0315dd
# ..        ...   ...    ...       ...       ...    ...       ...      ...
# 150   859.982  0.97  0.216  0.312500  0.222680      5  20241109  C1109cd
# 151   869.982  1.07  0.247  0.347826  0.230841      5  20241109  C1109cd
# 152   879.981  1.08  0.224  0.372093  0.207407      5  20241109  C1109cd
# 153   889.980  0.72  0.159  0.232558  0.220833      5  20241109  C1109cd
# 154  1189.974  1.80  0.476  0.848485  0.264444      5  20241109  C1109cd
#
#        Screen  taps              dataset    Gene  Allele    Age
# 0    PD_Aging   1.0   LRRK2_G2019S_7days   LRRK2  G2019S  7days
# 1    PD_Aging   2.0   LRRK2_G2019S_7days   LRRK2  G2019S  7days
# 2    PD_Aging   3.0   LRRK2_G2019S_7days   LRRK2  G2019S  7days
# 3    PD_Aging   4.0   LRRK2_G2019S_7days   LRRK2  G2019S  7days
# 4    PD_Aging   5.0   LRRK2_G2019S_7days   LRRK2  G2019S  7days
# ..        ...   ...                  ...     ...     ...    ...
# 150  PD_Aging  27.0  pink-1_tm1779_96hrs  pink-1  tm1779  96hrs
# 151  PD_Aging  28.0  pink-1_tm1779_96hrs  pink-1  tm1779  96hrs
# 152  PD_Aging  29.0  pink-1_tm1779_96hrs  pink-1  tm1779  96hrs
# 153  PD_Aging  30.0  pink-1_tm1779_96hrs  pink-1  tm1779  96hrs
# 154  PD_Aging  31.0  pink-1_tm1779_96hrs  pink-1  tm1779  96hrs
#
# [5695 rows x 14 columns]

# %%
print(TotalConcatenated.head(5))
# Out:
#       time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0  599.975  1.97  0.486  0.880000  0.246701      1  20250315  A0315dd
# 1  609.951  1.50  0.341  0.812500  0.227333      1  20250315  A0315dd
# 2  619.969  1.35  0.329  0.764706  0.243704      1  20250315  A0315dd
# 3  629.976  1.03  0.239  0.708333  0.232039      1  20250315  A0315dd
# 4  639.980  0.60  0.133  0.684211  0.221667      1  20250315  A0315dd
#
#      Screen  taps             dataset   Gene  Allele    Age
# 0  PD_Aging   1.0  LRRK2_G2019S_7days  LRRK2  G2019S  7days
# 1  PD_Aging   2.0  LRRK2_G2019S_7days  LRRK2  G2019S  7days
# 2  PD_Aging   3.0  LRRK2_G2019S_7days  LRRK2  G2019S  7days
# 3  PD_Aging   4.0  LRRK2_G2019S_7days  LRRK2  G2019S  7days
# 4  PD_Aging   5.0  LRRK2_G2019S_7days  LRRK2  G2019S  7days

# %%
TotalConcatenated['Allele']=TotalConcatenated['Allele'].fillna('N2')

# %%
print(TotalConcatenated[TotalConcatenated['Gene']=='N2'])
# Out:
#           time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0      599.961  2.24  0.806  0.800000  0.359821      1  20240706  A0707bb
# 1      609.979  0.50  0.135  0.772727  0.270000      1  20240706  A0707bb
# 2      619.976  0.82  0.285  0.575758  0.347561      1  20240706  A0707bb
# 3      629.973  0.82  0.251  0.533333  0.306098      1  20240706  A0707bb
# 4      639.987  0.84  0.268  0.567568  0.319048      1  20240706  A0707bb
# ...        ...   ...    ...       ...       ...    ...       ...      ...
# 1820   859.975  1.25  0.261  0.166667  0.208800     59  20241019  B1019ae
# 1821   869.936  1.42  0.260  0.192308  0.183099     59  20241019  B1019ae
# 1822   879.975  1.35  0.251  0.240000  0.185926     59  20241019  B1019ae
# 1823   889.978  1.01  0.197  0.233333  0.195050     59  20241019  B1019ae
# 1824  1189.941  1.78  0.451  0.760000  0.253371     59  20241019  B1019ae
#
#         Screen  taps      dataset Gene Allele    Age
# 0     PD_Aging   1.0  N2_N2_7days   N2     N2  7days
# 1     PD_Aging   2.0  N2_N2_7days   N2     N2  7days
# 2     PD_Aging   3.0  N2_N2_7days   N2     N2  7days
# 3     PD_Aging   4.0  N2_N2_7days   N2     N2  7days
# 4     PD_Aging   5.0  N2_N2_7days   N2     N2  7days
# ...        ...   ...          ...  ...    ...    ...
# 1820  PD_Aging  27.0  N2_N2_96hrs   N2     N2  96hrs
# 1821  PD_Aging  28.0  N2_N2_96hrs   N2     N2  96hrs
# 1822  PD_Aging  29.0  N2_N2_96hrs   N2     N2  96hrs
# 1823  PD_Aging  30.0  N2_N2_96hrs   N2     N2  96hrs
# 1824  PD_Aging  31.0  N2_N2_96hrs   N2     N2  96hrs
#
# [3621 rows x 14 columns]

# %%
TotalConcatenated=TotalConcatenated.dropna()

# %%
TotalConcatenated.to_csv('tap_output.csv')

# %%
# A debugging cell to test for strain 'XJ1' (which is the old N2)
print(TotalConcatenated[TotalConcatenated['Allele']=='XJ1'])

# %%
# If you want the default colour palette #
strains = TotalConcatenated['dataset'].unique()
pal = dict(zip(strains, sns.color_palette("deep", n_colors=len(strains))))
print('palette is:' + str(pal))


# pal = {'Wildtype (N2)': 'black', 
#        'cat-2 (e1112)': 'lavender', 
#        'cat-2 (n4547)': 'cornflowerblue', 
#        'cat-2 (tm2261)': 'blue', 
#        'dat-1 (ok157)': 'blueviolet', 
#        'cat-1 (ok441)': 'magenta', 
#        'pdr-1 (gk448)': 'rosybrown', 
#        'pdr-1 (tm395)': 'lightcoral', 
#        'pdr-1 (tm598)': 'indianred', 
#        'dop-1 (vs101)': 'slategray', 
#        'dop-3 (ok295)': 'darkslategray', 
#        'snb-5 (ok1434)': 'mediumseagreen', 
#        'unc-10 (ad591)': 'darkorange'}
print('palette is:' + str(pal))
# IF YOU WANT TO CUSTOMIZE THE COLOR PALETTE OF THE GRAPHS
# pal = {"N2": (0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#        "LX2060": (0.8666666666666667, 0.5176470588235295, 0.3215686274509804)
#     }

print('done setting colour palette')

# %%
# Outputs final data onto a spreadsheet
TotalConcatenated.to_csv("tap_output.csv")
print('done')

# %% [markdown]
# # 7.5: BONUS - Graph by plates to check for anomolies across each strain/treatment
#
# Here, we will be graphing each strain on their own by their individual plates - this will help us find any anomolies or outliers that we can then exclude!

# %%
Strain_pal = sns.choose_colorbrewer_palette('sequential')

# %%
StrainNames.get("Strain_1")

# %%
StrainConcatenated = TotalConcatenated[TotalConcatenated.dataset==StrainNames.get("Strain_1")] #Change/dictate which strain you are analyzing
print(StrainConcatenated)

# %%
StrainConcatenated = TotalConcatenated[
    TotalConcatenated.dataset == 'unc-10 (ad591)'] #Change/dictate which strain you are analyzing
StrainName = "unc-10 (ad591)" #Also change this, for labeling purposes


out1 = widgets.Output() #<- this is part of the code that helps display your graphs in tabs
out2 = widgets.Output()
out3 = widgets.Output()
out4 = widgets.Output()

tab = widgets.Tab(children = [out1, out2, out3, out4]) #<- more code to support tab display
tab.set_title(0, 'Probability')
tab.set_title(1, 'Distance')
tab.set_title(2, 'Duration')
tab.set_title(3, 'Speed')
display(tab)

plt.rcParams.update({'lines.markeredgewidth': 1})

# Probability
with out1:
    plt.figure(linewidth = 2.5) #<- Make your figure lines THICCCC for clean display (posters)
    plt.figure(figsize=(12,10)) #<- set your figure size (width, length)
    plt.gca().xaxis.grid(False) #<- gets rid of x-axis markers to make data look clean 
    ax = sns.pointplot(x="taps", #<- Here we use seaborn as our graphing package. 
                     y="prob",  
                     data = StrainConcatenated,
                     hue = 'plate', #<- Here we use the extra column from step 6 to separate by group
                     palette = Strain_pal, #<- Change colour palette here if you like
                     ci = 95) #<- Confidence interval. 95 = standard error
    plt.xlabel("Taps") #<- X-axis title
    plt.ylabel("Probability") #<- Y-Axis title
    plt.title(f"{StrainName} Probability of Tap Habituation, {ISI}ISI") #<- Figure Title
    plt.ylim(0,1)
    ax.legend(loc = 'upper right', fontsize = '12') #<- location of your legend
    plt.savefig(f'{StrainName}_Probability_{ISI}ISI_ByPlate.png', format='png', dpi=450) #<- saves your file to your folder at certain DPI
    plt.show()

# Distance
with out2:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                     y="dist", 
                     data = StrainConcatenated,
                     hue = 'plate',
                     palette = Strain_pal,
                     ci = 95)
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Distance", fontsize = '12')
    plt.title(f"{StrainName} Distance of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,1.5)
    ax.legend(loc = 'upper right', fontsize = '12')
    plt.savefig(f'{StrainName}_Distance_{ISI}ISI_ByPlate.png', format='png', dpi=450)
    plt.show()

# Duration
with out3:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                     y="dura", 
                     data = StrainConcatenated,
                     hue = 'plate',
                     palette = Strain_pal,
                     ci = 95)
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Duration", fontsize = '12')
    plt.title(f"{StrainName} Duration of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,3)
    ax.legend(loc = 'upper right', fontsize = '12')
    plt.savefig(f'{StrainName}_Duration_{ISI}ISI_ByPlate.png', format='png', dpi=450)
    plt.show()

# Speed
with out4:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                     y="speed", 
                     data = StrainConcatenated,
                     hue = 'plate',
                     palette = Strain_pal,
                     ci = 95)
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Speed", fontsize = '12')
    plt.title(f"{StrainName} Speed of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,0.5)
    ax.legend(loc = 'upper right', fontsize = '12')
    plt.savefig(f'{StrainName}_Speed_{ISI}ISI.png_ByPlate', format='png', dpi=450)
    plt.show()

# %% [markdown]
# # 8. Graph Data (Probability, Distance, Duration, Speed of Tap Habituation)
#
# ## Here, feel free to change the graph title and axis labels! Images are automatically saved in your folder with your data!
#
# Note: It has been agreed by the lab that distance is quite an outdated measure, and the three top measures we consider are:
#
# ## probability, duration and speed.

# %%
PD_tap=pd.read_csv('/Users/Joseph/Desktop/NewData/hab_output.csv').iloc[: , 1:]
N2=PD_tap[PD_tap.dataset=='N2']
mutant=PD_tap[PD_tap.Allele=='js125']
data=pd.concat([N2,mutant], ignore_index=True, sort=False)
data['Time']=data.time.round(-1)
# print(N2)
# print(mutant)
print(data)
data.to_csv('/Users/Joseph/Desktop/NewData/unc_output.csv')

# %%
out1 = widgets.Output() #<- this is part of the code that helps display your graphs in tabs
out2 = widgets.Output()
out3 = widgets.Output()
out4 = widgets.Output()

tab = widgets.Tab(children = [out1, out2, out3, out4]) #<- more code to support tab display
tab.set_title(0, 'Probability')
tab.set_title(1, 'Distance')
tab.set_title(2, 'Duration')
tab.set_title(3, 'Speed')
display(tab)

plt.rcParams.update({'lines.markeredgewidth': 1})
sns.set_context("poster")
# Probability
with out1:
    plt.figure(linewidth = 2.5) #<- Make your figure lines THICCCC for clean display (posters)
    plt.figure(figsize=(12,10)) #<- set your figure size (width, length)
    plt.gca().xaxis.grid(False) #<- gets rid of x-axis markers to make data look clean 
    ax = sns.lineplot(x="Time", #<- Here we use seaborn as our graphing package. 
                 y="prob",  
                 data = data,
                 hue = 'Gene', #<- Here we use the extra column from step 6 to separate by group
                 palette = 'deep',
                 linewidth=3,
                 style='Gene',
                 dashes=False,
                 markers=['o','o'],
                 markersize=12,
                 err_style='bars',
                 errorbar = 'se') #<- Confidence interval. 95 = standard error
    plt.xlabel("Time (s)") #<- X-axis title
    plt.ylabel("Probability") #<- Y-Axis title
    plt.title("Probability of Tap Habituation") #<- Figure Title
    plt.ylim(0,1)
    plt.xlim(550,None)
    plt.xticks(rotation=90)
    ax.legend(loc = 'upper right', fontsize = '20') #<- location of your legend
    plt.savefig('/Users/Joseph/Desktop/NewData/unc43prob.png', format='png', dpi=900,bbox_inches='tight') #<- saves your file to your folder at certain DPI
    plt.show()
    
# Distance
with out2:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="Time", 
                 y="dist", 
                 data = data,
                 hue = 'dataset',
                 palette = 'deep',
#                  palette = pal,
                 errorbar = 'se'
                      )
    plt.xlabel("Time (s)", fontsize = '12')
    plt.ylabel("Distance", fontsize = '12')
    plt.title("Distance of Tap Habituation", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Distance_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Duration
with out3:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="Time", 
                 y="dura", 
                 data = data,
                 hue = 'dataset',
                 palette = 'deep',
#                  palette = pal,
                 errorbar = 'se'
                      )
    plt.xlabel("Time (s)", fontsize = '12')
    plt.ylabel("Duration", fontsize = '12')
    plt.title("Duration of Tap Habituation", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Duration_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Speed
with out4:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="Time", 
                 y="speed", 
                 data = data,
                 hue = 'dataset',
                 palette = 'deep',
#                  palette = pal,
                 errorbar = 'se'
                      )
    plt.xlabel("Time (s)", fontsize = '12')
    plt.ylabel("Speed", fontsize = '12')
    plt.title("Speed of Tap Habituation", fontsize = '16')
    plt.ylim(0,None)
    plt.xticks(rotation=90)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Speed_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# %%
out1 = widgets.Output() #<- this is part of the code that helps display your graphs in tabs
out2 = widgets.Output()
out3 = widgets.Output()
out4 = widgets.Output()

tab = widgets.Tab(children = [out1, out2, out3, out4]) #<- more code to support tab display
tab.set_title(0, 'Probability')
tab.set_title(1, 'Distance')
tab.set_title(2, 'Duration')
tab.set_title(3, 'Speed')
display(tab)

plt.rcParams.update({'lines.markeredgewidth': 1})
sns.set_context("notebook")
# Probability
with out1:
    plt.figure(linewidth = 2.5) #<- Make your figure lines THICCCC for clean display (posters)
    plt.figure(figsize=(12,10)) #<- set your figure size (width, length)
    plt.gca().xaxis.grid(False) #<- gets rid of x-axis markers to make data look clean 
    ax = sns.pointplot(x="taps", #<- Here we use seaborn as our graphing package. 
                 y="prob",  
                 data = TotalConcatenated,
                 hue = 'dataset', #<- Here we use the extra column from step 6 to separate by group    
                 palette = pal, #<- Change colour palette here if you like
                 ci = 68) #<- Confidence interval. 95 = standard error
    plt.xlabel("Taps") #<- X-axis title
    plt.ylabel("Probability") #<- Y-Axis title
    plt.title(f"Probability of Tap Habituation, {ISI}ISI") #<- Figure Title
    plt.ylim(0,1)
    ax.legend(loc = 'upper right', fontsize = '12') #<- location of your legend
#     plt.savefig(f'Probability_{ISI}ISI.png', format='png', dpi=900) #<- saves your file to your folder at certain DPI
    plt.show()

# Distance
with out2:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                 y="dist", 
                 data = TotalConcatenated,
                 hue = 'dataset',
                 palette = pal,
                 ci = 68  #ci=68 for sem
                      )
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Distance", fontsize = '12')
    plt.title(f"Distance of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Distance_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Duration
with out3:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                 y="dura", 
                 data = TotalConcatenated,
                 hue = 'dataset',
                 palette = pal,
                 ci = 68  #ci=68 for sem
                      )
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Duration", fontsize = '12')
    plt.title(f"Duration of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Duration_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Speed
with out4:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                 y="speed", 
                 data = TotalConcatenated,
                 hue = 'dataset',
                 palette = pal,
                 ci = 68 #ci=68 for sem
                      )
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Speed", fontsize = '12')
    plt.title(f"Speed of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Speed_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# %% [markdown]
# # Done!
