# %% [markdown]
# # Jupyter Notebook UI to graph your TAP data!
#
# Version 1.7 - Joseph Liang, Rankin Lab
# Updated:
# 1. Upgraded folder path selection application
# 2. Upgraded dataset management (less moving parts for end-user)
# 3. output changed from tif -> png
# 4. Added tap-correction function for missing taps (should be working now)
# 5. Added plate column to evaluate plate-discrepancies
# 6. Added separate graphing function for plate-discrepancies
# 7. Added colour palette-setting function
#
# ## Known bug: Step 2 an empty windows displays in Mac. May also apply to linux/windows.
#
# ## Beginner Essentials:
# 1. Shift-Enter to run each cell. After you run, you should see an output "done step #". If not, an error has occured
# 2. When inputting your own code/revising the code, make sure you close all your quotation marks '' and brackets (), [], {}.
# 3. Don't leave any commas (,) hanging! (make sure an object always follows a comma. If there is nothing after a comma, remove the comma!
# 4. Learning to code? Each line of code is annotated to help you understand how this code works!
#
# ## 3. Run all cells/steps sequentially, even the ones that do not need input
#
# ## Steps that require input: #3, #6.1, #7

# %% [markdown]
# # 1. Importing Packages Required (No input required, just run)

# %%
import pandas as pd #<- package used to import and organize data
import numpy as np #<- package used to import and organize data
import math
import os #<- package used to work with system file paths
import seaborn as sns #<- package used to plot graphs
from matplotlib import pyplot as plt #<- another package used to plot graphs
from itertools import cycle #<- package used to iterate down rows (used in step 5 to add tap column)
import ipywidgets as widgets #<- widget tool to generate button and tab for graphs
from IPython.display import display #<- displays widgets
from ipyfilechooser import FileChooser
# from tkinter import Tk, filedialog #<- Tkinter is a GUI package
print("done step 1")
# Out:
# done step 1

# %% [markdown]
# # 2. Pick filepath (just run and click button from output)
#
# Run the following cell and click the button 'Select Folder' to pick a filepath.
#
# ## Important: Later on, this script uses the total file path for each file to import and group data. That means if your folder has whatever your strain is named, the script will not work.
#
# (ex. if your folder has "N2" in it this script sees all files inside this folder as having the "N2" search key)
#
# ## An easy fix is to just rename your folder to something else (make your strains lower-case, or just have the date)

# %%
starting_directory = '/Users/Joseph'
chooser = FileChooser(starting_directory)
display(chooser)
# Out:
# FileChooser(path='/Users/Joseph', filename='', title='', show_hidden=False, select_desc='Select', change_desc=…

# %%
print(chooser.selected_path)
folder_path=chooser.selected_path
# Out:
# /Volumes/JOSEPH/Neuron_Genes_Screen

# %%
# Obsolete
# ### Select Folder App - After you run, you can select your folder for filepath
# button = widgets.Button(description = 'Select Folder') #<- Creates a button variable
# display(button) #<- displays this button on output
# def select_folder(b): #<- This is an action. Requires a variable, so I put in an arbitrary one 'b'
#     global folder_path #<- sets a variable as a global variable, not just within this action
#     Tk().withdraw() #<- Tkinter likes to create annoying empty windows. This removes them
#     folder_path = filedialog.askdirectory() #<- Opens up a file explorer window, and determines folder path
#     Tk().update()#<- below
#     Tk().destroy()#<- this and the line above it removes the file explorer window after a selection is made
#     print(folder_path) #<- this helps confirm that this action was performed
#     print('done step 2')
# button.on_click(select_folder) #<- describes what happens when you click on this button

# %% [markdown]
# # 3. User Defined Variables (Add input here)
#
# Here, we add some constants to help you blaze through this code.
#
# 3.1: Number of taps is pretty self-explanatory. How any taps does your experiment have? put in that number + 1 (N+1)!
#
# This may be a bit confusing, but this is due to some coding syntax that you don't have to worry about.
#
# 3.2: Change your ISI number. This will be reflected in the name/title of the output figure.

# %%
number_of_taps = 30 ###<------ Taps in your experiment.

number_taps = range(1, number_of_taps + 1)  #<- do not change this


# if you have different ISIs in the same folder, then come back and change this 
# when you are graphing for the second set of data with the other ISI 
# (Generally data from same ISIs are graphed together)
# If changing ISI mid-analysis, you can just skip straight to step 8 after running this cell again

ISI = 10  ### <- What is your ISI? change accordingly
first_tap = 600 ### <- when is your first tap? check your TRV files

#Here, open up one of the trv files to determine the times for each of these taps. 
lower = np.arange(first_tap-1, first_tap-1+(number_of_taps*ISI), ISI) #(first tap, last tap+10s, ISI)
upper = np.arange(first_tap+1, first_tap+1+(number_of_taps*ISI), ISI) #(first tap, last tap+10s, ISI)
tolerances = list(zip(lower, upper)) 
taps = [i for i in range(1,number_of_taps+1)]

#### Add 31st Tap Here --------------------------------------------------<------------
tolerances.append((1188,1191))
taps.append(31)


#assign each tolerance to a tap number
accurate_taps = list((zip(taps, tolerances)))
print(accurate_taps)

for pair in accurate_taps:
   tap = pair[0]
   tolerance = pair[1]
   print("tap "+str(tap), "tolerance="+str(tolerance))

print("done step 3")
# Out:
# [(1, (599, 601)), (2, (609, 611)), (3, (619, 621)), (4, (629, 631)), (5, (639, 641)), (6, (649, 651)), (7, (659, 661)), (8, (669, 671)), (9, (679, 681)), (10, (689, 691)), (11, (699, 701)), (12, (709, 711)), (13, (719, 721)), (14, (729, 731)), (15, (739, 741)), (16, (749, 751)), (17, (759, 761)), (18, (769, 771)), (19, (779, 781)), (20, (789, 791)), (21, (799, 801)), (22, (809, 811)), (23, (819, 821)), (24, (829, 831)), (25, (839, 841)), (26, (849, 851)), (27, (859, 861)), (28, (869, 871)), (29, (879, 881)), (30, (889, 891)), (31, (1188, 1191))]
# tap 1 tolerance=(599, 601)
# tap 2 tolerance=(609, 611)
# tap 3 tolerance=(619, 621)
# tap 4 tolerance=(629, 631)
# tap 5 tolerance=(639, 641)
# tap 6 tolerance=(649, 651)
# tap 7 tolerance=(659, 661)
# tap 8 tolerance=(669, 671)
# tap 9 tolerance=(679, 681)
# tap 10 tolerance=(689, 691)
# tap 11 tolerance=(699, 701)
# tap 12 tolerance=(709, 711)
# tap 13 tolerance=(719, 721)
# tap 14 tolerance=(729, 731)
# tap 15 tolerance=(739, 741)
# tap 16 tolerance=(749, 751)
# tap 17 tolerance=(759, 761)
# tap 18 tolerance=(769, 771)
# tap 19 tolerance=(779, 781)
# tap 20 tolerance=(789, 791)
# tap 21 tolerance=(799, 801)
# tap 22 tolerance=(809, 811)
# tap 23 tolerance=(819, 821)
# tap 24 tolerance=(829, 831)
# tap 25 tolerance=(839, 841)
# tap 26 tolerance=(849, 851)
# tap 27 tolerance=(859, 861)
# tap 28 tolerance=(869, 871)
# tap 29 tolerance=(879, 881)
# tap 30 tolerance=(889, 891)
# tap 31 tolerance=(1188, 1191)
# done step 3

# %% [markdown]
# # 4. Constructing Filelist From Source File/Select File (Just run)

# %%
#folder_path = '/Users/Joseph/Desktop/AVR14_10sISI' #- manual folder path if Tkinter is acting up

os.chdir(folder_path) #<- setting your working directory so that your images will be saved here

filelist = list() #<- empty list
for root, dirs, files in os.walk(folder_path): #<- this for loop goes through your folder 
    for name in files:
        if name.endswith('.trv'): #<- and takes out all files with a .trv (file that contains your data)
            filepath = os.path.join(root, name) #<- Notes down the file path of each data file
            filelist.append(filepath) #<- saves it into the list
    
print(filelist)
print('done step 4')
# Out:
# ['/Volumes/JOSEPH/Neuron_Genes_Screen/inx-14_ag17/20100314_094414/AU98_5x4_f90h20C_10m30x10s10s_D0310aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/inx-14_ag17/20100314_100214/AU98_5x4_f90h20C_10m30x10s10s_D0310ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/inx-14_ag17/20100314_101744/AU98_5x4_f90h20C_10m30x10s10s_D0310ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/inx-14_ag17/20100314_110157/AU98_5x4_f91h20C_10m30x10s10s_D0310ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/spe-8_hc40/20100320_110314/BA785_10x5_f89h20C_10m30x10s10s_B0316aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/spe-8_hc40/20100320_111858/BA785_10x5_f89h20C_10m30x10s10s_B0316ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/spe-8_hc40/20100320_113453/BA785_10x5_f90h20C_10m30x10s10s_B0316ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/spe-8_hc40/20100320_115026/BA785_10x5_f90h20C_10m30x10s10s_B0316ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/cav-2_hc191/20100320_120802/BA1090_5x5_f90h20C_10m30x10s10s_D0316aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/cav-2_hc191/20100320_122349/BA1090_5x5_f90h20C_10m30x10s10s_D0316ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/cav-2_hc191/20100320_123952/BA1090_5x5_f91h20C_10m30x10s10s_D0316ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/cav-2_hc191/20100320_125523/BA1090_5x5_f91h20C_10m30x10s10s_D0316ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/snf-10_hc194/20100313_223126/BA1093_10x4_f85h20C_10m30x10s10s_C0310aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/snf-10_hc194/20100313_224759/BA1093_10x4_f85h20C_10m30x10s10s_C0310ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/snf-10_hc194/20100313_230413/BA1093_10x4_f85h20C_10m30x10s10s_C0310ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/snf-10_hc194/20100313_232006/BA1093_10x4_f85h20C_10m30x10s10s_C0310ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/adr-1_gv6/20100319_110636/BB2_8x4_f90h20C_10m30x10s10s_E0315aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/adr-1_gv6/20100319_112215/BB2_8x4_f90h20C_10m30x10s10s_E0315ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/adr-1_gv6/20100319_113836/BB2_8x4_f91h20C_10m30x10s10s_E0315ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/adr-1_gv6/20100319_115406/BB2_8x4_f91h20C_10m30x10s10s_E0315ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/eak-6_mg329/20100319_120948/BQ5_5x4_f91h20C_10m30x10s10s_A0315aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/eak-6_mg329/20100319_122714/BQ5_5x4_f91h20C_10m30x10s10s_A0315ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/eak-6_mg329/20100319_133209/BQ5_5x4_f93h20C_10m30x10s10s_A0315ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/eak-6_mg329/20100319_134836/BQ5_5x4_f93h20C_10m30x10s10s_A0315ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/pmk-3_ok169/20100314_111932/BS3383_5x4_f91h20C_10m30x10s10s_C0310aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/pmk-3_ok169/20100314_113727/BS3383_5x4_f92h20C_10m30x10s10s_C0310ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/pmk-3_ok169/20100314_115339/BS3383_5x4_f92h20C_10m30x10s10s_C0310ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/pmk-3_ok169/20100314_120914/BS3383_5x4_f92h20C_10m30x10s10s_C0310ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_121128/CB2_8x4_f91h20C_10m30x10s10s_D0315aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_122801/CB2_8x4_f91h20C_10m30x10s10s_D0315ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_133316/CB2_8x4_f93h20C_10m30x10s10s_D0315ac.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_134929/CB2_8x4_f93h20C_10m30x10s10s_D0315ad.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/unc-82_e1220/20101108_210743/CB1220_5x3_f77h20C_100s30x10s10s_A1105dc.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/unc-82_e1220/20101108_212729/CB1220_5x3_f77h20C_100s30x10s10s_A1105da.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/daf-18_e1375/20100313_194935/CB1375_7x4_f82h20C_10m30x10s10s_E0310aa.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/daf-18_e1375/20100313_200615/CB1375_7x4_f82h20C_10m30x10s10s_E0310ab.trv', '/Volumes/JOSEPH/Neuron_Genes_Screen/daf-18_e1375/2010031 ...
# done step 4

# %%
# string = '/Volumes/JOSEPH/PD_Screen/bas-1_tm351/20220809_103216/LC33_10x2_f72h20C_600s31x10s10s_B0809db.trv'
# print(string.split('/')[-3])
# print(string.split('/')[-2].split('_')[0])
# print(string.split('/')[-1].split('_')[-1].split('.')[0])

# %%
genotype=[]
for f in filelist:
    genotype.append(f.split('/')[-3])
# print(np.unique(genotype))
genotypes=np.unique(genotype)
print(genotypes)
print(len(np.unique(genotypes)))
strainNs = enumerate(genotypes,1)
strain_enum=list(strainNs)
print(strain_enum)
StrainNames=dict(strain_enum)
print(StrainNames)
# Out:
# ['C03A3.3_ok2834' 'C03B1.5_ok2345' 'C04B4.2_ok1212' 'C04E6.5_ok1497'
#  'C27B7.7_ok2868' 'C44H4.6_ok1560' 'C49C3.21_ok3180' 'D1081.4_ok2041'
#  'F07A11.4_ok3152' 'F09A5.2_ok1900' 'F09C12.2_hc185' 'F11A5.4_ok1857'
#  'F11E6.8_ok2754' 'F16B12.5_gk1009' 'F31E3.2_ok2044' 'F38B6.6_ok3009'
#  'F39E9.6_ok3515' 'F43B10.1_ok1441' 'F47G4.4_ok2219' 'F49C5.4_ok3082'
#  'F52B5.2_ok2069' 'F55D12.5_ok2543' 'F59A6.5_ok2885' 'F59E12.3_ok3507'
#  'K02E10.1_ok1871' 'M195.2_ok1503' 'N2_N2' 'N2_XJ1' 'RO5G6.10_ok1159'
#  'T01C3.3_ok2482' 'T02C1.1_ok3334' 'T10B10.3_ok2184' 'T15B12.1_gk751'
#  'W02B8.2_ok2328' 'W02C12.1_ok3422' 'W04B5.5_ok1309' 'Y106G6H.14_ok3081'
#  'Y45F10B.8_ok1607' 'Y47G6A.14_ok1106' 'Y4C6A.1_ok2938' 'Y52B11A.4_ok1023'
#  'Y64G10A.7_ok1062' 'ZC477.2_ok3206' 'ZK1248.15_ok2612' 'ZK909.3_ok3408'
#  'aak-2_gt33' 'abl-1_ok171' 'acy-1_ce2' 'acy-1_md1756' 'acy-1_nu329'
#  'adm-2_ok3178' 'adp-1_ky20' 'adr-1_gv6' 'aex-1_tg50' 'aex-3_js815'
#  'aex-5_sa23' 'aex-6_sa24' 'age-1_hx546' 'ahr-1_ju145' 'aka-1_ok707'
#  'akt-1_mg144' 'akt-2_ok393' 'ape-1_ok1085' 'arg-1_ok3127' 'arl-5_ok2407'
#  'atg-16.2_ok3224' 'atl-1_ok1063' 'atm-1_gk186' 'atn-1_ok84'
#  'bas-1xcat-4_ad446xe1141' 'bbs-8_nx77' 'cam-1_ks52' 'cav-1_ok2089'
#  'cav-2_hc191' 'cbp-1_ku258' 'cca-1_ad1650' 'cdc-7_ok1267' 'cdh-10_ok2920'
#  'cdh-1_gk784' 'cdh-3_pk87' 'cdh-4_ok1323' 'cdh-5_hc181' 'cdk-14_ok2844'
#  'cdkl-1_ok2694' 'ced-10_n3246' 'ced-6_n2095' 'cerk-1_ok1252'
#  'cex-1_ok3163' 'cfi-1_ky651' 'cfz-2_ok1201' 'che-14_e1960' 'che-14_ok193'
#  'che-3_e1124' 'chpf-2_ok2941' 'ckk-1_ok1033' 'ckr-1_ok2502'
#  'cla-1_ok2285' 'cle-1_gk364' 'clec-43_ok3188' 'clec-4_ok2050'
#  'clec-78_ok2088' 'clh-4_ok1162' 'clr-1_e1745' 'cls-3_ok3375'
#  'cmk-1_ok287' 'cng-1_jh111' 'cnt-2_ok1767' 'cnx-1_nr2009' 'copd-1_ok2725'
#  'cor-1_ok869' 'cpd-2_ok3147' 'cpn-3_gk336' 'cpna-3_ok922' 'crb-1_ok931'
#  'cul-5_ok1706' 'cul-6_ok1614' 'cwn-2_ok895' 'daf-10_e1387' 'daf-11_m47'
#  'daf-18_e1375' 'dapk-1_gk219' 'dat-1_ok157' 'dbl-1_nk3' 'dbn-1_ok925'
#  'dep-1_ok1844' 'dgk-1_nu62' 'dgk-2_gk124' 'dgk-3_gk110' 'dgk-4_ok1031'
#  'dgk-5_gk631' 'dig-1_n1321' 'dlk-1_km12' 'dnj-7_ok1495' 'dop-1_vs100'
#  'dop-2_vs105' 'dop-2xdop-1xdop-3_vs105xvs100xvs106' 'dop-3_ok295'
#  'dsh-1_ok1445' 'dsl-1_ok810' 'dsl-4_ok1020' 'dsl-6_ok2265' 'dyc-1_cx32'
#  'dyf-2_m160' 'dyf-5_mn400' 'dyn-1_ky51' 'dys-1_cx18' 'eak-6_mg329'
#  'eat-16_ce71' 'eat-16_sa609' 'eat-5_ad464' 'ebp-2_gk756' 'ect-2_ku427'
#  'efa-6_ok3533' 'efk-1_ok3609' 'egl-10_md176' 'egl-10_n692' 'egl-15_n484'
#  'egl-19_n582' 'egl-20_n585' 'egl-21_n611' 'egl-30_ad806' 'egl-30_ep271'
#  'egl-30_js126' 'egl-30_n686' 'egl-30_n715' 'egl-8_n488' 'egl-8_ok934'
#  'ehs-1_ok146' 'elks-1_ok2762' 'elp-1_gk168' 'elp-1_ok2357' 'emb-30_g53'
#  'esyt-2_ok2509' 'exc-5_km508' 'fer-1_hc1' 'flp-12_ok2409' 'flp-17_ok3587'
#  'flp-19_ok2460' 'flp-6_ok3056' 'flp-9_ok2730' 'frm-7_ok2081'
#  'frm-8_ok1769' 'frpr-10_ok1504' 'frpr-18_ok2698' 'fsn-1_gk429'
#  'gap-2_tm748' 'gck-2_ok2867' 'gipc-1_hc192' 'gipc-2_ok1172' 'glc-3_ok321'
#  'glr-2_ok2342' 'goa-1_n1134' 'goa-1_n3055' 'goa-1_sa734' 'gpa-11_pk349'
#  'gpa-12_pk322' 'gpa-13_pk1270' 'gpa-15_pk477' 'gpa-16_ok2349'
#  'gpa-1_ok2334' 'gpa-3_pk35' 'gpa-4_pk381' 'gpa-5_pk376' 'gpa-6_pk480'
#  'gpa-7_pk610' 'gpa-8_pk345' 'gpa-9_pk438' 'gpap-1_ok2805' 'gpb-2_pk751'
#  'gpc-1_pk298' 'gpr-2_ok1179' 'grk-1_ok1239' 'grk-2_rt97' 'gsa-1_ce81'
#  'gsa-1_ce94' 'hecw-1_ok1347' 'herc-1_ok1524' 'hid-1_sa1058'
#  'hpk-1_pk1393' 'hum-5_ok1885' 'hum-6_ok2365' 'hum-8_ok2414'
#  'ift-139_gk477' 'ifta-1_nx61' 'igcm-3_gk420' 'ikb-1_nr2027' 'ina-1_gm144'
#  'inft-1_gk386' 'ins-11_tm1053' 'ins-18_ok1672' 'ins-22_ok3616'
#  'ins-31_ok3543' 'ins-35_ok3297' 'ins-4_ok3534' 'inx-10_ok2714'
#  'inx-11_ok2783' 'inx-14_ag17' 'inx-19_ky634' 'inx-21_ok2524'
#  'inx-22_tm1661' 'inx-4_ok2373' 'inx-5_ok1053' 'inx-6_rr5' 'inx-8_gk42'
#  'inx-9_gk293' 'ipp-5_sy605' 'itsn-1_ok268' 'jkk-1_km2' 'kal-1_gb503'
#  'kcnl-1_nf110' 'kcnl-2_ok2818' 'kgb-1_km21' 'kgb-2_gk361' 'kin-2_ce179'
#  'klc-1_ok2609' 'klp-11_tm324' 'klp-15_ok1958' 'klp-15_ok1958_1'
#  'klp-16_ok1505' 'ksr-1_n2682' 'kvs-3_nf140' 'kvs-3_nf140_1'
#  'let-60_n1700' 'let-756_ok2058' 'let-92_ok1537' 'lin-23_ok2615'
#  'lin-2_e1309' 'lin-3_e1417' 'lin-44_n1792' 'lip-1_zh15' 'lrch-1_ok1543'
#  'lron-15_ok3309' 'lron-3_ok2614' 'lron-6_ok1119' 'madd-4_ok2862'
#  'magi-1_gk657' 'mbk-1_pk1389' 'mek-1_ks54' 'mekk-3_ok2178'
#  'mics-1_ok1451' 'mkk-4_ok1545' 'mlk-1_ok2471' 'mod-5_n822' 'mpz-4_ok1143'
#  'mrp-1_ut153' 'mrp-2_ok2157' 'mrp-3_ok955' 'mrp-4_cd8' 'mrp-6_ok1027'
#  'mtm-5_ok469' 'mtm-6_ok330' 'nck-1_ok383' 'ncs-1_qa406' 'nep-1_by159'
#  'neto-1_ok2468' 'nex-1_gk148' 'nex-3_gk385' 'nex-4_gk102' 'nhl-1_gk15'
#  'nhl-3_ok3223' 'nhr-83_ok1613' 'nhr-99_gk791' 'nipi-3_fr4' 'nlg-1_ok259'
#  'nlp-15_ok1512' 'nlp-18_ok1557' 'nlp-1_ok1479' 'nlp-20_ok1591'
#  'nlp-3_ok2688' 'nlp-5_ok1981' 'nmur-1_ok1387' 'nmur-2_ok3502'
#  'nnt-1_sv34' 'npr-14_ok2375' 'npr-16_ok1541' 'npr-18_ok1388'
#  'npr-19_ok2068' 'npr-25_ok2008' 'npr-32_ok2541' 'npr-8_ok1439'
#  'npr-8_ok1446' 'npr-9_tm1652' 'nra-1_ok1025' 'nsy-1_ag3' 'ntr-1_ok2780'
#  'oct-1_gk354' 'oct-1_ok3401' 'octr-1_ok371' 'odr-1_n1936' 'ogt-1_ok1474'
#  'old-1_mk1' 'old-2_ok1253' 'osm-6_p811' 'osm-9_yz6' 'oxi-1_ok1217'
#  'pak-2_ok332' 'par-1_ok2001' 'pde-1_ok2924' 'pde-4_ce268' 'pde-4_ok1290'
#  'pdl-1_gk157' 'pdr-1_gk448' 'pept-2_ok1192' 'pes-1_leDf1' 'pes-7_gk123'
#  'pes-9_ok1037' 'pfn-3_tm1362' 'piki-1_ok2346' 'pkc-1_nj1' 'pkg-2_ok966'
#  'plc-2_ok1761' 'plc-4_ok1215' 'pld-1_ok2222' 'plk-3_ok2812'
#  'pll-1_ok2003' 'plpp-1.1_ok1861' 'plx-1_nc36' 'pmk-3_ok169' 'ppl-3_n2835'
#  'prk-2_pk278' 'prmn-1_gk545' 'ptp-3_op147' 'qui-1_ok3571' 'rab-10_q373'
#  'rab-18_ok2020' 'rab-19_ok1845' 'rab-3_js49' 'rab-5_ok2605' 'rap-2_gk11'
#  'rbf-1_js232' 'rbx-2_ok1617' 'rga-5_ok2241' 'rgl-1_ok1821'
#  'rgs-10_ok1039' 'rgs-1_nr2017' 'rgs-2_vs17' 'rgs-4_vs93' 'rgs-5_vs58'
#  'rgs-6_vs62' 'ric-19_pk690' 'ric-4_gk322' 'ric-8_md1909' 'rig-3_ok2156'
#  'riok-3_ok2958' 'rme-6_b1014' 'rnf-1_ok501' 'rnf-5_tm794' 'rpm-1_ju41'
#  'rpy-1_ok145' 'rsd-3_pk2013' 'sac-2_ok2743' 'scd-2_sa249' 'scrm-3_ok1178'
#  'sek-1_km4' 'sek-6_ok1386' 'sel-5_ok149' 'ser-1_ok345' 'ser-2_pk1357'
#  'shn-1_gk181' 'sid-1_pk3321' 'skr-1_ok1696' 'skr-5_ok3068' 'sli-1_n3538'
#  'slt-1_ok255' 'sma-1_e30' 'sma-6_e1482' 'smg-1_r861' 'sms-5_ok2498'
#  'snb-1_js44' 'snb-1xunc-17_e245xe1563' 'snb-5_ok1434' 'snf-10_hc194'
#  'snf-11_ok156' 'snf-9_ok957' 'snt-5_ok3287' 'snt-6_ok3496' 'soc-1_n1789'
#  'soc-2_ku167' 'spe-8_hc40' 'sph-1_ok1466' 'sphk-1_ok1097' 'src-1_ok2685'
#  'ssr-2_ok1375' 'stn-1_ok292' 'stn-2_ok2417' 'strd-1_ok2283'
#  'swan-2_ok267' 'syd-1_ju82' 'syd-2_ju37' 'syg-2_ky671' 'sym-1_mn601'
#  'sym-4_mn619' 'tag-163_ok644' 'tag-180_ok779' 'tag-312_ok1356'
#  'tag-325_ok1330' 'tag-333_gk431' 'tag-344_gk524' 'tag-53_gk163'
#  'tag-68_gk185' 'tap-1_gk202' 'tax-2_ok3403' 'test-1_gk1003'
#  'tig-2_ok3416' 'tir-1_tm3036' 'tkr-2_ok1620' 'tli-1_ok1724'
#  'tol-1_nr2033' 'tom-1_ok188' 'trf-1_nr2014' 'trhr-1_ok1381' 'ttx-7_nj51'
#  'tub-1_ok1972' 'twk-20_nf130' 'tyra-3_ok325' 'ubc-16_ok3177' 'ubc-1_gk14'
#  'ubc-24_ok3451' 'ubc-25_ok1732' 'ubr-5_ok1108' 'ucr-2.3_pk732'
#  'unc-129_ev554' 'unc-130_oy10' 'unc-13_e312' 'unc-22_s16' 'unc-29_e193'
#  'unc-36_e251' 'unc-40_e271' 'unc-41_e268 ' 'unc-5_e152' 'unc-64_e246'
#  'unc-82_e1220' 'unc-89_e1460' 'unknown_KG6' 'unknown_RB2261' 'vab-1_e2'
#  'vap-1_ok392' 'ver-1_ok1738' 'ver-4_ok1079' 'vit-4_ok2982'
#  'vps-20_ok2425' 'wdfy-2_ok3592' 'wdr-5.2_ok1444' 'wrk-1_tm1099'
#  'wsp-1_gm324' 'wwp-1_ok1102' 'xol-1_y9' 'zig-12_ok2994' 'zig-3_ok1476'
#  'zig-7_ok2329' 'zip-5_gk646']
# 491
# [(1, 'C03A3.3_ok2834'), (2, 'C03B1.5_ok2345'), (3, 'C04B4.2_ok1212'), (4, 'C04E6.5_ok1497'), (5, 'C27B7.7_ok2868'), (6, 'C44H4.6_ok1560'), (7, 'C49C3.21_ok3180'), (8, 'D1081.4_ok2041'), (9, 'F07A11.4_ok3152'), (10, 'F09A5.2_ok1900'), (11, 'F09C12.2_hc185'), (12, 'F11A5.4_ok1857'), (13, 'F11E6.8_ok2754'), (14, 'F16B12.5_gk1009'), (15, 'F31E3.2_ok2044'), (16, 'F38B6.6_ok3009'), (17, 'F39E9.6_ok3515'), (18, 'F43B10.1_ok1441'), (19, 'F47G4.4_ok2219'), (20, 'F49C5.4_ok3082'), (21, 'F52B5.2_ok2069'), (22, 'F55D12.5_ok2543'), (23, 'F59A6.5_ok2885'), (24, 'F59E12.3_ok3507'), (25, 'K02E10.1_ok1871'), (26, 'M195.2_ok1503'), (27, 'N2_N2'), (28, 'N2_XJ1'), (29, 'RO5G6.10_ok1159'), (30, 'T01C3.3_ok2482'), (31, 'T02C1.1_ok3334'), (32, 'T10B10.3_ok2184'), (33, 'T15B12.1_gk751'), (34, 'W02B8.2_ok2328'), (35, 'W02C12.1_ok3422'), (36, 'W04B5.5_ok1309'), (37, 'Y106G6H.14_ok3081'), (38, 'Y45F10B.8_ok1607'), (39, 'Y47G6A.14_ok1106'), (40, 'Y4C6A.1_ok2938'), (41, 'Y52B11A.4_ok1023'), (42, 'Y64G10A.7_ok1062'), (43, 'ZC477.2_ok3206'), (44, 'ZK1248.15_ok2612'), (45, 'ZK909.3_ok3408'), (46, 'aak-2_gt33'), (47, 'abl-1_ok171'), (48, 'acy-1_ce2'), (49, 'acy-1_md1756'), (50, 'acy-1_nu329'), (51, 'adm-2_ok3178'), (52, 'adp-1_ky20'), (53, 'adr-1_gv6'), (54, 'aex-1_tg50'), (55, 'aex-3_js815'), (56, 'aex-5_sa23'), (57, 'aex-6_sa24'), (58, 'age-1_hx546'), (59, 'ahr-1_ju145'), (60, 'aka-1_ok707'), (61, 'akt-1_mg144'), (62, 'akt-2_ok393'), (63, 'ape-1_ok1085'), (64, 'arg-1_ok3127'), (65, 'arl-5_ok2407'), (66, 'atg-16.2_ok3224'), (67, 'atl-1_ok1063'), (68, 'atm-1_gk186'), (69, 'atn-1_ok84'), (70, 'bas-1xcat-4_ad446xe1141'), (71, 'bbs-8_nx77'), (72, 'cam-1_ks52'), (73, 'cav-1_ok2089'), (74, 'cav-2_hc191'), (75, 'cbp-1_ku258'), (76, 'cca-1_ad1650'), (77, 'cdc-7_ok1267'), (78, 'cdh-10_ok2920'), (79, 'cdh-1_gk784'), (80, 'cdh-3_pk87'), (81, 'cdh-4_ok1323'), (82, 'cdh-5_hc181'), (83, 'cdk-14_ok2844'), (84, 'cdkl-1_ok2694'), (85, 'ced-10_n3246'), (86, 'ced-6_n2095'), (87, 'cerk-1_ok1252'), (88, 'cex-1_ok3163'), (89, 'cfi-1_ky651'), (90, 'cfz-2_ok1201'), (91, 'che-14_e1960'), (92, 'che-14_ok193'), (93, 'che-3_e1124'), (94, 'chpf-2_ok2941'), (95, 'ckk-1_ok1033'), (96, 'ckr-1_ok2502'), (97, 'cla-1_ok2285'), (98, 'cle-1_gk364'), (99, 'clec-43_ok3188'), (100, 'clec-4_ok2050'), (101, 'clec-78_ok2088'), (102, 'clh-4_ok1162'), (103, 'clr-1_e1745'), (104, 'cls-3_ok3375'), (105, 'cmk-1_ok287'), (106, 'cng-1_jh111'), (107, 'cnt-2_ok1767'), (108, 'cnx-1_nr2009'), (109, 'copd-1_ok2725'), (110, 'cor-1_ok869'), (111, 'cpd-2_ok3147'), (112, 'cpn-3_gk336'), (113, 'cpna-3_ok922'), (114, 'crb-1_ok931'), (115, 'cul-5_ok1706'), (116, 'cul-6_ok1614'), (117, 'cwn-2_ok895'), (118, 'daf-10_e1387'), (119, 'daf-11_m47'), (120, 'daf-18_e1375'), (121, 'dapk-1_gk219'), (122, 'dat-1_ok157'), (123, 'dbl-1_nk3'), (124, 'dbn-1_ok925'), (125, 'dep-1_ok1844'), (126, 'dgk-1_nu62'), (127, 'dgk-2_gk124'), (128, 'dgk-3_gk110'), (129, 'dgk-4_ok1031'), (130, 'dgk-5_gk631'), (131, 'dig-1_n1321'), (132, 'dlk-1_km12'), (133, 'dnj-7_ok1495'), (134, 'dop-1_vs100'), (135, 'dop-2_vs105'), (136, 'dop-2xdop-1xdop-3_vs105xvs100xvs106'), (137, 'dop-3_ok295'), (138, 'dsh-1_ok1445'), (139, 'dsl-1_ok810'), (140, 'dsl-4_ok1020'), (141, 'dsl-6_ok2265'), (142, 'dyc-1_cx32'), (143, 'dyf-2_m160'), (144, 'dyf-5_mn400'), (145, 'dyn-1_ky51'), (146, 'dys-1_cx18'), (147, 'eak-6_mg329'), (148, 'eat-16_ce71'), (149, 'eat-16_sa609'), (150, 'eat-5_ad464'), (151, 'ebp-2_gk756'), (152, 'ect-2_ku427'), (153, 'efa-6_ok3533'), (154, 'efk-1_ok3609'), (155, 'egl-10_md176'), (156, 'egl-10_n692'), (157, 'egl-15_n484'), (158, 'egl-19_n582'), (159, 'egl-20_n585'), (160, 'egl-21_n611'), (161, 'egl-30_ad806'), (162, 'egl-30_ep271'), (163, 'egl-30_js126'), (164, 'egl-30_n686'), (165, 'egl-30_n715'), (166, 'egl-8_n488'), (167, 'egl-8_ok934'), (168, 'ehs-1_ok146'), (169, 'elks-1_ok2762'), (170, 'elp-1_gk168'), (171, 'elp-1_ok2357'), (172, 'emb-30_g53'), (173, 'esyt-2_ok2509'), (174, 'exc-5_km508'), (175, 'fer-1_hc1'), (176, 'flp-12_ok2409'), (177, 'flp-1 ...
# {1: 'C03A3.3_ok2834', 2: 'C03B1.5_ok2345', 3: 'C04B4.2_ok1212', 4: 'C04E6.5_ok1497', 5: 'C27B7.7_ok2868', 6: 'C44H4.6_ok1560', 7: 'C49C3.21_ok3180', 8: 'D1081.4_ok2041', 9: 'F07A11.4_ok3152', 10: 'F09A5.2_ok1900', 11: 'F09C12.2_hc185', 12: 'F11A5.4_ok1857', 13: 'F11E6.8_ok2754', 14: 'F16B12.5_gk1009', 15: 'F31E3.2_ok2044', 16: 'F38B6.6_ok3009', 17: 'F39E9.6_ok3515', 18: 'F43B10.1_ok1441', 19: 'F47G4.4_ok2219', 20: 'F49C5.4_ok3082', 21: 'F52B5.2_ok2069', 22: 'F55D12.5_ok2543', 23: 'F59A6.5_ok2885', 24: 'F59E12.3_ok3507', 25: 'K02E10.1_ok1871', 26: 'M195.2_ok1503', 27: 'N2_N2', 28: 'N2_XJ1', 29: 'RO5G6.10_ok1159', 30: 'T01C3.3_ok2482', 31: 'T02C1.1_ok3334', 32: 'T10B10.3_ok2184', 33: 'T15B12.1_gk751', 34: 'W02B8.2_ok2328', 35: 'W02C12.1_ok3422', 36: 'W04B5.5_ok1309', 37: 'Y106G6H.14_ok3081', 38: 'Y45F10B.8_ok1607', 39: 'Y47G6A.14_ok1106', 40: 'Y4C6A.1_ok2938', 41: 'Y52B11A.4_ok1023', 42: 'Y64G10A.7_ok1062', 43: 'ZC477.2_ok3206', 44: 'ZK1248.15_ok2612', 45: 'ZK909.3_ok3408', 46: 'aak-2_gt33', 47: 'abl-1_ok171', 48: 'acy-1_ce2', 49: 'acy-1_md1756', 50: 'acy-1_nu329', 51: 'adm-2_ok3178', 52: 'adp-1_ky20', 53: 'adr-1_gv6', 54: 'aex-1_tg50', 55: 'aex-3_js815', 56: 'aex-5_sa23', 57: 'aex-6_sa24', 58: 'age-1_hx546', 59: 'ahr-1_ju145', 60: 'aka-1_ok707', 61: 'akt-1_mg144', 62: 'akt-2_ok393', 63: 'ape-1_ok1085', 64: 'arg-1_ok3127', 65: 'arl-5_ok2407', 66: 'atg-16.2_ok3224', 67: 'atl-1_ok1063', 68: 'atm-1_gk186', 69: 'atn-1_ok84', 70: 'bas-1xcat-4_ad446xe1141', 71: 'bbs-8_nx77', 72: 'cam-1_ks52', 73: 'cav-1_ok2089', 74: 'cav-2_hc191', 75: 'cbp-1_ku258', 76: 'cca-1_ad1650', 77: 'cdc-7_ok1267', 78: 'cdh-10_ok2920', 79: 'cdh-1_gk784', 80: 'cdh-3_pk87', 81: 'cdh-4_ok1323', 82: 'cdh-5_hc181', 83: 'cdk-14_ok2844', 84: 'cdkl-1_ok2694', 85: 'ced-10_n3246', 86: 'ced-6_n2095', 87: 'cerk-1_ok1252', 88: 'cex-1_ok3163', 89: 'cfi-1_ky651', 90: 'cfz-2_ok1201', 91: 'che-14_e1960', 92: 'che-14_ok193', 93: 'che-3_e1124', 94: 'chpf-2_ok2941', 95: 'ckk-1_ok1033', 96: 'ckr-1_ok2502', 97: 'cla-1_ok2285', 98: 'cle-1_gk364', 99: 'clec-43_ok3188', 100: 'clec-4_ok2050', 101: 'clec-78_ok2088', 102: 'clh-4_ok1162', 103: 'clr-1_e1745', 104: 'cls-3_ok3375', 105: 'cmk-1_ok287', 106: 'cng-1_jh111', 107: 'cnt-2_ok1767', 108: 'cnx-1_nr2009', 109: 'copd-1_ok2725', 110: 'cor-1_ok869', 111: 'cpd-2_ok3147', 112: 'cpn-3_gk336', 113: 'cpna-3_ok922', 114: 'crb-1_ok931', 115: 'cul-5_ok1706', 116: 'cul-6_ok1614', 117: 'cwn-2_ok895', 118: 'daf-10_e1387', 119: 'daf-11_m47', 120: 'daf-18_e1375', 121: 'dapk-1_gk219', 122: 'dat-1_ok157', 123: 'dbl-1_nk3', 124: 'dbn-1_ok925', 125: 'dep-1_ok1844', 126: 'dgk-1_nu62', 127: 'dgk-2_gk124', 128: 'dgk-3_gk110', 129: 'dgk-4_ok1031', 130: 'dgk-5_gk631', 131: 'dig-1_n1321', 132: 'dlk-1_km12', 133: 'dnj-7_ok1495', 134: 'dop-1_vs100', 135: 'dop-2_vs105', 136: 'dop-2xdop-1xdop-3_vs105xvs100xvs106', 137: 'dop-3_ok295', 138: 'dsh-1_ok1445', 139: 'dsl-1_ok810', 140: 'dsl-4_ok1020', 141: 'dsl-6_ok2265', 142: 'dyc-1_cx32', 143: 'dyf-2_m160', 144: 'dyf-5_mn400', 145: 'dyn-1_ky51', 146: 'dys-1_cx18', 147: 'eak-6_mg329', 148: 'eat-16_ce71', 149: 'eat-16_sa609', 150: 'eat-5_ad464', 151: 'ebp-2_gk756', 152: 'ect-2_ku427', 153: 'efa-6_ok3533', 154: 'efk-1_ok3609', 155: 'egl-10_md176', 156: 'egl-10_n692', 157: 'egl-15_n484', 158: 'egl-19_n582', 159: 'egl-20_n585', 160: 'egl-21_n611', 161: 'egl-30_ad806', 162: 'egl-30_ep271', 163: 'egl-30_js126', 164: 'egl-30_n686', 165: 'egl-30_n715', 166: 'egl-8_n488', 167: 'egl-8_ok934', 168: 'ehs-1_ok146', 169: 'elks-1_ok2762', 170: 'elp-1_gk168', 171: 'elp-1_ok2357', 172: 'emb-30_g53', 173: 'esyt-2_ok2509', 174: 'exc-5_km508', 175: 'fer-1_hc1', 176: 'flp-12_ok2409', 177: 'flp-17_ok3587', 178: 'flp-19_ok2460', 179: 'flp-6_ok3056', 180: 'flp-9_ok2730', 181: 'frm-7_ok2081', 182: 'frm-8_ok1769', 183: 'frpr-10_ok1504', 184: 'frpr-18_ok2698', 185: 'fsn-1_gk429', 186: 'gap-2_tm748', 187: 'gck-2_ok2867', 188: 'gipc-1_hc192', 189: 'gipc-2_ok1172', 190: 'glc-3_ok321', 191: 'glr-2_ok2342', 192: 'goa-1_n1134', 193: 'goa-1_n3055', 194:  ...

# %% [markdown]
# # 5. Process Data Function (Just Run)

# %%
def ProcessData(strain): #<- an example of a user-defined function
    strain_filelist = [x for x in filelist if strain in x] #<- goes through the list and filters for keyword
    Strain_N = len(strain_filelist) #<- N per strain, or number of plates
    Plate_N = 1
    print(f'this strain/treatment has {Strain_N} plates') #<- will output as the first number
    if Strain_N == 0:
        raise AssertionError ('{} is not a good identifier'.format(strain))
    else:
        pass
        print(f'now working on strain {strain}')
        strain_filelist = [file for file in filelist if strain in file]
        df_list=[]
        for file in strain_filelist:
            if file.split('/')[-1].startswith('._'):
                pass
            else:
                print(f"working on file {file}")
                df= pd.read_csv(file, sep=' ', header = None, encoding_errors='ignore')
                df['Plate_id'] = file.split('/')[-1].split('_')[-1].split('.')[0]
                df['Date'] = file.split('/')[-2].split('_')[0]
                df['Screen'] = file.split('/')[-4]
                df_list.append(df)
        DF_Total = pd.concat(df_list, ignore_index = True)
#     for f in strain_filelist:
#         DF_Total = pd.concat(pd.read_csv(f, sep=' ', skiprows = 4, header = None))
        # DF_Total = pd.concat([pd.read_csv(f, sep=' ', header = None, encoding_errors='ignore') for f in strain_filelist],
        #               ignore_index=True) #<- imports your data files
#         DF_Total = DF_Total.dropna(axis = 1) #<- cleans your data
        DF_Total = DF_Total.rename( #<- more cleaning
                    {0:'time',
                    2:'rev_before',
                    3:'no_rev',
                    4:'stim_rev',
                    7:'dist',
                    8:'dist_std',
                    9:'dist_stderr',
                    11:'dist_0th',
                    12:'dist_1st',
                    13:'dist_2nd',
                    14:'dist_3rd',
                    15:'dist_100th',
                    18:'dura',
                    19:'dura_std',
                    20:'dura_stderr',
                    22:'dura_0th',
                    23:'dura_1st',
                    24:'dura_2nd',
                    25:'dura_3rd',
                    26:'dura_100th'}, axis=1)
        #check function here for NaN Columns
        DF_Total['plate'] = 0
        DF_Total['prob'] = DF_Total['stim_rev']/ (DF_Total['no_rev'] + DF_Total['stim_rev']) #<- calculate prob
        DF_Total['speed'] = DF_Total['dist']/DF_Total['dura'] #<- calculate speed
        DF_Total_rows = int(DF_Total.shape[0])
        print(f'this strain/treatment has {DF_Total_rows} total taps') #<- Outputs as the second number. Check if you are missing taps!
        DF_Final = DF_Total[["time", "dura", "dist", "prob", "speed", "plate", "Date","Plate_id","Screen"]].copy()

    return{
            'N': Strain_N,
            'Confirm':DF_Total,
            'Final': DF_Final}
    print('done!')



def assign_taps(DF, tolerances):
    DF['taps'] = ""
    for taps, tolerance in enumerate(tolerances): #[(99, 101), (109,111), ...]
        tap_lower,tap_upper = tolerance
        TimesInTapRange = DF['time'].between(tap_lower,tap_upper, inclusive="both")
        DF.loc[TimesInTapRange,'taps'] = taps+1 #set the tap to i where times are between



    
def insert_plates(df):   
    """This function inserts a plate column into a dataframe.
    
    :param df: any dataframe
    :type: pandas.core.frame.DataFrame
    
    :return: dataframe with a plate column
    :type: pandas.core.frame.DataFrame
    """
    df['plate']=(df['taps'] ==1).cumsum()


            
print('done step 5')
# Out:
# done step 5

# %% [markdown]
# # 6.1 Process Data (PLEASE READ, Add input here)

# %% [markdown]
# Here is the hardest part - From your naming convention, you need to pick a unique identifier for each group.
#
# This means that all of names of your files for that strain should have that in common but is not commone with across all other files! If you did a good job naming your files and following a good naming convention, this should be easy.
#
# ## Be careful and really look hard in your naming structure. Note you want an unique identifier in the entire file path for the same group of files. An easy mistake is to have the strain name in the overall folder name, in this case if you use your strain name as a keyword it would include all files in that folder!
#
# For example, if all your N2 files have a certain pattern like "N2_5x4" in this following example:
# '/Users/Joseph/Desktop/AVR14_10sISI_TapHab_0710_2019/N2/20190710_141740/N2_5x4_f94h20c_100s30x10s10s_C0710ab.trv'
#
# Then you need to set that identifier for the strain keyword:
# 'Strain_1' = 'N2_5x4'
#
# ## Depending on how many strains you are running for comparison, you may need to add/delete some lines!
#
# ## You are not naming your data groups here, we have a step for that later!
# ## Here, you want to note down ALL the strains you have in the folder
#
# If you have just 2 strains, add hashtags (#) in front of the lines you do not need.
# If you need more strains, just add more lines, following the same format!

# %%
# #Format: 'Strain_#'' = 'unique_identifier'

# ### Make into dictionary
# StrainNames = {
#     'Strain_1' : 'N2',  #<- each strain will be designated to a unique identifier here
#     'Strain_2' : 'cat-2_e1112',
#     'Strain_3' : 'cat-2_n4547',
#     'Strain_4' : 'cat-2_tm2261',
#     'Strain_5' : 'dat-1_ok157',
#     'Strain_6' : 'cat-1_ok411',
#     'Strain_7' : 'pdr-1_gk448', #<- empty entries are for those hardcore trackers that tracks this many strains
#     'Strain_8' : 'pdr-1_tm395',
#     'Strain_9' : 'pdr-1_tm598',
#     'Strain_10' : 'dop-1_vs101',
#     'Strain_11' : 'dop-3_ok295',
#     'Strain_12' : 'snb-5_ok1434',
#     'Strain_13' : 'unc-10_ad591',
# #     'Strain_14' : '',
# #     'Strain_15' : '',
# }
# #...etc, etc

# print('done step 6.1')

# %%
print(list(StrainNames.values()))
print(type(list(StrainNames.values())))
print(type(list(StrainNames.values())[0]))

# %% [markdown]
# # 6.2 Process Data (just run this cell)

# %%
# print(ProcessData('F53B2.5_ok226')['Final'])

# %%
# with open('/Volumes/JOSEPH/PD_Screen/F53B2.5_ok226/20220524_141642/ZE1_10x2_f72h20C_600s31x10s10s_B0520ba.trv') as f:
#     print(f)

# %%
# import threading

# %%
DataLists = [0]  #<- generates empty list. 0 is there to account for python's index starting at 0. 
# we want indexing to start at 1 (when I say #1 I want the first point, not the second point)

for s in list(StrainNames.values()): #<- goes through the dictionary in step 6.1 and processes data
    if not s == '':
#         threading.Thread(target=DataLists.append(ProcessData(s)['Final'])).start()
        DataLists.append(ProcessData(s)['Final']) #<- appends all data into a list of dataframes


for df in DataLists[1:]: 
    assign_taps(df, tolerances)
for df in DataLists[1:]:    
    insert_plates(df)

# print(x)
# print(DataLists[0])
# print(DataLists[1])
#print(DataLists[2])
#print(len(DataLists))        
print('done step 6.2')
# Out:
# this strain/treatment has 4 plates
# now working on strain C03A3.3_ok2834
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03A3.3_ok2834/20100516_100357/RB2130_5x4_f89h20C_10m30x10s10s_C0512aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03A3.3_ok2834/20100516_102007/RB2130_5x4_f89h20C_10m30x10s10s_C0512ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03A3.3_ok2834/20100516_103621/RB2130_5x4_f90h20C_10m30x10s10s_C0512ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03A3.3_ok2834/20100516_105157/RB2130_5x4_f90h20C_10m30x10s10s_C0512ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain C03B1.5_ok2345
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03B1.5_ok2345/20100516_090030/RB1811_5x4_f88h20C_10m30x10s10s_D0512aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03B1.5_ok2345/20100516_091627/RB1811_5x4_f88h20C_10m30x10s10s_D0512ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03B1.5_ok2345/20100516_093207/RB1811_5x4_f89h20C_10m30x10s10s_D0512ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C03B1.5_ok2345/20100516_094738/RB1811_5x4_f89h20C_10m30x10s10s_D0512ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain C04B4.2_ok1212
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04B4.2_ok1212/20100422_112007/RB1170_5x4_f89h20C_10m30x10s10s_E0418aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04B4.2_ok1212/20100422_113619/RB1170_5x4_f90h20C_10m30x10s10s_E0418ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04B4.2_ok1212/20100422_115221/RB1170_5x4_f90h20C_10m30x10s10s_E0418ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04B4.2_ok1212/20100422_120803/RB1170_5x4_f90h20C_10m30x10s10s_E0418ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain C04E6.5_ok1497
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04E6.5_ok1497/20100321_154246/VC1000_5x3_f88h20C_10m30x10s10s_B0317aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04E6.5_ok1497/20100321_155849/VC1000_5x3_f88h20C_10m30x10s10s_B0317ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04E6.5_ok1497/20100321_161411/VC1000_5x3_f88h20C_10m30x10s10s_B0317ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C04E6.5_ok1497/20100321_162934/VC1000_5x3_f88h20C_10m30x10s10s_B0317ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain C27B7.7_ok2868
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C27B7.7_ok2868/20100510_193521/VC2141_8x4_f82h20C_10m30x10s10s_B0507aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C27B7.7_ok2868/20100510_195157/VC2141_8x4_f82h20C_10m30x10s10s_B0507ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C27B7.7_ok2868/20100510_200721/VC2141_8x4_f82h20C_10m30x10s10s_B0507ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C27B7.7_ok2868/20100510_202248/VC2141_8x4_f82h20C_10m30x10s10s_B0507ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain C44H4.6_ok1560
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C44H4.6_ok1560/20100423_133715/RB1375_5x4_f91h20C_10m30x10s10s_A0419aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C44H4.6_ok1560/20100423_135423/RB1375_5x4_f91h20C_10m30x10s10s_A0419ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C44H4.6_ok1560/20100423_140954/RB1375_5x4_f91h20C_10m30x10s10s_A0419ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C44H4.6_ok1560/20100423_142523/RB1375_5x4_f91h20C_10m30x10s10s_A0419ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain C49C3.21_ok3180
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C49C3.21_ok3180/20100513_144500/RB2344_5x4_f90h20C_10m30x10s10s_C0509aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C49C3.21_ok3180/20100513_150044/RB2344_5x4_f90h20C_10m30x10s10s_C0509ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C49C3.21_ok3180/20100513_151647/RB2344_5x4_f90h20C_10m30x10s10s_C0509ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/C49C3.21_ok3180/20100513_153301/RB2344_5x4_f90h20C_10m30x10s10s_C0509ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain D1081.4_ok2041
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/D1081.4_ok2041/20100510_231541/RB1652_5x4_f84h20C_10m30x10s10s_A0507aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/D1081.4_ok2041/20100510_233252/RB1652_5x4_f84h20C_10m30x10s10s_A0507ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/D1081.4_ok2041/20100510_234908/RB1652_5x4_f84h20C_10m30x10s10s_A0507ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/D1081.4_ok2041/20100511_000436/RB1652_5x4_f84h20C_10m30x10s10s_A0507ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F07A11.4_ok3152
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F07A11.4_ok3152/20100422_223653/RB2320_5x4_f85h20C_10m30x10s10s_C0419aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F07A11.4_ok3152/20100422_225313/RB2320_5x4_f85h20C_10m30x10s10s_C0419ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F07A11.4_ok3152/20100422_230841/RB2320_5x4_f85h20C_10m30x10s10s_C0419ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F07A11.4_ok3152/20100422_232411/RB2320_5x4_f85h20C_10m30x10s10s_C0419ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F09A5.2_ok1900
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09A5.2_ok1900/20100422_101358/RB1566_5x5_f88h20C_10m30x10s10s_D0418aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09A5.2_ok1900/20100422_102940/RB1566_5x5_f88h20C_10m30x10s10s_D0418ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09A5.2_ok1900/20100422_104540/RB1566_5x5_f89h20C_10m30x10s10s_D0418ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09A5.2_ok1900/20100422_110128/RB1566_5x5_f89h20C_10m30x10s10s_D0418ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F09C12.2_hc185
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09C12.2_hc185/20100320_110358/BA1084_5x5_f89h20C_10m30x10s10s_C0316aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09C12.2_hc185/20100320_111948/BA1084_5x5_f89h20C_10m30x10s10s_C0316ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09C12.2_hc185/20100320_113551/BA1084_5x5_f90h20C_10m30x10s10s_C0316ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F09C12.2_hc185/20100320_115133/BA1084_5x5_f90h20C_10m30x10s10s_C0316ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F11A5.4_ok1857
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11A5.4_ok1857/20100420_204725/RB1544_5x4_f80h20C_10m30x10s10s_D0417aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11A5.4_ok1857/20100420_210423/RB1544_5x4_f80h20C_10m30x10s10s_D0417ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11A5.4_ok1857/20100420_212150/RB1544_5x4_f80h20C_10m30x10s10s_D0417ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11A5.4_ok1857/20100420_214155/RB1544_5x4_f80h20C_10m30x10s10s_D0417ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F11E6.8_ok2754
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11E6.8_ok2754/20100513_134219/RB2088_5x4_f89h20C_10m30x10s10s_E0509aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11E6.8_ok2754/20100513_135745/RB2088_5x4_f89h20C_10m30x10s10s_E0509ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11E6.8_ok2754/20100513_141312/RB2088_5x4_f89h20C_10m30x10s10s_E0509ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F11E6.8_ok2754/20100513_142854/RB2088_5x4_f89h20C_10m30x10s10s_E0509ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F16B12.5_gk1009
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F16B12.5_gk1009/20100419_232718/VC2154_5x4_f86h20C_10m30x10s10s_B0416aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F16B12.5_gk1009/20100419_234432/VC2154_5x4_f86h20C_10m30x10s10s_B0416ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F16B12.5_gk1009/20100420_000001/VC2154_5x4_f87h20C_10m30x10s10s_B0416ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F16B12.5_gk1009/20100420_001530/VC2154_5x4_f87h20C_10m30x10s10s_B0416ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F31E3.2_ok2044
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F31E3.2_ok2044/20100420_114058/RB1654_7x4_f91h20C_10m30x10s10s_C0416aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F31E3.2_ok2044/20100420_115725/RB1654_7x4_f91h20C_10m30x10s10s_C0416ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F31E3.2_ok2044/20100420_121301/RB1654_7x4_f91h20C_10m30x10s10s_C0416ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F31E3.2_ok2044/20100420_122829/RB1654_7x4_f91h20C_10m30x10s10s_C0416ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F38B6.6_ok3009
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F38B6.6_ok3009/20100513_103715/RB2224_5x4_f88h20C_10m30x10s10s_A0509aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F38B6.6_ok3009/20100513_105452/RB2224_5x4_f88h20C_10m30x10s10s_A0509ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F38B6.6_ok3009/20100513_111029/RB2224_5x4_f88h20C_10m30x10s10s_A0509ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F38B6.6_ok3009/20100513_112556/RB2224_5x4_f88h20C_10m30x10s10s_A0509ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F39E9.6_ok3515
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F39E9.6_ok3515/20100516_100236/RB2534_9x4_f89h20C_10m30x10s10s_B0512aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F39E9.6_ok3515/20100516_101907/RB2534_9x4_f89h20C_10m30x10s10s_B0512ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F39E9.6_ok3515/20100516_103518/RB2534_9x4_f90h20C_10m30x10s10s_B0512ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F39E9.6_ok3515/20100516_105058/RB2534_9x4_f90h20C_10m30x10s10s_B0512ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F43B10.1_ok1441
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F43B10.1_ok1441/20100424_150207/RB1323_5x3_f92h20C_10m30x10s10s_D0420aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F43B10.1_ok1441/20100424_151755/RB1323_5x3_f92h20C_10m30x10s10s_D0420ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F43B10.1_ok1441/20100424_153410/RB1323_5x3_f92h20C_10m30x10s10s_D0420ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F43B10.1_ok1441/20100424_155007/RB1323_5x3_f92h20C_10m30x10s10s_D0420ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F47G4.4_ok2219
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F47G4.4_ok2219/20100515_105829/RB1734_5x4_f88h20C_10m30x10s10s_E0511aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F47G4.4_ok2219/20100515_111512/RB1734_5x4_f88h20C_10m30x10s10s_E0511ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F47G4.4_ok2219/20100515_113041/RB1734_5x4_f88h20C_10m30x10s10s_E0511ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F47G4.4_ok2219/20100515_114604/RB1734_5x4_f88h20C_10m30x10s10s_E0511ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F49C5.4_ok3082
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F49C5.4_ok3082/20100422_223606/RB2272_8x4_f85h20C_10m30x10s10s_B0419aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F49C5.4_ok3082/20100422_225247/RB2272_8x4_f85h20C_10m30x10s10s_B0419ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F49C5.4_ok3082/20100422_230817/RB2272_8x4_f85h20C_10m30x10s10s_B0419ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F49C5.4_ok3082/20100422_232350/RB2272_8x4_f85h20C_10m30x10s10s_B0419ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F52B5.2_ok2069
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F52B5.2_ok2069/20100420_103528/VC1620_7x4_f90h20C_10m30x10s10s_D0416aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F52B5.2_ok2069/20100420_105122/VC1620_7x4_f90h20C_10m30x10s10s_D0416ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F52B5.2_ok2069/20100420_110657/VC1620_7x4_f90h20C_10m30x10s10s_D0416ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F52B5.2_ok2069/20100420_112232/VC1620_7x4_f90h20C_10m30x10s10s_D0416ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F55D12.5_ok2543
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F55D12.5_ok2543/20100512_213844/RB1940_5x4_f79h20C_10m30x10s10s_D0509aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F55D12.5_ok2543/20100512_215429/RB1940_5x4_f79h20C_10m30x10s10s_D0509ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F55D12.5_ok2543/20100512_220957/RB1940_5x4_f79h20C_10m30x10s10s_D0509ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F55D12.5_ok2543/20100512_222523/RB1940_5x4_f79h20C_10m30x10s10s_D0509ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F59A6.5_ok2885
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59A6.5_ok2885/20100427_103124/VC2205_5x4_f86h20C_10m30x10s10s_C0423aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59A6.5_ok2885/20100427_104708/VC2205_5x4_f86h20C_10m30x10s10s_C0423ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59A6.5_ok2885/20100427_110244/VC2205_5x4_f87h20C_10m30x10s10s_C0423ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59A6.5_ok2885/20100427_111819/VC2205_5x4_f87h20C_10m30x10s10s_C0423ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain F59E12.3_ok3507
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59E12.3_ok3507/20100515_210013/RB2531_5x4_f83h20C_10m30x10s10s_E0512aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59E12.3_ok3507/20100515_211625/RB2531_5x4_f83h20C_10m30x10s10s_E0512ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59E12.3_ok3507/20100515_213152/RB2531_5x4_f83h20C_10m30x10s10s_E0512ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/F59E12.3_ok3507/20100515_214720/RB2531_5x4_f83h20C_10m30x10s10s_E0512ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 3 plates
# now working on strain K02E10.1_ok1871
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/K02E10.1_ok1871/20100424_132003/RB1553_5x4_f90h20C_10m30x10s10s_B0420aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/K02E10.1_ok1871/20100424_133632/RB1553_5x4_f90h20C_10m30x10s10s_B0420ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/K02E10.1_ok1871/20100424_143559/RB1553_5x4_f91h20C_10m30x10s10s_B0420ad.trv
# this strain/treatment has 90 total taps
# this strain/treatment has 4 plates
# now working on strain M195.2_ok1503
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/M195.2_ok1503/20100321_103700/RB1348_7x4_f89h20C_10m30x10s10s_E0317aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/M195.2_ok1503/20100321_105226/RB1348_7x4_f89h20C_10m30x10s10s_E0317ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/M195.2_ok1503/20100321_110750/RB1348_7x4_f89h20C_10m30x10s10s_E0317ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/M195.2_ok1503/20100321_112317/RB1348_7x4_f89h20C_10m30x10s10s_E0317ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 426 plates
# now working on strain N2_N2
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_094114/N2_f89h20C_10m30x10s10s_A0306aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_094136/N2_f89h20C_10m30x10s10s_B0306ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_095703/N2_f89h20C_10m30x10s10s_A0306ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_095714/N2_f89h20C_10m30x10s10s_B0306bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_101440/N2_f90h20C_10m30x10s10s_A0306ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_101451/N2_f90h20C_10m30x10s10s_B0306bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_103009/N2_f90h20C_10m30x10s10s_A0306ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_103019/N2_f90h20C_10m30x10s10s_B0306bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_104818/N2_f90h20C_10m30x10s10s_C0306ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_110416/N2_f91h20C_10m30x10s10s_C0306cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_111944/N2_f91h20C_10m30x10s10s_C0306cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_113612/N2_f91h20C_10m30x10s10s_C0306cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_115318/N2_f91h20C_10m30x10s10s_D0306da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_115407/N2_f91h20C_10m30x10s10s_E0306ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_120848/N2_f92h20C_10m30x10s10s_D0306db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_120934/N2_f92h20C_10m30x10s10s_E0306eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_122445/N2_f92h20C_10m30x10s10s_D0306dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_122523/N2_f92h20C_10m30x10s10s_E0306ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_124012/N2_f92h20C_10m30x10s10s_D0306dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_124048/N2_f92h20C_10m30x10s10s_E0306ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_205533/N2_f77h20C_10m30x10s10s_A0307aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_211120/N2_f78h20C_10m30x10s10s_A0307ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_212648/N2_f78h20C_10m30x10s10s_A0307ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_214213/N2_f78h20C_10m30x10s10s_A0307ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_220113/N2_f78h20C_10m30x10s10s_E0307ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_221644/N2_f79h20C_10m30x10s10s_E0307bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_223211/N2_f79h20C_10m30x10s10s_E0307bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_224740/N2_f79h20C_10m30x10s10s_E0307bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_230214/N2_f80h20C_10m30x10s10s_B0307ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_230310/N2_f80h20C_10m30x10s10s_C0307da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_230347/N2_f80h20C_10m30x10s10s_D0307ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_232105/N2_f80h20C_10m30x10s10s_B0307cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_232144/N2_f80h20C_10m30x10s10s_C0307db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_232159/N2_f80h20C_10m30x10s10s_D0307eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_233720/N2_f80h20C_10m30x10s10s_C0307dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_233738/N2_f80h20C_10m30x10s10s_D0307ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_235321/N2_f80h20C_10m30x10s10s_B0307cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_235359/N2_f80h20C_10m30x10s10s_C0307dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100310_235415/N2_f80h20C_10m30x10s10s_D0307ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_102951/N2_4x4_f88h20C_10m30x10s10s_B0309da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_103109/N2_4x4_f88h20C_10m30x10s10s_C0309ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_104647/N2_4x4_f88h20C_10m30x10s10s_B0309db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_104650/N2_4x4_f88h20C_10m30x10s10s_A0309cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_104732/N2_4x4_f88h20C_10m30x10s10s_C0309eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_110236/N2_4x4_f89h20C_10m30x10s10s_B0309dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_110239/N2_4x4_f89h20C_10m30x10s10s_A0309cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_110322/N2_4x4_f89h20C_10m30x10s10s_C0309ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_112237/N2_4x4_f89h20C_10m30x10s10s_B0309dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120423_100810/N2_5x4_f90h20C_600s30x10s10s_A0423aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120423_100948/N2_5x4_f90h20C_600s30x10s10s_A0423ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120423_101203/N2_5x4_f90h20C_600s30x10s10s_A0423ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120423_102705/N2_5x4_f90h20C_600s30x10s10s_A0423ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120423_102853/N2_5x4_f90h20C_600s30x10s10s_A0423ae.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120423_103113/N2_5x4_f90h20C_600s30x10s10s_A0423af.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120710_150042/N2_5x4_f90h20C_600s30x10s10s_A0710aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120710_152435/N2_5x4_f90h20C_600s30x10s10s_A0710ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120710_154048/N2_5x4_f90h20C_600s30x10s10s_A0710ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120710_155055/N2_5x4_f90h20C_600s30x10s10s_A0710ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120710_160650/N2_5x4_f90h20C_600s30x10s10s_A0710ae.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120710_162718/N2_5x4_f90h20C_600s30x10s10s_A0710af.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120612_102650/N2_5x4_f90h20C_600s30x10s10s_A0608aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120612_103344/N2_5x4_f90h20C_600s30x10s10s_A0608ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120612_105158/N2_5x4_f90h20C_600s30x10s10s_A0608ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120612_105839/N2_5x4_f90h20C_600s30x10s10s_A0608ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120612_111522/N2_5x4_f90h20C_600s30x10s10s_A0608ae.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120612_112218/N2_5x4_f90h20C_600s30x10s10s_A0608af.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120626_072235/N2_5x4_f90h20C_600s30x10s10s_A0626aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120626_073118/N2_5x4_f90h20C_600s30x10s10s_A0626ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120626_073845/N2_5x4_f90h20C_600s30x10s10s_A0626ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20120626_074722/N2_5x4_f90h20C_600s30x10s10s_A0626ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_201740/N2_5x3_f83h20C_10m30x10s10s_D0309aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_201837/N2_5x3_f83h20C_10m30x10s10s_E0309ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_203321/N2_5x3_f83h20C_10m30x10s10s_D0309ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_203402/N2_5x3_f83h20C_10m30x10s10s_E0309bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_204911/N2_5x3_f83h20C_10m30x10s10s_D0309ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_204946/N2_5x3_f83h20C_10m30x10s10s_E0309bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_210610/N2_5x3_f84h20C_10m30x10s10s_D0309ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100312_210653/N2_5x3_f84h20C_10m30x10s10s_E0309bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_194826/N2_5x4_f82h20C_10m30x10s10s_B0310ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_194839/N2_5x4_f82h20C_10m30x10s10s_A0310aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_200425/N2_5x4_f82h20C_10m30x10s10s_B0310bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_202029/N2_5x4_f82h20C_10m30x10s10s_B0310bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_202032/N2_5x4_f82h20C_10m30x10s10s_A0310ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_203603/N2_5x4_f83h20C_10m30x10s10s_B0310bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_203604/N2_5x4_f83h20C_10m30x10s10s_A0310ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_205425/N2_5x4_f83h20C_10m30x10s10s_D0310ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_205523/N2_5x4_f83h20C_10m30x10s10s_E0310da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_210957/N2_5x4_f83h20C_10m30x10s10s_D0310cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_211049/N2_5x4_f83h20C_10m30x10s10s_E0310db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_212541/N2_5x4_f83h20C_10m30x10s10s_D0310cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_212621/N2_5x4_f83h20C_10m30x10s10s_E0310dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_214126/N2_5x4_f84h20C_10m30x10s10s_D0310cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_214207/N2_5x4_f84h20C_10m30x10s10s_E0310dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_223012/N2_5x4_f85h20C_10m30x10s10s_B0310ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_224717/N2_5x4_f85h20C_10m30x10s10s_B0310eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_230322/N2_5x4_f85h20C_10m30x10s10s_B0310ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100313_231921/N2_5x4_f85h20C_10m30x10s10s_B0310ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_104451/N2_5x4_f90h20C_10m30x10s10s_E0310fa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_110249/N2_5x4_f90h20C_10m30x10s10s_E0310fb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_111818/N2_5x4_f90h20C_10m30x10s10s_E0310fc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_112001/N2_5x4_f91h20C_10m30x10s10s_D0310ga.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_113745/N2_5x4_f92h20C_10m30x10s10s_D0310gb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_115354/N2_5x4_f92h20C_10m30x10s10s_D0310gc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_121741/N2_5x4_f91h20C_10m30x10s10s_B0310ha.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_122649/N2_5x4_f92h20C_10m30x10s10s_A0310ia.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_122817/N2_5x4_f92h20C_10m30x10s10s_D0310ka.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_123641/N2_5x4_f92h20C_10m30x10s10s_B0310hb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_124548/N2_5x4_f93h20C_10m30x10s10s_A0310ib.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_124649/N2_5x4_f93h20C_10m30x10s10s_D0310kb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_125255/N2_5x4_f92h20C_10m30x10s10s_B0310hc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_130238/N2_5x4_f93h20C_10m30x10s10s_A0310ic.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_130328/N2_5x4_f93h20C_10m30x10s10s_D0310kc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_130831/N2_5x4_f92h20C_10m30x10s10s_B0310hd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_131812/N2_5x4_f93h20C_10m30x10s10s_A0310id.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_131903/N2_5x4_f93h20C_10m30x10s10s_D0310kd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_132652/N2_5x4_f92h20C_10m30x10s10s_B0310ja.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_132908/N2_5x4_f92h20C_10m30x10s10s_E0310la.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_134730/N2_5x4_f93h20C_10m30x10s10s_E0310lb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_140231/N2_5x4_f93h20C_10m30x10s10s_B0310jc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_140407/N2_5x4_f93h20C_10m30x10s10s_E0310lc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_141805/N2_5x4_f93h20C_10m30x10s10s_B0310jd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100314_141942/N2_5x4_f93h20C_10m30x10s10s_E0310ld.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_110253/N2_5x4_f89h20C_10m30x10s10s_B0314da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_110535/N2_5x4_f89h20C_10m30x10s10s_E0314ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_111840/N2_5x4_f89h20C_10m30x10s10s_B0314db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_112059/N2_5x4_f89h20C_10m30x10s10s_E0314eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_113428/N2_5x4_f90h20C_10m30x10s10s_B0314dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_113636/N2_5x4_f90h20C_10m30x10s10s_E0314ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_114955/N2_5x4_f90h20C_10m30x10s10s_B0314dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_115158/N2_5x4_f90h20C_10m30x10s10s_E0314ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_172611/N2_5x3_f79h20C_10m30x10s10s_A0315aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_174136/N2_5x3_f80h20C_10m30x10s10s_A0315ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_175730/N2_5x3_f80h20C_10m30x10s10s_A0315ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_181254/N2_5x3_f80h20C_10m30x10s10s_A0315ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_213746/N2_5x4_f84h20C_10m30x10s10s_E0315ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_215615/N2_5x4_f84h20C_10m30x10s10s_E0315bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_221217/N2_5x4_f84h20C_10m30x10s10s_E0315bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100318_222754/N2_5x4_f84h20C_10m30x10s10s_E0315bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_110334/N2_5x5_f89h20C_10m30x10s10s_A0316aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_110442/N2_5x5_f89h20C_10m30x10s10s_E0316ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_111912/N2_5x5_f89h20C_10m30x10s10s_A0316ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_112043/N2_5x5_f89h20C_10m30x10s10s_E0316bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_113444/N2_5x5_f90h20C_10m30x10s10s_A0316ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_113655/N2_5x5_f90h20C_10m30x10s10s_E0316bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_115013/N2_5x5_f90h20C_10m30x10s10s_A0316ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_115231/N2_5x5_f90h20C_10m30x10s10s_E0316bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_120729/N2_5x5_f90h20C_10m30x10s10s_C0316ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_122414/N2_5x5_f90h20C_10m30x10s10s_C0316cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_123939/N2_5x5_f91h20C_10m30x10s10s_C0316cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_125517/N2_5x5_f91h20C_10m30x10s10s_C0316cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_131031/N2_5x5_f91h20C_10m30x10s10s_B0316da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_131203/N2_5x5_f91h20C_10m30x10s10s_D0316ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_132555/N2_5x5_f91h20C_10m30x10s10s_B0316db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_132732/N2_5x5_f91h20C_10m30x10s10s_D0316eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_134127/N2_5x5_f92h20C_10m30x10s10s_B0316dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_134306/N2_5x5_f92h20C_10m30x10s10s_D0316ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_135719/N2_5x5_f92h20C_10m30x10s10s_B0316dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100320_135835/N2_5x5_f92h20C_10m30x10s10s_D0316ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_100120/N2_5x4_f88h20C_10m30x10s10s_E0312aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_101714/N2_5x4_f88h20C_10m30x10s10s_E0312ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_103252/N2_5x4_f89h20C_10m30x10s10s_E0312ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_104814/N2_5x4_f89h20C_10m30x10s10s_E0312ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_110358/N2_5x4_f89h20C_10m30x10s10s_C0312ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_111927/N2_5x4_f89h20C_10m30x10s10s_C0312bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_113503/N2_5x4_f90h20C_10m30x10s10s_C0312bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100316_115040/N2_5x4_f90h20C_10m30x10s10s_C0312bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_093057/N2_5x4_f89h20C_10m30x10s10s_A0319aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_093117/N2_5x4_f89h20C_10m30x10s10s_C0319ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_093205/N2_5x4_f89h20C_10m30x10s10s_E0319ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_094631/N2_5x4_f89h20C_10m30x10s10s_A0319ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_094707/N2_5x4_f89h20C_10m30x10s10s_C0319cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_094804/N2_5x4_f89h20C_10m30x10s10s_E0319eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_100159/N2_5x4_f89h20C_10m30x10s10s_A0319ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_100334/N2_5x4_f89h20C_10m30x10s10s_E0319ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_100432/N2_5x4_f89h20C_10m30x10s10s_C0319cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_101919/N2_5x4_f89h20C_10m30x10s10s_A0319ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_101956/N2_5x4_f89h20C_10m30x10s10s_C0319cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100323_102051/N2_5x4_f89h20C_10m30x10s10s_E0319ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_100044/N2_5x4_f89h20C_10m30x10s10s_D0315ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_101658/N2_5x4_f89h20C_10m30x10s10s_D0315cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_103253/N2_5x4_f90h20C_10m30x10s10s_D0315cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_104827/N2_5x4_f90h20C_10m30x10s10s_D0315cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_110458/N2_5x4_f90h20C_10m30x10s10s_C0315da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_112119/N2_5x4_f90h20C_10m30x10s10s_C0315db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_113724/N2_5x4_f91h20C_10m30x10s10s_C0315dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_115302/N2_5x4_f91h20C_10m30x10s10s_C0315dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_122701/N2_5x4_f91h20C_10m30x10s10s_B0315eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_133208/N2_5x4_f93h20C_10m30x10s10s_B0315ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100319_134825/N2_5x4_f93h20C_10m30x10s10s_B0315ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_200258/N2_5x4_f83h20C_10m30x10s10s_B0321ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_200306/N2_5x4_f83h20C_10m30x10s10s_A0321aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_200415/N2_5x4_f83h20C_10m30x10s10s_C0321ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_200432/N2_5x4_f83h20C_10m30x10s10s_D0321da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_200536/N2_5x4_f83h20C_10m30x10s10s_E0321ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_201855/N2_5x4_f83h20C_10m30x10s10s_B0321bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_201919/N2_5x4_f83h20C_10m30x10s10s_A0321ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_201953/N2_5x4_f83h20C_10m30x10s10s_C0321cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_202002/N2_5x4_f83h20C_10m30x10s10s_D0321db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_202058/N2_5x4_f83h20C_10m30x10s10s_E0321eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_203430/N2_5x4_f83h20C_10m30x10s10s_B0321bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_203454/N2_5x4_f83h20C_10m30x10s10s_A0321ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_203527/N2_5x4_f83h20C_10m30x10s10s_C0321cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_203533/N2_5x4_f83h20C_10m30x10s10s_D0321dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_203622/N2_5x4_f83h20C_10m30x10s10s_E0321ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_204955/N2_5x4_f83h20C_10m30x10s10s_B0321bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_205019/N2_5x4_f83h20C_10m30x10s10s_A0321ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_205052/N2_5x4_f83h20C_10m30x10s10s_C0321cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_205059/N2_5x4_f83h20C_10m30x10s10s_D0321dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_205149/N2_5x4_f83h20C_10m30x10s10s_E0321ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_093116/N2_5x4_f88h20C_10m30x10s10s_D0317aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_093157/N2_5x4_f88h20C_10m30x10s10s_E0317ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_094742/N2_5x4_f88h20C_10m30x10s10s_D0317ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_094829/N2_5x4_f88h20C_10m30x10s10s_E0317bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_100312/N2_5x4_f88h20C_10m30x10s10s_D0317ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_100357/N2_5x4_f88h20C_10m30x10s10s_E0317bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_101844/N2_5x4_f88h20C_10m30x10s10s_D0317ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_101931/N2_5x4_f88h20C_10m30x10s10s_E0317bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_103516/N2_5x4_f89h20C_10m30x10s10s_C0317ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_105040/N2_5x4_f89h20C_10m30x10s10s_C0317cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_110610/N2_5x4_f89h20C_10m30x10s10s_C0317cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_112153/N2_5x4_f89h20C_10m30x10s10s_C0317cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_113654/N2_5x4_f90h20C_10m30x10s10s_B0317ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_113655/N2_5x4_f90h20C_10m30x10s10s_A0317da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_115353/N2_5x4_f90h20C_10m30x10s10s_B0317eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_115409/N2_5x4_f90h20C_10m30x10s10s_A0317db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_120927/N2_5x4_f90h20C_10m30x10s10s_B0317ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_120945/N2_5x4_f90h20C_10m30x10s10s_A0317dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_122501/N2_5x4_f90h20C_10m30x10s10s_B0317ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_122517/N2_5x4_f90h20C_10m30x10s10s_A0317dd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_133627/N2_5x4_f86h20C_10m30x10s10s_C0317fa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_135208/N2_5x4_f86h20C_10m30x10s10s_C0317fb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_140747/N2_5x4_f86h20C_10m30x10s10s_C0317fc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_142308/N2_5x4_f86h20C_10m30x10s10s_C0317fd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_143850/N2_5x4_f87h20C_10m30x10s10s_B0317ga.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_144024/N2_5x4_f87h20C_10m30x10s10s_D0317ha.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_145543/N2_5x4_f87h20C_10m30x10s10s_B0317gb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_145642/N2_5x4_f87h20C_10m30x10s10s_D0317hb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_151117/N2_5x4_f87h20C_10m30x10s10s_B0317gc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_151210/N2_5x4_f87h20C_10m30x10s10s_D0317hc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_152647/N2_5x4_f87h20C_10m30x10s10s_B0317gd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_152743/N2_5x4_f87h20C_10m30x10s10s_D0317hd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_154242/N2_5x3_f88h20C_10m30x10s10s_A0317ia.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_154529/N2_5x3_f88h20C_10m30x10s10s_E0317ja.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_155906/N2_5x3_f88h20C_10m30x10s10s_A0317ib.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_160050/N2_5x3_f88h20C_10m30x10s10s_E0317jb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_161429/N2_5x3_f88h20C_10m30x10s10s_A0317ic.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_161613/N2_5x3_f88h20C_10m30x10s10s_E0317jc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_162949/N2_5x3_f88h20C_10m30x10s10s_A0317id.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100321_163136/N2_5x3_f88h20C_10m30x10s10s_E0317jd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_121726/N2_5x4_f91h20C_10m30x10s10s_B0318ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_121735/N2_5x4_f91h20C_10m30x10s10s_A0318aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_121834/N2_5x4_f91h20C_10m30x10s10s_C0318ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_121859/N2_5x4_f91h20C_10m30x10s10s_D0318da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_122004/N2_5x4_f91h20C_10m30x10s10s_E0318ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_123257/N2_5x4_f91h20C_10m30x10s10s_B0318bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_123303/N2_5x4_f91h20C_10m30x10s10s_A0318ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_123359/N2_5x4_f91h20C_10m30x10s10s_C0318cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_123425/N2_5x4_f91h20C_10m30x10s10s_D0318db.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_123529/N2_5x4_f91h20C_10m30x10s10s_E0318eb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_124854/N2_5x4_f91h20C_10m30x10s10s_B0318bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_124911/N2_5x4_f91h20C_10m30x10s10s_A0318ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_124945/N2_5x4_f91h20C_10m30x10s10s_C0318cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_124953/N2_5x4_f91h20C_10m30x10s10s_D0318dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_125053/N2_5x4_f91h20C_10m30x10s10s_E0318ec.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_130448/N2_5x4_f92h20C_10m30x10s10s_B0318bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_130507/N2_5x4_f92h20C_10m30x10s10s_A0318ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_130540/N2_5x4_f92h20C_10m30x10s10s_C0318cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_130636/N2_5x4_f92h20C_10m30x10s10s_E0318ed.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_173839/N2_5x3_f90h20C_10m30x10s10s_C0318fa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_175455/N2_5x3_f90h20C_10m30x10s10s_C0318fb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_181026/N2_5x3_f90h20C_10m30x10s10s_C0318fc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100322_182551/N2_5x3_f90h20C_10m30x10s10s_C0318fd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_103335/N2_5x4_f90h20C_10m30x10s10s_B0320ba.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_103337/N2_5x4_f90h20C_10m30x10s10s_A0320aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_103451/N2_5x4_f90h20C_10m30x10s10s_C0320ca.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_103520/N2_5x4_f90h20C_10m30x10s10s_D0320da.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_103637/N2_5x4_f90h20C_10m30x10s10s_E0320ea.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_104955/N2_5x4_f90h20C_10m30x10s10s_B0320bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_105018/N2_5x4_f90h20C_10m30x10s10s_A0320ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/N2_N2/20100324_105050/N2_5x4_f90h20C_10m30x10s10s_C0320cb.trv
# ...
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unc-29_e193
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-29_e193/20100319_110348/CB193_8x4_f90h20C_10m30x10s10s_B0315aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-29_e193/20100319_112028/CB193_8x4_f90h20C_10m30x10s10s_B0315ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-29_e193/20100319_113628/CB193_8x4_f91h20C_10m30x10s10s_B0315ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-29_e193/20100319_115210/CB193_8x4_f91h20C_10m30x10s10s_B0315ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unc-36_e251
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-36_e251/20100319_100122/CB251_10x4_f89h20C_10m30x10s10s_E0315aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-36_e251/20100319_101750/CB251_10x4_f89h20C_10m30x10s10s_E0315ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-36_e251/20100319_103345/CB251_10x4_f90h20C_10m30x10s10s_E0315ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-36_e251/20100319_104915/CB251_10x4_f90h20C_10m30x10s10s_E0315ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unc-40_e271
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-40_e271/20100320_120915/CB271_10x5_f90h20C_10m30x10s10s_E0316aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-40_e271/20100320_122447/CB271_10x5_f90h20C_10m30x10s10s_E0316ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-40_e271/20100320_124044/CB271_10x5_f91h20C_10m30x10s10s_E0316ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-40_e271/20100320_125627/CB271_10x5_f91h20C_10m30x10s10s_E0316ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unc-41_e268
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-41_e268 /20100320_131143/CB268_8x5_f91h20C_10m30x10s10s_C0316aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-41_e268 /20100320_132711/CB268_8x5_f91h20C_10m30x10s10s_C0316ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-41_e268 /20100320_134243/CB268_8x5_f92h20C_10m30x10s10s_C0316ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-41_e268 /20100320_135807/CB268_8x5_f92h20C_10m30x10s10s_C0316ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unc-5_e152
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-5_e152/20100314_094330/CB152_10x4_f90h20C_10m30x10s10s_A0310aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-5_e152/20100314_100123/CB152_10x4_f90h20C_10m30x10s10s_A0310ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-5_e152/20100314_101657/CB152_10x4_f90h20C_10m30x10s10s_A0310ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-5_e152/20100314_110026/CB152_10x4_f91h20C_10m30x10s10s_A0310ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unc-64_e246
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-64_e246/20100927_223302/CB246_5x3_f78h20C_100s30x10s10s_A0924ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-64_e246/20100927_224020/CB246_5x3_f78h20C_100s30x10s10s_A0924ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-64_e246/20100927_224739/CB246_5x3_f78h20C_100s30x10s10s_A0924ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-64_e246/20100927_225501/CB246_5x3_f78h20C_100s30x10s10s_A0924aa.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 2 plates
# now working on strain unc-82_e1220
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-82_e1220/20101108_210743/CB1220_5x3_f77h20C_100s30x10s10s_A1105dc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-82_e1220/20101108_212729/CB1220_5x3_f77h20C_100s30x10s10s_A1105da.trv
# this strain/treatment has 60 total taps
# this strain/treatment has 4 plates
# now working on strain unc-89_e1460
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-89_e1460/20100318_120829/CB1460_14x4_f90h20C_10m30x10s10s_E0314aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-89_e1460/20100318_122401/CB1460_14x4_f90h20C_10m30x10s10s_E0314ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-89_e1460/20100318_124038/CB1460_14x4_f91h20C_10m30x10s10s_E0314ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unc-89_e1460/20100318_134426/CB1460_14x4_f92h20C_10m30x10s10s_E0314ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unknown_KG6
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_KG6/20100416_090349/KG6_7x4_f86h20C_10m30x10s10s_A0412aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_KG6/20100416_091922/KG6_7x4_f86h20C_10m30x10s10s_A0412ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_KG6/20100416_093458/KG6_7x4_f87h20C_10m30x10s10s_A0412ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_KG6/20100416_095059/KG6_7x4_f87h20C_10m30x10s10s_A0412ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain unknown_RB2261
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_RB2261/20100324_113923/RB2261_7x3_f91h20C_10m30x10s10s_E0320aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_RB2261/20100324_115448/RB2261_7x3_f91h20C_10m30x10s10s_E0320ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_RB2261/20100324_121024/RB2261_7x3_f91h20C_10m30x10s10s_E0320ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/unknown_RB2261/20100324_122607/RB2261_7x3_f91h20C_10m30x10s10s_E0320ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain vab-1_e2
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_121128/CB2_8x4_f91h20C_10m30x10s10s_D0315aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_122801/CB2_8x4_f91h20C_10m30x10s10s_D0315ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_133316/CB2_8x4_f93h20C_10m30x10s10s_D0315ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vab-1_e2/20100319_134929/CB2_8x4_f93h20C_10m30x10s10s_D0315ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain vap-1_ok392
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vap-1_ok392/20100420_204944/VC230_5x4_f80h20C_10m30x10s10s_E0417aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vap-1_ok392/20100420_210618/VC230_5x4_f80h20C_10m30x10s10s_E0417ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vap-1_ok392/20100420_212347/VC230_5x4_f80h20C_10m30x10s10s_E0417ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vap-1_ok392/20100420_214349/VC230_5x4_f80h20C_10m30x10s10s_E0417ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain ver-1_ok1738
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-1_ok1738/20100511_150008/VC1263_5x3_f92h20C_10m30x10s10s_A0507aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-1_ok1738/20100511_151700/VC1263_5x3_f92h20C_10m30x10s10s_A0507ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-1_ok1738/20100511_153231/VC1263_5x3_f92h20C_10m30x10s10s_A0507ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-1_ok1738/20100511_154828/VC1263_5x3_f92h20C_10m30x10s10s_A0507ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain ver-4_ok1079
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-4_ok1079/20100420_003527/RB1100_5x3_f87h20C_10m30x10s10s_E0416aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-4_ok1079/20100420_005135/RB1100_5x3_f87h20C_10m30x10s10s_E0416ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-4_ok1079/20100420_010748/RB1100_5x3_f88h20C_10m30x10s10s_E0416ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/ver-4_ok1079/20100420_012526/RB1100_5x3_f88h20C_10m30x10s10s_E0416ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain vit-4_ok2982
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vit-4_ok2982/20100510_221209/RB2202_5x4_f83h20C_10m30x10s10s_B0507aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vit-4_ok2982/20100510_222838/RB2202_5x4_f83h20C_10m30x10s10s_B0507ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vit-4_ok2982/20100510_224407/RB2202_5x4_f83h20C_10m30x10s10s_B0507ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vit-4_ok2982/20100510_225934/RB2202_5x4_f83h20C_10m30x10s10s_B0507ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain vps-20_ok2425
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vps-20_ok2425/20100510_193647/RB1875_5x4_f82h20C_10m30x10s10s_C0507aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vps-20_ok2425/20100510_195253/RB1875_5x4_f82h20C_10m30x10s10s_C0507ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vps-20_ok2425/20100510_200818/RB1875_5x4_f82h20C_10m30x10s10s_C0507ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/vps-20_ok2425/20100510_202344/RB1875_5x4_f82h20C_10m30x10s10s_C0507ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 8 plates
# now working on strain wdfy-2_ok3592
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100427_103056/RB2580_5x4_f86h20C_10m30x10s10s_A0423aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100427_104629/RB2580_5x4_f86h20C_10m30x10s10s_A0423ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100427_110200/RB2580_5x4_f87h20C_10m30x10s10s_A0423ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100427_111741/RB2580_5x4_f87h20C_10m30x10s10s_A0423ad.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100920_212720/RB2580_5x3_f78h20C_100s30x10s10s_A0917bd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100920_213449/RB2580_5x3_f78h20C_100s30x10s10s_A0917bc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100920_214220/RB2580_5x3_f78h20C_100s30x10s10s_A0917bb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdfy-2_ok3592/20100920_214940/RB2580_5x3_f78h20C_100s30x10s10s_A0917ba.trv
# this strain/treatment has 240 total taps
# this strain/treatment has 4 plates
# now working on strain wdr-5.2_ok1444
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdr-5.2_ok1444/20100422_090550/RB1327_5x5_f87h20C_10m30x10s10s_A0418aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdr-5.2_ok1444/20100422_092124/RB1327_5x5_f87h20C_10m30x10s10s_A0418ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdr-5.2_ok1444/20100422_093739/RB1327_5x5_f88h20C_10m30x10s10s_A0418ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wdr-5.2_ok1444/20100422_095455/RB1327_5x5_f88h20C_10m30x10s10s_A0418ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 3 plates
# now working on strain wrk-1_tm1099
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wrk-1_tm1099/20100316_101615/OH4149_12x4_f88h20C_10m30x10s10s_C0312ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wrk-1_tm1099/20100316_103154/OH4149_12x4_f89h20C_10m30x10s10s_C0312ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wrk-1_tm1099/20100316_104715/OH4149_12x4_f89h20C_10m30x10s10s_C0312ad.trv
# this strain/treatment has 90 total taps
# this strain/treatment has 4 plates
# now working on strain wsp-1_gm324
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wsp-1_gm324/20100310_094210/NG324_f89h20C_10m30x10s10s_C0306aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wsp-1_gm324/20100310_095751/NG324_f89h20C_10m30x10s10s_C0306ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wsp-1_gm324/20100310_101529/NG324_f90h20C_10m30x10s10s_C0306ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wsp-1_gm324/20100310_103054/NG324_f90h20C_10m30x10s10s_C0306ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain wwp-1_ok1102
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wwp-1_ok1102/20100508_214817/RB1178_5x5_f84h20C_10m30x10s10s_B0505aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wwp-1_ok1102/20100508_220400/RB1178_5x5_f84h20C_10m30x10s10s_B0505ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wwp-1_ok1102/20100508_221959/RB1178_5x5_f84h20C_10m30x10s10s_B0505ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/wwp-1_ok1102/20100508_223530/RB1178_5x5_f84h20C_10m30x10s10s_B0505ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain xol-1_y9
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/xol-1_y9/20100514_170515/TY1807_5x4_f78h20C_10m30x10s10s_B0511aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/xol-1_y9/20100514_172122/TY1807_5x4_f78h20C_10m30x10s10s_B0511ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/xol-1_y9/20100514_173739/TY1807_5x4_f78h20C_10m30x10s10s_B0511ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/xol-1_y9/20100514_175341/TY1807_5x4_f78h20C_10m30x10s10s_B0511ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain zig-12_ok2994
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-12_ok2994/20100510_221150/RB2212_5x4_f83h20C_10m30x10s10s_A0507aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-12_ok2994/20100510_222834/RB2212_5x4_f83h20C_10m30x10s10s_A0507ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-12_ok2994/20100510_224421/RB2212_5x4_f83h20C_10m30x10s10s_A0507ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-12_ok2994/20100510_225947/RB2212_5x4_f83h20C_10m30x10s10s_A0507ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain zig-3_ok1476
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-3_ok1476/20100428_100036/RB1344_10x4_f89h20C_10m30x10s10s_C0424aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-3_ok1476/20100428_101712/RB1344_10x4_f89h20C_10m30x10s10s_C0424ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-3_ok1476/20100428_103257/RB1344_10x4_f90h20C_10m30x10s10s_C0424ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-3_ok1476/20100428_104834/RB1344_10x4_f90h20C_10m30x10s10s_C0424ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain zig-7_ok2329
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-7_ok2329/20100423_133935/RB1798_5x4_f91h20C_10m30x10s10s_D0419aa.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-7_ok2329/20100423_135539/RB1798_5x4_f91h20C_10m30x10s10s_D0419ab.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-7_ok2329/20100423_141104/RB1798_5x4_f91h20C_10m30x10s10s_D0419ac.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zig-7_ok2329/20100423_142634/RB1798_5x4_f91h20C_10m30x10s10s_D0419ad.trv
# this strain/treatment has 120 total taps
# this strain/treatment has 4 plates
# now working on strain zip-5_gk646
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zip-5_gk646/20101116_010428/VC1392_5x3_f79h20C_100s30x10s10s_A1112cb.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zip-5_gk646/20101116_011137/VC1392_5x3_f79h20C_100s30x10s10s_A1112cc.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zip-5_gk646/20101116_011846/VC1392_5x3_f79h20C_100s30x10s10s_A1112cd.trv
# working on file /Volumes/JOSEPH/Neuron_Genes_Screen/zip-5_gk646/20101116_012550/VC1392_5x3_f79h20C_100s30x10s10s_A1112ca.trv
# this strain/treatment has 120 total taps
# done step 6.2

# %%
# DataLists.append(ProcessData('vps-35_ok1880')['Final'])

# %%
print(DataLists[-1])
# print(StrainNames.get(1))
# Out:
#         time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     99.994  2.83  0.821  0.888889  0.290106      0  20101116  A1112cb
# 1    109.970  2.51  0.665  0.727273  0.264940      0  20101116  A1112cb
# 2    119.979  2.30  0.569  0.923077  0.247391      0  20101116  A1112cb
# 3    129.983  1.50  0.321  0.923077  0.214000      0  20101116  A1112cb
# 4    139.980  2.08  0.484  0.615385  0.232692      0  20101116  A1112cb
# ..       ...   ...    ...       ...       ...    ...       ...      ...
# 115  349.960  0.69  0.173  0.400000  0.250725      0  20101116  A1112ca
# 116  359.997  0.25  0.058  0.666667  0.232000      0  20101116  A1112ca
# 117  369.994  0.79  0.192  0.428571  0.243038      0  20101116  A1112ca
# 118  379.988  1.28  0.266  0.571429  0.207813      0  20101116  A1112ca
# 119  389.964  0.55  0.109  0.666667  0.198182      0  20101116  A1112ca
#
#                   Screen taps
# 0    Neuron_Genes_Screen
# 1    Neuron_Genes_Screen
# 2    Neuron_Genes_Screen
# 3    Neuron_Genes_Screen
# 4    Neuron_Genes_Screen
# ..                   ...  ...
# 115  Neuron_Genes_Screen
# 116  Neuron_Genes_Screen
# 117  Neuron_Genes_Screen
# 118  Neuron_Genes_Screen
# 119  Neuron_Genes_Screen
#
# [120 rows x 10 columns]

# %%
print(len(genotypes))
print(len(np.unique(genotypes)))
print(len(DataLists))

# %% [markdown]
# # 7. Grouping Data and Naming (Optional: Add input here)
#
# Here, you get to name your data groups/strain! Name your groups however you like under between the quotation marks for each strain.
#
# For example: If your Strain1 is N2 and you wish for the group to be called N2,
# your line should look like:
#
# DataLists[x].assign(dataset = 'N2')
#
# ## Go back to step 6.1 to check which strain is which item on the DataLists.
# In this example, the first item on DataLists is N2.
#
#
# ## Remember: Put your name in quotes. (ex: 'N2' and not N2)
#
# As default, the names are set to the unique identifier labels.
#
# ## Depending on the number of strains you are running the comparison, you may have to delete/add lines of code (following the same format).
# ## Remember to add/delete commas too.
#
# # If you want to change your groups, you do that here.
# For example, if you have 5 strains in your folder but only want to compare between 2 or 3 strains, designate that here and follow through with steps 6 and 7. Once you are done, come back to step 6 and change your groups again (You are going to have to change your graph titles for the second run-through though)!

# %%
TotalConcatenated=pd.DataFrame()
for d in range(1,len(np.unique(genotypes))+1):
    # print(d)
    TotalConcatenated=pd.concat([TotalConcatenated,
                                 DataLists[d].assign(dataset=StrainNames.get(d))])



# TotalConcatenated = pd.concat([ #<- this function joins your data together with an extra column for which group 
#                           DataLists[1].assign(dataset = "Wildtype (N2)"), 
#                           DataLists[2].assign(dataset = "cat-2 (e1112)"),
#                           DataLists[3].assign(dataset = "cat-2 (n4547)"),
#                           DataLists[4].assign(dataset = "cat-2 (tm2261)"),
#                           DataLists[5].assign(dataset = "dat-1 (ok157)"),
#                           DataLists[6].assign(dataset = "cat-1 (ok441)"),
#                           DataLists[7].assign(dataset = "pdr-1 (gk448)"),
#                           DataLists[8].assign(dataset = "pdr-1 (tm395)"),
#                           DataLists[9].assign(dataset = "pdr-1 (tm598)"),
#                           DataLists[10].assign(dataset = "dop-1 (vs101)"),
#                           DataLists[11].assign(dataset = "dop-3 (ok295)"),
#                           DataLists[12].assign(dataset = "snb-5 (ok1434)"),
#                           DataLists[13].assign(dataset = "unc-10 (ad591)"),
# #                           DataLists[14].assign(dataset = "GOA1 Mutant (n3055)"),
# #                           DataLists[5].assign(dataset = StrainNames.get("Strain_5")),
# #                         DataLists[5].assign(dataset = "StrainNameOnePoster"), #<----- example of custom name
                          
# ])
# # ...etc etc
TotalConcatenated.reset_index(inplace=False)
print(TotalConcatenated)

#if TotalConcatenated["taps"].loc[ind] is not 1:
#   TotalConcatenated["taps"].loc[ind:indices[c+1]] = list(range(1,len(TotalConcatenated["taps"].loc[ind:indices[c+1]])+1))
# missing_taps(TotalConcatenated, accurate_taps, tolerances)

print('done step 7')
# Out:
#          time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     599.985  2.48  0.708  0.416667  0.285484      1  20190723  C0723gc
# 1     609.977  2.06  0.507  0.218750  0.246117      1  20190723  C0723gc
# 2     619.980  2.49  0.727  0.766667  0.291968      1  20190723  C0723gc
# 3     629.975  2.17  0.661  0.843750  0.304608      1  20190723  C0723gc
# 4     639.982  2.00  0.556  0.558824  0.278000      1  20190723  C0723gc
# ..        ...   ...    ...       ...       ...    ...       ...      ...
# 150   859.990  1.32  0.299  0.142857  0.226515      5  20160526  C0526eb
# 151   869.989  1.20  0.151  0.500000  0.125833      5  20160526  C0526eb
# 152   879.989  1.12  0.153  0.142857  0.136607      5  20160526  C0526eb
# 153   889.989  2.54  0.465  0.428571  0.183071      5  20160526  C0526eb
# 154  1189.984  5.52  0.814  0.333333  0.147464      5  20160526  C0526eb
#
#          Screen taps         dataset
# 0    ASD_Screen    1  C18H9.3_tm4671
# 1    ASD_Screen    2  C18H9.3_tm4671
# 2    ASD_Screen    3  C18H9.3_tm4671
# 3    ASD_Screen    4  C18H9.3_tm4671
# 4    ASD_Screen    5  C18H9.3_tm4671
# ..          ...  ...             ...
# 150  ASD_Screen   27    ztf-6_tm1803
# 151  ASD_Screen   28    ztf-6_tm1803
# 152  ASD_Screen   29    ztf-6_tm1803
# 153  ASD_Screen   30    ztf-6_tm1803
# 154  ASD_Screen   31    ztf-6_tm1803
#
# [24685 rows x 11 columns]
# done step 7

# %% [markdown]
# # Setting Colour Palette - Only run the below cell ONCE
#
# The following code sets the colour palette for the whole experiment - and then designate one colour to each strain. After this, if as you are graphing you take away some strains, you can do so with the colours still matching accordingly.

# %%
# print(TotalConcatenated['dataset'].str.split("_", n=1, expand=True))

# %%
TotalConcatenated[['Gene', 'Allele']] = TotalConcatenated['dataset'].str.split('_', n=1, expand=True)
print(TotalConcatenated)
# Out:
#          time  dura   dist      prob     speed  plate      Date Plate_id  \
# 0     599.985  2.48  0.708  0.416667  0.285484      1  20190723  C0723gc
# 1     609.977  2.06  0.507  0.218750  0.246117      1  20190723  C0723gc
# 2     619.980  2.49  0.727  0.766667  0.291968      1  20190723  C0723gc
# 3     629.975  2.17  0.661  0.843750  0.304608      1  20190723  C0723gc
# 4     639.982  2.00  0.556  0.558824  0.278000      1  20190723  C0723gc
# ..        ...   ...    ...       ...       ...    ...       ...      ...
# 150   859.990  1.32  0.299  0.142857  0.226515      5  20160526  C0526eb
# 151   869.989  1.20  0.151  0.500000  0.125833      5  20160526  C0526eb
# 152   879.989  1.12  0.153  0.142857  0.136607      5  20160526  C0526eb
# 153   889.989  2.54  0.465  0.428571  0.183071      5  20160526  C0526eb
# 154  1189.984  5.52  0.814  0.333333  0.147464      5  20160526  C0526eb
#
#          Screen taps         dataset     Gene  Allele
# 0    ASD_Screen    1  C18H9.3_tm4671  C18H9.3  tm4671
# 1    ASD_Screen    2  C18H9.3_tm4671  C18H9.3  tm4671
# 2    ASD_Screen    3  C18H9.3_tm4671  C18H9.3  tm4671
# 3    ASD_Screen    4  C18H9.3_tm4671  C18H9.3  tm4671
# 4    ASD_Screen    5  C18H9.3_tm4671  C18H9.3  tm4671
# ..          ...  ...             ...      ...     ...
# 150  ASD_Screen   27    ztf-6_tm1803    ztf-6  tm1803
# 151  ASD_Screen   28    ztf-6_tm1803    ztf-6  tm1803
# 152  ASD_Screen   29    ztf-6_tm1803    ztf-6  tm1803
# 153  ASD_Screen   30    ztf-6_tm1803    ztf-6  tm1803
# 154  ASD_Screen   31    ztf-6_tm1803    ztf-6  tm1803
#
# [24685 rows x 13 columns]

# %%
TotalConcatenated['Allele']=TotalConcatenated['Allele'].fillna('N2')

# %%
TotalConcatenated.to_csv('ASD_new_tap_output.csv')

# %%
# If you want the default colour palette #
strains = TotalConcatenated['dataset'].unique()
pal = dict(zip(strains, sns.color_palette("deep", n_colors=len(strains))))
print('palette is:' + str(pal))


# pal = {'Wildtype (N2)': 'black', 
#        'cat-2 (e1112)': 'lavender', 
#        'cat-2 (n4547)': 'cornflowerblue', 
#        'cat-2 (tm2261)': 'blue', 
#        'dat-1 (ok157)': 'blueviolet', 
#        'cat-1 (ok441)': 'magenta', 
#        'pdr-1 (gk448)': 'rosybrown', 
#        'pdr-1 (tm395)': 'lightcoral', 
#        'pdr-1 (tm598)': 'indianred', 
#        'dop-1 (vs101)': 'slategray', 
#        'dop-3 (ok295)': 'darkslategray', 
#        'snb-5 (ok1434)': 'mediumseagreen', 
#        'unc-10 (ad591)': 'darkorange'}
print('palette is:' + str(pal))
# IF YOU WANT TO CUSTOMIZE THE COLOR PALETTE OF THE GRAPHS
# pal = {"N2": (0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#        "LX2060": (0.8666666666666667, 0.5176470588235295, 0.3215686274509804)
#     }

print('done setting colour palette')

# %%
# Outputs final data onto a spreadsheet
TotalConcatenated.to_csv("tap_output.csv")
print('done')

# %% [markdown]
# # 7.5: BONUS - Graph by plates to check for anomolies across each strain/treatment
#
# Here, we will be graphing each strain on their own by their individual plates - this will help us find any anomolies or outliers that we can then exclude!

# %%
Strain_pal = sns.choose_colorbrewer_palette('sequential')

# %%
StrainNames.get("Strain_1")

# %%
StrainConcatenated = TotalConcatenated[TotalConcatenated.dataset==StrainNames.get("Strain_1")] #Change/dictate which strain you are analyzing
print(StrainConcatenated)

# %%
StrainConcatenated = TotalConcatenated[
    TotalConcatenated.dataset == 'unc-10 (ad591)'] #Change/dictate which strain you are analyzing
StrainName = "unc-10 (ad591)" #Also change this, for labeling purposes


out1 = widgets.Output() #<- this is part of the code that helps display your graphs in tabs
out2 = widgets.Output()
out3 = widgets.Output()
out4 = widgets.Output()

tab = widgets.Tab(children = [out1, out2, out3, out4]) #<- more code to support tab display
tab.set_title(0, 'Probability')
tab.set_title(1, 'Distance')
tab.set_title(2, 'Duration')
tab.set_title(3, 'Speed')
display(tab)

plt.rcParams.update({'lines.markeredgewidth': 1})

# Probability
with out1:
    plt.figure(linewidth = 2.5) #<- Make your figure lines THICCCC for clean display (posters)
    plt.figure(figsize=(12,10)) #<- set your figure size (width, length)
    plt.gca().xaxis.grid(False) #<- gets rid of x-axis markers to make data look clean 
    ax = sns.pointplot(x="taps", #<- Here we use seaborn as our graphing package. 
                     y="prob",  
                     data = StrainConcatenated,
                     hue = 'plate', #<- Here we use the extra column from step 6 to separate by group
                     palette = Strain_pal, #<- Change colour palette here if you like
                     ci = 95) #<- Confidence interval. 95 = standard error
    plt.xlabel("Taps") #<- X-axis title
    plt.ylabel("Probability") #<- Y-Axis title
    plt.title(f"{StrainName} Probability of Tap Habituation, {ISI}ISI") #<- Figure Title
    plt.ylim(0,1)
    ax.legend(loc = 'upper right', fontsize = '12') #<- location of your legend
    plt.savefig(f'{StrainName}_Probability_{ISI}ISI_ByPlate.png', format='png', dpi=450) #<- saves your file to your folder at certain DPI
    plt.show()

# Distance
with out2:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                     y="dist", 
                     data = StrainConcatenated,
                     hue = 'plate',
                     palette = Strain_pal,
                     ci = 95)
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Distance", fontsize = '12')
    plt.title(f"{StrainName} Distance of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,1.5)
    ax.legend(loc = 'upper right', fontsize = '12')
    plt.savefig(f'{StrainName}_Distance_{ISI}ISI_ByPlate.png', format='png', dpi=450)
    plt.show()

# Duration
with out3:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                     y="dura", 
                     data = StrainConcatenated,
                     hue = 'plate',
                     palette = Strain_pal,
                     ci = 95)
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Duration", fontsize = '12')
    plt.title(f"{StrainName} Duration of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,3)
    ax.legend(loc = 'upper right', fontsize = '12')
    plt.savefig(f'{StrainName}_Duration_{ISI}ISI_ByPlate.png', format='png', dpi=450)
    plt.show()

# Speed
with out4:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                     y="speed", 
                     data = StrainConcatenated,
                     hue = 'plate',
                     palette = Strain_pal,
                     ci = 95)
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Speed", fontsize = '12')
    plt.title(f"{StrainName} Speed of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,0.5)
    ax.legend(loc = 'upper right', fontsize = '12')
    plt.savefig(f'{StrainName}_Speed_{ISI}ISI.png_ByPlate', format='png', dpi=450)
    plt.show()

# %% [markdown]
# # 8. Graph Data (Probability, Distance, Duration, Speed of Tap Habituation)
#
# ## Here, feel free to change the graph title and axis labels! Images are automatically saved in your folder with your data!
#
# Note: It has been agreed by the lab that distance is quite an outdated measure, and the three top measures we consider are:
#
# ## probability, duration and speed.

# %%
PD_tap=pd.read_csv('/Users/Joseph/Desktop/NewData/hab_output.csv').iloc[: , 1:]
N2=PD_tap[PD_tap.dataset=='N2']
mutant=PD_tap[PD_tap.Allele=='js125']
data=pd.concat([N2,mutant], ignore_index=True, sort=False)
data['Time']=data.time.round(-1)
# print(N2)
# print(mutant)
print(data)
data.to_csv('/Users/Joseph/Desktop/NewData/unc_output.csv')

# %%
out1 = widgets.Output() #<- this is part of the code that helps display your graphs in tabs
out2 = widgets.Output()
out3 = widgets.Output()
out4 = widgets.Output()

tab = widgets.Tab(children = [out1, out2, out3, out4]) #<- more code to support tab display
tab.set_title(0, 'Probability')
tab.set_title(1, 'Distance')
tab.set_title(2, 'Duration')
tab.set_title(3, 'Speed')
display(tab)

plt.rcParams.update({'lines.markeredgewidth': 1})
sns.set_context("poster")
# Probability
with out1:
    plt.figure(linewidth = 2.5) #<- Make your figure lines THICCCC for clean display (posters)
    plt.figure(figsize=(12,10)) #<- set your figure size (width, length)
    plt.gca().xaxis.grid(False) #<- gets rid of x-axis markers to make data look clean 
    ax = sns.lineplot(x="Time", #<- Here we use seaborn as our graphing package. 
                 y="prob",  
                 data = data,
                 hue = 'Gene', #<- Here we use the extra column from step 6 to separate by group
                 palette = 'deep',
                 linewidth=3,
                 style='Gene',
                 dashes=False,
                 markers=['o','o'],
                 markersize=12,
                 err_style='bars',
                 errorbar = 'se') #<- Confidence interval. 95 = standard error
    plt.xlabel("Time (s)") #<- X-axis title
    plt.ylabel("Probability") #<- Y-Axis title
    plt.title("Probability of Tap Habituation") #<- Figure Title
    plt.ylim(0,1)
    plt.xlim(550,None)
    plt.xticks(rotation=90)
    ax.legend(loc = 'upper right', fontsize = '20') #<- location of your legend
    plt.savefig('/Users/Joseph/Desktop/NewData/unc43prob.png', format='png', dpi=900,bbox_inches='tight') #<- saves your file to your folder at certain DPI
    plt.show()
    
# Distance
with out2:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="Time", 
                 y="dist", 
                 data = data,
                 hue = 'dataset',
                 palette = 'deep',
#                  palette = pal,
                 errorbar = 'se'
                      )
    plt.xlabel("Time (s)", fontsize = '12')
    plt.ylabel("Distance", fontsize = '12')
    plt.title("Distance of Tap Habituation", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Distance_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Duration
with out3:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="Time", 
                 y="dura", 
                 data = data,
                 hue = 'dataset',
                 palette = 'deep',
#                  palette = pal,
                 errorbar = 'se'
                      )
    plt.xlabel("Time (s)", fontsize = '12')
    plt.ylabel("Duration", fontsize = '12')
    plt.title("Duration of Tap Habituation", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Duration_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Speed
with out4:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="Time", 
                 y="speed", 
                 data = data,
                 hue = 'dataset',
                 palette = 'deep',
#                  palette = pal,
                 errorbar = 'se'
                      )
    plt.xlabel("Time (s)", fontsize = '12')
    plt.ylabel("Speed", fontsize = '12')
    plt.title("Speed of Tap Habituation", fontsize = '16')
    plt.ylim(0,None)
    plt.xticks(rotation=90)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Speed_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# %%
out1 = widgets.Output() #<- this is part of the code that helps display your graphs in tabs
out2 = widgets.Output()
out3 = widgets.Output()
out4 = widgets.Output()

tab = widgets.Tab(children = [out1, out2, out3, out4]) #<- more code to support tab display
tab.set_title(0, 'Probability')
tab.set_title(1, 'Distance')
tab.set_title(2, 'Duration')
tab.set_title(3, 'Speed')
display(tab)

plt.rcParams.update({'lines.markeredgewidth': 1})
sns.set_context("notebook")
# Probability
with out1:
    plt.figure(linewidth = 2.5) #<- Make your figure lines THICCCC for clean display (posters)
    plt.figure(figsize=(12,10)) #<- set your figure size (width, length)
    plt.gca().xaxis.grid(False) #<- gets rid of x-axis markers to make data look clean 
    ax = sns.pointplot(x="taps", #<- Here we use seaborn as our graphing package. 
                 y="prob",  
                 data = TotalConcatenated,
                 hue = 'dataset', #<- Here we use the extra column from step 6 to separate by group    
                 palette = pal, #<- Change colour palette here if you like
                 ci = 68) #<- Confidence interval. 95 = standard error
    plt.xlabel("Taps") #<- X-axis title
    plt.ylabel("Probability") #<- Y-Axis title
    plt.title(f"Probability of Tap Habituation, {ISI}ISI") #<- Figure Title
    plt.ylim(0,1)
    ax.legend(loc = 'upper right', fontsize = '12') #<- location of your legend
#     plt.savefig(f'Probability_{ISI}ISI.png', format='png', dpi=900) #<- saves your file to your folder at certain DPI
    plt.show()

# Distance
with out2:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                 y="dist", 
                 data = TotalConcatenated,
                 hue = 'dataset',
                 palette = pal,
                 ci = 68  #ci=68 for sem
                      )
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Distance", fontsize = '12')
    plt.title(f"Distance of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Distance_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Duration
with out3:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                 y="dura", 
                 data = TotalConcatenated,
                 hue = 'dataset',
                 palette = pal,
                 ci = 68  #ci=68 for sem
                      )
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Duration", fontsize = '12')
    plt.title(f"Duration of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Duration_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# Speed
with out4:
    plt.figure(linewidth = 2.5)
    plt.figure(figsize=(12,10))
    plt.gca().xaxis.grid(False)
    ax = sns.pointplot(x="taps", 
                 y="speed", 
                 data = TotalConcatenated,
                 hue = 'dataset',
                 palette = pal,
                 ci = 68 #ci=68 for sem
                      )
    plt.xlabel("Taps", fontsize = '12')
    plt.ylabel("Speed", fontsize = '12')
    plt.title(f"Speed of Tap Habituation, {ISI}ISI", fontsize = '16')
    plt.ylim(0,None)
    ax.legend(loc = 'upper right', fontsize = '12')
#     plt.savefig(f'Speed_{ISI}ISI.png', format='png', dpi=900)
    plt.show()

# %% [markdown]
# # Done!
