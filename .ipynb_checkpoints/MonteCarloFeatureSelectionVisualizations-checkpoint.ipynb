# %% [markdown]
# # Script to Plot MonteCarlo Stats

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from ipyfilechooser import FileChooser

# %%
starting_directory='/Users/Joseph/Desktop/'
chooser=FileChooser(starting_directory)
display(chooser)
# Out:
# FileChooser(path='/Users/Joseph/Desktop', filename='', title='', show_hidden=False, select_desc='Select', chan…

# %%
file_path=chooser.selected
print(file_path)
# Out:
# /Users/Joseph/Desktop/ASD_MonteCarloFeatureSelection.csv

# %%
MonteCarlo1 = pd.read_csv(file_path)
MonteCarlo1
# Out:
#       Unnamed: 0      Feature Indices  \
# 0              0  {0, 3, 6, 7, 9, 16}
# 1              1       {8, 16, 6, 15}
# 2              2    {2, 6, 8, 15, 16}
# 3              3     {0, 5, 6, 9, 16}
# 4              4       {16, 17, 6, 7}
# ...          ...                  ...
# 4995        4995    {1, 6, 8, 15, 16}
# 4996        4996    {2, 6, 9, 16, 17}
# 4997        4997   {3, 8, 11, 15, 16}
# 4998        4998           {16, 9, 6}
# 4999        4999    {2, 6, 9, 11, 16}
#
#                                           Feature Names  Accuracy
# 0     {'Curve', 'Final Response Speed', 'Instantaneo...  0.875969
# 1     {'Final Response Probability', 'Final Response...  0.891473
# 2     {'Final Response Speed', 'Final Response Proba...  0.914729
# 3     {'Curve', 'Final Response Speed', 'Width', 'Bi...  0.852713
# 4     {'Aspect Ratio', 'Habituation of Response Dura...  0.891473
# ...                                                 ...       ...
# 4995  {'Final Response Speed', 'Length', 'Final Resp...  0.883721
# 4996  {'Curve', 'Final Response Speed', 'Bias', 'Hab...  0.891473
# 4997  {'Final Response Speed', 'Instantaneous Speed'...  0.860465
# 4998          {'Curve', 'Final Response Speed', 'Bias'}  0.844961
# 4999  {'Curve', 'Final Response Speed', 'Bias', 'Ini...  0.860465
#
# [5000 rows x 4 columns]

# %%
MonteCarlo1['Feature Indices String'] = MonteCarlo1['Feature Names'].map(str)
# MonteCarlo1['Feature Names String'] = MonteCarlo1['Feature Names'].map(str)
MonteCarlo1
# Out:
#       Unnamed: 0      Feature Indices  \
# 0              0  {0, 3, 6, 7, 9, 16}
# 1              1       {8, 16, 6, 15}
# 2              2    {2, 6, 8, 15, 16}
# 3              3     {0, 5, 6, 9, 16}
# 4              4       {16, 17, 6, 7}
# ...          ...                  ...
# 4995        4995    {1, 6, 8, 15, 16}
# 4996        4996    {2, 6, 9, 16, 17}
# 4997        4997   {3, 8, 11, 15, 16}
# 4998        4998           {16, 9, 6}
# 4999        4999    {2, 6, 9, 11, 16}
#
#                                           Feature Names  Accuracy  \
# 0     {'Curve', 'Final Response Speed', 'Instantaneo...  0.875969
# 1     {'Final Response Probability', 'Final Response...  0.891473
# 2     {'Final Response Speed', 'Final Response Proba...  0.914729
# 3     {'Curve', 'Final Response Speed', 'Width', 'Bi...  0.852713
# 4     {'Aspect Ratio', 'Habituation of Response Dura...  0.891473
# ...                                                 ...       ...
# 4995  {'Final Response Speed', 'Length', 'Final Resp...  0.883721
# 4996  {'Curve', 'Final Response Speed', 'Bias', 'Hab...  0.891473
# 4997  {'Final Response Speed', 'Instantaneous Speed'...  0.860465
# 4998          {'Curve', 'Final Response Speed', 'Bias'}  0.844961
# 4999  {'Curve', 'Final Response Speed', 'Bias', 'Ini...  0.860465
#
#                                  Feature Indices String
# 0     {'Curve', 'Final Response Speed', 'Instantaneo...
# 1     {'Final Response Probability', 'Final Response...
# 2     {'Final Response Speed', 'Final Response Proba...
# 3     {'Curve', 'Final Response Speed', 'Width', 'Bi...
# 4     {'Aspect Ratio', 'Habituation of Response Dura...
# ...                                                 ...
# 4995  {'Final Response Speed', 'Length', 'Final Resp...
# 4996  {'Curve', 'Final Response Speed', 'Bias', 'Hab...
# 4997  {'Final Response Speed', 'Instantaneous Speed'...
# 4998          {'Curve', 'Final Response Speed', 'Bias'}
# 4999  {'Curve', 'Final Response Speed', 'Bias', 'Ini...
#
# [5000 rows x 5 columns]

# %%
MonteCarlo_1 = MonteCarlo1.drop(columns=['Unnamed: 0', 'Feature Indices', 'Feature Names'])
MonteCarlo_1
# Out:
#       Accuracy                             Feature Indices String
# 0     0.875969  {'Curve', 'Final Response Speed', 'Instantaneo...
# 1     0.891473  {'Final Response Probability', 'Final Response...
# 2     0.914729  {'Final Response Speed', 'Final Response Proba...
# 3     0.852713  {'Curve', 'Final Response Speed', 'Width', 'Bi...
# 4     0.891473  {'Aspect Ratio', 'Habituation of Response Dura...
# ...        ...                                                ...
# 4995  0.883721  {'Final Response Speed', 'Length', 'Final Resp...
# 4996  0.891473  {'Curve', 'Final Response Speed', 'Bias', 'Hab...
# 4997  0.860465  {'Final Response Speed', 'Instantaneous Speed'...
# 4998  0.844961          {'Curve', 'Final Response Speed', 'Bias'}
# 4999  0.860465  {'Curve', 'Final Response Speed', 'Bias', 'Ini...
#
# [5000 rows x 2 columns]

# %%
MonteCarlo = pd.read_csv(file_path)
MonteCarlo
# Out:
#       Unnamed: 0             Feature Indices  \
# 0              0       {0, 3, 9, 10, 14, 15}
# 1              1          {1, 8, 10, 14, 15}
# 2              2    {1, 3, 4, 8, 12, 14, 15}
# 3              3              {3, 12, 5, 14}
# 4              4   {2, 6, 9, 11, 14, 15, 17}
# ...          ...                         ...
# 9995        9995  {0, 6, 11, 14, 15, 16, 19}
# 9996        9996          {2, 8, 10, 12, 14}
# 9997        9997           {1, 5, 6, 12, 14}
# 9998        9998              {3, 12, 14, 7}
# 9999        9999          {0, 9, 10, 13, 14}
#
#                                           Feature Names  Accuracy
# 0     {'Width', 'Final Response Probability', 'Insta...  0.868217
# 1     {'Final Response Probability', 'Length', 'Crab...  0.875969
# 2     {'Final Response Probability', 'Instantaneous ...  0.860465
# 3     {'Angular Speed', 'Initial Response Probabilit...  0.829457
# 4     {'Bias', 'Habituation of Response Duration', '...  0.875969
# ...                                                 ...       ...
# 9995  {'Bias', 'Width', 'Habituation of Response Spe...  0.883721
# 9996  {'Area', 'Crab', 'Kink', 'Initial Response Pro...  0.868217
# 9997  {'Bias', 'Length', 'Angular Speed', 'Initial R...  0.868217
# 9998  {'Initial Response Probability', 'Final Respon...  0.829457
# 9999  {'Width', 'Final Response Duration', 'Crab', '...  0.852713
#
# [10000 rows x 4 columns]

# %%
MonteCarlo['Feature Indices String'] = MonteCarlo['Feature Names'].map(str)
# MonteCarlo['Feature Names String'] = MonteCarlo['Feature Names'].map(str)
MonteCarlo
# Out:
#       Unnamed: 0             Feature Indices  \
# 0              0       {0, 3, 9, 10, 14, 15}
# 1              1          {1, 8, 10, 14, 15}
# 2              2    {1, 3, 4, 8, 12, 14, 15}
# 3              3              {3, 12, 5, 14}
# 4              4   {2, 6, 9, 11, 14, 15, 17}
# ...          ...                         ...
# 9995        9995  {0, 6, 11, 14, 15, 16, 19}
# 9996        9996          {2, 8, 10, 12, 14}
# 9997        9997           {1, 5, 6, 12, 14}
# 9998        9998              {3, 12, 14, 7}
# 9999        9999          {0, 9, 10, 13, 14}
#
#                                           Feature Names  Accuracy  \
# 0     {'Width', 'Final Response Probability', 'Insta...  0.868217
# 1     {'Final Response Probability', 'Length', 'Crab...  0.875969
# 2     {'Final Response Probability', 'Instantaneous ...  0.860465
# 3     {'Angular Speed', 'Initial Response Probabilit...  0.829457
# 4     {'Bias', 'Habituation of Response Duration', '...  0.875969
# ...                                                 ...       ...
# 9995  {'Bias', 'Width', 'Habituation of Response Spe...  0.883721
# 9996  {'Area', 'Crab', 'Kink', 'Initial Response Pro...  0.868217
# 9997  {'Bias', 'Length', 'Angular Speed', 'Initial R...  0.868217
# 9998  {'Initial Response Probability', 'Final Respon...  0.829457
# 9999  {'Width', 'Final Response Duration', 'Crab', '...  0.852713
#
#                                  Feature Indices String
# 0     {'Width', 'Final Response Probability', 'Insta...
# 1     {'Final Response Probability', 'Length', 'Crab...
# 2     {'Final Response Probability', 'Instantaneous ...
# 3     {'Angular Speed', 'Initial Response Probabilit...
# 4     {'Bias', 'Habituation of Response Duration', '...
# ...                                                 ...
# 9995  {'Bias', 'Width', 'Habituation of Response Spe...
# 9996  {'Area', 'Crab', 'Kink', 'Initial Response Pro...
# 9997  {'Bias', 'Length', 'Angular Speed', 'Initial R...
# 9998  {'Initial Response Probability', 'Final Respon...
# 9999  {'Width', 'Final Response Duration', 'Crab', '...
#
# [10000 rows x 5 columns]

# %%
MonteCarlo_0 = MonteCarlo.drop(columns=['Unnamed: 0', 'Feature Names'])
MonteCarlo_0
# Out:
#                  Feature Indices  Accuracy  \
# 0          {0, 3, 9, 10, 14, 15}  0.868217
# 1             {1, 8, 10, 14, 15}  0.875969
# 2       {1, 3, 4, 8, 12, 14, 15}  0.860465
# 3                 {3, 12, 5, 14}  0.829457
# 4      {2, 6, 9, 11, 14, 15, 17}  0.875969
# ...                          ...       ...
# 9995  {0, 6, 11, 14, 15, 16, 19}  0.883721
# 9996          {2, 8, 10, 12, 14}  0.868217
# 9997           {1, 5, 6, 12, 14}  0.868217
# 9998              {3, 12, 14, 7}  0.829457
# 9999          {0, 9, 10, 13, 14}  0.852713
#
#                                  Feature Indices String
# 0     {'Width', 'Final Response Probability', 'Insta...
# 1     {'Final Response Probability', 'Length', 'Crab...
# 2     {'Final Response Probability', 'Instantaneous ...
# 3     {'Angular Speed', 'Initial Response Probabilit...
# 4     {'Bias', 'Habituation of Response Duration', '...
# ...                                                 ...
# 9995  {'Bias', 'Width', 'Habituation of Response Spe...
# 9996  {'Area', 'Crab', 'Kink', 'Initial Response Pro...
# 9997  {'Bias', 'Length', 'Angular Speed', 'Initial R...
# 9998  {'Initial Response Probability', 'Final Respon...
# 9999  {'Width', 'Final Response Duration', 'Crab', '...
#
# [10000 rows x 3 columns]

# %%
MonteCarloPD = pd.concat([MonteCarlo_0, MonteCarlo_1], ignore_index=True)
MonteCarloPD
# Out:
#       Accuracy                             Feature Indices String
# 0     0.813953                          {'Angular Speed', 'Bias'}
# 1     0.813953                          {'Angular Speed', 'Bias'}
# 2     0.813953                          {'Angular Speed', 'Bias'}
# 3     0.813953                          {'Angular Speed', 'Bias'}
# 4     0.813953                          {'Angular Speed', 'Bias'}
# ...        ...                                                ...
# 9995  0.883721  {'Final Response Speed', 'Length', 'Final Resp...
# 9996  0.891473  {'Curve', 'Final Response Speed', 'Bias', 'Hab...
# 9997  0.860465  {'Final Response Speed', 'Instantaneous Speed'...
# 9998  0.844961          {'Curve', 'Final Response Speed', 'Bias'}
# 9999  0.860465  {'Curve', 'Final Response Speed', 'Bias', 'Ini...
#
# [10000 rows x 2 columns]

# %%
MonteCarlo_0.to_csv('/Users/Joseph/Desktop/ASD_MonteCarloFeatureSelection_10000.csv')

# %%
ValueCounts = MonteCarlo_0['Feature Indices String'].value_counts()
ValueCounts
# Out:
# Feature Indices String
# {'Final Response Probability', 'Length', 'Crab', 'Kink', 'Final Response Duration'}                                                                                 102
# {'Angular Speed', 'Final Response Duration', 'Final Response Probability', 'Instantaneous Speed'}                                                                    88
# {'Final Response Duration', 'Final Response Probability', 'Kink', 'Length'}                                                                                          77
# {'Final Response Duration', 'Crab', 'Aspect Ratio', 'Length'}                                                                                                        76
# {'Bias', 'Curve', 'Final Response Duration', 'Length'}                                                                                                               69
#                                                                                                                                                                    ...
# {'Area', 'Aspect Ratio', 'Initial Response Duration', 'Length', 'Crab', 'Final Response Duration', 'Interval Speed'}                                                  1
# {'Width', 'Length', 'Angular Speed', 'Initial Response Probability', 'Final Response Duration', 'Interval Speed'}                                                     1
# {'Bias', 'Final Response Probability', 'Aspect Ratio', 'Final Response Duration', 'Habituation of Respones Probability'}                                              1
# {'Width', 'Aspect Ratio', 'Final Response Duration', 'Length', 'Crab', 'Angular Speed', 'Curve'}                                                                      1
# {'Bias', 'Width', 'Habituation of Response Speed', 'Final Response Probability', 'Final Response Speed', 'Initial Response Duration', 'Final Response Duration'}      1
# Name: count, Length: 3670, dtype: int64

# %%
FilteredValueCounts = ValueCounts[ValueCounts >= 50]
FilteredValueCounts
# Out:
# Feature Indices String
# {'Final Response Probability', 'Length', 'Crab', 'Kink', 'Final Response Duration'}                                                  102
# {'Angular Speed', 'Final Response Duration', 'Final Response Probability', 'Instantaneous Speed'}                                     88
# {'Final Response Duration', 'Final Response Probability', 'Kink', 'Length'}                                                           77
# {'Final Response Duration', 'Crab', 'Aspect Ratio', 'Length'}                                                                         76
# {'Bias', 'Curve', 'Final Response Duration', 'Length'}                                                                                69
# {'Bias', 'Habituation of Response Duration', 'Initial Response Duration'}                                                             67
# {'Bias', 'Final Response Probability', 'Length', 'Initial Response Probability', 'Final Response Duration'}                           65
# {'Final Response Duration', 'Crab', 'Aspect Ratio', 'Area'}                                                                           60
# {'Initial Response Probability', 'Habituation of Response Duration', 'Instantaneous Speed'}                                           56
# {'Width', 'Final Response Duration', 'Crab', 'Aspect Ratio'}                                                                          55
# {'Bias', 'Final Response Duration', 'Length', 'Crab', 'Curve'}                                                                        53
# {'Final Response Duration', 'Crab', 'Kink', 'Length'}                                                                                 53
# {'Final Response Probability', 'Instantaneous Speed', 'Angular Speed', 'Initial Response Probability', 'Final Response Duration'}     50
# {'Width', 'Final Response Duration', 'Length', 'Crab', 'Curve'}                                                                       50
# Name: count, dtype: int64

# %%
print(list(FilteredValueCounts.index))
print(FilteredValueCounts.sum())
# Out:
# ["{'Final Response Probability', 'Length', 'Crab', 'Kink', 'Final Response Duration'}", "{'Angular Speed', 'Final Response Duration', 'Final Response Probability', 'Instantaneous Speed'}", "{'Final Response Duration', 'Final Response Probability', 'Kink', 'Length'}", "{'Final Response Duration', 'Crab', 'Aspect Ratio', 'Length'}", "{'Bias', 'Curve', 'Final Response Duration', 'Length'}", "{'Bias', 'Habituation of Response Duration', 'Initial Response Duration'}", "{'Bias', 'Final Response Probability', 'Length', 'Initial Response Probability', 'Final Response Duration'}", "{'Final Response Duration', 'Crab', 'Aspect Ratio', 'Area'}", "{'Initial Response Probability', 'Habituation of Response Duration', 'Instantaneous Speed'}", "{'Width', 'Final Response Duration', 'Crab', 'Aspect Ratio'}", "{'Bias', 'Final Response Duration', 'Length', 'Crab', 'Curve'}", "{'Final Response Duration', 'Crab', 'Kink', 'Length'}", "{'Final Response Probability', 'Instantaneous Speed', 'Angular Speed', 'Initial Response Probability', 'Final Response Duration'}", "{'Width', 'Final Response Duration', 'Length', 'Crab', 'Curve'}"]
# 921

# %%
Filtered_MonteCarlo = MonteCarlo_0[MonteCarlo_0["Feature Indices String"].isin(list(FilteredValueCounts.index))]
Filtered_MonteCarlo
# Out:
#          Feature Indices  Accuracy  \
# 1     {1, 8, 10, 14, 15}  0.875969
# 5         {3, 5, 14, 15}  0.883721
# 6         {8, 1, 14, 15}  0.875969
# 19           {17, 11, 6}  0.837209
# 34        {8, 1, 10, 14}  0.868217
# ...                  ...       ...
# 9886      {2, 10, 14, 7}  0.868217
# 9898  {1, 8, 10, 14, 15}  0.899225
# 9928         {17, 11, 6}  0.844961
# 9940   {1, 6, 9, 10, 14}  0.883721
# 9954      {1, 10, 14, 7}  0.906977
#
#                                  Feature Indices String
# 1     {'Final Response Probability', 'Length', 'Crab...
# 5     {'Angular Speed', 'Final Response Duration', '...
# 6     {'Final Response Duration', 'Final Response Pr...
# 19    {'Bias', 'Habituation of Response Duration', '...
# 34    {'Final Response Duration', 'Crab', 'Kink', 'L...
# ...                                                 ...
# 9886  {'Final Response Duration', 'Crab', 'Aspect Ra...
# 9898  {'Final Response Probability', 'Length', 'Crab...
# 9928  {'Bias', 'Habituation of Response Duration', '...
# 9940  {'Bias', 'Final Response Duration', 'Length', ...
# 9954  {'Final Response Duration', 'Crab', 'Aspect Ra...
#
# [921 rows x 3 columns]

# %%
my_order = Filtered_MonteCarlo.groupby(by=["Feature Indices String"])["Accuracy"].mean().sort_values().index
my_order
# Out:
# Index(['{'Initial Response Probability', 'Habituation of Response Duration', 'Instantaneous Speed'}',
#        '{'Bias', 'Habituation of Response Duration', 'Initial Response Duration'}',
#        '{'Bias', 'Curve', 'Final Response Duration', 'Length'}',
#        '{'Final Response Probability', 'Instantaneous Speed', 'Angular Speed', 'Initial Response Probability', 'Final Response Duration'}',
#        '{'Final Response Duration', 'Crab', 'Kink', 'Length'}',
#        '{'Bias', 'Final Response Duration', 'Length', 'Crab', 'Curve'}',
#        '{'Angular Speed', 'Final Response Duration', 'Final Response Probability', 'Instantaneous Speed'}',
#        '{'Final Response Duration', 'Final Response Probability', 'Kink', 'Length'}',
#        '{'Bias', 'Final Response Probability', 'Length', 'Initial Response Probability', 'Final Response Duration'}',
#        '{'Width', 'Final Response Duration', 'Crab', 'Aspect Ratio'}',
#        '{'Final Response Duration', 'Crab', 'Aspect Ratio', 'Area'}',
#        '{'Final Response Duration', 'Crab', 'Aspect Ratio', 'Length'}',
#        '{'Final Response Probability', 'Length', 'Crab', 'Kink', 'Final Response Duration'}',
#        '{'Width', 'Final Response Duration', 'Length', 'Crab', 'Curve'}'],
#       dtype='object', name='Feature Indices String')

# %%
fig, axs = plt.subplots(figsize=(20, 5))
# Box Plot Of MonteCarlo Simulations
sns.violinplot(
    Filtered_MonteCarlo, x="Feature Indices String", y="Accuracy", hue="Feature Indices String",
    # whis=[0, 100], 
    width=.6, palette=sns.color_palette("husl", 20), inner="quart", density_norm="count", order=my_order
)

# Add in points to show each observation
sns.stripplot(Filtered_MonteCarlo, x="Feature Indices String", y="Accuracy", size=5, color=".3", order=my_order)

# Tweak the visual presentation
# ax.xaxis.grid(True)

# plt.title("lalala")
axs.set_title("Accuracy Score of 10000 Feature Selection Simulations, With Features Sets Selected At Least 50 Times Or More")
axs.set_xlabel("Selected Features")
axs.set_ylabel("Accuracy")
# plt.title = "Accuracy Score of 5000 Feature Selection Simulations, With Features Selected At Least 50 Times Or More"
# plt.xlabel = "Selected Features"
# plt.ylabel = "Accuracy"
plt.xticks(rotation=90)
# plt.set(ylabel="Accuracy", xlabel="Selected Features")
# sns.despine(trim=True, left=True)
plt.savefig('/Users/Joseph/Desktop/ASD_MonteCarloFeatureSelections_10000.png', bbox_inches='tight')
plt.show()
# plt.savefig('/Users/Joseph/Desktop/PD_MonteCarloFeatureSelections.png', bbox_inches='tight')
# Out:
# /var/folders/31/jpj6mpsx60d9829cymplqfsh0000gn/T/ipykernel_65260/1841099387.py:3: UserWarning: The palette list has more values (20) than needed (14), which may not be intended.
#   sns.violinplot(
